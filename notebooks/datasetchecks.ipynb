# %%
from inductive_query.res_proc_helper import *
import importlib
import inductive_query.utils as ih
importlib.reload(ih)
CompletelyUnseenQueryExtractor = ih.CompletelyUnseenQueryExtractor

path = '/data/DBpedia_3_Full_weight_loss'
split_path = f"{path}/test_sampled.tsv"
c = CompletelyUnseenQueryExtractor(path)
q_files = c.run()
print(len(q_files))
# Out:
# 221

# %%
from inductive_query.res_proc_helper import *
import importlib
import inductive_query.utils as ih
importlib.reload(ih)
CompletelyUnseenQueryExtractor = ih.CompletelyUnseenQueryExtractor
path = '/data/Wikidata_3_Full_weight_loss'
split_path = f"{path}/test_sampled.tsv"
c1 = CompletelyUnseenQueryExtractor(path)
q1_files = c1.run()
print(len(q1_files))
# Out:
# 927

# %%
import pandas as pd
import os
from pathlib import Path
df = pd.read_csv(split_path, sep='\t')
df['id'] = df['id'].apply(lambda x: x[20:])
#print(df)
files = [Path(x).name for x in q1_files]
com_df = df[df['id'].isin(files)]
com_df['time_cls'] = com_df['mean_latency'].apply(lambda x : 0 if x<1 else 1 if x < 10 else 2)
com_df
# Out:
# /tmp/ipykernel_61301/4168740043.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   com_df['time_cls'] = com_df['mean_latency'].apply(lambda x : 0 if x<1 else 1 if x < 10 else 2)
#                                                      id  \
# 1     lsqQuery-HfyjChluX9OPM5vL5SV2f8HATP7rzn_KrO_52...
# 5     lsqQuery-VlUThm6Kms5S-Fi0BaON_nqVPUxG6-iuFnvC4...
# 17    lsqQuery-G7un_AbhICUHQ9kOrCkjmDplCBOQnLSA61tqN...
# 23    lsqQuery-n9e-wTB2gzzLPP8LNn-fT_VwJPhKs3s7R1WEh...
# 24    lsqQuery-Jy6U838Om2nMLwGeps6UqkcZ_OV_tzTvRSepQ...
# ...                                                 ...
# 8788  lsqQuery-KzdgjmT3u9qwvxYpXb3HbPNodx2phGfhauou4...
# 8799  lsqQuery-Xfzv0jCeOpaxmKlpFAEDwpY1RmcHEgCh9Vrek...
# 8804  lsqQuery-g16vJAs48iRwdNeztb7A2Zx8TDuVrpf3nqoWP...
# 8805  lsqQuery-JZeN4OO6KheHb-AXaqoIsf8VSBPT7CoKiEKfh...
# 9276  lsqQuery-YY65yFqCHImG3jTaluofOUisapRHVOCICLYAz...
#
#                                             queryString  \
# 1     PREFIX wde: <http://www.wikidata.org/entity/> ...
# 5     PREFIX wde: <http://www.wikidata.org/entity/> ...
# 17    PREFIX wde: <http://www.wikidata.org/entity/> ...
# 23    PREFIX xsd: <http://www.w3.org/2001/XMLSchema#...
# 24    PREFIX wde: <http://www.wikidata.org/entity/> ...
# ...                                                 ...
# 8788  PREFIX xsd: <http://www.w3.org/2001/XMLSchema#...
# 8799  PREFIX wde: <http://www.wikidata.org/entity/> ...
# 8804  PREFIX wde: <http://www.wikidata.org/entity/> ...
# 8805  PREFIX wde: <http://www.wikidata.org/entity/> ...
# 9276  PREFIX wdt: <http://www.wikidata.org/prop/dire...
#
#                                          query_string_0  latency_0  \
# 1     PREFIX wde: <http://www.wikidata.org/entity/> ...   0.020312
# 5     PREFIX wde: <http://www.wikidata.org/entity/> ...   0.000357
# 17    PREFIX wde: <http://www.wikidata.org/entity/> ...   0.003606
# 23    PREFIX xsd: <http://www.w3.org/2001/XMLSchema#...   0.000324
# 24    PREFIX wde: <http://www.wikidata.org/entity/> ...   0.007520
# ...                                                 ...        ...
# 8788  PREFIX xsd: <http://www.w3.org/2001/XMLSchema#...   0.000336
# 8799  PREFIX wde: <http://www.wikidata.org/entity/> ...   0.003479
# 8804  PREFIX wde: <http://www.wikidata.org/entity/> ...   0.000327
# 8805  PREFIX wde: <http://www.wikidata.org/entity/> ...   0.017120
# 9276  PREFIX wdt: <http://www.wikidata.org/prop/dire...   0.000377
#
#       resultset_0                                     query_string_1  \
# 1             NaN  PREFIX wde: <http://www.wikidata.org/entity/> ...
# 5             NaN  PREFIX wde: <http://www.wikidata.org/entity/> ...
# 17            NaN  PREFIX wde: <http://www.wikidata.org/entity/> ...
# 23            NaN  PREFIX xsd: <http://www.w3.org/2001/XMLSchema#...
# 24            NaN  PREFIX wde: <http://www.wikidata.org/entity/> ...
# ...           ...                                                ...
# 8788          NaN  PREFIX xsd: <http://www.w3.org/2001/XMLSchema#...
# 8799          NaN  PREFIX wde: <http://www.wikidata.org/entity/> ...
# 8804          NaN  PREFIX wde: <http://www.wikidata.org/entity/> ...
# 8805          NaN  PREFIX wde: <http://www.wikidata.org/entity/> ...
# 9276          NaN  PREFIX wdt: <http://www.wikidata.org/prop/dire...
#
#       latency_1  resultset_1  \
# 1      0.018399          NaN
# 5      0.000357          NaN
# 17     0.002761          NaN
# 23     0.000324          NaN
# 24     0.007665          NaN
# ...         ...          ...
# 8788   0.000340          NaN
# 8799   0.003227          NaN
# 8804   0.000329          NaN
# 8805   0.005643          NaN
# 9276   0.000368          NaN
#
#                                          query_string_2  latency_2  ...  \
# 1     PREFIX wde: <http://www.wikidata.org/entity/> ...   0.018752  ...
# 5     PREFIX wde: <http://www.wikidata.org/entity/> ...   0.000352  ...
# 17    PREFIX wde: <http://www.wikidata.org/entity/> ...   0.003107  ...
# 23    PREFIX xsd: <http://www.w3.org/2001/XMLSchema#...   0.000317  ...
# 24    PREFIX wde: <http://www.wikidata.org/entity/> ...   0.007117  ...
# ...                                                 ...        ...  ...
# 8788  PREFIX xsd: <http://www.w3.org/2001/XMLSchema#...   0.000335  ...
# 8799  PREFIX wde: <http://www.wikidata.org/entity/> ...   0.002885  ...
# 8804  PREFIX wde: <http://www.wikidata.org/entity/> ...   0.000322  ...
# 8805  PREFIX wde: <http://www.wikidata.org/entity/> ...   0.004881  ...
# 9276  PREFIX wdt: <http://www.wikidata.org/prop/dire...   0.000368  ...
#
#       ComplexPath  MoreThanOnePredicate  \
# 1               0                     0
# 5               0                     0
# 17              0                     0
# 23              0                     0
# 24              0                     0
# ...           ...                   ...
# 8788            0                     0
# 8799            0                     0
# 8804            0                     0
# 8805            0                     0
# 9276            0                     0
#
#                                                 queryID  Queries with 1 TP  \
# 1     http://lsq.aksw.org/lsqQuery-HfyjChluX9OPM5vL5...                  1
# 5     http://lsq.aksw.org/lsqQuery-VlUThm6Kms5S-Fi0B...                  0
# 17    http://lsq.aksw.org/lsqQuery-G7un_AbhICUHQ9kOr...                  1
# 23    http://lsq.aksw.org/lsqQuery-n9e-wTB2gzzLPP8LN...                  1
# 24    http://lsq.aksw.org/lsqQuery-Jy6U838Om2nMLwGep...                  1
# ...                                                 ...                ...
# 8788  http://lsq.aksw.org/lsqQuery-KzdgjmT3u9qwvxYpX...                  1
# 8799  http://lsq.aksw.org/lsqQuery-Xfzv0jCeOpaxmKlpF...                  1
# 8804  http://lsq.aksw.org/lsqQuery-g16vJAs48iRwdNezt...                  1
# 8805  http://lsq.aksw.org/lsqQuery-JZeN4OO6KheHb-AXa...                  1
# 9276  http://lsq.aksw.org/lsqQuery-YY65yFqCHImG3jTal...                  1
#
#       Queries with 2 TP  Queries with more TP  S-P Concrete  P-O Concrete  \
# 1                     0                     0             0             0
# 5                     1                     0             0             0
# 17                    0                     0             0             0
# 23                    0                     0             0             0
# 24                    0                     0             0             0
# ...                 ...                   ...           ...           ...
# 8788                  0                     0             0             0
# 8799                  0                     0             0             0
# 8804                  0                     0             0             0
# 8805                  0                     0             0             0
# 9276                  0                     0             0             0
#
#       S-O Concrete  time_cls
# 1                0         0
# 5                0         0
# 17               0         0
# 23               0         0
# 24               0         0
# ...            ...       ...
# 8788             0         0
# 8799             0         0
# 8804             0         0
# 8805             0         0
# 9276             0         0
#
# [927 rows x 43 columns]
