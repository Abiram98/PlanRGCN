# %% [markdown]
# file paths

# %%
train_file = '/work/data/splits/splits_0.05/train.json'
val_file = '/work/data/splits/splits_0.05/val.json'
test_file = '/work/data/splits/splits_0.05/test.json'
import os

path_to_save = '/work/data/models2_6'
os.system(f'mkdir -p {path_to_save}')
path_to_res = '/work/data/results/2_6_2023_tp_graph_5re.txt'

# %% [markdown]
# import

# %%
# %load_ext autoreload
# %autoreload 2
import json
import dgl
from sklearn.metrics import f1_score
import torch as th
import dgl.nn.pytorch as dglnn
import torch.nn as nn
from dgl.dataloading import GraphDataLoader
import torch.nn.functional as F
import networkx as nx
import warnings
from feature_extraction.base_featurizer import BaseFeaturizer
import torch
from graph_construction.tps_graph import create_dummy_dgl_graph, tps_graph
import numpy as np

from dgl_classifier.trainer import GraphDataset,snap_pred, tps_to_dgl, get_clasification_vec,\
tps_graph_const, extract_data, runner


import warnings

from preprocessing.utils import load_BGPS_from_json
warnings.filterwarnings('ignore', category=UserWarning, message='TypedStorage is deprecated')

# %%
#seed
dgl.seed(1223)

# %% [markdown]
# Model

# %%
class Classifier(nn.Module):
    def __init__(self, in_dim, hidden_dim, n_classes):
        super(Classifier, self).__init__()
        self.conv1 = dglnn.RelGraphConv(in_dim, hidden_dim, 8)
        #self.conv1 = dglnn.GraphConv(in_dim, hidden_ˇdim)
        self.conv2 = dglnn.RelGraphConv(hidden_dim, hidden_dim, 8)
        #self.conv2 = dglnn.GraphConv(hidden_dim, hidden_dim)
        self.classify = nn.Linear(hidden_dim, n_classes)

    def forward(self, g, h, rel_types):
        # Apply graph convolution and activation.
        h = F.relu(self.conv1(g, h, rel_types))
        h = F.relu(self.conv2(g, h, rel_types))
        with g.local_scope():
            g.ndata['node_features'] = h
            # Calculate graph representation by average readout.
            hg = dgl.mean_nodes(g, 'node_features')
            return F.softmax( self.classify(hg), dim=1)
model = Classifier(113, 20, 2)

# %% [markdown]
# hyperparameters

# %%
early_stop =100
model = Classifier(113, 32, 2)
lr = 0.01
wd = 5e-4
epochs = 100

# %%
train_dataloader, val_dataloader, test_dataloader = extract_data(train_file, val_file, test_file, community_no=30, batch_size = 50, verbose=True)
# Out:
# /usr/local/lib/python3.10/dist-packages/dgl/backend/pytorch/tensor.py:52: UserWarning: Creating a tensor from a list of numpy.ndarrays is extremely slow. Please consider converting the list to a single numpy.ndarray with numpy.array() before converting to a tensor. (Triggered internally at ../torch/csrc/utils/tensor_new.cpp:245.)
#   return th.as_tensor(data, dtype=dtype)
# # of catesian products: 36
# # of catesian products: 10
# # of catesian products: 13
# # of predicate feats not in validation 47
# # of predicate feats not in test 7
# Training dataset size 250
# Validation dataset size 86
# Test dataset size 83

# %%
best_model_path = runner(train_dataloader,val_dataloader,test_dataloader,model, early_stop, lr, wd, epochs, path_to_res, path_to_save=path_to_save)
# Out:
# Epoch 1
# --------------------------------------------------------------
# Epoch:    1        1 Batch loss: 0.674869 Batch F1: 0.0
# Epoch:    1        2 Batch loss: 0.729311 Batch F1: 0.0
# Epoch:    1        3 Batch loss: 0.692163 Batch F1: 0.0
# Epoch:    1        4 Batch loss: 0.641009 Batch F1: 0.0
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Epoch:    1        5 Batch loss: 0.668636 Batch F1: 0.0
# Train Avg Loss    1: 0.681198
#
# Train Avg F1    1: 0.0
#
# Val Avg Loss    1: 0.299139
#
# Val Avg F1    1:  0.08333333333333333
#
# Optimal Val loss (Epoch 1): 0.299139142036438
#
# Epoch 2
# --------------------------------------------------------------
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Epoch:    2        1 Batch loss: 0.604070 Batch F1: 0.0
# Epoch:    2        2 Batch loss: 0.702145 Batch F1: 0.07692307692307693
# Epoch:    2        3 Batch loss: 0.689868 Batch F1: 0.08333333333333333
# Epoch:    2        4 Batch loss: 0.608127 Batch F1: 0.1904761904761905
# Epoch:    2        5 Batch loss: 0.615573 Batch F1: 0.6285714285714286
# Train Avg Loss    2: 0.643957
#
# Train Avg F1    2: 0.19586080586080584
#
# Val Avg Loss    2: 0.263704
#
# Val Avg F1    2:  0.545054945054945
#
# Optimal Val loss (Epoch 2): 0.26370376348495483
#
# Epoch 3
# --------------------------------------------------------------
# Epoch:    3        1 Batch loss: 0.597757 Batch F1: 0.7
# Epoch:    3        2 Batch loss: 0.624141 Batch F1: 0.6153846153846154
# Epoch:    3        3 Batch loss: 0.602391 Batch F1: 0.6666666666666666
# Epoch:    3        4 Batch loss: 0.678484 Batch F1: 0.42424242424242425
# Epoch:    3        5 Batch loss: 0.574297 Batch F1: 0.5333333333333333
# Train Avg Loss    3: 0.615414
#
# Train Avg F1    3: 0.5879254079254079
#
# Val Avg Loss    3: 0.282587
#
# Val Avg F1    3:  0.49267399267399264
#
# Optimal Val loss (Epoch 2): 0.26370376348495483
#
# Epoch 4
# --------------------------------------------------------------
# Epoch:    4        1 Batch loss: 0.589617 Batch F1: 0.631578947368421
# Epoch:    4        2 Batch loss: 0.615749 Batch F1: 0.6818181818181819
# Epoch:    4        3 Batch loss: 0.537493 Batch F1: 0.6428571428571429
# Epoch:    4        4 Batch loss: 0.573337 Batch F1: 0.7083333333333333
# Epoch:    4        5 Batch loss: 0.648273 Batch F1: 0.33333333333333337
# Train Avg Loss    4: 0.592894
#
# Train Avg F1    4: 0.5995841877420826
#
# Val Avg Loss    4: 0.266573
#
# Val Avg F1    4:  0.6046195652173914
#
# Optimal Val loss (Epoch 2): 0.26370376348495483
#
# Epoch 5
# --------------------------------------------------------------
# Epoch:    5        1 Batch loss: 0.554902 Batch F1: 0.7555555555555556
# Epoch:    5        2 Batch loss: 0.530834 Batch F1: 0.56
# Epoch:    5        3 Batch loss: 0.671142 Batch F1: 0.4
# Epoch:    5        4 Batch loss: 0.489343 Batch F1: 0.7272727272727273
# Epoch:    5        5 Batch loss: 0.608909 Batch F1: 0.5294117647058824
# Train Avg Loss    5: 0.571026
#
# Train Avg F1    5: 0.5944480095068331
#
# Val Avg Loss    5: 0.294651
#
# Val Avg F1    5:  0.481896551724138
#
# Optimal Val loss (Epoch 2): 0.26370376348495483
#
# Epoch 6
# --------------------------------------------------------------
# Epoch:    6        1 Batch loss: 0.478876 Batch F1: 0.7096774193548387
# Epoch:    6        2 Batch loss: 0.621407 Batch F1: 0.5405405405405406
# Epoch:    6        3 Batch loss: 0.531902 Batch F1: 0.7179487179487181
# Epoch:    6        4 Batch loss: 0.612859 Batch F1: 0.6190476190476191
# Epoch:    6        5 Batch loss: 0.595425 Batch F1: 0.6938775510204083
# Train Avg Loss    6: 0.568094
#
# Train Avg F1    6: 0.6562183695824249
#
# Val Avg Loss    6: 0.249753
#
# Val Avg F1    6:  0.7408435072142064
#
# Optimal Val loss (Epoch 6): 0.24975322932004929
#
# Epoch 7
# --------------------------------------------------------------
# Epoch:    7        1 Batch loss: 0.549123 Batch F1: 0.6666666666666667
# Epoch:    7        2 Batch loss: 0.490006 Batch F1: 0.7878787878787877
# Epoch:    7        3 Batch loss: 0.511390 Batch F1: 0.5833333333333334
# Epoch:    7        4 Batch loss: 0.635275 Batch F1: 0.5
# Epoch:    7        5 Batch loss: 0.695186 Batch F1: 0.303030303030303
# Train Avg Loss    7: 0.576196
#
# Train Avg F1    7: 0.5681818181818181
#
# Val Avg Loss    7: 0.305736
#
# Val Avg F1    7:  0.4523326572008114
#
# Optimal Val loss (Epoch 6): 0.24975322932004929
#
# Epoch 8
# --------------------------------------------------------------
# Epoch:    8        1 Batch loss: 0.557000 Batch F1: 0.6111111111111112
# Epoch:    8        2 Batch loss: 0.534692 Batch F1: 0.5517241379310344
# Epoch:    8        3 Batch loss: 0.607389 Batch F1: 0.7083333333333334
# Epoch:    8        4 Batch loss: 0.560929 Batch F1: 0.76
# Epoch:    8        5 Batch loss: 0.489581 Batch F1: 0.7906976744186046
# Train Avg Loss    8: 0.549918
#
# Train Avg F1    8: 0.6843732513588168
#
# Val Avg Loss    8: 0.257772
#
# Val Avg F1    8:  0.6614227086183311
#
# Optimal Val loss (Epoch 6): 0.24975322932004929
#
# Epoch 9
# --------------------------------------------------------------
# Epoch:    9        1 Batch loss: 0.566051 Batch F1: 0.7
# Epoch:    9        2 Batch loss: 0.582888 Batch F1: 0.4
# Epoch:    9        3 Batch loss: 0.492979 Batch F1: 0.7777777777777778
# Epoch:    9        4 Batch loss: 0.510324 Batch F1: 0.7058823529411764
# Epoch:    9        5 Batch loss: 0.534423 Batch F1: 0.5384615384615385
# Train Avg Loss    9: 0.537333
#
# Train Avg F1    9: 0.6244243338360984
#
# Val Avg Loss    9: 0.272129
#
# Val Avg F1    9:  0.6594202898550725
#
# Optimal Val loss (Epoch 6): 0.24975322932004929
#
# Epoch 10
# --------------------------------------------------------------
# Epoch:   10        1 Batch loss: 0.534328 Batch F1: 0.7499999999999999
# Epoch:   10        2 Batch loss: 0.497341 Batch F1: 0.7999999999999999
# Epoch:   10        3 Batch loss: 0.495341 Batch F1: 0.8181818181818182
# Epoch:   10        4 Batch loss: 0.552500 Batch F1: 0.5555555555555556
# Epoch:   10        5 Batch loss: 0.526616 Batch F1: 0.56
# Train Avg Loss   10: 0.521225
#
# Train Avg F1   10: 0.6967474747474747
#
# Val Avg Loss   10: 0.259437
#
# Val Avg F1   10:  0.6619318181818181
#
# Optimal Val loss (Epoch 6): 0.24975322932004929
#
# Epoch 11
# --------------------------------------------------------------
# Epoch:   11        1 Batch loss: 0.529211 Batch F1: 0.7555555555555556
# Epoch:   11        2 Batch loss: 0.549067 Batch F1: 0.6486486486486486
# Epoch:   11        3 Batch loss: 0.446514 Batch F1: 0.75
# Epoch:   11        4 Batch loss: 0.497611 Batch F1: 0.7906976744186047
# Epoch:   11        5 Batch loss: 0.562197 Batch F1: 0.65
# Train Avg Loss   11: 0.516920
#
# Train Avg F1   11: 0.7189803757245617
#
# Val Avg Loss   11: 0.247039
#
# Val Avg F1   11:  0.655266757865937
#
# Optimal Val loss (Epoch 11): 0.24703935533761978
#
# Epoch 12
# --------------------------------------------------------------
# Epoch:   12        1 Batch loss: 0.466086 Batch F1: 0.8571428571428572
# Epoch:   12        2 Batch loss: 0.495830 Batch F1: 0.7096774193548387
# Epoch:   12        3 Batch loss: 0.521087 Batch F1: 0.75
# Epoch:   12        4 Batch loss: 0.568006 Batch F1: 0.6111111111111112
# Epoch:   12        5 Batch loss: 0.509125 Batch F1: 0.7428571428571429
# Train Avg Loss   12: 0.512027
#
# Train Avg F1   12: 0.73415770609319
#
# Val Avg Loss   12: 0.248938
#
# Val Avg F1   12:  0.6760869565217391
#
# Optimal Val loss (Epoch 11): 0.24703935533761978
#
# Epoch 13
# --------------------------------------------------------------
# Epoch:   13        1 Batch loss: 0.466616 Batch F1: 0.8
# Epoch:   13        2 Batch loss: 0.510400 Batch F1: 0.7222222222222222
# Epoch:   13        3 Batch loss: 0.556424 Batch F1: 0.7179487179487181
# Epoch:   13        4 Batch loss: 0.489646 Batch F1: 0.7894736842105262
# Epoch:   13        5 Batch loss: 0.492562 Batch F1: 0.7272727272727274
# Train Avg Loss   13: 0.503130
#
# Train Avg F1   13: 0.7513834703308387
#
# Val Avg Loss   13: 0.297028
#
# Val Avg F1   13:  0.640282131661442
#
# Optimal Val loss (Epoch 11): 0.24703935533761978
#
# Epoch 14
# --------------------------------------------------------------
# Epoch:   14        1 Batch loss: 0.449860 Batch F1: 0.7741935483870968
# Epoch:   14        2 Batch loss: 0.547367 Batch F1: 0.38095238095238093
# Epoch:   14        3 Batch loss: 0.576649 Batch F1: 0.5454545454545454
# Epoch:   14        4 Batch loss: 0.512481 Batch F1: 0.7368421052631577
# Epoch:   14        5 Batch loss: 0.536121 Batch F1: 0.75
# Train Avg Loss   14: 0.524496
#
# Train Avg F1   14: 0.6374885160114362
#
# Val Avg Loss   14: 0.298978
#
# Val Avg F1   14:  0.672316384180791
#
# Optimal Val loss (Epoch 11): 0.24703935533761978
#
# Epoch 15
# --------------------------------------------------------------
# Epoch:   15        1 Batch loss: 0.624753 Batch F1: 0.6250000000000001
# Epoch:   15        2 Batch loss: 0.486813 Batch F1: 0.7916666666666666
# Epoch:   15        3 Batch loss: 0.542715 Batch F1: 0.6857142857142857
# Epoch:   15        4 Batch loss: 0.495031 Batch F1: 0.7368421052631577
# Epoch:   15        5 Batch loss: 0.538170 Batch F1: 0.5517241379310345
# Train Avg Loss   15: 0.537497
#
# Train Avg F1   15: 0.678189439115029
#
# Val Avg Loss   15: 0.372862
#
# Val Avg F1   15:  0.263448275862069
#
# Optimal Val loss (Epoch 11): 0.24703935533761978
#
# Epoch 16
# --------------------------------------------------------------
# Epoch:   16        1 Batch loss: 0.538157 Batch F1: 0.6470588235294118
# Epoch:   16        2 Batch loss: 0.549795 Batch F1: 0.6470588235294117
# Epoch:   16        3 Batch loss: 0.483484 Batch F1: 0.7647058823529412
# Epoch:   16        4 Batch loss: 0.510283 Batch F1: 0.7567567567567568
# Epoch:   16        5 Batch loss: 0.503787 Batch F1: 0.7441860465116279
# Train Avg Loss   16: 0.517101
#
# Train Avg F1   16: 0.7119532665360299
#
# Val Avg Loss   16: 0.276397
#
# Val Avg F1   16:  0.6261398176291794
#
# Optimal Val loss (Epoch 11): 0.24703935533761978
#
# Epoch 17
# --------------------------------------------------------------
# Epoch:   17        1 Batch loss: 0.601955 Batch F1: 0.6956521739130435
# Epoch:   17        2 Batch loss: 0.378661 Batch F1: 0.9142857142857143
# Epoch:   17        3 Batch loss: 0.512948 Batch F1: 0.782608695652174
# Epoch:   17        4 Batch loss: 0.513017 Batch F1: 0.6153846153846154
# Epoch:   17        5 Batch loss: 0.512215 Batch F1: 0.6875
# Train Avg Loss   17: 0.503759
#
# Train Avg F1   17: 0.7390862398471094
#
# Val Avg Loss   17: 0.273611
#
# Val Avg F1   17:  0.6200000000000001
#
# Optimal Val loss (Epoch 11): 0.24703935533761978
#
# Epoch 18
# --------------------------------------------------------------
# Epoch:   18        1 Batch loss: 0.485756 Batch F1: 0.7777777777777777
# Epoch:   18        2 Batch loss: 0.566183 Batch F1: 0.6486486486486486
# Epoch:   18        3 Batch loss: 0.551149 Batch F1: 0.6829268292682927
# Epoch:   18        4 Batch loss: 0.480997 Batch F1: 0.8095238095238095
# Epoch:   18        5 Batch loss: 0.449365 Batch F1: 0.8125000000000001
# Train Avg Loss   18: 0.506690
#
# Train Avg F1   18: 0.7462754130437057
#
# Val Avg Loss   18: 0.277666
#
# Val Avg F1   18:  0.5946516537649542
#
# Optimal Val loss (Epoch 11): 0.24703935533761978
#
# Epoch 19
# --------------------------------------------------------------
# Epoch:   19        1 Batch loss: 0.536231 Batch F1: 0.6666666666666666
# Epoch:   19        2 Batch loss: 0.446063 Batch F1: 0.8235294117647058
# Epoch:   19        3 Batch loss: 0.521922 Batch F1: 0.7058823529411764
# Epoch:   19        4 Batch loss: 0.439459 Batch F1: 0.8500000000000001
# Epoch:   19        5 Batch loss: 0.539414 Batch F1: 0.7441860465116279
# Train Avg Loss   19: 0.496618
#
# Train Avg F1   19: 0.7580528955768354
#
# Val Avg Loss   19: 0.276073
#
# Val Avg F1   19:  0.6068313953488372
#
# Optimal Val loss (Epoch 11): 0.24703935533761978
#
# Epoch 20
# --------------------------------------------------------------
# Epoch:   20        1 Batch loss: 0.558815 Batch F1: 0.6842105263157895
# Epoch:   20        2 Batch loss: 0.489431 Batch F1: 0.7692307692307693
# Epoch:   20        3 Batch loss: 0.424901 Batch F1: 0.8148148148148148
# Epoch:   20        4 Batch loss: 0.492717 Batch F1: 0.8085106382978724
# Epoch:   20        5 Batch loss: 0.499190 Batch F1: 0.742857142857143
# Train Avg Loss   20: 0.493011
#
# Train Avg F1   20: 0.7639247783032778
#
# Val Avg Loss   20: 0.257836
#
# Val Avg F1   20:  0.6525252525252525
#
# Optimal Val loss (Epoch 11): 0.24703935533761978
#
# Epoch 21
# --------------------------------------------------------------
# Epoch:   21        1 Batch loss: 0.438198 Batch F1: 0.7857142857142857
# Epoch:   21        2 Batch loss: 0.473352 Batch F1: 0.8095238095238095
# Epoch:   21        3 Batch loss: 0.510655 Batch F1: 0.7222222222222223
# Epoch:   21        4 Batch loss: 0.527927 Batch F1: 0.7317073170731708
# Epoch:   21        5 Batch loss: 0.528376 Batch F1: 0.717948717948718
# Train Avg Loss   21: 0.495701
#
# Train Avg F1   21: 0.7534232704964413
#
# Val Avg Loss   21: 0.259985
#
# Val Avg F1   21:  0.6527110501029513
#
# Optimal Val loss (Epoch 11): 0.24703935533761978
#
# Epoch 22
# --------------------------------------------------------------
# Epoch:   22        1 Batch loss: 0.451071 Batch F1: 0.8636363636363635
# Epoch:   22        2 Batch loss: 0.531271 Batch F1: 0.6857142857142857
# Epoch:   22        3 Batch loss: 0.463266 Batch F1: 0.7096774193548386
# Epoch:   22        4 Batch loss: 0.562773 Batch F1: 0.7346938775510203
# Epoch:   22        5 Batch loss: 0.489604 Batch F1: 0.7096774193548387
# Train Avg Loss   22: 0.499597
#
# Train Avg F1   22: 0.7406798731222693
#
# Val Avg Loss   22: 0.300902
#
# Val Avg F1   22:  0.568888888888889
#
# Optimal Val loss (Epoch 11): 0.24703935533761978
#
# Epoch 23
# --------------------------------------------------------------
# Epoch:   23        1 Batch loss: 0.515344 Batch F1: 0.6857142857142856
# Epoch:   23        2 Batch loss: 0.450852 Batch F1: 0.8108108108108109
# Epoch:   23        3 Batch loss: 0.527413 Batch F1: 0.6666666666666666
# Epoch:   23        4 Batch loss: 0.480425 Batch F1: 0.8095238095238095
# Epoch:   23        5 Batch loss: 0.552112 Batch F1: 0.7450980392156864
# Train Avg Loss   23: 0.505229
#
# Train Avg F1   23: 0.7435627223862518
#
# Val Avg Loss   23: 0.258441
#
# Val Avg F1   23:  0.6336917562724014
#
# Optimal Val loss (Epoch 11): 0.24703935533761978
#
# Epoch 24
# --------------------------------------------------------------
# Epoch:   24        1 Batch loss: 0.493570 Batch F1: 0.7692307692307692
# Epoch:   24        2 Batch loss: 0.492217 Batch F1: 0.7222222222222223
# Epoch:   24        3 Batch loss: 0.531103 Batch F1: 0.7317073170731708
# Epoch:   24        4 Batch loss: 0.532470 Batch F1: 0.6451612903225806
# Epoch:   24        5 Batch loss: 0.428957 Batch F1: 0.8571428571428571
# Train Avg Loss   24: 0.495664
#
# Train Avg F1   24: 0.74509289119832
#
# Val Avg Loss   24: 0.297035
#
# Val Avg F1   24:  0.6144927536231883
#
# Optimal Val loss (Epoch 11): 0.24703935533761978
#
# Epoch 25
# --------------------------------------------------------------
# Epoch:   25        1 Batch loss: 0.539663 Batch F1: 0.6249999999999999
# Epoch:   25        2 Batch loss: 0.443688 Batch F1: 0.8636363636363635
# Epoch:   25        3 Batch loss: 0.501597 Batch F1: 0.7804878048780488
# Epoch:   25        4 Batch loss: 0.473464 Batch F1: 0.7499999999999999
# Epoch:   25        5 Batch loss: 0.505161 Batch F1: 0.7692307692307692
# Train Avg Loss   25: 0.492715
#
# Train Avg F1   25: 0.7576709875490362
#
# Val Avg Loss   25: 0.277056
#
# Val Avg F1   25:  0.6146926536731634
#
# Optimal Val loss (Epoch 11): 0.24703935533761978
#
# Epoch 26
# --------------------------------------------------------------
# Epoch:   26        1 Batch loss: 0.396787 Batch F1: 0.8648648648648648
# Epoch:   26        2 Batch loss: 0.540747 Batch F1: 0.6857142857142857
# Epoch:   26        3 Batch loss: 0.475462 Batch F1: 0.7647058823529413
# Epoch:   26        4 Batch loss: 0.594581 Batch F1: 0.6111111111111112
# Epoch:   26        5 Batch loss: 0.477191 Batch F1: 0.7692307692307693
# Train Avg Loss   26: 0.496954
#
# Train Avg F1   26: 0.7391253826547944
#
# Val Avg Loss   26: 0.285527
#
# Val Avg F1   26:  0.586940572267058
#
# Optimal Val loss (Epoch 11): 0.24703935533761978
#
# Epoch 27
# --------------------------------------------------------------
# Epoch:   27        1 Batch loss: 0.513905 Batch F1: 0.7222222222222222
# Epoch:   27        2 Batch loss: 0.528054 Batch F1: 0.7441860465116279
# Epoch:   27        3 Batch loss: 0.489468 Batch F1: 0.8399999999999999
# Epoch:   27        4 Batch loss: 0.524173 Batch F1: 0.6451612903225806
# Epoch:   27        5 Batch loss: 0.456132 Batch F1: 0.7878787878787878
# Train Avg Loss   27: 0.502346
#
# Train Avg F1   27: 0.7478896693870437
#
# Val Avg Loss   27: 0.326926
#
# Val Avg F1   27:  0.5402930402930404
#
# Optimal Val loss (Epoch 11): 0.24703935533761978
#
# Epoch 28
# --------------------------------------------------------------
# Epoch:   28        1 Batch loss: 0.531722 Batch F1: 0.6206896551724138
# Epoch:   28        2 Batch loss: 0.441809 Batch F1: 0.8108108108108109
# Epoch:   28        3 Batch loss: 0.529721 Batch F1: 0.6842105263157895
# Epoch:   28        4 Batch loss: 0.487867 Batch F1: 0.7567567567567568
# Epoch:   28        5 Batch loss: 0.508589 Batch F1: 0.717948717948718
# Train Avg Loss   28: 0.499942
#
# Train Avg F1   28: 0.7180832934008977
#
# Val Avg Loss   28: 0.269198
#
# Val Avg F1   28:  0.6458333333333333
#
# Optimal Val loss (Epoch 11): 0.24703935533761978
#
# Epoch 29
# --------------------------------------------------------------
# Epoch:   29        1 Batch loss: 0.436284 Batch F1: 0.8000000000000002
# Epoch:   29        2 Batch loss: 0.526036 Batch F1: 0.7555555555555555
# Epoch:   29        3 Batch loss: 0.516413 Batch F1: 0.7368421052631577
# Epoch:   29        4 Batch loss: 0.499733 Batch F1: 0.7906976744186047
# Epoch:   29        5 Batch loss: 0.544936 Batch F1: 0.6857142857142856
# Train Avg Loss   29: 0.504680
#
# Train Avg F1   29: 0.7537619241903208
#
# Val Avg Loss   29: 0.286387
#
# Val Avg F1   29:  0.6456241032998564
#
# Optimal Val loss (Epoch 11): 0.24703935533761978
#
# Epoch 30
# --------------------------------------------------------------
# Epoch:   30        1 Batch loss: 0.473891 Batch F1: 0.8085106382978724
# Epoch:   30        2 Batch loss: 0.557608 Batch F1: 0.4545454545454545
# Epoch:   30        3 Batch loss: 0.496125 Batch F1: 0.7272727272727274
# Epoch:   30        4 Batch loss: 0.439875 Batch F1: 0.8125000000000001
# Epoch:   30        5 Batch loss: 0.513851 Batch F1: 0.823529411764706
# Train Avg Loss   30: 0.496270
#
# Train Avg F1   30: 0.7252716463761522
#
# Val Avg Loss   30: 0.281033
#
# Val Avg F1   30:  0.6377068557919622
#
# Optimal Val loss (Epoch 11): 0.24703935533761978
#
# Epoch 31
# --------------------------------------------------------------
# Epoch:   31        1 Batch loss: 0.521140 Batch F1: 0.7058823529411764
# Epoch:   31        2 Batch loss: 0.491207 Batch F1: 0.8148148148148148
# Epoch:   31        3 Batch loss: 0.510010 Batch F1: 0.742857142857143
# Epoch:   31        4 Batch loss: 0.490689 Batch F1: 0.742857142857143
# Epoch:   31        5 Batch loss: 0.433249 Batch F1: 0.8333333333333334
# Train Avg Loss   31: 0.489259
#
# Train Avg F1   31: 0.7679489573607221
#
# Val Avg Loss   31: 0.292717
#
# Val Avg F1   31:  0.6162123385939742
#
# Optimal Val loss (Epoch 11): 0.24703935533761978
#
# Epoch 32
# --------------------------------------------------------------
# Epoch:   32        1 Batch loss: 0.434133 Batch F1: 0.823529411764706
# Epoch:   32        2 Batch loss: 0.462968 Batch F1: 0.7777777777777778
# Epoch:   32        3 Batch loss: 0.511776 Batch F1: 0.7027027027027025
# Epoch:   32        4 Batch loss: 0.443822 Batch F1: 0.8125000000000001
# Epoch:   32        5 Batch loss: 0.620175 Batch F1: 0.6190476190476191
# Train Avg Loss   32: 0.494575
#
# Train Avg F1   32: 0.747111502258561
#
# Val Avg Loss   32: 0.276030
#
# Val Avg F1   32:  0.603584229390681
#
# Optimal Val loss (Epoch 11): 0.24703935533761978
#
# Epoch 33
# --------------------------------------------------------------
# Epoch:   33        1 Batch loss: 0.440641 Batch F1: 0.7857142857142857
# Epoch:   33        2 Batch loss: 0.556217 Batch F1: 0.7234042553191491
# Epoch:   33        3 Batch loss: 0.501777 Batch F1: 0.7692307692307692
# Epoch:   33        4 Batch loss: 0.522436 Batch F1: 0.7027027027027025
# Epoch:   33        5 Batch loss: 0.431650 Batch F1: 0.8837209302325582
# Train Avg Loss   33: 0.490544
#
# Train Avg F1   33: 0.772954588639893
#
# Val Avg Loss   33: 0.290477
#
# Val Avg F1   33:  0.6398671096345515
#
# Optimal Val loss (Epoch 11): 0.24703935533761978
#
# Epoch 34
# --------------------------------------------------------------
# Epoch:   34        1 Batch loss: 0.450483 Batch F1: 0.7333333333333333
# Epoch:   34        2 Batch loss: 0.468591 Batch F1: 0.7647058823529412
# Epoch:   34        3 Batch loss: 0.455144 Batch F1: 0.8181818181818182
# Epoch:   34        4 Batch loss: 0.505988 Batch F1: 0.7027027027027025
# Epoch:   34        5 Batch loss: 0.575653 Batch F1: 0.6818181818181818
# Train Avg Loss   34: 0.491172
#
# Train Avg F1   34: 0.7401483836777955
#
# Val Avg Loss   34: 0.271419
#
# Val Avg F1   34:  0.6723057644110275
#
# Optimal Val loss (Epoch 11): 0.24703935533761978
#
# Epoch 35
# --------------------------------------------------------------
# Epoch:   35        1 Batch loss: 0.455649 Batch F1: 0.8627450980392156
# Epoch:   35        2 Batch loss: 0.479506 Batch F1: 0.8108108108108107
# Epoch:   35        3 Batch loss: 0.568347 Batch F1: 0.6666666666666667
# Epoch:   35        4 Batch loss: 0.466753 Batch F1: 0.8292682926829269
# Epoch:   35        5 Batch loss: 0.460943 Batch F1: 0.7999999999999999
# Train Avg Loss   35: 0.486240
#
# Train Avg F1   35: 0.7938981736399239
#
# Val Avg Loss   35: 0.317272
#
# Val Avg F1   35:  0.5701754385964912
#
# Optimal Val loss (Epoch 11): 0.24703935533761978
#
# Epoch 36
# --------------------------------------------------------------
# Epoch:   36        1 Batch loss: 0.506676 Batch F1: 0.7826086956521738
# Epoch:   36        2 Batch loss: 0.529194 Batch F1: 0.6666666666666667
# Epoch:   36        3 Batch loss: 0.534507 Batch F1: 0.7222222222222223
# Epoch:   36        4 Batch loss: 0.472112 Batch F1: 0.7142857142857143
# Epoch:   36        5 Batch loss: 0.450674 Batch F1: 0.8108108108108109
# Train Avg Loss   36: 0.498632
#
# Train Avg F1   36: 0.7393188219275177
#
# Val Avg Loss   36: 0.284516
#
# Val Avg F1   36:  0.6330532212885154
#
# Optimal Val loss (Epoch 11): 0.24703935533761978
#
# Epoch 37
# --------------------------------------------------------------
# Epoch:   37        1 Batch loss: 0.532726 Batch F1: 0.6666666666666667
# Epoch:   37        2 Batch loss: 0.489273 Batch F1: 0.7804878048780488
# Epoch:   37        3 Batch loss: 0.485069 Batch F1: 0.8181818181818182
# Epoch:   37        4 Batch loss: 0.417902 Batch F1: 0.8888888888888888
# Epoch:   37        5 Batch loss: 0.529177 Batch F1: 0.7027027027027029
# Train Avg Loss   37: 0.490829
#
# Train Avg F1   37: 0.7713855762636251
#
# Val Avg Loss   37: 0.290152
#
# Val Avg F1   37:  0.6287878787878787
#
# Optimal Val loss (Epoch 11): 0.24703935533761978
#
# Epoch 38
# --------------------------------------------------------------
# Epoch:   38        1 Batch loss: 0.487790 Batch F1: 0.7096774193548386
# Epoch:   38        2 Batch loss: 0.483343 Batch F1: 0.8181818181818181
# Epoch:   38        3 Batch loss: 0.488027 Batch F1: 0.7096774193548387
# Epoch:   38        4 Batch loss: 0.489176 Batch F1: 0.7619047619047621
# Epoch:   38        5 Batch loss: 0.550441 Batch F1: 0.6976744186046512
# Train Avg Loss   38: 0.499756
#
# Train Avg F1   38: 0.7394231674801817
#
# Val Avg Loss   38: 0.284470
#
# Val Avg F1   38:  0.6354166666666667
#
# Optimal Val loss (Epoch 11): 0.24703935533761978
#
# Epoch 39
# --------------------------------------------------------------
# Epoch:   39        1 Batch loss: 0.479321 Batch F1: 0.7428571428571428
# Epoch:   39        2 Batch loss: 0.516764 Batch F1: 0.6875000000000001
# Epoch:   39        3 Batch loss: 0.490787 Batch F1: 0.7999999999999999
# Epoch:   39        4 Batch loss: 0.457857 Batch F1: 0.8205128205128205
# Epoch:   39        5 Batch loss: 0.500852 Batch F1: 0.742857142857143
# Train Avg Loss   39: 0.489116
#
# Train Avg F1   39: 0.7587454212454212
#
# Val Avg Loss   39: 0.271868
#
# Val Avg F1   39:  0.6228269085411942
#
# Optimal Val loss (Epoch 11): 0.24703935533761978
#
# Epoch 40
# --------------------------------------------------------------
# Epoch:   40        1 Batch loss: 0.528527 Batch F1: 0.6428571428571429
# Epoch:   40        2 Batch loss: 0.499222 Batch F1: 0.6875
# Epoch:   40        3 Batch loss: 0.503666 Batch F1: 0.7555555555555554
# Epoch:   40        4 Batch loss: 0.532903 Batch F1: 0.6666666666666667
# Epoch:   40        5 Batch loss: 0.409543 Batch F1: 0.923076923076923
# Train Avg Loss   40: 0.494772
#
# Train Avg F1   40: 0.7351312576312575
#
# Val Avg Loss   40: 0.287910
#
# Val Avg F1   40:  0.657680250783699
#
# Optimal Val loss (Epoch 11): 0.24703935533761978
#
# Epoch 41
# --------------------------------------------------------------
# Epoch:   41        1 Batch loss: 0.538069 Batch F1: 0.7391304347826089
# Epoch:   41        2 Batch loss: 0.423211 Batch F1: 0.8333333333333333
# Epoch:   41        3 Batch loss: 0.542192 Batch F1: 0.7317073170731707
# Epoch:   41        4 Batch loss: 0.536300 Batch F1: 0.6470588235294117
# Epoch:   41        5 Batch loss: 0.502680 Batch F1: 0.7692307692307693
# Train Avg Loss   41: 0.508491
#
# Train Avg F1   41: 0.7440921355898588
#
# Val Avg Loss   41: 0.310952
#
# Val Avg F1   41:  0.6061980347694633
#
# Optimal Val loss (Epoch 11): 0.24703935533761978
#
# Epoch 42
# --------------------------------------------------------------
# Epoch:   42        1 Batch loss: 0.615352 Batch F1: 0.6153846153846153
# Epoch:   42        2 Batch loss: 0.451160 Batch F1: 0.8108108108108107
# Epoch:   42        3 Batch loss: 0.391090 Batch F1: 0.8823529411764706
# Epoch:   42        4 Batch loss: 0.475154 Batch F1: 0.8372093023255814
# Epoch:   42        5 Batch loss: 0.537642 Batch F1: 0.6857142857142857
# Train Avg Loss   42: 0.494079
#
# Train Avg F1   42: 0.7662943910823528
#
# Val Avg Loss   42: 0.298074
#
# Val Avg F1   42:  0.6138147566718996
#
# Optimal Val loss (Epoch 11): 0.24703935533761978
#
# Epoch 43
# --------------------------------------------------------------
# Epoch:   43        1 Batch loss: 0.500757 Batch F1: 0.8085106382978724
# Epoch:   43        2 Batch loss: 0.433533 Batch F1: 0.7692307692307693
# Epoch:   43        3 Batch loss: 0.459494 Batch F1: 0.8292682926829269
# Epoch:   43        4 Batch loss: 0.515739 Batch F1: 0.7222222222222223
# Epoch:   43        5 Batch loss: 0.543676 Batch F1: 0.6666666666666665
# Train Avg Loss   43: 0.490640
#
# Train Avg F1   43: 0.7591797178200914
#
# Val Avg Loss   43: 0.297060
#
# Val Avg F1   43:  0.6355810616929699
#
# Optimal Val loss (Epoch 11): 0.24703935533761978
#
# Epoch 44
# --------------------------------------------------------------
# Epoch:   44        1 Batch loss: 0.503002 Batch F1: 0.7727272727272727
# Epoch:   44        2 Batch loss: 0.438504 Batch F1: 0.6956521739130435
# Epoch:   44        3 Batch loss: 0.543130 Batch F1: 0.7027027027027026
# Epoch:   44        4 Batch loss: 0.430831 Batch F1: 0.8500000000000001
# Epoch:   44        5 Batch loss: 0.521357 Batch F1: 0.7441860465116279
# Train Avg Loss   44: 0.487365
#
# Train Avg F1   44: 0.7530536391709294
#
# Val Avg Loss   44: 0.291147
#
# Val Avg F1   44:  0.5703703703703704
#
# Optimal Val loss (Epoch 11): 0.24703935533761978
#
# Epoch 45
# --------------------------------------------------------------
# Epoch:   45        1 Batch loss: 0.456395 Batch F1: 0.7647058823529413
# Epoch:   45        2 Batch loss: 0.438924 Batch F1: 0.8484848484848485
# Epoch:   45        3 Batch loss: 0.491319 Batch F1: 0.8085106382978724
# Epoch:   45        4 Batch loss: 0.499984 Batch F1: 0.7222222222222222
# Epoch:   45        5 Batch loss: 0.545562 Batch F1: 0.6842105263157895
# Train Avg Loss   45: 0.486437
#
# Train Avg F1   45: 0.7656268235347348
#
# Val Avg Loss   45: 0.301491
#
# Val Avg F1   45:  0.5835913312693498
#
# Optimal Val loss (Epoch 11): 0.24703935533761978
#
# Epoch 46
# --------------------------------------------------------------
# Epoch:   46        1 Batch loss: 0.448994 Batch F1: 0.8125000000000001
# Epoch:   46        2 Batch loss: 0.430430 Batch F1: 0.8108108108108109
# Epoch:   46        3 Batch loss: 0.394421 Batch F1: 0.888888888888889
# Epoch:   46        4 Batch loss: 0.578544 Batch F1: 0.6808510638297872
# Epoch:   46        5 Batch loss: 0.586957 Batch F1: 0.6818181818181819
# Train Avg Loss   46: 0.487869
#
# Train Avg F1   46: 0.7749737890695337
#
# Val Avg Loss   46: 0.270509
#
# Val Avg F1   46:  0.6889632107023411
#
# Optimal Val loss (Epoch 11): 0.24703935533761978
#
# Epoch 47
# --------------------------------------------------------------
# Epoch:   47        1 Batch loss: 0.470767 Batch F1: 0.8181818181818182
# Epoch:   47        2 Batch loss: 0.529396 Batch F1: 0.6666666666666665
# Epoch:   47        3 Batch loss: 0.465713 Batch F1: 0.8205128205128205
# Epoch:   47        4 Batch loss: 0.478110 Batch F1: 0.7647058823529411
# Epoch:   47        5 Batch loss: 0.489335 Batch F1: 0.7692307692307693
# Train Avg Loss   47: 0.486664
#
# Train Avg F1   47: 0.7678595913890032
#
# Val Avg Loss   47: 0.300229
#
# Val Avg F1   47:  0.6228070175438597
#
# Optimal Val loss (Epoch 11): 0.24703935533761978
#
# Epoch 48
# --------------------------------------------------------------
# Epoch:   48        1 Batch loss: 0.454055 Batch F1: 0.8205128205128205
# Epoch:   48        2 Batch loss: 0.520305 Batch F1: 0.7916666666666667
# Epoch:   48        3 Batch loss: 0.450321 Batch F1: 0.7586206896551724
# Epoch:   48        4 Batch loss: 0.486207 Batch F1: 0.7777777777777777
# Epoch:   48        5 Batch loss: 0.510526 Batch F1: 0.6857142857142857
# Train Avg Loss   48: 0.484283
#
# Train Avg F1   48: 0.7668584480653446
#
# Val Avg Loss   48: 0.260965
#
# Val Avg F1   48:  0.7125
#
# Optimal Val loss (Epoch 11): 0.24703935533761978
#
# Epoch 49
# --------------------------------------------------------------
# Epoch:   49        1 Batch loss: 0.442645 Batch F1: 0.8695652173913043
# Epoch:   49        2 Batch loss: 0.485397 Batch F1: 0.8108108108108109
# Epoch:   49        3 Batch loss: 0.456383 Batch F1: 0.8846153846153846
# Epoch:   49        4 Batch loss: 0.542737 Batch F1: 0.6451612903225806
# Epoch:   49        5 Batch loss: 0.495428 Batch F1: 0.7222222222222223
# Train Avg Loss   49: 0.484518
#
# Train Avg F1   49: 0.7864749850724605
#
# Val Avg Loss   49: 0.290488
#
# Val Avg F1   49:  0.5853448275862068
#
# Optimal Val loss (Epoch 11): 0.24703935533761978
#
# Epoch 50
# --------------------------------------------------------------
# Epoch:   50        1 Batch loss: 0.551196 Batch F1: 0.6842105263157896
# Epoch:   50        2 Batch loss: 0.543288 Batch F1: 0.6666666666666665
# Epoch:   50        3 Batch loss: 0.412972 Batch F1: 0.8484848484848485
# Epoch:   50        4 Batch loss: 0.486528 Batch F1: 0.7777777777777778
# Epoch:   50        5 Batch loss: 0.454859 Batch F1: 0.8292682926829269
# Train Avg Loss   50: 0.489768
#
# Train Avg F1   50: 0.7612816223856018
#
# Val Avg Loss   50: 0.278036
#
# Val Avg F1   50:  0.687641723356009
#
# Optimal Val loss (Epoch 11): 0.24703935533761978
#
# Epoch 51
# --------------------------------------------------------------
# Epoch:   51        1 Batch loss: 0.515505 Batch F1: 0.8000000000000002
# Epoch:   51        2 Batch loss: 0.517500 Batch F1: 0.7222222222222223
# Epoch:   51        3 Batch loss: 0.454303 Batch F1: 0.8372093023255814
# Epoch:   51        4 Batch loss: 0.431808 Batch F1: 0.75
# Epoch:   51        5 Batch loss: 0.513873 Batch F1: 0.7826086956521738
# Train Avg Loss   51: 0.486598
#
# Train Avg F1   51: 0.7784080440399956
#
# Val Avg Loss   51: 0.347604
#
# Val Avg F1   51:  0.536541889483066
#
# Optimal Val loss (Epoch 11): 0.24703935533761978
#
# Epoch 52
# --------------------------------------------------------------
# Epoch:   52        1 Batch loss: 0.466207 Batch F1: 0.7777777777777778
# Epoch:   52        2 Batch loss: 0.560982 Batch F1: 0.7000000000000001
# Epoch:   52        3 Batch loss: 0.456112 Batch F1: 0.7741935483870968
# Epoch:   52        4 Batch loss: 0.575247 Batch F1: 0.65
# Epoch:   52        5 Batch loss: 0.406831 Batch F1: 0.8823529411764706
# Train Avg Loss   52: 0.493076
#
# Train Avg F1   52: 0.756864853468269
#
# Val Avg Loss   52: 0.264540
#
# Val Avg F1   52:  0.7110512129380053
#
# Optimal Val loss (Epoch 11): 0.24703935533761978
#
# Epoch 53
# --------------------------------------------------------------
# Epoch:   53        1 Batch loss: 0.457458 Batch F1: 0.8292682926829269
# Epoch:   53        2 Batch loss: 0.581598 Batch F1: 0.6829268292682927
# Epoch:   53        3 Batch loss: 0.438599 Batch F1: 0.8235294117647058
# Epoch:   53        4 Batch loss: 0.529326 Batch F1: 0.625
# Epoch:   53        5 Batch loss: 0.497061 Batch F1: 0.7999999999999999
# Train Avg Loss   53: 0.500809
#
# Train Avg F1   53: 0.7521449067431851
#
# Val Avg Loss   53: 0.309504
#
# Val Avg F1   53:  0.6016504126031508
#
# Optimal Val loss (Epoch 11): 0.24703935533761978
#
# Epoch 54
# --------------------------------------------------------------
# Epoch:   54        1 Batch loss: 0.533528 Batch F1: 0.6250000000000001
# Epoch:   54        2 Batch loss: 0.495581 Batch F1: 0.7999999999999999
# Epoch:   54        3 Batch loss: 0.467802 Batch F1: 0.8
# Epoch:   54        4 Batch loss: 0.500117 Batch F1: 0.7096774193548387
# Epoch:   54        5 Batch loss: 0.446043 Batch F1: 0.8108108108108107
# Train Avg Loss   54: 0.488614
#
# Train Avg F1   54: 0.7490976460331298
#
# Val Avg Loss   54: 0.274262
#
# Val Avg F1   54:  0.6339285714285714
#
# Optimal Val loss (Epoch 11): 0.24703935533761978
#
# Epoch 55
# --------------------------------------------------------------
# Epoch:   55        1 Batch loss: 0.440752 Batch F1: 0.7857142857142857
# Epoch:   55        2 Batch loss: 0.466989 Batch F1: 0.8
# Epoch:   55        3 Batch loss: 0.589642 Batch F1: 0.5882352941176471
# Epoch:   55        4 Batch loss: 0.472513 Batch F1: 0.8
# Epoch:   55        5 Batch loss: 0.441467 Batch F1: 0.8444444444444444
# Train Avg Loss   55: 0.482273
#
# Train Avg F1   55: 0.7636788048552755
#
# Val Avg Loss   55: 0.273285
#
# Val Avg F1   55:  0.6703772418058133
#
# Optimal Val loss (Epoch 11): 0.24703935533761978
#
# Epoch 56
# --------------------------------------------------------------
# Epoch:   56        1 Batch loss: 0.473322 Batch F1: 0.8800000000000001
# Epoch:   56        2 Batch loss: 0.564740 Batch F1: 0.6060606060606061
# Epoch:   56        3 Batch loss: 0.442324 Batch F1: 0.8372093023255814
# Epoch:   56        4 Batch loss: 0.469645 Batch F1: 0.7894736842105263
# Epoch:   56        5 Batch loss: 0.494430 Batch F1: 0.7096774193548387
# Train Avg Loss   56: 0.488892
#
# Train Avg F1   56: 0.7644842023903106
#
# Val Avg Loss   56: 0.302380
#
# Val Avg F1   56:  0.5894145950280674
#
# Optimal Val loss (Epoch 11): 0.24703935533761978
#
# Epoch 57
# --------------------------------------------------------------
# Epoch:   57        1 Batch loss: 0.452276 Batch F1: 0.8627450980392156
# Epoch:   57        2 Batch loss: 0.501130 Batch F1: 0.7428571428571429
# Epoch:   57        3 Batch loss: 0.453273 Batch F1: 0.7999999999999999
# Epoch:   57        4 Batch loss: 0.500373 Batch F1: 0.6666666666666667
# Epoch:   57        5 Batch loss: 0.524291 Batch F1: 0.6857142857142857
# Train Avg Loss   57: 0.486269
#
# Train Avg F1   57: 0.7515966386554622
#
# Val Avg Loss   57: 0.287404
#
# Val Avg F1   57:  0.6854700854700855
#
# Optimal Val loss (Epoch 11): 0.24703935533761978
#
# Epoch 58
# --------------------------------------------------------------
# Epoch:   58        1 Batch loss: 0.427309 Batch F1: 0.888888888888889
# Epoch:   58        2 Batch loss: 0.508123 Batch F1: 0.717948717948718
# Epoch:   58        3 Batch loss: 0.572347 Batch F1: 0.6486486486486486
# Epoch:   58        4 Batch loss: 0.433006 Batch F1: 0.8387096774193548
# Epoch:   58        5 Batch loss: 0.514403 Batch F1: 0.744186046511628
# Train Avg Loss   58: 0.491038
#
# Train Avg F1   58: 0.7676763958834477
#
# Val Avg Loss   58: 0.330013
#
# Val Avg F1   58:  0.5595238095238095
#
# Optimal Val loss (Epoch 11): 0.24703935533761978
#
# Epoch 59
# --------------------------------------------------------------
# Epoch:   59        1 Batch loss: 0.540155 Batch F1: 0.7142857142857143
# Epoch:   59        2 Batch loss: 0.470165 Batch F1: 0.75
# Epoch:   59        3 Batch loss: 0.565690 Batch F1: 0.6829268292682927
# Epoch:   59        4 Batch loss: 0.437091 Batch F1: 0.8571428571428571
# Epoch:   59        5 Batch loss: 0.460349 Batch F1: 0.7407407407407406
# Train Avg Loss   59: 0.494690
#
# Train Avg F1   59: 0.749019228287521
#
# Val Avg Loss   59: 0.290762
#
# Val Avg F1   59:  0.5987411487018096
#
# Optimal Val loss (Epoch 11): 0.24703935533761978
#
# Epoch 60
# --------------------------------------------------------------
# Epoch:   60        1 Batch loss: 0.516119 Batch F1: 0.7027027027027029
# Epoch:   60        2 Batch loss: 0.465728 Batch F1: 0.7894736842105262
# Epoch:   60        3 Batch loss: 0.448588 Batch F1: 0.8235294117647058
# Epoch:   60        4 Batch loss: 0.450034 Batch F1: 0.8372093023255814
# Epoch:   60        5 Batch loss: 0.536370 Batch F1: 0.6451612903225806
# Train Avg Loss   60: 0.483368
#
# Train Avg F1   60: 0.7596152782652194
#
# Val Avg Loss   60: 0.304622
#
# Val Avg F1   60:  0.58125
#
# Optimal Val loss (Epoch 11): 0.24703935533761978
#
# Epoch 61
# --------------------------------------------------------------
# Epoch:   61        1 Batch loss: 0.445401 Batch F1: 0.8695652173913043
# Epoch:   61        2 Batch loss: 0.428682 Batch F1: 0.8
# Epoch:   61        3 Batch loss: 0.517597 Batch F1: 0.6666666666666667
# Epoch:   61        4 Batch loss: 0.568795 Batch F1: 0.6285714285714286
# Epoch:   61        5 Batch loss: 0.466510 Batch F1: 0.8095238095238096
# Train Avg Loss   61: 0.485397
#
# Train Avg F1   61: 0.754865424430642
#
# Val Avg Loss   61: 0.320208
#
# Val Avg F1   61:  0.5555555555555556
#
# Optimal Val loss (Epoch 11): 0.24703935533761978
#
# Epoch 62
# --------------------------------------------------------------
# Epoch:   62        1 Batch loss: 0.539366 Batch F1: 0.6666666666666667
# Epoch:   62        2 Batch loss: 0.446129 Batch F1: 0.7999999999999999
# Epoch:   62        3 Batch loss: 0.417018 Batch F1: 0.8500000000000001
# Epoch:   62        4 Batch loss: 0.497015 Batch F1: 0.7894736842105262
# Epoch:   62        5 Batch loss: 0.525758 Batch F1: 0.7179487179487181
# Train Avg Loss   62: 0.485057
#
# Train Avg F1   62: 0.7648178137651822
#
# Val Avg Loss   62: 0.294948
#
# Val Avg F1   62:  0.5703703703703704
#
# Optimal Val loss (Epoch 11): 0.24703935533761978
#
# Epoch 63
# --------------------------------------------------------------
# Epoch:   63        1 Batch loss: 0.495507 Batch F1: 0.7058823529411764
# Epoch:   63        2 Batch loss: 0.494602 Batch F1: 0.7368421052631579
# Epoch:   63        3 Batch loss: 0.584968 Batch F1: 0.5625000000000001
# Epoch:   63        4 Batch loss: 0.406180 Batch F1: 0.9268292682926829
# Epoch:   63        5 Batch loss: 0.433505 Batch F1: 0.851063829787234
# Train Avg Loss   63: 0.482953
#
# Train Avg F1   63: 0.7566235112568502
#
# Val Avg Loss   63: 0.306123
#
# Val Avg F1   63:  0.5755813953488371
#
# Optimal Val loss (Epoch 11): 0.24703935533761978
#
# Epoch 64
# --------------------------------------------------------------
# Epoch:   64        1 Batch loss: 0.478559 Batch F1: 0.7692307692307693
# Epoch:   64        2 Batch loss: 0.532495 Batch F1: 0.7222222222222222
# Epoch:   64        3 Batch loss: 0.506629 Batch F1: 0.7058823529411764
# Epoch:   64        4 Batch loss: 0.421038 Batch F1: 0.8648648648648649
# Epoch:   64        5 Batch loss: 0.480512 Batch F1: 0.7692307692307692
# Train Avg Loss   64: 0.483846
#
# Train Avg F1   64: 0.7662861956979604
#
# Val Avg Loss   64: 0.281769
#
# Val Avg F1   64:  0.6024187452758881
#
# Optimal Val loss (Epoch 11): 0.24703935533761978
#
# Epoch 65
# --------------------------------------------------------------
# Epoch:   65        1 Batch loss: 0.494572 Batch F1: 0.7727272727272727
# Epoch:   65        2 Batch loss: 0.398785 Batch F1: 0.8648648648648648
# Epoch:   65        3 Batch loss: 0.507734 Batch F1: 0.7999999999999999
# Epoch:   65        4 Batch loss: 0.512568 Batch F1: 0.717948717948718
# Epoch:   65        5 Batch loss: 0.506592 Batch F1: 0.7027027027027027
# Train Avg Loss   65: 0.484050
#
# Train Avg F1   65: 0.7716487116487116
#
# Val Avg Loss   65: 0.307791
#
# Val Avg F1   65:  0.575
#
# Optimal Val loss (Epoch 11): 0.24703935533761978
#
# Epoch 66
# --------------------------------------------------------------
# Epoch:   66        1 Batch loss: 0.433182 Batch F1: 0.8235294117647058
# Epoch:   66        2 Batch loss: 0.624402 Batch F1: 0.5789473684210527
# Epoch:   66        3 Batch loss: 0.479703 Batch F1: 0.7333333333333334
# Epoch:   66        4 Batch loss: 0.426593 Batch F1: 0.8837209302325582
# Epoch:   66        5 Batch loss: 0.477681 Batch F1: 0.7894736842105263
# Train Avg Loss   66: 0.488312
#
# Train Avg F1   66: 0.7618009455924353
#
# Val Avg Loss   66: 0.302977
#
# Val Avg F1   66:  0.58125
#
# Optimal Val loss (Epoch 11): 0.24703935533761978
#
# Epoch 67
# --------------------------------------------------------------
# Epoch:   67        1 Batch loss: 0.561540 Batch F1: 0.48
# Epoch:   67        2 Batch loss: 0.494318 Batch F1: 0.7692307692307693
# Epoch:   67        3 Batch loss: 0.513819 Batch F1: 0.7659574468085106
# Epoch:   67        4 Batch loss: 0.459250 Batch F1: 0.8275862068965518
# Epoch:   67        5 Batch loss: 0.409604 Batch F1: 0.8846153846153846
# Train Avg Loss   67: 0.487706
#
# Train Avg F1   67: 0.7454779615102433
#
# Val Avg Loss   67: 0.292840
#
# Val Avg F1   67:  0.5518207282913166
#
# Optimal Val loss (Epoch 11): 0.24703935533761978
#
# Epoch 68
# --------------------------------------------------------------
# Epoch:   68        1 Batch loss: 0.425760 Batch F1: 0.8695652173913043
# Epoch:   68        2 Batch loss: 0.571926 Batch F1: 0.6285714285714286
# Epoch:   68        3 Batch loss: 0.413539 Batch F1: 0.8717948717948718
# Epoch:   68        4 Batch loss: 0.532964 Batch F1: 0.6666666666666667
# Epoch:   68        5 Batch loss: 0.477836 Batch F1: 0.6896551724137931
# Train Avg Loss   68: 0.484405
#
# Train Avg F1   68: 0.7452506713676128
#
# Val Avg Loss   68: 0.309489
#
# Val Avg F1   68:  0.594551282051282
#
# Optimal Val loss (Epoch 11): 0.24703935533761978
#
# Epoch 69
# --------------------------------------------------------------
# Epoch:   69        1 Batch loss: 0.448455 Batch F1: 0.8372093023255814
# Epoch:   69        2 Batch loss: 0.524206 Batch F1: 0.6666666666666667
# Epoch:   69        3 Batch loss: 0.495298 Batch F1: 0.7567567567567567
# Epoch:   69        4 Batch loss: 0.533394 Batch F1: 0.6666666666666667
# Epoch:   69        5 Batch loss: 0.437652 Batch F1: 0.8421052631578947
# Train Avg Loss   69: 0.487801
#
# Train Avg F1   69: 0.7538809311147132
#
# Val Avg Loss   69: 0.271511
#
# Val Avg F1   69:  0.6122448979591837
#
# Optimal Val loss (Epoch 11): 0.24703935533761978
#
# Epoch 70
# --------------------------------------------------------------
# Epoch:   70        1 Batch loss: 0.452551 Batch F1: 0.7777777777777778
# Epoch:   70        2 Batch loss: 0.496303 Batch F1: 0.8085106382978724
# Epoch:   70        3 Batch loss: 0.587614 Batch F1: 0.6153846153846153
# Epoch:   70        4 Batch loss: 0.459105 Batch F1: 0.8181818181818182
# Epoch:   70        5 Batch loss: 0.439781 Batch F1: 0.8235294117647058
# Train Avg Loss   70: 0.487071
#
# Train Avg F1   70: 0.768676852281358
#
# Val Avg Loss   70: 0.305153
#
# Val Avg F1   70:  0.6220238095238095
#
# Optimal Val loss (Epoch 11): 0.24703935533761978
#
# Epoch 71
# --------------------------------------------------------------
# Epoch:   71        1 Batch loss: 0.368305 Batch F1: 0.9268292682926829
# Epoch:   71        2 Batch loss: 0.626892 Batch F1: 0.5294117647058825
# Epoch:   71        3 Batch loss: 0.511494 Batch F1: 0.6857142857142857
# Epoch:   71        4 Batch loss: 0.601877 Batch F1: 0.65
# Epoch:   71        5 Batch loss: 0.422835 Batch F1: 0.8275862068965517
# Train Avg Loss   71: 0.506281
#
# Train Avg F1   71: 0.7239083051218805
#
# Val Avg Loss   71: 0.250726
#
# Val Avg F1   71:  0.683625730994152
#
# Optimal Val loss (Epoch 11): 0.24703935533761978
#
# Epoch 72
# --------------------------------------------------------------
# Epoch:   72        1 Batch loss: 0.528974 Batch F1: 0.7058823529411765
# Epoch:   72        2 Batch loss: 0.452345 Batch F1: 0.8444444444444444
# Epoch:   72        3 Batch loss: 0.496882 Batch F1: 0.7727272727272727
# Epoch:   72        4 Batch loss: 0.451581 Batch F1: 0.7407407407407408
# Epoch:   72        5 Batch loss: 0.549323 Batch F1: 0.744186046511628
# Train Avg Loss   72: 0.495821
#
# Train Avg F1   72: 0.7615961714730525
#
# Val Avg Loss   72: 0.301454
#
# Val Avg F1   72:  0.56
#
# Optimal Val loss (Epoch 11): 0.24703935533761978
#
# Epoch 73
# --------------------------------------------------------------
# Epoch:   73        1 Batch loss: 0.425147 Batch F1: 0.8780487804878049
# Epoch:   73        2 Batch loss: 0.439411 Batch F1: 0.85
# Epoch:   73        3 Batch loss: 0.463545 Batch F1: 0.7878787878787878
# Epoch:   73        4 Batch loss: 0.645471 Batch F1: 0.5499999999999999
# Epoch:   73        5 Batch loss: 0.456101 Batch F1: 0.7878787878787877
# Train Avg Loss   73: 0.485935
#
# Train Avg F1   73: 0.770761271249076
#
# Val Avg Loss   73: 0.268982
#
# Val Avg F1   73:  0.6950354609929077
#
# Optimal Val loss (Epoch 11): 0.24703935533761978
#
# Epoch 74
# --------------------------------------------------------------
# Epoch:   74        1 Batch loss: 0.454417 Batch F1: 0.8108108108108107
# Epoch:   74        2 Batch loss: 0.496129 Batch F1: 0.8444444444444443
# Epoch:   74        3 Batch loss: 0.466283 Batch F1: 0.8372093023255814
# Epoch:   74        4 Batch loss: 0.465866 Batch F1: 0.8181818181818182
# Epoch:   74        5 Batch loss: 0.538900 Batch F1: 0.6
# Train Avg Loss   74: 0.484319
#
# Train Avg F1   74: 0.7821292751525311
#
# Val Avg Loss   74: 0.295886
#
# Val Avg F1   74:  0.6312316715542523
#
# Optimal Val loss (Epoch 11): 0.24703935533761978
#
# Epoch 75
# --------------------------------------------------------------
# Epoch:   75        1 Batch loss: 0.461388 Batch F1: 0.7200000000000001
# Epoch:   75        2 Batch loss: 0.482556 Batch F1: 0.7894736842105262
# Epoch:   75        3 Batch loss: 0.519009 Batch F1: 0.75
# Epoch:   75        4 Batch loss: 0.418477 Batch F1: 0.8484848484848484
# Epoch:   75        5 Batch loss: 0.561797 Batch F1: 0.7450980392156863
# Train Avg Loss   75: 0.488645
#
# Train Avg F1   75: 0.7706113143822122
#
# Val Avg Loss   75: 0.295252
#
# Val Avg F1   75:  0.6236559139784945
#
# Optimal Val loss (Epoch 11): 0.24703935533761978
#
# Epoch 76
# --------------------------------------------------------------
# Epoch:   76        1 Batch loss: 0.412578 Batch F1: 0.8979591836734694
# Epoch:   76        2 Batch loss: 0.417241 Batch F1: 0.761904761904762
# Epoch:   76        3 Batch loss: 0.470223 Batch F1: 0.8
# Epoch:   76        4 Batch loss: 0.557880 Batch F1: 0.6285714285714286
# Epoch:   76        5 Batch loss: 0.556538 Batch F1: 0.6829268292682926
# Train Avg Loss   76: 0.482892
#
# Train Avg F1   76: 0.7542724406835906
#
# Val Avg Loss   76: 0.287983
#
# Val Avg F1   76:  0.6036414565826331
#
# Optimal Val loss (Epoch 11): 0.24703935533761978
#
# Epoch 77
# --------------------------------------------------------------
# Epoch:   77        1 Batch loss: 0.439112 Batch F1: 0.8421052631578948
# Epoch:   77        2 Batch loss: 0.500199 Batch F1: 0.7222222222222222
# Epoch:   77        3 Batch loss: 0.473810 Batch F1: 0.7894736842105262
# Epoch:   77        4 Batch loss: 0.498393 Batch F1: 0.8085106382978724
# Epoch:   77        5 Batch loss: 0.510880 Batch F1: 0.7142857142857143
# Train Avg Loss   77: 0.484479
#
# Train Avg F1   77: 0.775319504434846
#
# Val Avg Loss   77: 0.302472
#
# Val Avg F1   77:  0.5555555555555556
#
# Optimal Val loss (Epoch 11): 0.24703935533761978
#
# Epoch 78
# --------------------------------------------------------------
# Epoch:   78        1 Batch loss: 0.408990 Batch F1: 0.8571428571428572
# Epoch:   78        2 Batch loss: 0.500695 Batch F1: 0.7096774193548387
# Epoch:   78        3 Batch loss: 0.526991 Batch F1: 0.717948717948718
# Epoch:   78        4 Batch loss: 0.537975 Batch F1: 0.7272727272727272
# Epoch:   78        5 Batch loss: 0.486068 Batch F1: 0.7096774193548387
# Train Avg Loss   78: 0.492144
#
# Train Avg F1   78: 0.7443438282147958
#
# Val Avg Loss   78: 0.269112
#
# Val Avg F1   78:  0.64
#
# Optimal Val loss (Epoch 11): 0.24703935533761978
#
# Epoch 79
# --------------------------------------------------------------
# Epoch:   79        1 Batch loss: 0.476917 Batch F1: 0.8
# Epoch:   79        2 Batch loss: 0.575969 Batch F1: 0.7234042553191491
# Epoch:   79        3 Batch loss: 0.368797 Batch F1: 0.9444444444444444
# Epoch:   79        4 Batch loss: 0.571540 Batch F1: 0.6341463414634148
# Epoch:   79        5 Batch loss: 0.474960 Batch F1: 0.7222222222222223
# Train Avg Loss   79: 0.493637
#
# Train Avg F1   79: 0.7648434526898462
#
# Val Avg Loss   79: 0.298585
#
# Val Avg F1   79:  0.5925039872408293
#
# Optimal Val loss (Epoch 11): 0.24703935533761978
#
# Epoch 80
# --------------------------------------------------------------
# Epoch:   80        1 Batch loss: 0.457260 Batch F1: 0.7741935483870968
# Epoch:   80        2 Batch loss: 0.517099 Batch F1: 0.7727272727272727
# Epoch:   80        3 Batch loss: 0.582593 Batch F1: 0.6976744186046512
# Epoch:   80        4 Batch loss: 0.497135 Batch F1: 0.6875
# Epoch:   80        5 Batch loss: 0.483955 Batch F1: 0.6666666666666667
# Train Avg Loss   80: 0.507609
#
# Train Avg F1   80: 0.7197523812771374
#
# Val Avg Loss   80: 0.302843
#
# Val Avg F1   80:  0.5253411306042886
#
# Optimal Val loss (Epoch 11): 0.24703935533761978
#
# Epoch 81
# --------------------------------------------------------------
# Epoch:   81        1 Batch loss: 0.427687 Batch F1: 0.8125000000000001
# Epoch:   81        2 Batch loss: 0.477033 Batch F1: 0.7894736842105262
# Epoch:   81        3 Batch loss: 0.595926 Batch F1: 0.6341463414634146
# Epoch:   81        4 Batch loss: 0.438306 Batch F1: 0.8125000000000001
# Epoch:   81        5 Batch loss: 0.484000 Batch F1: 0.7727272727272727
# Train Avg Loss   81: 0.484590
#
# Train Avg F1   81: 0.7642694596802426
#
# Val Avg Loss   81: 0.280083
#
# Val Avg F1   81:  0.6760869565217391
#
# Optimal Val loss (Epoch 11): 0.24703935533761978
#
# Epoch 82
# --------------------------------------------------------------
# Epoch:   82        1 Batch loss: 0.503390 Batch F1: 0.7906976744186046
# Epoch:   82        2 Batch loss: 0.464162 Batch F1: 0.7567567567567567
# Epoch:   82        3 Batch loss: 0.509149 Batch F1: 0.7368421052631579
# Epoch:   82        4 Batch loss: 0.513428 Batch F1: 0.7555555555555556
# Epoch:   82        5 Batch loss: 0.446820 Batch F1: 0.8500000000000001
# Train Avg Loss   82: 0.487390
#
# Train Avg F1   82: 0.777970418398815
#
# Val Avg Loss   82: 0.277978
#
# Val Avg F1   82:  0.6364329268292683
#
# Optimal Val loss (Epoch 11): 0.24703935533761978
#
# Epoch 83
# --------------------------------------------------------------
# Epoch:   83        1 Batch loss: 0.454409 Batch F1: 0.8108108108108109
# Epoch:   83        2 Batch loss: 0.466679 Batch F1: 0.7647058823529412
# Epoch:   83        3 Batch loss: 0.541082 Batch F1: 0.7000000000000001
# Epoch:   83        4 Batch loss: 0.483017 Batch F1: 0.7692307692307692
# Epoch:   83        5 Batch loss: 0.457689 Batch F1: 0.7777777777777778
# Train Avg Loss   83: 0.480575
#
# Train Avg F1   83: 0.7645050480344598
#
# Val Avg Loss   83: 0.277181
#
# Val Avg F1   83:  0.6102941176470588
#
# Optimal Val loss (Epoch 11): 0.24703935533761978
#
# Epoch 84
# --------------------------------------------------------------
# Epoch:   84        1 Batch loss: 0.476464 Batch F1: 0.75
# Epoch:   84        2 Batch loss: 0.472635 Batch F1: 0.7894736842105262
# Epoch:   84        3 Batch loss: 0.422045 Batch F1: 0.8421052631578947
# Epoch:   84        4 Batch loss: 0.535804 Batch F1: 0.5925925925925926
# Epoch:   84        5 Batch loss: 0.516635 Batch F1: 0.7755102040816326
# Train Avg Loss   84: 0.484716
#
# Train Avg F1   84: 0.7499363488085292
#
# Val Avg Loss   84: 0.299686
#
# Val Avg F1   84:  0.5593495934959349
#
# Optimal Val loss (Epoch 11): 0.24703935533761978
#
# Epoch 85
# --------------------------------------------------------------
# Epoch:   85        1 Batch loss: 0.471772 Batch F1: 0.7142857142857143
# Epoch:   85        2 Batch loss: 0.484742 Batch F1: 0.7777777777777777
# Epoch:   85        3 Batch loss: 0.429449 Batch F1: 0.8421052631578948
# Epoch:   85        4 Batch loss: 0.546735 Batch F1: 0.7857142857142857
# Epoch:   85        5 Batch loss: 0.498669 Batch F1: 0.782608695652174
# Train Avg Loss   85: 0.486274
#
# Train Avg F1   85: 0.7804983473175693
#
# Val Avg Loss   85: 0.279535
#
# Val Avg F1   85:  0.5789909015715466
#
# Optimal Val loss (Epoch 11): 0.24703935533761978
#
# Epoch 86
# --------------------------------------------------------------
# Epoch:   86        1 Batch loss: 0.530100 Batch F1: 0.717948717948718
# Epoch:   86        2 Batch loss: 0.486088 Batch F1: 0.7567567567567567
# Epoch:   86        3 Batch loss: 0.507114 Batch F1: 0.7058823529411765
# Epoch:   86        4 Batch loss: 0.410820 Batch F1: 0.8275862068965517
# Epoch:   86        5 Batch loss: 0.501245 Batch F1: 0.7826086956521738
# Train Avg Loss   86: 0.487073
#
# Train Avg F1   86: 0.7581565460390753
#
# Val Avg Loss   86: 0.278126
#
# Val Avg F1   86:  0.6469387755102041
#
# Optimal Val loss (Epoch 11): 0.24703935533761978
#
# Epoch 87
# --------------------------------------------------------------
# Epoch:   87        1 Batch loss: 0.409726 Batch F1: 0.823529411764706
# Epoch:   87        2 Batch loss: 0.502163 Batch F1: 0.7222222222222222
# Epoch:   87        3 Batch loss: 0.409450 Batch F1: 0.888888888888889
# Epoch:   87        4 Batch loss: 0.553957 Batch F1: 0.5806451612903226
# Epoch:   87        5 Batch loss: 0.539291 Batch F1: 0.7659574468085107
# Train Avg Loss   87: 0.482917
#
# Train Avg F1   87: 0.7562486261949302
#
# Val Avg Loss   87: 0.310634
#
# Val Avg F1   87:  0.5727272727272728
#
# Optimal Val loss (Epoch 11): 0.24703935533761978
#
# Epoch 88
# --------------------------------------------------------------
# Epoch:   88        1 Batch loss: 0.455410 Batch F1: 0.7777777777777777
# Epoch:   88        2 Batch loss: 0.546616 Batch F1: 0.6842105263157896
# Epoch:   88        3 Batch loss: 0.549917 Batch F1: 0.7391304347826088
# Epoch:   88        4 Batch loss: 0.441897 Batch F1: 0.8108108108108109
# Epoch:   88        5 Batch loss: 0.441037 Batch F1: 0.8235294117647058
# Train Avg Loss   88: 0.486975
#
# Train Avg F1   88: 0.7670917922903385
#
# Val Avg Loss   88: 0.269283
#
# Val Avg F1   88:  0.6392045454545454
#
# Optimal Val loss (Epoch 11): 0.24703935533761978
#
# Epoch 89
# --------------------------------------------------------------
# Epoch:   89        1 Batch loss: 0.458608 Batch F1: 0.8095238095238095
# Epoch:   89        2 Batch loss: 0.498989 Batch F1: 0.7222222222222223
# Epoch:   89        3 Batch loss: 0.522413 Batch F1: 0.717948717948718
# Epoch:   89        4 Batch loss: 0.468258 Batch F1: 0.7741935483870968
# Epoch:   89        5 Batch loss: 0.468252 Batch F1: 0.7692307692307692
# Train Avg Loss   89: 0.483304
#
# Train Avg F1   89: 0.7586238134625232
#
# Val Avg Loss   89: 0.282700
#
# Val Avg F1   89:  0.5778723404255319
#
# Optimal Val loss (Epoch 11): 0.24703935533761978
#
# Epoch 90
# --------------------------------------------------------------
# Epoch:   90        1 Batch loss: 0.512706 Batch F1: 0.6666666666666667
# Epoch:   90        2 Batch loss: 0.490842 Batch F1: 0.689655172413793
# Epoch:   90        3 Batch loss: 0.441174 Batch F1: 0.7777777777777778
# Epoch:   90        4 Batch loss: 0.487157 Batch F1: 0.7999999999999999
# Epoch:   90        5 Batch loss: 0.495900 Batch F1: 0.8
# Train Avg Loss   90: 0.485556
#
# Train Avg F1   90: 0.7468199233716474
#
# Val Avg Loss   90: 0.319963
#
# Val Avg F1   90:  0.5835913312693499
#
# Optimal Val loss (Epoch 11): 0.24703935533761978
#
# Epoch 91
# --------------------------------------------------------------
# Epoch:   91        1 Batch loss: 0.454241 Batch F1: 0.8
# Epoch:   91        2 Batch loss: 0.450047 Batch F1: 0.7777777777777778
# Epoch:   91        3 Batch loss: 0.514501 Batch F1: 0.7317073170731708
# Epoch:   91        4 Batch loss: 0.530359 Batch F1: 0.5806451612903225
# Epoch:   91        5 Batch loss: 0.493547 Batch F1: 0.8085106382978723
# Train Avg Loss   91: 0.488539
#
# Train Avg F1   91: 0.7397281788878287
#
# Val Avg Loss   91: 0.267158
#
# Val Avg F1   91:  0.6436781609195403
#
# Optimal Val loss (Epoch 11): 0.24703935533761978
#
# Epoch 92
# --------------------------------------------------------------
# Epoch:   92        1 Batch loss: 0.441055 Batch F1: 0.8205128205128205
# Epoch:   92        2 Batch loss: 0.482865 Batch F1: 0.7894736842105263
# Epoch:   92        3 Batch loss: 0.469551 Batch F1: 0.6666666666666667
# Epoch:   92        4 Batch loss: 0.520253 Batch F1: 0.761904761904762
# Epoch:   92        5 Batch loss: 0.545639 Batch F1: 0.7000000000000001
# Train Avg Loss   92: 0.491872
#
# Train Avg F1   92: 0.7477115866589552
#
# Val Avg Loss   92: 0.301503
#
# Val Avg F1   92:  0.6060606060606062
#
# Optimal Val loss (Epoch 11): 0.24703935533761978
#
# Epoch 93
# --------------------------------------------------------------
# Epoch:   93        1 Batch loss: 0.528239 Batch F1: 0.7027027027027025
# Epoch:   93        2 Batch loss: 0.396364 Batch F1: 0.8484848484848484
# Epoch:   93        3 Batch loss: 0.559395 Batch F1: 0.6666666666666667
# Epoch:   93        4 Batch loss: 0.483702 Batch F1: 0.7804878048780488
# Epoch:   93        5 Batch loss: 0.475215 Batch F1: 0.7647058823529411
# Train Avg Loss   93: 0.488583
#
# Train Avg F1   93: 0.7526095810170415
#
# Val Avg Loss   93: 0.286155
#
# Val Avg F1   93:  0.6524822695035462
#
# Optimal Val loss (Epoch 11): 0.24703935533761978
#
# Epoch 94
# --------------------------------------------------------------
# Epoch:   94        1 Batch loss: 0.542224 Batch F1: 0.7555555555555556
# Epoch:   94        2 Batch loss: 0.444433 Batch F1: 0.8780487804878049
# Epoch:   94        3 Batch loss: 0.430419 Batch F1: 0.8695652173913043
# Epoch:   94        4 Batch loss: 0.488014 Batch F1: 0.742857142857143
# Epoch:   94        5 Batch loss: 0.533084 Batch F1: 0.6666666666666667
# Train Avg Loss   94: 0.487635
#
# Train Avg F1   94: 0.782538672591695
#
# Val Avg Loss   94: 0.298838
#
# Val Avg F1   94:  0.6268412438625204
#
# Optimal Val loss (Epoch 11): 0.24703935533761978
#
# Epoch 95
# --------------------------------------------------------------
# Epoch:   95        1 Batch loss: 0.467975 Batch F1: 0.8108108108108109
# Epoch:   95        2 Batch loss: 0.499231 Batch F1: 0.7428571428571429
# Epoch:   95        3 Batch loss: 0.542885 Batch F1: 0.7142857142857143
# Epoch:   95        4 Batch loss: 0.505698 Batch F1: 0.7272727272727272
# Epoch:   95        5 Batch loss: 0.453765 Batch F1: 0.8205128205128205
# Train Avg Loss   95: 0.493911
#
# Train Avg F1   95: 0.7631478431478431
#
# Val Avg Loss   95: 0.307841
#
# Val Avg F1   95:  0.6060606060606061
#
# Optimal Val loss (Epoch 11): 0.24703935533761978
#
# Epoch 96
# --------------------------------------------------------------
# Epoch:   96        1 Batch loss: 0.539509 Batch F1: 0.7142857142857143
# Epoch:   96        2 Batch loss: 0.496492 Batch F1: 0.7692307692307693
# Epoch:   96        3 Batch loss: 0.450517 Batch F1: 0.8292682926829269
# Epoch:   96        4 Batch loss: 0.558143 Batch F1: 0.6818181818181819
# Epoch:   96        5 Batch loss: 0.483597 Batch F1: 0.7692307692307692
# Train Avg Loss   96: 0.505652
#
# Train Avg F1   96: 0.7527667454496723
#
# Val Avg Loss   96: 0.283445
#
# Val Avg F1   96:  0.5975806451612903
#
# Optimal Val loss (Epoch 11): 0.24703935533761978
#
# Epoch 97
# --------------------------------------------------------------
# Epoch:   97        1 Batch loss: 0.517356 Batch F1: 0.7222222222222222
# Epoch:   97        2 Batch loss: 0.511698 Batch F1: 0.6153846153846153
# Epoch:   97        3 Batch loss: 0.547229 Batch F1: 0.6285714285714286
# Epoch:   97        4 Batch loss: 0.562750 Batch F1: 0.6829268292682926
# Epoch:   97        5 Batch loss: 0.438446 Batch F1: 0.8333333333333334
# Train Avg Loss   97: 0.515496
#
# Train Avg F1   97: 0.6964876857559784
#
# Val Avg Loss   97: 0.280348
#
# Val Avg F1   97:  0.6558441558441558
#
# Optimal Val loss (Epoch 11): 0.24703935533761978
#
# Epoch 98
# --------------------------------------------------------------
# Epoch:   98        1 Batch loss: 0.462807 Batch F1: 0.8205128205128205
# Epoch:   98        2 Batch loss: 0.444823 Batch F1: 0.7741935483870968
# Epoch:   98        3 Batch loss: 0.501101 Batch F1: 0.7804878048780487
# Epoch:   98        4 Batch loss: 0.497480 Batch F1: 0.7804878048780488
# Epoch:   98        5 Batch loss: 0.564382 Batch F1: 0.65
# Train Avg Loss   98: 0.494119
#
# Train Avg F1   98: 0.7611363957312028
#
# Val Avg Loss   98: 0.301437
#
# Val Avg F1   98:  0.6277777777777778
#
# Optimal Val loss (Epoch 11): 0.24703935533761978
#
# Epoch 99
# --------------------------------------------------------------
# Epoch:   99        1 Batch loss: 0.479112 Batch F1: 0.8095238095238095
# Epoch:   99        2 Batch loss: 0.501554 Batch F1: 0.7368421052631577
# Epoch:   99        3 Batch loss: 0.437073 Batch F1: 0.8235294117647058
# Epoch:   99        4 Batch loss: 0.434294 Batch F1: 0.8717948717948718
# Epoch:   99        5 Batch loss: 0.600007 Batch F1: 0.5555555555555556
# Train Avg Loss   99: 0.490408
#
# Train Avg F1   99: 0.7594491507804202
#
# Val Avg Loss   99: 0.276562
#
# Val Avg F1   99:  0.6236559139784947
#
# Optimal Val loss (Epoch 11): 0.24703935533761978
#
# Epoch 100
# --------------------------------------------------------------
# Epoch:  100        1 Batch loss: 0.486892 Batch F1: 0.7428571428571429
# Epoch:  100        2 Batch loss: 0.443116 Batch F1: 0.8108108108108109
# Epoch:  100        3 Batch loss: 0.510106 Batch F1: 0.761904761904762
# Epoch:  100        4 Batch loss: 0.492418 Batch F1: 0.7272727272727273
# Epoch:  100        5 Batch loss: 0.524359 Batch F1: 0.7727272727272727
# Train Avg Loss  100: 0.491378
#
# Train Avg F1  100: 0.7631145431145431
#
# Val Avg Loss  100: 0.259411
#
# Val Avg F1  100:  0.7077798861480076
#
# Optimal Val loss (Epoch 11): 0.24703935533761978
#
# Done!

# %%
import json

# %%
results = json.load(open(path_to_res))

# %%
#print('best f1', np.max(results['val_f1']), np.argmax(results['val_f1']))
print('best f1 val', results['val_f1'][np.argmax(results['val_f1'])])
print('corr f1 train', results['train_f1'][np.argmax(results['val_f1'])])
print('corr f1 test', results['test_f1'][np.argmax(results['val_f1'])])
#print('best f1 train', np.max(results['train_f1']), np.argmax(results['train_f1']))
# Out:
# best f1 val 0.7408435072142064
# corr f1 train 0.6562183695824249
# corr f1 test 0.5735785953177257

# %%
import matplotlib.pyplot as plt

# %%
plt.title('F1 score plot 5% RE threshold')
plt.ylabel('F1')
plt.xlabel('Epochs')
plt.plot(results['train_f1'],'-g', label='Train F1')
plt.plot(results['val_f1'],'-b', label='Val F1')
plt.legend(loc='upper left')
plt.ylim([0.0,1.0])
# Out:
# (0.0, 1.0)

# %%
list(results.keys())
# Out:
# ['train_loss',
#  'val_loss',
#  'test_loss',
#  'train_f1',
#  'val_f1',
#  'test_f1',
#  'train_prec',
#  'val_prec',
#  'test_prec',
#  'train_recall',
#  'val_recall',
#  'test_recall']

# %%
plt.title('Precision score plot 5% RE threshold')
plt.ylabel('Precision')
plt.xlabel('Epochs')
plt.plot(results['train_prec'],'-g', label='Train Precision')
plt.plot(results['val_prec'],'-b', label='Val Precision')
plt.legend(loc='upper left')
plt.ylim([0.0,1.0])
# Out:
# (0.0, 1.0)

# %%
plt.title('Recall score plot 5% RE threshold')
plt.ylabel('Recall')
plt.xlabel('Epochs')
plt.plot(results['train_recall'],'-g', label='Train Recall')
plt.plot(results['val_recall'],'-b', label='Val Recall')
plt.legend(loc='upper left')
plt.ylim([0.0,1.0])
# Out:
# (0.0, 1.0)

# %%
import torch
model = torch.load(best_model_path)
model.eval()
model
# Out:
# Classifier(
#   (conv1): RelGraphConv(
#     (linear_r): TypedLinear(in_size=113, out_size=32, num_types=8)
#     (dropout): Dropout(p=0.0, inplace=False)
#   )
#   (conv2): RelGraphConv(
#     (linear_r): TypedLinear(in_size=32, out_size=32, num_types=8)
#     (dropout): Dropout(p=0.0, inplace=False)
#   )
#   (classify): Linear(in_features=32, out_features=2, bias=True)
# )

# %%
from dgl_classifier. trainer import predict2samples
print(train_file)
train_data, val_data,test_data = predict2samples(model,train_file, val_file, test_file, community_no=10, verbose=True, clust_verbose=False, clust_load_path='/work/data/confs/May2/pred_clust.json')
# Out:
# /work/data/splits/splits_0.05/train.json

# %%
for k in train_data.keys():
    print(train_data[k])
    break
# Out:
# {'bloom_runtime': 0.087360461, 'jena_runtime': 0.084558884, 'gt': False, 'bgp_construction_duration': 7.319450378417969e-05, 'tps_const_duration': 0.0002605915069580078, 'prediction': 1, 'inference_time': 0.010159730911254883}

# %%
from dgl_classifier.post import *
train_rt, avg_train = avg_runtime(train_data)
_,_, avg_train_jena,avg_train_blf = avg_runtime_type(train_data)
val_rt, avg_val = avg_runtime(val_data)
_,_, avg_val_jena,avg_val_blf = avg_runtime_type(val_data)
test_rt, avg_test = avg_runtime(test_data)
_,_, avg_test_jena,avg_test_blf = avg_runtime_type(test_data)

# %%
print('Train\n','\tWith Predictions ',round(avg_train,3),', Jena: ', round(avg_train_jena,3), ', Bloom Filter',round(avg_train_blf,3))
print('Validation\n','\tWith Predictions ',round(avg_val,3),', Jena: ', round(avg_val_jena,3), ', Bloom Filter',round(avg_val_blf,3))
print('Test\n','\tWith Predictions ',round(avg_test,3),', Jena: ', round(avg_test_jena,3), ', Bloom Filter',round(avg_test_blf,3))
#print(avg_val,avg_val_jena,avg_val_blf)
#print(avg_test,avg_test_jena,avg_test_blf)
# Out:
# Train
#  	With Predictions  3.29 , Jena:  3.76 , Bloom Filter 4.543
# Validation
#  	With Predictions  5.973 , Jena:  6.664 , Bloom Filter 7.355
# Test
#  	With Predictions  3.847 , Jena:  4.401 , Bloom Filter 5.024

# %% [markdown]
# Relative difference in average time

# %%
print(f'Train: relative difference : {round(((avg_train_jena-avg_train)/avg_train_jena)*100,2)}')
print(f'Val: relative difference : {round(((avg_val_jena-avg_val)/avg_val_jena)*100,2)}')
print(f'Test: relative difference : {round(((avg_test_jena-avg_test)/avg_test_jena)*100,2)}')
# Out:
# Train: relative difference : 12.48
# Val: relative difference : 10.38
# Test: relative difference : 12.59
