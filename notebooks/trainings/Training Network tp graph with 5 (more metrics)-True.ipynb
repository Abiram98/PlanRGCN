# %% [markdown]
# file paths

# %%
train_file = '/work/data/splits/splits_0.05/train.json'
val_file = '/work/data/splits/splits_0.05/val.json'
test_file = '/work/data/splits/splits_0.05/test.json'
import os

path_to_save = '/work/data/models2_6'
os.system(f'mkdir -p {path_to_save}')
path_to_res = '/work/data/results/2_6_2023_tp_graph_5re.txt'

# %% [markdown]
# import

# %%
# %load_ext autoreload
# %autoreload 2
import json
import dgl
from sklearn.metrics import f1_score
import torch as th
import dgl.nn.pytorch as dglnn
import torch.nn as nn
from dgl.dataloading import GraphDataLoader
import torch.nn.functional as F
import networkx as nx
import warnings
from feature_extraction.base_featurizer import BaseFeaturizer
import torch
from graph_construction.tps_graph import create_dummy_dgl_graph, tps_graph
import numpy as np

from dgl_classifier.trainer import GraphDataset,snap_pred, tps_to_dgl, get_clasification_vec,\
tps_graph_const, extract_data, runner


import warnings

from preprocessing.utils import load_BGPS_from_json
warnings.filterwarnings('ignore', category=UserWarning, message='TypedStorage is deprecated')

# %%
#seed
dgl.seed(1223)

# %% [markdown]
# Model

# %%
class Classifier(nn.Module):
    def __init__(self, in_dim, hidden_dim, n_classes):
        super(Classifier, self).__init__()
        self.conv1 = dglnn.RelGraphConv(in_dim, hidden_dim, 8)
        #self.conv1 = dglnn.GraphConv(in_dim, hidden_ˇdim)
        self.conv2 = dglnn.RelGraphConv(hidden_dim, hidden_dim, 8)
        #self.conv2 = dglnn.GraphConv(hidden_dim, hidden_dim)
        self.classify = nn.Linear(hidden_dim, n_classes)

    def forward(self, g, h, rel_types):
        # Apply graph convolution and activation.
        h = F.relu(self.conv1(g, h, rel_types))
        h = F.relu(self.conv2(g, h, rel_types))
        with g.local_scope():
            g.ndata['node_features'] = h
            # Calculate graph representation by average readout.
            hg = dgl.mean_nodes(g, 'node_features')
            return F.softmax( self.classify(hg), dim=1)
model = Classifier(113, 20, 2)

# %% [markdown]
# hyperparameters

# %%
early_stop =100
model = Classifier(113, 32, 2)
lr = 0.01
wd = 5e-4
epochs = 100

# %%
train_dataloader, val_dataloader, test_dataloader = extract_data(train_file, val_file, test_file, community_no=30, batch_size = 50, verbose=True)
# Out:
# /usr/local/lib/python3.10/dist-packages/dgl/backend/pytorch/tensor.py:52: UserWarning: Creating a tensor from a list of numpy.ndarrays is extremely slow. Please consider converting the list to a single numpy.ndarray with numpy.array() before converting to a tensor. (Triggered internally at ../torch/csrc/utils/tensor_new.cpp:245.)
#   return th.as_tensor(data, dtype=dtype)
# # of catesian products: 36
# # of catesian products: 10
# # of catesian products: 13
# # of predicate feats not in validation 47
# # of predicate feats not in test 7
# Training dataset size 250
# Validation dataset size 86
# Test dataset size 83

# %%
best_model_path = runner(train_dataloader,val_dataloader,test_dataloader,model, early_stop, lr, wd, epochs, path_to_res, path_to_save=path_to_save)
# Out:
# Epoch 1
# --------------------------------------------------------------
# Epoch:    1        1 Batch loss: 0.828641 Batch F1: 0.5294117647058824
# Epoch:    1        2 Batch loss: 0.685826 Batch F1: 0.16666666666666666
# Epoch:    1        3 Batch loss: 0.671124 Batch F1: 0.0
# Epoch:    1        4 Batch loss: 0.660712 Batch F1: 0.0
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Epoch:    1        5 Batch loss: 0.648469 Batch F1: 0.3448275862068966
# Train Avg Loss    1: 0.698955
#
# Train Avg F1    1: 0.20818120351588912
#
# Val Avg Loss    1: 0.250675
#
# Val Avg F1    1:  0.6089417091114884
#
# Optimal Val loss (Epoch 1): 0.2506752386689186
#
# Epoch 2
# --------------------------------------------------------------
# Epoch:    2        1 Batch loss: 0.634208 Batch F1: 0.7391304347826089
# Epoch:    2        2 Batch loss: 0.667082 Batch F1: 0.5714285714285713
# Epoch:    2        3 Batch loss: 0.590475 Batch F1: 0.6666666666666667
# Epoch:    2        4 Batch loss: 0.659385 Batch F1: 0.4827586206896552
# Epoch:    2        5 Batch loss: 0.567330 Batch F1: 0.5384615384615385
# Train Avg Loss    2: 0.623696
#
# Train Avg F1    2: 0.5996891664058082
#
# Val Avg Loss    2: 0.312101
#
# Val Avg F1    2:  0.2721804511278195
#
# Optimal Val loss (Epoch 1): 0.2506752386689186
#
# Epoch 3
# --------------------------------------------------------------
# Epoch:    3        1 Batch loss: 0.584110 Batch F1: 0.4
# Epoch:    3        2 Batch loss: 0.638670 Batch F1: 0.4666666666666667
# Epoch:    3        3 Batch loss: 0.607508 Batch F1: 0.6222222222222222
# Epoch:    3        4 Batch loss: 0.641991 Batch F1: 0.6046511627906976
# Epoch:    3        5 Batch loss: 0.505954 Batch F1: 0.8333333333333333
# Train Avg Loss    3: 0.595647
#
# Train Avg F1    3: 0.5853746770025839
#
# Val Avg Loss    3: 0.275510
#
# Val Avg F1    3:  0.5517970401691332
#
# Optimal Val loss (Epoch 1): 0.2506752386689186
#
# Epoch 4
# --------------------------------------------------------------
# Epoch:    4        1 Batch loss: 0.562973 Batch F1: 0.6285714285714286
# Epoch:    4        2 Batch loss: 0.562568 Batch F1: 0.7027027027027029
# Epoch:    4        3 Batch loss: 0.549842 Batch F1: 0.5945945945945946
# Epoch:    4        4 Batch loss: 0.597026 Batch F1: 0.6956521739130435
# Epoch:    4        5 Batch loss: 0.672975 Batch F1: 0.4615384615384615
# Train Avg Loss    4: 0.589077
#
# Train Avg F1    4: 0.6166118722640462
#
# Val Avg Loss    4: 0.239355
#
# Val Avg F1    4:  0.7339393939393939
#
# Optimal Val loss (Epoch 4): 0.23935460299253464
#
# Epoch 5
# --------------------------------------------------------------
# Epoch:    5        1 Batch loss: 0.530375 Batch F1: 0.7333333333333334
# Epoch:    5        2 Batch loss: 0.662984 Batch F1: 0.3448275862068966
# Epoch:    5        3 Batch loss: 0.598478 Batch F1: 0.3636363636363636
# Epoch:    5        4 Batch loss: 0.647924 Batch F1: 0.29629629629629634
# Epoch:    5        5 Batch loss: 0.612224 Batch F1: 0.6153846153846153
# Train Avg Loss    5: 0.610397
#
# Train Avg F1    5: 0.470695638971501
#
# Val Avg Loss    5: 0.271800
#
# Val Avg F1    5:  0.5250447227191413
#
# Optimal Val loss (Epoch 4): 0.23935460299253464
#
# Epoch 6
# --------------------------------------------------------------
# Epoch:    6        1 Batch loss: 0.514163 Batch F1: 0.6666666666666667
# Epoch:    6        2 Batch loss: 0.567825 Batch F1: 0.6666666666666667
# Epoch:    6        3 Batch loss: 0.660520 Batch F1: 0.6046511627906977
# Epoch:    6        4 Batch loss: 0.479717 Batch F1: 0.8085106382978724
# Epoch:    6        5 Batch loss: 0.673276 Batch F1: 0.6296296296296297
# Train Avg Loss    6: 0.579100
#
# Train Avg F1    6: 0.6752249528103067
#
# Val Avg Loss    6: 0.260366
#
# Val Avg F1    6:  0.7302302302302303
#
# Optimal Val loss (Epoch 4): 0.23935460299253464
#
# Epoch 7
# --------------------------------------------------------------
# Epoch:    7        1 Batch loss: 0.539082 Batch F1: 0.7826086956521738
# Epoch:    7        2 Batch loss: 0.559934 Batch F1: 0.7272727272727272
# Epoch:    7        3 Batch loss: 0.569578 Batch F1: 0.6842105263157896
# Epoch:    7        4 Batch loss: 0.548103 Batch F1: 0.4347826086956522
# Epoch:    7        5 Batch loss: 0.551208 Batch F1: 0.625
# Train Avg Loss    7: 0.553581
#
# Train Avg F1    7: 0.6507749115872686
#
# Val Avg Loss    7: 0.336641
#
# Val Avg F1    7:  0.3436692506459948
#
# Optimal Val loss (Epoch 4): 0.23935460299253464
#
# Epoch 8
# --------------------------------------------------------------
# Epoch:    8        1 Batch loss: 0.521573 Batch F1: 0.6451612903225806
# Epoch:    8        2 Batch loss: 0.533481 Batch F1: 0.5806451612903225
# Epoch:    8        3 Batch loss: 0.605152 Batch F1: 0.5
# Epoch:    8        4 Batch loss: 0.555678 Batch F1: 0.631578947368421
# Epoch:    8        5 Batch loss: 0.576162 Batch F1: 0.6938775510204083
# Train Avg Loss    8: 0.558409
#
# Train Avg F1    8: 0.6102525900003466
#
# Val Avg Loss    8: 0.283306
#
# Val Avg F1    8:  0.6857142857142857
#
# Optimal Val loss (Epoch 4): 0.23935460299253464
#
# Epoch 9
# --------------------------------------------------------------
# Epoch:    9        1 Batch loss: 0.533537 Batch F1: 0.7916666666666667
# Epoch:    9        2 Batch loss: 0.562339 Batch F1: 0.723404255319149
# Epoch:    9        3 Batch loss: 0.579062 Batch F1: 0.6666666666666666
# Epoch:    9        4 Batch loss: 0.506234 Batch F1: 0.7027027027027027
# Epoch:    9        5 Batch loss: 0.583786 Batch F1: 0.5
# Train Avg Loss    9: 0.552992
#
# Train Avg F1    9: 0.676888058271037
#
# Val Avg Loss    9: 0.291952
#
# Val Avg F1    9:  0.6375641966250918
#
# Optimal Val loss (Epoch 4): 0.23935460299253464
#
# Epoch 10
# --------------------------------------------------------------
# Epoch:   10        1 Batch loss: 0.545644 Batch F1: 0.56
# Epoch:   10        2 Batch loss: 0.521635 Batch F1: 0.7027027027027027
# Epoch:   10        3 Batch loss: 0.624329 Batch F1: 0.5294117647058824
# Epoch:   10        4 Batch loss: 0.570204 Batch F1: 0.7
# Epoch:   10        5 Batch loss: 0.440305 Batch F1: 0.8648648648648648
# Train Avg Loss   10: 0.540423
#
# Train Avg F1   10: 0.67139586645469
#
# Val Avg Loss   10: 0.262517
#
# Val Avg F1   10:  0.6825396825396826
#
# Optimal Val loss (Epoch 4): 0.23935460299253464
#
# Epoch 11
# --------------------------------------------------------------
# Epoch:   11        1 Batch loss: 0.463680 Batch F1: 0.8333333333333334
# Epoch:   11        2 Batch loss: 0.577507 Batch F1: 0.6842105263157896
# Epoch:   11        3 Batch loss: 0.524594 Batch F1: 0.6470588235294117
# Epoch:   11        4 Batch loss: 0.525085 Batch F1: 0.6857142857142857
# Epoch:   11        5 Batch loss: 0.559311 Batch F1: 0.7346938775510203
# Train Avg Loss   11: 0.530035
#
# Train Avg F1   11: 0.7170021692887681
#
# Val Avg Loss   11: 0.261552
#
# Val Avg F1   11:  0.6547619047619048
#
# Optimal Val loss (Epoch 4): 0.23935460299253464
#
# Epoch 12
# --------------------------------------------------------------
# Epoch:   12        1 Batch loss: 0.459506 Batch F1: 0.7999999999999999
# Epoch:   12        2 Batch loss: 0.501577 Batch F1: 0.7692307692307692
# Epoch:   12        3 Batch loss: 0.529466 Batch F1: 0.6470588235294118
# Epoch:   12        4 Batch loss: 0.544893 Batch F1: 0.6470588235294118
# Epoch:   12        5 Batch loss: 0.633143 Batch F1: 0.5128205128205128
# Train Avg Loss   12: 0.533717
#
# Train Avg F1   12: 0.675233785822021
#
# Val Avg Loss   12: 0.286118
#
# Val Avg F1   12:  0.636231884057971
#
# Optimal Val loss (Epoch 4): 0.23935460299253464
#
# Epoch 13
# --------------------------------------------------------------
# Epoch:   13        1 Batch loss: 0.545306 Batch F1: 0.717948717948718
# Epoch:   13        2 Batch loss: 0.524557 Batch F1: 0.6875000000000001
# Epoch:   13        3 Batch loss: 0.548982 Batch F1: 0.7659574468085107
# Epoch:   13        4 Batch loss: 0.503299 Batch F1: 0.7368421052631579
# Epoch:   13        5 Batch loss: 0.478544 Batch F1: 0.7428571428571428
# Train Avg Loss   13: 0.520137
#
# Train Avg F1   13: 0.730221082575506
#
# Val Avg Loss   13: 0.251481
#
# Val Avg F1   13:  0.7
#
# Optimal Val loss (Epoch 4): 0.23935460299253464
#
# Epoch 14
# --------------------------------------------------------------
# Epoch:   14        1 Batch loss: 0.554332 Batch F1: 0.7027027027027027
# Epoch:   14        2 Batch loss: 0.538529 Batch F1: 0.7317073170731707
# Epoch:   14        3 Batch loss: 0.509863 Batch F1: 0.7692307692307693
# Epoch:   14        4 Batch loss: 0.500511 Batch F1: 0.7567567567567568
# Epoch:   14        5 Batch loss: 0.502931 Batch F1: 0.7272727272727273
# Train Avg Loss   14: 0.521233
#
# Train Avg F1   14: 0.7375340546072253
#
# Val Avg Loss   14: 0.257887
#
# Val Avg F1   14:  0.6598639455782314
#
# Optimal Val loss (Epoch 4): 0.23935460299253464
#
# Epoch 15
# --------------------------------------------------------------
# Epoch:   15        1 Batch loss: 0.500740 Batch F1: 0.742857142857143
# Epoch:   15        2 Batch loss: 0.477863 Batch F1: 0.8292682926829269
# Epoch:   15        3 Batch loss: 0.542892 Batch F1: 0.7
# Epoch:   15        4 Batch loss: 0.546427 Batch F1: 0.7441860465116279
# Epoch:   15        5 Batch loss: 0.470455 Batch F1: 0.7333333333333334
# Train Avg Loss   15: 0.507675
#
# Train Avg F1   15: 0.7499289630770062
#
# Val Avg Loss   15: 0.252124
#
# Val Avg F1   15:  0.7338056680161943
#
# Optimal Val loss (Epoch 4): 0.23935460299253464
#
# Epoch 16
# --------------------------------------------------------------
# Epoch:   16        1 Batch loss: 0.486908 Batch F1: 0.8085106382978724
# Epoch:   16        2 Batch loss: 0.463072 Batch F1: 0.8372093023255814
# Epoch:   16        3 Batch loss: 0.535535 Batch F1: 0.6666666666666666
# Epoch:   16        4 Batch loss: 0.492204 Batch F1: 0.7647058823529411
# Epoch:   16        5 Batch loss: 0.566126 Batch F1: 0.6666666666666667
# Train Avg Loss   16: 0.508769
#
# Train Avg F1   16: 0.7487518312619457
#
# Val Avg Loss   16: 0.269677
#
# Val Avg F1   16:  0.6232114467408585
#
# Optimal Val loss (Epoch 4): 0.23935460299253464
#
# Epoch 17
# --------------------------------------------------------------
# Epoch:   17        1 Batch loss: 0.482644 Batch F1: 0.8181818181818181
# Epoch:   17        2 Batch loss: 0.520366 Batch F1: 0.7272727272727273
# Epoch:   17        3 Batch loss: 0.417798 Batch F1: 0.8636363636363635
# Epoch:   17        4 Batch loss: 0.571941 Batch F1: 0.6956521739130435
# Epoch:   17        5 Batch loss: 0.593953 Batch F1: 0.5517241379310345
# Train Avg Loss   17: 0.517341
#
# Train Avg F1   17: 0.7312934441869974
#
# Val Avg Loss   17: 0.235029
#
# Val Avg F1   17:  0.7526881720430108
#
# Optimal Val loss (Epoch 17): 0.2350292131304741
#
# Epoch 18
# --------------------------------------------------------------
# Epoch:   18        1 Batch loss: 0.445095 Batch F1: 0.8292682926829269
# Epoch:   18        2 Batch loss: 0.488292 Batch F1: 0.7567567567567567
# Epoch:   18        3 Batch loss: 0.517721 Batch F1: 0.7096774193548387
# Epoch:   18        4 Batch loss: 0.505592 Batch F1: 0.7368421052631577
# Epoch:   18        5 Batch loss: 0.571317 Batch F1: 0.6976744186046512
# Train Avg Loss   18: 0.505603
#
# Train Avg F1   18: 0.7460437985324663
#
# Val Avg Loss   18: 0.273280
#
# Val Avg F1   18:  0.541880341880342
#
# Optimal Val loss (Epoch 17): 0.2350292131304741
#
# Epoch 19
# --------------------------------------------------------------
# Epoch:   19        1 Batch loss: 0.480873 Batch F1: 0.8095238095238096
# Epoch:   19        2 Batch loss: 0.565168 Batch F1: 0.65
# Epoch:   19        3 Batch loss: 0.481009 Batch F1: 0.7428571428571428
# Epoch:   19        4 Batch loss: 0.560122 Batch F1: 0.588235294117647
# Epoch:   19        5 Batch loss: 0.425395 Batch F1: 0.8421052631578947
# Train Avg Loss   19: 0.502513
#
# Train Avg F1   19: 0.7265443019312988
#
# Val Avg Loss   19: 0.268635
#
# Val Avg F1   19:  0.6324675324675325
#
# Optimal Val loss (Epoch 17): 0.2350292131304741
#
# Epoch 20
# --------------------------------------------------------------
# Epoch:   20        1 Batch loss: 0.495477 Batch F1: 0.742857142857143
# Epoch:   20        2 Batch loss: 0.449099 Batch F1: 0.8372093023255814
# Epoch:   20        3 Batch loss: 0.404961 Batch F1: 0.9302325581395349
# Epoch:   20        4 Batch loss: 0.584946 Batch F1: 0.6341463414634146
# Epoch:   20        5 Batch loss: 0.557541 Batch F1: 0.6060606060606061
# Train Avg Loss   20: 0.498405
#
# Train Avg F1   20: 0.750101190169256
#
# Val Avg Loss   20: 0.256714
#
# Val Avg F1   20:  0.65
#
# Optimal Val loss (Epoch 17): 0.2350292131304741
#
# Epoch 21
# --------------------------------------------------------------
# Epoch:   21        1 Batch loss: 0.530556 Batch F1: 0.6857142857142857
# Epoch:   21        2 Batch loss: 0.494225 Batch F1: 0.7777777777777778
# Epoch:   21        3 Batch loss: 0.598915 Batch F1: 0.6511627906976744
# Epoch:   21        4 Batch loss: 0.434223 Batch F1: 0.8235294117647058
# Epoch:   21        5 Batch loss: 0.442182 Batch F1: 0.8205128205128205
# Train Avg Loss   21: 0.500020
#
# Train Avg F1   21: 0.7517394172934528
#
# Val Avg Loss   21: 0.256240
#
# Val Avg F1   21:  0.644110275689223
#
# Optimal Val loss (Epoch 17): 0.2350292131304741
#
# Epoch 22
# --------------------------------------------------------------
# Epoch:   22        1 Batch loss: 0.460396 Batch F1: 0.7804878048780488
# Epoch:   22        2 Batch loss: 0.497202 Batch F1: 0.7727272727272727
# Epoch:   22        3 Batch loss: 0.545966 Batch F1: 0.7
# Epoch:   22        4 Batch loss: 0.493631 Batch F1: 0.8235294117647057
# Epoch:   22        5 Batch loss: 0.479882 Batch F1: 0.7407407407407408
# Train Avg Loss   22: 0.495415
#
# Train Avg F1   22: 0.7634970460221535
#
# Val Avg Loss   22: 0.288842
#
# Val Avg F1   22:  0.5948275862068966
#
# Optimal Val loss (Epoch 17): 0.2350292131304741
#
# Epoch 23
# --------------------------------------------------------------
# Epoch:   23        1 Batch loss: 0.508763 Batch F1: 0.6666666666666667
# Epoch:   23        2 Batch loss: 0.561799 Batch F1: 0.6285714285714286
# Epoch:   23        3 Batch loss: 0.509159 Batch F1: 0.742857142857143
# Epoch:   23        4 Batch loss: 0.519927 Batch F1: 0.7906976744186047
# Epoch:   23        5 Batch loss: 0.461560 Batch F1: 0.8333333333333334
# Train Avg Loss   23: 0.512242
#
# Train Avg F1   23: 0.7324252491694353
#
# Val Avg Loss   23: 0.277849
#
# Val Avg F1   23:  0.696969696969697
#
# Optimal Val loss (Epoch 17): 0.2350292131304741
#
# Epoch 24
# --------------------------------------------------------------
# Epoch:   24        1 Batch loss: 0.477106 Batch F1: 0.7804878048780488
# Epoch:   24        2 Batch loss: 0.524712 Batch F1: 0.7391304347826088
# Epoch:   24        3 Batch loss: 0.488519 Batch F1: 0.8260869565217391
# Epoch:   24        4 Batch loss: 0.516805 Batch F1: 0.5833333333333334
# Epoch:   24        5 Batch loss: 0.584393 Batch F1: 0.65
# Train Avg Loss   24: 0.518307
#
# Train Avg F1   24: 0.715807705903146
#
# Val Avg Loss   24: 0.319874
#
# Val Avg F1   24:  0.5779220779220778
#
# Optimal Val loss (Epoch 17): 0.2350292131304741
#
# Epoch 25
# --------------------------------------------------------------
# Epoch:   25        1 Batch loss: 0.532416 Batch F1: 0.7567567567567568
# Epoch:   25        2 Batch loss: 0.554931 Batch F1: 0.7
# Epoch:   25        3 Batch loss: 0.481694 Batch F1: 0.7777777777777778
# Epoch:   25        4 Batch loss: 0.489509 Batch F1: 0.7428571428571428
# Epoch:   25        5 Batch loss: 0.452853 Batch F1: 0.8421052631578947
# Train Avg Loss   25: 0.502281
#
# Train Avg F1   25: 0.7638993881099144
#
# Val Avg Loss   25: 0.290418
#
# Val Avg F1   25:  0.6372613561553655
#
# Optimal Val loss (Epoch 17): 0.2350292131304741
#
# Epoch 26
# --------------------------------------------------------------
# Epoch:   26        1 Batch loss: 0.447522 Batch F1: 0.8372093023255814
# Epoch:   26        2 Batch loss: 0.507360 Batch F1: 0.7368421052631577
# Epoch:   26        3 Batch loss: 0.468834 Batch F1: 0.7878787878787877
# Epoch:   26        4 Batch loss: 0.488916 Batch F1: 0.742857142857143
# Epoch:   26        5 Batch loss: 0.582295 Batch F1: 0.6153846153846153
# Train Avg Loss   26: 0.498985
#
# Train Avg F1   26: 0.744034390741857
#
# Val Avg Loss   26: 0.293514
#
# Val Avg F1   26:  0.5996847911741529
#
# Optimal Val loss (Epoch 17): 0.2350292131304741
#
# Epoch 27
# --------------------------------------------------------------
# Epoch:   27        1 Batch loss: 0.581712 Batch F1: 0.6829268292682927
# Epoch:   27        2 Batch loss: 0.491536 Batch F1: 0.7272727272727272
# Epoch:   27        3 Batch loss: 0.467811 Batch F1: 0.7500000000000001
# Epoch:   27        4 Batch loss: 0.445951 Batch F1: 0.8936170212765957
# Epoch:   27        5 Batch loss: 0.504593 Batch F1: 0.761904761904762
# Train Avg Loss   27: 0.498321
#
# Train Avg F1   27: 0.7631442679444754
#
# Val Avg Loss   27: 0.283984
#
# Val Avg F1   27:  0.6615087040618954
#
# Optimal Val loss (Epoch 17): 0.2350292131304741
#
# Epoch 28
# --------------------------------------------------------------
# Epoch:   28        1 Batch loss: 0.434246 Batch F1: 0.888888888888889
# Epoch:   28        2 Batch loss: 0.395975 Batch F1: 0.8749999999999999
# Epoch:   28        3 Batch loss: 0.539014 Batch F1: 0.6829268292682927
# Epoch:   28        4 Batch loss: 0.539184 Batch F1: 0.56
# Epoch:   28        5 Batch loss: 0.558714 Batch F1: 0.7272727272727274
# Train Avg Loss   28: 0.493427
#
# Train Avg F1   28: 0.7468176890859819
#
# Val Avg Loss   28: 0.298122
#
# Val Avg F1   28:  0.6190476190476191
#
# Optimal Val loss (Epoch 17): 0.2350292131304741
#
# Epoch 29
# --------------------------------------------------------------
# Epoch:   29        1 Batch loss: 0.517158 Batch F1: 0.7058823529411764
# Epoch:   29        2 Batch loss: 0.442763 Batch F1: 0.8636363636363636
# Epoch:   29        3 Batch loss: 0.448139 Batch F1: 0.7741935483870969
# Epoch:   29        4 Batch loss: 0.482877 Batch F1: 0.7692307692307693
# Epoch:   29        5 Batch loss: 0.582544 Batch F1: 0.611111111111111
# Train Avg Loss   29: 0.494696
#
# Train Avg F1   29: 0.7448108290613035
#
# Val Avg Loss   29: 0.268399
#
# Val Avg F1   29:  0.6369047619047619
#
# Optimal Val loss (Epoch 17): 0.2350292131304741
#
# Epoch 30
# --------------------------------------------------------------
# Epoch:   30        1 Batch loss: 0.511830 Batch F1: 0.717948717948718
# Epoch:   30        2 Batch loss: 0.547684 Batch F1: 0.6666666666666666
# Epoch:   30        3 Batch loss: 0.524000 Batch F1: 0.6875
# Epoch:   30        4 Batch loss: 0.436506 Batch F1: 0.888888888888889
# Epoch:   30        5 Batch loss: 0.440798 Batch F1: 0.8125000000000001
# Train Avg Loss   30: 0.492164
#
# Train Avg F1   30: 0.7547008547008547
#
# Val Avg Loss   30: 0.284734
#
# Val Avg F1   30:  0.6428571428571428
#
# Optimal Val loss (Epoch 17): 0.2350292131304741
#
# Epoch 31
# --------------------------------------------------------------
# Epoch:   31        1 Batch loss: 0.538271 Batch F1: 0.7346938775510203
# Epoch:   31        2 Batch loss: 0.493379 Batch F1: 0.7272727272727272
# Epoch:   31        3 Batch loss: 0.472178 Batch F1: 0.7499999999999999
# Epoch:   31        4 Batch loss: 0.472012 Batch F1: 0.7272727272727273
# Epoch:   31        5 Batch loss: 0.472697 Batch F1: 0.8095238095238096
# Train Avg Loss   31: 0.489707
#
# Train Avg F1   31: 0.7497526283240569
#
# Val Avg Loss   31: 0.279588
#
# Val Avg F1   31:  0.6153846153846154
#
# Optimal Val loss (Epoch 17): 0.2350292131304741
#
# Epoch 32
# --------------------------------------------------------------
# Epoch:   32        1 Batch loss: 0.510346 Batch F1: 0.7368421052631579
# Epoch:   32        2 Batch loss: 0.433472 Batch F1: 0.8421052631578947
# Epoch:   32        3 Batch loss: 0.448735 Batch F1: 0.8260869565217392
# Epoch:   32        4 Batch loss: 0.519299 Batch F1: 0.6857142857142857
# Epoch:   32        5 Batch loss: 0.533639 Batch F1: 0.6829268292682927
# Train Avg Loss   32: 0.489098
#
# Train Avg F1   32: 0.754735087985074
#
# Val Avg Loss   32: 0.286382
#
# Val Avg F1   32:  0.6159039759939986
#
# Optimal Val loss (Epoch 17): 0.2350292131304741
#
# Epoch 33
# --------------------------------------------------------------
# Epoch:   33        1 Batch loss: 0.509818 Batch F1: 0.75
# Epoch:   33        2 Batch loss: 0.526168 Batch F1: 0.7659574468085106
# Epoch:   33        3 Batch loss: 0.497147 Batch F1: 0.7058823529411764
# Epoch:   33        4 Batch loss: 0.468913 Batch F1: 0.8108108108108109
# Epoch:   33        5 Batch loss: 0.439444 Batch F1: 0.75
# Train Avg Loss   33: 0.488298
#
# Train Avg F1   33: 0.7565301221120996
#
# Val Avg Loss   33: 0.292174
#
# Val Avg F1   33:  0.6439393939393939
#
# Optimal Val loss (Epoch 17): 0.2350292131304741
#
# Epoch 34
# --------------------------------------------------------------
# Epoch:   34        1 Batch loss: 0.511875 Batch F1: 0.6153846153846154
# Epoch:   34        2 Batch loss: 0.469052 Batch F1: 0.8095238095238095
# Epoch:   34        3 Batch loss: 0.480548 Batch F1: 0.8292682926829269
# Epoch:   34        4 Batch loss: 0.473973 Batch F1: 0.8333333333333334
# Epoch:   34        5 Batch loss: 0.497583 Batch F1: 0.7368421052631577
# Train Avg Loss   34: 0.486606
#
# Train Avg F1   34: 0.7648704312375687
#
# Val Avg Loss   34: 0.278941
#
# Val Avg F1   34:  0.6372679045092837
#
# Optimal Val loss (Epoch 17): 0.2350292131304741
#
# Epoch 35
# --------------------------------------------------------------
# Epoch:   35        1 Batch loss: 0.470400 Batch F1: 0.7096774193548386
# Epoch:   35        2 Batch loss: 0.515856 Batch F1: 0.7727272727272727
# Epoch:   35        3 Batch loss: 0.387583 Batch F1: 0.9268292682926829
# Epoch:   35        4 Batch loss: 0.527943 Batch F1: 0.744186046511628
# Epoch:   35        5 Batch loss: 0.537499 Batch F1: 0.6470588235294118
# Train Avg Loss   35: 0.487856
#
# Train Avg F1   35: 0.7600957660831668
#
# Val Avg Loss   35: 0.276261
#
# Val Avg F1   35:  0.5742753623188406
#
# Optimal Val loss (Epoch 17): 0.2350292131304741
#
# Epoch 36
# --------------------------------------------------------------
# Epoch:   36        1 Batch loss: 0.432010 Batch F1: 0.8148148148148148
# Epoch:   36        2 Batch loss: 0.454725 Batch F1: 0.8108108108108109
# Epoch:   36        3 Batch loss: 0.485099 Batch F1: 0.7428571428571429
# Epoch:   36        4 Batch loss: 0.558879 Batch F1: 0.7391304347826088
# Epoch:   36        5 Batch loss: 0.538797 Batch F1: 0.7368421052631579
# Train Avg Loss   36: 0.493902
#
# Train Avg F1   36: 0.768891061705707
#
# Val Avg Loss   36: 0.252444
#
# Val Avg F1   36:  0.7051282051282052
#
# Optimal Val loss (Epoch 17): 0.2350292131304741
#
# Epoch 37
# --------------------------------------------------------------
# Epoch:   37        1 Batch loss: 0.513853 Batch F1: 0.7499999999999999
# Epoch:   37        2 Batch loss: 0.499547 Batch F1: 0.7804878048780488
# Epoch:   37        3 Batch loss: 0.445671 Batch F1: 0.85
# Epoch:   37        4 Batch loss: 0.569273 Batch F1: 0.631578947368421
# Epoch:   37        5 Batch loss: 0.435154 Batch F1: 0.8
# Train Avg Loss   37: 0.492700
#
# Train Avg F1   37: 0.7624133504492938
#
# Val Avg Loss   37: 0.301076
#
# Val Avg F1   37:  0.5827702702702702
#
# Optimal Val loss (Epoch 17): 0.2350292131304741
#
# Epoch 38
# --------------------------------------------------------------
# Epoch:   38        1 Batch loss: 0.507739 Batch F1: 0.6896551724137931
# Epoch:   38        2 Batch loss: 0.500038 Batch F1: 0.7567567567567568
# Epoch:   38        3 Batch loss: 0.481712 Batch F1: 0.7692307692307693
# Epoch:   38        4 Batch loss: 0.466151 Batch F1: 0.8
# Epoch:   38        5 Batch loss: 0.516947 Batch F1: 0.7027027027027029
# Train Avg Loss   38: 0.494517
#
# Train Avg F1   38: 0.7436690802208045
#
# Val Avg Loss   38: 0.291956
#
# Val Avg F1   38:  0.6196660482374767
#
# Optimal Val loss (Epoch 17): 0.2350292131304741
#
# Epoch 39
# --------------------------------------------------------------
# Epoch:   39        1 Batch loss: 0.529297 Batch F1: 0.7727272727272727
# Epoch:   39        2 Batch loss: 0.521532 Batch F1: 0.6857142857142857
# Epoch:   39        3 Batch loss: 0.467696 Batch F1: 0.787878787878788
# Epoch:   39        4 Batch loss: 0.454346 Batch F1: 0.7777777777777777
# Epoch:   39        5 Batch loss: 0.522668 Batch F1: 0.744186046511628
# Train Avg Loss   39: 0.499108
#
# Train Avg F1   39: 0.7536568341219504
#
# Val Avg Loss   39: 0.272324
#
# Val Avg F1   39:  0.6287878787878787
#
# Optimal Val loss (Epoch 17): 0.2350292131304741
#
# Epoch 40
# --------------------------------------------------------------
# Epoch:   40        1 Batch loss: 0.459757 Batch F1: 0.7333333333333334
# Epoch:   40        2 Batch loss: 0.403815 Batch F1: 0.8823529411764706
# Epoch:   40        3 Batch loss: 0.501307 Batch F1: 0.7222222222222223
# Epoch:   40        4 Batch loss: 0.587194 Batch F1: 0.7083333333333333
# Epoch:   40        5 Batch loss: 0.509117 Batch F1: 0.782608695652174
# Train Avg Loss   40: 0.492238
#
# Train Avg F1   40: 0.7657701051435067
#
# Val Avg Loss   40: 0.272090
#
# Val Avg F1   40:  0.7047930283224402
#
# Optimal Val loss (Epoch 17): 0.2350292131304741
#
# Epoch 41
# --------------------------------------------------------------
# Epoch:   41        1 Batch loss: 0.468420 Batch F1: 0.8181818181818182
# Epoch:   41        2 Batch loss: 0.524443 Batch F1: 0.7222222222222222
# Epoch:   41        3 Batch loss: 0.511046 Batch F1: 0.7500000000000001
# Epoch:   41        4 Batch loss: 0.540202 Batch F1: 0.6666666666666665
# Epoch:   41        5 Batch loss: 0.416446 Batch F1: 0.9130434782608696
# Train Avg Loss   41: 0.492112
#
# Train Avg F1   41: 0.7740228370663154
#
# Val Avg Loss   41: 0.317367
#
# Val Avg F1   41:  0.55
#
# Optimal Val loss (Epoch 17): 0.2350292131304741
#
# Epoch 42
# --------------------------------------------------------------
# Epoch:   42        1 Batch loss: 0.531117 Batch F1: 0.5384615384615384
# Epoch:   42        2 Batch loss: 0.502630 Batch F1: 0.7428571428571429
# Epoch:   42        3 Batch loss: 0.443564 Batch F1: 0.8372093023255814
# Epoch:   42        4 Batch loss: 0.559729 Batch F1: 0.6666666666666667
# Epoch:   42        5 Batch loss: 0.427477 Batch F1: 0.8717948717948718
# Train Avg Loss   42: 0.492903
#
# Train Avg F1   42: 0.7313979044211603
#
# Val Avg Loss   42: 0.269768
#
# Val Avg F1   42:  0.6339285714285714
#
# Optimal Val loss (Epoch 17): 0.2350292131304741
#
# Epoch 43
# --------------------------------------------------------------
# Epoch:   43        1 Batch loss: 0.510732 Batch F1: 0.6153846153846154
# Epoch:   43        2 Batch loss: 0.487915 Batch F1: 0.7692307692307692
# Epoch:   43        3 Batch loss: 0.469614 Batch F1: 0.7999999999999999
# Epoch:   43        4 Batch loss: 0.488173 Batch F1: 0.742857142857143
# Epoch:   43        5 Batch loss: 0.500948 Batch F1: 0.8085106382978723
# Train Avg Loss   43: 0.491477
#
# Train Avg F1   43: 0.7471966331540799
#
# Val Avg Loss   43: 0.283855
#
# Val Avg F1   43:  0.6162123385939742
#
# Optimal Val loss (Epoch 17): 0.2350292131304741
#
# Epoch 44
# --------------------------------------------------------------
# Epoch:   44        1 Batch loss: 0.515885 Batch F1: 0.6206896551724138
# Epoch:   44        2 Batch loss: 0.471001 Batch F1: 0.8444444444444444
# Epoch:   44        3 Batch loss: 0.506641 Batch F1: 0.75
# Epoch:   44        4 Batch loss: 0.482024 Batch F1: 0.8181818181818182
# Epoch:   44        5 Batch loss: 0.460900 Batch F1: 0.8000000000000002
# Train Avg Loss   44: 0.487290
#
# Train Avg F1   44: 0.7666631835597354
#
# Val Avg Loss   44: 0.269120
#
# Val Avg F1   44:  0.6491112574061882
#
# Optimal Val loss (Epoch 17): 0.2350292131304741
#
# Epoch 45
# --------------------------------------------------------------
# Epoch:   45        1 Batch loss: 0.392388 Batch F1: 0.8888888888888888
# Epoch:   45        2 Batch loss: 0.551721 Batch F1: 0.7
# Epoch:   45        3 Batch loss: 0.493422 Batch F1: 0.7428571428571428
# Epoch:   45        4 Batch loss: 0.541824 Batch F1: 0.711111111111111
# Epoch:   45        5 Batch loss: 0.454444 Batch F1: 0.816326530612245
# Train Avg Loss   45: 0.486760
#
# Train Avg F1   45: 0.7718367346938775
#
# Val Avg Loss   45: 0.285813
#
# Val Avg F1   45:  0.541880341880342
#
# Optimal Val loss (Epoch 17): 0.2350292131304741
#
# Epoch 46
# --------------------------------------------------------------
# Epoch:   46        1 Batch loss: 0.509932 Batch F1: 0.761904761904762
# Epoch:   46        2 Batch loss: 0.534641 Batch F1: 0.7142857142857143
# Epoch:   46        3 Batch loss: 0.431071 Batch F1: 0.7878787878787877
# Epoch:   46        4 Batch loss: 0.499561 Batch F1: 0.7368421052631579
# Epoch:   46        5 Batch loss: 0.452621 Batch F1: 0.7999999999999999
# Train Avg Loss   46: 0.485565
#
# Train Avg F1   46: 0.7601822738664843
#
# Val Avg Loss   46: 0.268787
#
# Val Avg F1   46:  0.6464285714285716
#
# Optimal Val loss (Epoch 17): 0.2350292131304741
#
# Epoch 47
# --------------------------------------------------------------
# Epoch:   47        1 Batch loss: 0.421483 Batch F1: 0.7857142857142858
# Epoch:   47        2 Batch loss: 0.500846 Batch F1: 0.7906976744186047
# Epoch:   47        3 Batch loss: 0.460091 Batch F1: 0.8108108108108107
# Epoch:   47        4 Batch loss: 0.500871 Batch F1: 0.7222222222222222
# Epoch:   47        5 Batch loss: 0.529354 Batch F1: 0.744186046511628
# Train Avg Loss   47: 0.482529
#
# Train Avg F1   47: 0.7707262079355103
#
# Val Avg Loss   47: 0.290547
#
# Val Avg F1   47:  0.6436781609195402
#
# Optimal Val loss (Epoch 17): 0.2350292131304741
#
# Epoch 48
# --------------------------------------------------------------
# Epoch:   48        1 Batch loss: 0.410537 Batch F1: 0.8571428571428571
# Epoch:   48        2 Batch loss: 0.497988 Batch F1: 0.6666666666666666
# Epoch:   48        3 Batch loss: 0.495926 Batch F1: 0.7906976744186046
# Epoch:   48        4 Batch loss: 0.517636 Batch F1: 0.782608695652174
# Epoch:   48        5 Batch loss: 0.493107 Batch F1: 0.7804878048780488
# Train Avg Loss   48: 0.483039
#
# Train Avg F1   48: 0.7755207397516702
#
# Val Avg Loss   48: 0.294211
#
# Val Avg F1   48:  0.6192592592592593
#
# Optimal Val loss (Epoch 17): 0.2350292131304741
#
# Epoch 49
# --------------------------------------------------------------
# Epoch:   49        1 Batch loss: 0.500251 Batch F1: 0.7567567567567567
# Epoch:   49        2 Batch loss: 0.514665 Batch F1: 0.7441860465116279
# Epoch:   49        3 Batch loss: 0.465558 Batch F1: 0.7999999999999999
# Epoch:   49        4 Batch loss: 0.452029 Batch F1: 0.8421052631578948
# Epoch:   49        5 Batch loss: 0.492373 Batch F1: 0.761904761904762
# Train Avg Loss   49: 0.484975
#
# Train Avg F1   49: 0.7809905656662082
#
# Val Avg Loss   49: 0.310432
#
# Val Avg F1   49:  0.55
#
# Optimal Val loss (Epoch 17): 0.2350292131304741
#
# Epoch 50
# --------------------------------------------------------------
# Epoch:   50        1 Batch loss: 0.536589 Batch F1: 0.6206896551724138
# Epoch:   50        2 Batch loss: 0.431387 Batch F1: 0.8500000000000001
# Epoch:   50        3 Batch loss: 0.420211 Batch F1: 0.8571428571428571
# Epoch:   50        4 Batch loss: 0.543163 Batch F1: 0.6666666666666665
# Epoch:   50        5 Batch loss: 0.509367 Batch F1: 0.6842105263157895
# Train Avg Loss   50: 0.488143
#
# Train Avg F1   50: 0.7357419410595454
#
# Val Avg Loss   50: 0.295549
#
# Val Avg F1   50:  0.596969696969697
#
# Optimal Val loss (Epoch 17): 0.2350292131304741
#
# Epoch 51
# --------------------------------------------------------------
# Epoch:   51        1 Batch loss: 0.518061 Batch F1: 0.7500000000000001
# Epoch:   51        2 Batch loss: 0.511882 Batch F1: 0.7555555555555554
# Epoch:   51        3 Batch loss: 0.454158 Batch F1: 0.7878787878787877
# Epoch:   51        4 Batch loss: 0.539051 Batch F1: 0.6666666666666667
# Epoch:   51        5 Batch loss: 0.427544 Batch F1: 0.7999999999999999
# Train Avg Loss   51: 0.490139
#
# Train Avg F1   51: 0.7520202020202019
#
# Val Avg Loss   51: 0.316698
#
# Val Avg F1   51:  0.5504065040650407
#
# Optimal Val loss (Epoch 17): 0.2350292131304741
#
# Epoch 52
# --------------------------------------------------------------
# Epoch:   52        1 Batch loss: 0.500250 Batch F1: 0.7804878048780487
# Epoch:   52        2 Batch loss: 0.485940 Batch F1: 0.75
# Epoch:   52        3 Batch loss: 0.432006 Batch F1: 0.8148148148148148
# Epoch:   52        4 Batch loss: 0.442040 Batch F1: 0.7692307692307693
# Epoch:   52        5 Batch loss: 0.558018 Batch F1: 0.7450980392156864
# Train Avg Loss   52: 0.483651
#
# Train Avg F1   52: 0.7719262856278638
#
# Val Avg Loss   52: 0.295100
#
# Val Avg F1   52:  0.5954545454545455
#
# Optimal Val loss (Epoch 17): 0.2350292131304741
#
# Epoch 53
# --------------------------------------------------------------
# Epoch:   53        1 Batch loss: 0.441584 Batch F1: 0.8636363636363636
# Epoch:   53        2 Batch loss: 0.482173 Batch F1: 0.7428571428571428
# Epoch:   53        3 Batch loss: 0.528657 Batch F1: 0.7027027027027029
# Epoch:   53        4 Batch loss: 0.459030 Batch F1: 0.7647058823529413
# Epoch:   53        5 Batch loss: 0.498049 Batch F1: 0.7368421052631579
# Train Avg Loss   53: 0.481899
#
# Train Avg F1   53: 0.7621488393624618
#
# Val Avg Loss   53: 0.257990
#
# Val Avg F1   53:  0.664488017429194
#
# Optimal Val loss (Epoch 17): 0.2350292131304741
#
# Epoch 54
# --------------------------------------------------------------
# Epoch:   54        1 Batch loss: 0.475401 Batch F1: 0.7777777777777778
# Epoch:   54        2 Batch loss: 0.495371 Batch F1: 0.7659574468085107
# Epoch:   54        3 Batch loss: 0.552757 Batch F1: 0.7000000000000001
# Epoch:   54        4 Batch loss: 0.501583 Batch F1: 0.761904761904762
# Epoch:   54        5 Batch loss: 0.455289 Batch F1: 0.8205128205128205
# Train Avg Loss   54: 0.496080
#
# Train Avg F1   54: 0.7652305614007743
#
# Val Avg Loss   54: 0.268848
#
# Val Avg F1   54:  0.6810712111990261
#
# Optimal Val loss (Epoch 17): 0.2350292131304741
#
# Epoch 55
# --------------------------------------------------------------
# Epoch:   55        1 Batch loss: 0.531350 Batch F1: 0.7317073170731708
# Epoch:   55        2 Batch loss: 0.514017 Batch F1: 0.7777777777777779
# Epoch:   55        3 Batch loss: 0.497466 Batch F1: 0.6206896551724139
# Epoch:   55        4 Batch loss: 0.456587 Batch F1: 0.8333333333333334
# Epoch:   55        5 Batch loss: 0.418335 Batch F1: 0.8387096774193549
# Train Avg Loss   55: 0.483551
#
# Train Avg F1   55: 0.7604435521552102
#
# Val Avg Loss   55: 0.285618
#
# Val Avg F1   55:  0.5891472868217054
#
# Optimal Val loss (Epoch 17): 0.2350292131304741
#
# Epoch 56
# --------------------------------------------------------------
# Epoch:   56        1 Batch loss: 0.570720 Batch F1: 0.6666666666666667
# Epoch:   56        2 Batch loss: 0.445691 Batch F1: 0.8333333333333334
# Epoch:   56        3 Batch loss: 0.480245 Batch F1: 0.7272727272727272
# Epoch:   56        4 Batch loss: 0.427508 Batch F1: 0.8780487804878049
# Epoch:   56        5 Batch loss: 0.515397 Batch F1: 0.6666666666666667
# Train Avg Loss   56: 0.487912
#
# Train Avg F1   56: 0.7543976348854396
#
# Val Avg Loss   56: 0.280521
#
# Val Avg F1   56:  0.6242690058479532
#
# Optimal Val loss (Epoch 17): 0.2350292131304741
#
# Epoch 57
# --------------------------------------------------------------
# Epoch:   57        1 Batch loss: 0.466258 Batch F1: 0.8
# Epoch:   57        2 Batch loss: 0.501973 Batch F1: 0.7368421052631579
# Epoch:   57        3 Batch loss: 0.555856 Batch F1: 0.6486486486486486
# Epoch:   57        4 Batch loss: 0.466196 Batch F1: 0.8108108108108109
# Epoch:   57        5 Batch loss: 0.432053 Batch F1: 0.85
# Train Avg Loss   57: 0.484467
#
# Train Avg F1   57: 0.7692603129445235
#
# Val Avg Loss   57: 0.297118
#
# Val Avg F1   57:  0.6069017254313578
#
# Optimal Val loss (Epoch 17): 0.2350292131304741
#
# Epoch 58
# --------------------------------------------------------------
# Epoch:   58        1 Batch loss: 0.500377 Batch F1: 0.8163265306122449
# Epoch:   58        2 Batch loss: 0.452699 Batch F1: 0.7878787878787877
# Epoch:   58        3 Batch loss: 0.460146 Batch F1: 0.8400000000000001
# Epoch:   58        4 Batch loss: 0.453529 Batch F1: 0.7333333333333334
# Epoch:   58        5 Batch loss: 0.541799 Batch F1: 0.5517241379310345
# Train Avg Loss   58: 0.481710
#
# Train Avg F1   58: 0.7458525579510802
#
# Val Avg Loss   58: 0.284934
#
# Val Avg F1   58:  0.5887445887445888
#
# Optimal Val loss (Epoch 17): 0.2350292131304741
#
# Epoch 59
# --------------------------------------------------------------
# Epoch:   59        1 Batch loss: 0.501797 Batch F1: 0.7916666666666667
# Epoch:   59        2 Batch loss: 0.495331 Batch F1: 0.7999999999999999
# Epoch:   59        3 Batch loss: 0.457520 Batch F1: 0.6666666666666666
# Epoch:   59        4 Batch loss: 0.472831 Batch F1: 0.8372093023255814
# Epoch:   59        5 Batch loss: 0.497190 Batch F1: 0.7555555555555556
# Train Avg Loss   59: 0.484934
#
# Train Avg F1   59: 0.7702196382428941
#
# Val Avg Loss   59: 0.276477
#
# Val Avg F1   59:  0.6444444444444445
#
# Optimal Val loss (Epoch 17): 0.2350292131304741
#
# Epoch 60
# --------------------------------------------------------------
# Epoch:   60        1 Batch loss: 0.518279 Batch F1: 0.6451612903225806
# Epoch:   60        2 Batch loss: 0.514241 Batch F1: 0.7692307692307693
# Epoch:   60        3 Batch loss: 0.468111 Batch F1: 0.7878787878787877
# Epoch:   60        4 Batch loss: 0.497215 Batch F1: 0.7924528301886793
# Epoch:   60        5 Batch loss: 0.436066 Batch F1: 0.7999999999999999
# Train Avg Loss   60: 0.486783
#
# Train Avg F1   60: 0.7589447355241633
#
# Val Avg Loss   60: 0.290339
#
# Val Avg F1   60:  0.6777777777777778
#
# Optimal Val loss (Epoch 17): 0.2350292131304741
#
# Epoch 61
# --------------------------------------------------------------
# Epoch:   61        1 Batch loss: 0.494128 Batch F1: 0.8095238095238095
# Epoch:   61        2 Batch loss: 0.446456 Batch F1: 0.8095238095238095
# Epoch:   61        3 Batch loss: 0.528673 Batch F1: 0.7
# Epoch:   61        4 Batch loss: 0.546726 Batch F1: 0.6666666666666665
# Epoch:   61        5 Batch loss: 0.445340 Batch F1: 0.7878787878787878
# Train Avg Loss   61: 0.492264
#
# Train Avg F1   61: 0.7547186147186146
#
# Val Avg Loss   61: 0.283926
#
# Val Avg F1   61:  0.6249084249084249
#
# Optimal Val loss (Epoch 17): 0.2350292131304741
#
# Epoch 62
# --------------------------------------------------------------
# Epoch:   62        1 Batch loss: 0.517102 Batch F1: 0.7058823529411765
# Epoch:   62        2 Batch loss: 0.419637 Batch F1: 0.8275862068965517
# Epoch:   62        3 Batch loss: 0.422450 Batch F1: 0.8571428571428571
# Epoch:   62        4 Batch loss: 0.535074 Batch F1: 0.761904761904762
# Epoch:   62        5 Batch loss: 0.524037 Batch F1: 0.75
# Train Avg Loss   62: 0.483660
#
# Train Avg F1   62: 0.7805032357770695
#
# Val Avg Loss   62: 0.274883
#
# Val Avg F1   62:  0.7065337763012182
#
# Optimal Val loss (Epoch 17): 0.2350292131304741
#
# Epoch 63
# --------------------------------------------------------------
# Epoch:   63        1 Batch loss: 0.492232 Batch F1: 0.7222222222222222
# Epoch:   63        2 Batch loss: 0.463026 Batch F1: 0.7777777777777778
# Epoch:   63        3 Batch loss: 0.552952 Batch F1: 0.6829268292682927
# Epoch:   63        4 Batch loss: 0.457827 Batch F1: 0.8571428571428571
# Epoch:   63        5 Batch loss: 0.482501 Batch F1: 0.7567567567567567
# Train Avg Loss   63: 0.489708
#
# Train Avg F1   63: 0.7593652886335813
#
# Val Avg Loss   63: 0.287273
#
# Val Avg F1   63:  0.6261224489795918
#
# Optimal Val loss (Epoch 17): 0.2350292131304741
#
# Epoch 64
# --------------------------------------------------------------
# Epoch:   64        1 Batch loss: 0.455418 Batch F1: 0.7878787878787878
# Epoch:   64        2 Batch loss: 0.494985 Batch F1: 0.7222222222222223
# Epoch:   64        3 Batch loss: 0.395412 Batch F1: 0.8947368421052632
# Epoch:   64        4 Batch loss: 0.539273 Batch F1: 0.7368421052631579
# Epoch:   64        5 Batch loss: 0.539522 Batch F1: 0.7142857142857143
# Train Avg Loss   64: 0.484922
#
# Train Avg F1   64: 0.7711931343510291
#
# Val Avg Loss   64: 0.285217
#
# Val Avg F1   64:  0.634788189987163
#
# Optimal Val loss (Epoch 17): 0.2350292131304741
#
# Epoch 65
# --------------------------------------------------------------
# Epoch:   65        1 Batch loss: 0.454308 Batch F1: 0.7647058823529411
# Epoch:   65        2 Batch loss: 0.472839 Batch F1: 0.7647058823529412
# Epoch:   65        3 Batch loss: 0.445305 Batch F1: 0.8571428571428572
# Epoch:   65        4 Batch loss: 0.506130 Batch F1: 0.7317073170731708
# Epoch:   65        5 Batch loss: 0.578612 Batch F1: 0.6111111111111112
# Train Avg Loss   65: 0.491439
#
# Train Avg F1   65: 0.7458746100066043
#
# Val Avg Loss   65: 0.299210
#
# Val Avg F1   65:  0.6145833333333335
#
# Optimal Val loss (Epoch 17): 0.2350292131304741
#
# Epoch 66
# --------------------------------------------------------------
# Epoch:   66        1 Batch loss: 0.491389 Batch F1: 0.8085106382978724
# Epoch:   66        2 Batch loss: 0.438061 Batch F1: 0.85
# Epoch:   66        3 Batch loss: 0.434012 Batch F1: 0.8235294117647058
# Epoch:   66        4 Batch loss: 0.559801 Batch F1: 0.6486486486486486
# Epoch:   66        5 Batch loss: 0.480021 Batch F1: 0.7777777777777778
# Train Avg Loss   66: 0.480657
#
# Train Avg F1   66: 0.781693295297801
#
# Val Avg Loss   66: 0.278584
#
# Val Avg F1   66:  0.6153846153846154
#
# Optimal Val loss (Epoch 17): 0.2350292131304741
#
# Epoch 67
# --------------------------------------------------------------
# Epoch:   67        1 Batch loss: 0.406332 Batch F1: 0.8947368421052632
# Epoch:   67        2 Batch loss: 0.516872 Batch F1: 0.7368421052631579
# Epoch:   67        3 Batch loss: 0.609930 Batch F1: 0.5945945945945946
# Epoch:   67        4 Batch loss: 0.471363 Batch F1: 0.7499999999999999
# Epoch:   67        5 Batch loss: 0.410474 Batch F1: 0.8636363636363635
# Train Avg Loss   67: 0.482994
#
# Train Avg F1   67: 0.7679619811198759
#
# Val Avg Loss   67: 0.278317
#
# Val Avg F1   67:  0.6406025824964132
#
# Optimal Val loss (Epoch 17): 0.2350292131304741
#
# Epoch 68
# --------------------------------------------------------------
# Epoch:   68        1 Batch loss: 0.442257 Batch F1: 0.8235294117647058
# Epoch:   68        2 Batch loss: 0.475292 Batch F1: 0.7500000000000001
# Epoch:   68        3 Batch loss: 0.436341 Batch F1: 0.8695652173913043
# Epoch:   68        4 Batch loss: 0.450506 Batch F1: 0.8181818181818181
# Epoch:   68        5 Batch loss: 0.619758 Batch F1: 0.4666666666666667
# Train Avg Loss   68: 0.484831
#
# Train Avg F1   68: 0.7455886228008991
#
# Val Avg Loss   68: 0.275547
#
# Val Avg F1   68:  0.6914350538854226
#
# Optimal Val loss (Epoch 17): 0.2350292131304741
#
# Epoch 69
# --------------------------------------------------------------
# Epoch:   69        1 Batch loss: 0.456030 Batch F1: 0.8292682926829269
# Epoch:   69        2 Batch loss: 0.396433 Batch F1: 0.92
# Epoch:   69        3 Batch loss: 0.559437 Batch F1: 0.6829268292682926
# Epoch:   69        4 Batch loss: 0.591969 Batch F1: 0.6341463414634148
# Epoch:   69        5 Batch loss: 0.469045 Batch F1: 0.7878787878787877
# Train Avg Loss   69: 0.494583
#
# Train Avg F1   69: 0.7708440502586844
#
# Val Avg Loss   69: 0.327666
#
# Val Avg F1   69:  0.5519421860885275
#
# Optimal Val loss (Epoch 17): 0.2350292131304741
#
# Epoch 70
# --------------------------------------------------------------
# Epoch:   70        1 Batch loss: 0.482597 Batch F1: 0.7647058823529412
# Epoch:   70        2 Batch loss: 0.513905 Batch F1: 0.6666666666666667
# Epoch:   70        3 Batch loss: 0.508647 Batch F1: 0.7368421052631577
# Epoch:   70        4 Batch loss: 0.486338 Batch F1: 0.7567567567567568
# Epoch:   70        5 Batch loss: 0.521341 Batch F1: 0.7027027027027029
# Train Avg Loss   70: 0.502566
#
# Train Avg F1   70: 0.725534822748445
#
# Val Avg Loss   70: 0.284993
#
# Val Avg F1   70:  0.6248275862068966
#
# Optimal Val loss (Epoch 17): 0.2350292131304741
#
# Epoch 71
# --------------------------------------------------------------
# Epoch:   71        1 Batch loss: 0.498174 Batch F1: 0.7567567567567567
# Epoch:   71        2 Batch loss: 0.443736 Batch F1: 0.8108108108108109
# Epoch:   71        3 Batch loss: 0.498098 Batch F1: 0.7567567567567567
# Epoch:   71        4 Batch loss: 0.539286 Batch F1: 0.6842105263157894
# Epoch:   71        5 Batch loss: 0.498854 Batch F1: 0.7804878048780488
# Train Avg Loss   71: 0.495630
#
# Train Avg F1   71: 0.7578045311036326
#
# Val Avg Loss   71: 0.308198
#
# Val Avg F1   71:  0.5354545454545454
#
# Optimal Val loss (Epoch 17): 0.2350292131304741
#
# Epoch 72
# --------------------------------------------------------------
# Epoch:   72        1 Batch loss: 0.487404 Batch F1: 0.7272727272727274
# Epoch:   72        2 Batch loss: 0.447319 Batch F1: 0.8205128205128205
# Epoch:   72        3 Batch loss: 0.459546 Batch F1: 0.8
# Epoch:   72        4 Batch loss: 0.569911 Batch F1: 0.5454545454545454
# Epoch:   72        5 Batch loss: 0.523366 Batch F1: 0.7441860465116279
# Train Avg Loss   72: 0.497509
#
# Train Avg F1   72: 0.7274852279503442
#
# Val Avg Loss   72: 0.280561
#
# Val Avg F1   72:  0.6820512820512821
#
# Optimal Val loss (Epoch 17): 0.2350292131304741
#
# Epoch 73
# --------------------------------------------------------------
# Epoch:   73        1 Batch loss: 0.559735 Batch F1: 0.6829268292682927
# Epoch:   73        2 Batch loss: 0.572615 Batch F1: 0.6666666666666667
# Epoch:   73        3 Batch loss: 0.446381 Batch F1: 0.8421052631578947
# Epoch:   73        4 Batch loss: 0.498166 Batch F1: 0.7727272727272727
# Epoch:   73        5 Batch loss: 0.516220 Batch F1: 0.7027027027027025
# Train Avg Loss   73: 0.518623
#
# Train Avg F1   73: 0.7334257469045659
#
# Val Avg Loss   73: 0.312276
#
# Val Avg F1   73:  0.5478036175710594
#
# Optimal Val loss (Epoch 17): 0.2350292131304741
#
# Epoch 74
# --------------------------------------------------------------
# Epoch:   74        1 Batch loss: 0.480296 Batch F1: 0.8181818181818181
# Epoch:   74        2 Batch loss: 0.493473 Batch F1: 0.5454545454545454
# Epoch:   74        3 Batch loss: 0.517115 Batch F1: 0.7500000000000001
# Epoch:   74        4 Batch loss: 0.519863 Batch F1: 0.7222222222222222
# Epoch:   74        5 Batch loss: 0.462600 Batch F1: 0.8292682926829269
# Train Avg Loss   74: 0.494669
#
# Train Avg F1   74: 0.7330253757083026
#
# Val Avg Loss   74: 0.287988
#
# Val Avg F1   74:  0.6610389610389611
#
# Optimal Val loss (Epoch 17): 0.2350292131304741
#
# Epoch 75
# --------------------------------------------------------------
# Epoch:   75        1 Batch loss: 0.488791 Batch F1: 0.7906976744186046
# Epoch:   75        2 Batch loss: 0.557249 Batch F1: 0.6666666666666667
# Epoch:   75        3 Batch loss: 0.499187 Batch F1: 0.7999999999999999
# Epoch:   75        4 Batch loss: 0.424313 Batch F1: 0.823529411764706
# Epoch:   75        5 Batch loss: 0.501928 Batch F1: 0.8205128205128205
# Train Avg Loss   75: 0.494294
#
# Train Avg F1   75: 0.7802813146725596
#
# Val Avg Loss   75: 0.280543
#
# Val Avg F1   75:  0.6458333333333335
#
# Optimal Val loss (Epoch 17): 0.2350292131304741
#
# Epoch 76
# --------------------------------------------------------------
# Epoch:   76        1 Batch loss: 0.475187 Batch F1: 0.7647058823529411
# Epoch:   76        2 Batch loss: 0.506226 Batch F1: 0.7441860465116279
# Epoch:   76        3 Batch loss: 0.486438 Batch F1: 0.8085106382978724
# Epoch:   76        4 Batch loss: 0.468695 Batch F1: 0.7586206896551725
# Epoch:   76        5 Batch loss: 0.479979 Batch F1: 0.7647058823529411
# Train Avg Loss   76: 0.483305
#
# Train Avg F1   76: 0.768145827834111
#
# Val Avg Loss   76: 0.292105
#
# Val Avg F1   76:  0.5838509316770186
#
# Optimal Val loss (Epoch 17): 0.2350292131304741
#
# Epoch 77
# --------------------------------------------------------------
# Epoch:   77        1 Batch loss: 0.444624 Batch F1: 0.8421052631578948
# Epoch:   77        2 Batch loss: 0.473617 Batch F1: 0.7499999999999999
# Epoch:   77        3 Batch loss: 0.469660 Batch F1: 0.7499999999999999
# Epoch:   77        4 Batch loss: 0.472613 Batch F1: 0.851063829787234
# Epoch:   77        5 Batch loss: 0.582579 Batch F1: 0.5945945945945946
# Train Avg Loss   77: 0.488618
#
# Train Avg F1   77: 0.7575527375079447
#
# Val Avg Loss   77: 0.278766
#
# Val Avg F1   77:  0.6802721088435375
#
# Optimal Val loss (Epoch 17): 0.2350292131304741
#
# Epoch 78
# --------------------------------------------------------------
# Epoch:   78        1 Batch loss: 0.527829 Batch F1: 0.7346938775510204
# Epoch:   78        2 Batch loss: 0.491942 Batch F1: 0.7727272727272727
# Epoch:   78        3 Batch loss: 0.530507 Batch F1: 0.7368421052631577
# Epoch:   78        4 Batch loss: 0.456119 Batch F1: 0.823529411764706
# Epoch:   78        5 Batch loss: 0.452854 Batch F1: 0.8
# Train Avg Loss   78: 0.491850
#
# Train Avg F1   78: 0.7735585334612315
#
# Val Avg Loss   78: 0.272601
#
# Val Avg F1   78:  0.6559060895084372
#
# Optimal Val loss (Epoch 17): 0.2350292131304741
#
# Epoch 79
# --------------------------------------------------------------
# Epoch:   79        1 Batch loss: 0.452773 Batch F1: 0.8292682926829269
# Epoch:   79        2 Batch loss: 0.426044 Batch F1: 0.8500000000000001
# Epoch:   79        3 Batch loss: 0.481683 Batch F1: 0.7894736842105263
# Epoch:   79        4 Batch loss: 0.547672 Batch F1: 0.6666666666666666
# Epoch:   79        5 Batch loss: 0.523090 Batch F1: 0.6451612903225806
# Train Avg Loss   79: 0.486253
#
# Train Avg F1   79: 0.7561139867765401
#
# Val Avg Loss   79: 0.286570
#
# Val Avg F1   79:  0.6260869565217391
#
# Optimal Val loss (Epoch 17): 0.2350292131304741
#
# Epoch 80
# --------------------------------------------------------------
# Epoch:   80        1 Batch loss: 0.500476 Batch F1: 0.7692307692307693
# Epoch:   80        2 Batch loss: 0.522994 Batch F1: 0.6666666666666667
# Epoch:   80        3 Batch loss: 0.431466 Batch F1: 0.8571428571428571
# Epoch:   80        4 Batch loss: 0.469024 Batch F1: 0.8085106382978724
# Epoch:   80        5 Batch loss: 0.493758 Batch F1: 0.7619047619047619
# Train Avg Loss   80: 0.483543
#
# Train Avg F1   80: 0.7726911386485855
#
# Val Avg Loss   80: 0.275277
#
# Val Avg F1   80:  0.6818181818181818
#
# Optimal Val loss (Epoch 17): 0.2350292131304741
#
# Epoch 81
# --------------------------------------------------------------
# Epoch:   81        1 Batch loss: 0.441180 Batch F1: 0.8636363636363636
# Epoch:   81        2 Batch loss: 0.458855 Batch F1: 0.8095238095238095
# Epoch:   81        3 Batch loss: 0.495117 Batch F1: 0.6857142857142857
# Epoch:   81        4 Batch loss: 0.537857 Batch F1: 0.6976744186046512
# Epoch:   81        5 Batch loss: 0.520031 Batch F1: 0.7027027027027026
# Train Avg Loss   81: 0.490608
#
# Train Avg F1   81: 0.7518503160363624
#
# Val Avg Loss   81: 0.313672
#
# Val Avg F1   81:  0.568888888888889
#
# Optimal Val loss (Epoch 17): 0.2350292131304741
#
# Epoch 82
# --------------------------------------------------------------
# Epoch:   82        1 Batch loss: 0.525551 Batch F1: 0.7179487179487181
# Epoch:   82        2 Batch loss: 0.542669 Batch F1: 0.6666666666666665
# Epoch:   82        3 Batch loss: 0.496327 Batch F1: 0.7804878048780487
# Epoch:   82        4 Batch loss: 0.444997 Batch F1: 0.787878787878788
# Epoch:   82        5 Batch loss: 0.432778 Batch F1: 0.8235294117647058
# Train Avg Loss   82: 0.488464
#
# Train Avg F1   82: 0.7553022778273855
#
# Val Avg Loss   82: 0.284460
#
# Val Avg F1   82:  0.6458333333333333
#
# Optimal Val loss (Epoch 17): 0.2350292131304741
#
# Epoch 83
# --------------------------------------------------------------
# Epoch:   83        1 Batch loss: 0.485198 Batch F1: 0.7692307692307693
# Epoch:   83        2 Batch loss: 0.466268 Batch F1: 0.7894736842105263
# Epoch:   83        3 Batch loss: 0.495850 Batch F1: 0.8085106382978724
# Epoch:   83        4 Batch loss: 0.430936 Batch F1: 0.8648648648648648
# Epoch:   83        5 Batch loss: 0.546178 Batch F1: 0.6206896551724138
# Train Avg Loss   83: 0.484886
#
# Train Avg F1   83: 0.7705539223552893
#
# Val Avg Loss   83: 0.280461
#
# Val Avg F1   83:  0.6436781609195402
#
# Optimal Val loss (Epoch 17): 0.2350292131304741
#
# Epoch 84
# --------------------------------------------------------------
# Epoch:   84        1 Batch loss: 0.462662 Batch F1: 0.8108108108108109
# Epoch:   84        2 Batch loss: 0.541029 Batch F1: 0.7027027027027027
# Epoch:   84        3 Batch loss: 0.457136 Batch F1: 0.7333333333333334
# Epoch:   84        4 Batch loss: 0.465280 Batch F1: 0.8181818181818182
# Epoch:   84        5 Batch loss: 0.481267 Batch F1: 0.7999999999999999
# Train Avg Loss   84: 0.481475
#
# Train Avg F1   84: 0.773005733005733
#
# Val Avg Loss   84: 0.284213
#
# Val Avg F1   84:  0.6349924585218703
#
# Optimal Val loss (Epoch 17): 0.2350292131304741
#
# Epoch 85
# --------------------------------------------------------------
# Epoch:   85        1 Batch loss: 0.430084 Batch F1: 0.8571428571428572
# Epoch:   85        2 Batch loss: 0.473305 Batch F1: 0.7804878048780488
# Epoch:   85        3 Batch loss: 0.530158 Batch F1: 0.7272727272727274
# Epoch:   85        4 Batch loss: 0.550410 Batch F1: 0.6060606060606061
# Epoch:   85        5 Batch loss: 0.431031 Batch F1: 0.8125000000000001
# Train Avg Loss   85: 0.482997
#
# Train Avg F1   85: 0.7566927990708479
#
# Val Avg Loss   85: 0.259430
#
# Val Avg F1   85:  0.713885778275476
#
# Optimal Val loss (Epoch 17): 0.2350292131304741
#
# Epoch 86
# --------------------------------------------------------------
# Epoch:   86        1 Batch loss: 0.475874 Batch F1: 0.761904761904762
# Epoch:   86        2 Batch loss: 0.513465 Batch F1: 0.6
# Epoch:   86        3 Batch loss: 0.431481 Batch F1: 0.85
# Epoch:   86        4 Batch loss: 0.474716 Batch F1: 0.8333333333333333
# Epoch:   86        5 Batch loss: 0.529459 Batch F1: 0.6666666666666667
# Train Avg Loss   86: 0.484999
#
# Train Avg F1   86: 0.7423809523809524
#
# Val Avg Loss   86: 0.258486
#
# Val Avg F1   86:  0.7015018773466835
#
# Optimal Val loss (Epoch 17): 0.2350292131304741
#
# Epoch 87
# --------------------------------------------------------------
# Epoch:   87        1 Batch loss: 0.469636 Batch F1: 0.8
# Epoch:   87        2 Batch loss: 0.495094 Batch F1: 0.7804878048780488
# Epoch:   87        3 Batch loss: 0.509702 Batch F1: 0.75
# Epoch:   87        4 Batch loss: 0.496732 Batch F1: 0.6842105263157895
# Epoch:   87        5 Batch loss: 0.439188 Batch F1: 0.7741935483870969
# Train Avg Loss   87: 0.482070
#
# Train Avg F1   87: 0.757778375916187
#
# Val Avg Loss   87: 0.293007
#
# Val Avg F1   87:  0.5509031198686372
#
# Optimal Val loss (Epoch 17): 0.2350292131304741
#
# Epoch 88
# --------------------------------------------------------------
# Epoch:   88        1 Batch loss: 0.391154 Batch F1: 0.8571428571428571
# Epoch:   88        2 Batch loss: 0.493213 Batch F1: 0.7619047619047621
# Epoch:   88        3 Batch loss: 0.534527 Batch F1: 0.7317073170731708
# Epoch:   88        4 Batch loss: 0.425858 Batch F1: 0.8125
# Epoch:   88        5 Batch loss: 0.559726 Batch F1: 0.6829268292682927
# Train Avg Loss   88: 0.480896
#
# Train Avg F1   88: 0.7692363530778166
#
# Val Avg Loss   88: 0.289070
#
# Val Avg F1   88:  0.6236559139784947
#
# Optimal Val loss (Epoch 17): 0.2350292131304741
#
# Epoch 89
# --------------------------------------------------------------
# Epoch:   89        1 Batch loss: 0.554908 Batch F1: 0.7777777777777777
# Epoch:   89        2 Batch loss: 0.409748 Batch F1: 0.8275862068965517
# Epoch:   89        3 Batch loss: 0.452108 Batch F1: 0.7741935483870968
# Epoch:   89        4 Batch loss: 0.432863 Batch F1: 0.8235294117647058
# Epoch:   89        5 Batch loss: 0.566364 Batch F1: 0.6666666666666667
# Train Avg Loss   89: 0.483198
#
# Train Avg F1   89: 0.7739507222985598
#
# Val Avg Loss   89: 0.274670
#
# Val Avg F1   89:  0.6330532212885154
#
# Optimal Val loss (Epoch 17): 0.2350292131304741
#
# Epoch 90
# --------------------------------------------------------------
# Epoch:   90        1 Batch loss: 0.591814 Batch F1: 0.611111111111111
# Epoch:   90        2 Batch loss: 0.428231 Batch F1: 0.8510638297872339
# Epoch:   90        3 Batch loss: 0.517492 Batch F1: 0.7567567567567567
# Epoch:   90        4 Batch loss: 0.444953 Batch F1: 0.7999999999999999
# Epoch:   90        5 Batch loss: 0.442189 Batch F1: 0.8108108108108107
# Train Avg Loss   90: 0.484936
#
# Train Avg F1   90: 0.7659485016931825
#
# Val Avg Loss   90: 0.264841
#
# Val Avg F1   90:  0.6491112574061882
#
# Optimal Val loss (Epoch 17): 0.2350292131304741
#
# Epoch 91
# --------------------------------------------------------------
# Epoch:   91        1 Batch loss: 0.494821 Batch F1: 0.7567567567567567
# Epoch:   91        2 Batch loss: 0.405742 Batch F1: 0.9
# Epoch:   91        3 Batch loss: 0.550929 Batch F1: 0.6285714285714286
# Epoch:   91        4 Batch loss: 0.478099 Batch F1: 0.7777777777777778
# Epoch:   91        5 Batch loss: 0.482730 Batch F1: 0.7567567567567568
# Train Avg Loss   91: 0.482464
#
# Train Avg F1   91: 0.763972543972544
#
# Val Avg Loss   91: 0.289328
#
# Val Avg F1   91:  0.5853858784893268
#
# Optimal Val loss (Epoch 17): 0.2350292131304741
#
# Epoch 92
# --------------------------------------------------------------
# Epoch:   92        1 Batch loss: 0.465620 Batch F1: 0.8292682926829269
# Epoch:   92        2 Batch loss: 0.416409 Batch F1: 0.8648648648648649
# Epoch:   92        3 Batch loss: 0.528295 Batch F1: 0.6451612903225806
# Epoch:   92        4 Batch loss: 0.523878 Batch F1: 0.717948717948718
# Epoch:   92        5 Batch loss: 0.467862 Batch F1: 0.742857142857143
# Train Avg Loss   92: 0.480413
#
# Train Avg F1   92: 0.7600200617352467
#
# Val Avg Loss   92: 0.272538
#
# Val Avg F1   92:  0.6534017971758663
#
# Optimal Val loss (Epoch 17): 0.2350292131304741
#
# Epoch 93
# --------------------------------------------------------------
# Epoch:   93        1 Batch loss: 0.528254 Batch F1: 0.6666666666666666
# Epoch:   93        2 Batch loss: 0.439781 Batch F1: 0.7894736842105262
# Epoch:   93        3 Batch loss: 0.405480 Batch F1: 0.9
# Epoch:   93        4 Batch loss: 0.557025 Batch F1: 0.6666666666666667
# Epoch:   93        5 Batch loss: 0.524793 Batch F1: 0.7659574468085107
# Train Avg Loss   93: 0.491067
#
# Train Avg F1   93: 0.7577528928704742
#
# Val Avg Loss   93: 0.251842
#
# Val Avg F1   93:  0.7131313131313131
#
# Optimal Val loss (Epoch 17): 0.2350292131304741
#
# Epoch 94
# --------------------------------------------------------------
# Epoch:   94        1 Batch loss: 0.504469 Batch F1: 0.7567567567567567
# Epoch:   94        2 Batch loss: 0.417138 Batch F1: 0.8717948717948718
# Epoch:   94        3 Batch loss: 0.544400 Batch F1: 0.625
# Epoch:   94        4 Batch loss: 0.531899 Batch F1: 0.6206896551724138
# Epoch:   94        5 Batch loss: 0.445876 Batch F1: 0.875
# Train Avg Loss   94: 0.488756
#
# Train Avg F1   94: 0.7498482567448084
#
# Val Avg Loss   94: 0.305849
#
# Val Avg F1   94:  0.6195652173913044
#
# Optimal Val loss (Epoch 17): 0.2350292131304741
#
# Epoch 95
# --------------------------------------------------------------
# Epoch:   95        1 Batch loss: 0.539046 Batch F1: 0.5384615384615385
# Epoch:   95        2 Batch loss: 0.467602 Batch F1: 0.7500000000000001
# Epoch:   95        3 Batch loss: 0.424542 Batch F1: 0.8837209302325583
# Epoch:   95        4 Batch loss: 0.489370 Batch F1: 0.7272727272727272
# Epoch:   95        5 Batch loss: 0.511827 Batch F1: 0.8363636363636363
# Train Avg Loss   95: 0.486478
#
# Train Avg F1   95: 0.7471637664660922
#
# Val Avg Loss   95: 0.276906
#
# Val Avg F1   95:  0.6380813953488371
#
# Optimal Val loss (Epoch 17): 0.2350292131304741
#
# Epoch 96
# --------------------------------------------------------------
# Epoch:   96        1 Batch loss: 0.446607 Batch F1: 0.8333333333333334
# Epoch:   96        2 Batch loss: 0.553403 Batch F1: 0.7499999999999999
# Epoch:   96        3 Batch loss: 0.579234 Batch F1: 0.5185185185185185
# Epoch:   96        4 Batch loss: 0.393241 Batch F1: 0.888888888888889
# Epoch:   96        5 Batch loss: 0.447332 Batch F1: 0.7586206896551724
# Train Avg Loss   96: 0.483963
#
# Train Avg F1   96: 0.7498722860791827
#
# Val Avg Loss   96: 0.304859
#
# Val Avg F1   96:  0.5666666666666667
#
# Optimal Val loss (Epoch 17): 0.2350292131304741
#
# Epoch 97
# --------------------------------------------------------------
# Epoch:   97        1 Batch loss: 0.470245 Batch F1: 0.7804878048780487
# Epoch:   97        2 Batch loss: 0.483951 Batch F1: 0.7647058823529412
# Epoch:   97        3 Batch loss: 0.515819 Batch F1: 0.7368421052631577
# Epoch:   97        4 Batch loss: 0.423100 Batch F1: 0.85
# Epoch:   97        5 Batch loss: 0.518268 Batch F1: 0.6666666666666666
# Train Avg Loss   97: 0.482277
#
# Train Avg F1   97: 0.7597404918321629
#
# Val Avg Loss   97: 0.286792
#
# Val Avg F1   97:  0.628526645768025
#
# Optimal Val loss (Epoch 17): 0.2350292131304741
#
# Epoch 98
# --------------------------------------------------------------
# Epoch:   98        1 Batch loss: 0.443585 Batch F1: 0.8636363636363636
# Epoch:   98        2 Batch loss: 0.472606 Batch F1: 0.7567567567567567
# Epoch:   98        3 Batch loss: 0.560458 Batch F1: 0.6486486486486486
# Epoch:   98        4 Batch loss: 0.454529 Batch F1: 0.8333333333333334
# Epoch:   98        5 Batch loss: 0.469593 Batch F1: 0.7692307692307692
# Train Avg Loss   98: 0.480154
#
# Train Avg F1   98: 0.7743211743211743
#
# Val Avg Loss   98: 0.274220
#
# Val Avg F1   98:  0.6879652605459057
#
# Optimal Val loss (Epoch 17): 0.2350292131304741
#
# Epoch 99
# --------------------------------------------------------------
# Epoch:   99        1 Batch loss: 0.458746 Batch F1: 0.8679245283018867
# Epoch:   99        2 Batch loss: 0.590241 Batch F1: 0.6341463414634146
# Epoch:   99        3 Batch loss: 0.418353 Batch F1: 0.8717948717948718
# Epoch:   99        4 Batch loss: 0.444505 Batch F1: 0.7200000000000001
# Epoch:   99        5 Batch loss: 0.511021 Batch F1: 0.6428571428571429
# Train Avg Loss   99: 0.484573
#
# Train Avg F1   99: 0.7473445768834632
#
# Val Avg Loss   99: 0.297122
#
# Val Avg F1   99:  0.5833333333333334
#
# Optimal Val loss (Epoch 17): 0.2350292131304741
#
# Epoch 100
# --------------------------------------------------------------
# Epoch:  100        1 Batch loss: 0.458444 Batch F1: 0.5333333333333333
# Epoch:  100        2 Batch loss: 0.495340 Batch F1: 0.823529411764706
# Epoch:  100        3 Batch loss: 0.468685 Batch F1: 0.742857142857143
# Epoch:  100        4 Batch loss: 0.509539 Batch F1: 0.761904761904762
# Epoch:  100        5 Batch loss: 0.472233 Batch F1: 0.7999999999999999
# Train Avg Loss  100: 0.480848
#
# Train Avg F1  100: 0.7323249299719887
#
# Val Avg Loss  100: 0.278998
#
# Val Avg F1  100:  0.6153846153846153
#
# Optimal Val loss (Epoch 17): 0.2350292131304741
#
# Done!

# %%
import json

# %%
results = json.load(open(path_to_res))

# %%
#print('best f1', np.max(results['val_f1']), np.argmax(results['val_f1']))
print('best f1 val', results['val_f1'][np.argmax(results['val_f1'])])
print('corr f1 train', results['train_f1'][np.argmax(results['val_f1'])])
print('corr f1 test', results['test_f1'][np.argmax(results['val_f1'])])
#print('best f1 train', np.max(results['train_f1']), np.argmax(results['train_f1']))
# Out:
# best f1 val 0.7526881720430108
# corr f1 train 0.7312934441869974
# corr f1 test 0.59

# %%
import matplotlib.pyplot as plt

# %%
plt.title('F1 score plot 5% RE threshold')
plt.ylabel('F1')
plt.xlabel('Epochs')
plt.plot(results['train_f1'],'-g', label='Train F1')
plt.plot(results['val_f1'],'-b', label='Val F1')
plt.legend(loc='upper left')
plt.ylim([0.0,1.0])
# Out:
# (0.0, 1.0)

# %%
list(results.keys())
# Out:
# ['train_loss',
#  'val_loss',
#  'test_loss',
#  'train_f1',
#  'val_f1',
#  'test_f1',
#  'train_prec',
#  'val_prec',
#  'test_prec',
#  'train_recall',
#  'val_recall',
#  'test_recall']

# %%
plt.title('Precision score plot 5% RE threshold')
plt.ylabel('Precision')
plt.xlabel('Epochs')
plt.plot(results['train_prec'],'-g', label='Train Precision')
plt.plot(results['val_prec'],'-b', label='Val Precision')
plt.legend(loc='upper left')
plt.ylim([0.0,1.0])
# Out:
# (0.0, 1.0)

# %%
plt.title('Recall score plot 5% RE threshold')
plt.ylabel('Recall')
plt.xlabel('Epochs')
plt.plot(results['train_recall'],'-g', label='Train Recall')
plt.plot(results['val_recall'],'-b', label='Val Recall')
plt.legend(loc='upper left')
plt.ylim([0.0,1.0])
# Out:
# (0.0, 1.0)

# %%
import torch
model = torch.load('/work/data/models2_6/best_f1_model_74.pt')
model.eval()
model
# Out:
# Classifier(
#   (conv1): RelGraphConv(
#     (linear_r): TypedLinear(in_size=113, out_size=32, num_types=8)
#     (dropout): Dropout(p=0.0, inplace=False)
#   )
#   (conv2): RelGraphConv(
#     (linear_r): TypedLinear(in_size=32, out_size=32, num_types=8)
#     (dropout): Dropout(p=0.0, inplace=False)
#   )
#   (classify): Linear(in_features=32, out_features=2, bias=True)
# )

# %%
from dgl_classifier. trainer import predict2samples
print(train_file)
train_data, val_data,test_data = predict2samples(model,train_file, val_file, test_file, community_no=10, verbose=True, clust_verbose=False, clust_load_path='/work/data/confs/May2/pred_clust.json')
# Out:
# /work/data/splits/splits_0.05/train.json

# %%
for k in train_data.keys():
    print(train_data[k])
    break
# Out:
# {'bloom_runtime': 0.087360461, 'jena_runtime': 0.084558884, 'gt': False, 'bgp_construction_duration': 5.4836273193359375e-05, 'tps_const_duration': 0.0002028942108154297, 'prediction': 1, 'inference_time': 0.005201816558837891}

# %%
from dgl_classifier.post import *
train_rt, avg_train = avg_runtime(train_data)
_,_, avg_train_jena,avg_train_blf = avg_runtime_type(train_data)
val_rt, avg_val = avg_runtime(val_data)
_,_, avg_val_jena,avg_val_blf = avg_runtime_type(val_data)
test_rt, avg_test = avg_runtime(test_data)
_,_, avg_test_jena,avg_test_blf = avg_runtime_type(test_data)

# %%
print('Train\n','\tWith Predictions ',round(avg_train,3),', Jena: ', round(avg_train_jena,3), ', Bloom Filter',round(avg_train_blf,3))
print('Validation\n','\tWith Predictions ',round(avg_val,3),', Jena: ', round(avg_val_jena,3), ', Bloom Filter',round(avg_val_blf,3))
print('Test\n','\tWith Predictions ',round(avg_test,3),', Jena: ', round(avg_test_jena,3), ', Bloom Filter',round(avg_test_blf,3))
#print(avg_val,avg_val_jena,avg_val_blf)
#print(avg_test,avg_test_jena,avg_test_blf)
# Out:
# 3.287565739380094 3.759739541464 4.543417418276
# 5.972785981242262 6.664473213034885 7.355454263860466
# 3.8463032295911077 4.40134811313253 5.0240766965180725
