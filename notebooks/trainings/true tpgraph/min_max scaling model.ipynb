# %% [markdown]
# file paths

# %%
train_file = '/work/data/splits/splits_0.05/train.json'
val_file = '/work/data/splits/splits_0.05/val.json'
test_file = '/work/data/splits/splits_0.05/test.json'
import os

path_to_save = '/work/data/models2_6'
os.system(f'mkdir -p {path_to_save}')
path_to_res = '/work/data/results/2_6_2023_tp_graph_5re.txt'
neurons = 64

# %% [markdown]
# import

# %%
# %load_ext autoreload
# %autoreload 2
import json
import dgl
from sklearn.metrics import f1_score
import torch as th
import dgl.nn.pytorch as dglnn
import torch.nn as nn
from dgl.dataloading import GraphDataLoader
import torch.nn.functional as F
import networkx as nx
import warnings
from feature_extraction.base_featurizer import BaseFeaturizer
import torch
from graph_construction.tps_graph import create_dummy_dgl_graph, tps_graph
import numpy as np

from dgl_classifier.trainer import GraphDataset,snap_pred, tps_to_dgl, get_clasification_vec,\
tps_graph_const, extract_data, runner


import warnings

from preprocessing.utils import load_BGPS_from_json
warnings.filterwarnings('ignore', category=UserWarning, message='TypedStorage is deprecated')

# %%
#seed
dgl.seed(1223)

# %% [markdown]
# Model

# %%
import math
class Classifier(nn.Module):
    def __init__(self, in_dim, hidden_dim, n_classes):
        super(Classifier, self).__init__()
        self.conv1 = dglnn.RelGraphConv(in_dim, hidden_dim, 8)
        #self.conv1 = dglnn.GraphConv(in_dim, hidden_ˇdim)
        self.conv2 = dglnn.RelGraphConv(hidden_dim, math.ceil(hidden_dim), 8)
        #self.conv2 = dglnn.GraphConv(hidden_dim, hidden_dim)
        self.classify = nn.Linear(math.ceil(hidden_dim), n_classes)

    def forward(self, g, h, rel_types):
        # Apply graph convolution and activation.
        h = F.relu(self.conv1(g, h, rel_types))
        h = F.relu(self.conv2(g, h, rel_types))
        with g.local_scope():
            g.ndata['h'] = h
            # Calculate graph representation by average readout.
            hg = 0
            for ntype in g.ntypes:
                hg = hg + dgl.mean_nodes(g, 'h', ntype=ntype)
            #hg = dgl.mean_nodes(g, 'node_features')
            return F.softmax( self.classify(hg), dim=1)
model = Classifier(113, 20, 2)

# %% [markdown]
# hyperparameters

# %%
early_stop =100
model = Classifier(117, neurons, 2)
lr = 0.01
wd = 5e-4
epochs = 100

# %%
train_dataloader, val_dataloader, test_dataloader = extract_data(train_file, val_file, test_file, community_no=30, batch_size = 50, verbose=True)
# Out:
# /usr/local/lib/python3.10/dist-packages/dgl/backend/pytorch/tensor.py:52: UserWarning: Creating a tensor from a list of numpy.ndarrays is extremely slow. Please consider converting the list to a single numpy.ndarray with numpy.array() before converting to a tensor. (Triggered internally at ../torch/csrc/utils/tensor_new.cpp:245.)
#   return th.as_tensor(data, dtype=dtype)
# # of catesian products: 0
# # of catesian products: 0
# # of catesian products: 0
# # of predicate feats not in validation 53
# # of predicate feats not in test 7
# Training dataset size 286
# Validation dataset size 96
# Test dataset size 96

# %%
best_model_path = runner(train_dataloader,val_dataloader,test_dataloader,model, early_stop, lr, wd, epochs, path_to_res, path_to_save=path_to_save)
;
# Out:
# Epoch 1
# --------------------------------------------------------------
# Epoch:    1        1 Batch loss: 0.699547 Batch F1: 0.33333333333333337
# Epoch:    1        2 Batch loss: 0.733047 Batch F1: 0.0
# Epoch:    1        3 Batch loss: 0.863807 Batch F1: 0.0
# Epoch:    1        4 Batch loss: 0.741717 Batch F1: 0.0
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Epoch:    1        5 Batch loss: 0.863792 Batch F1: 0.0
# Epoch:    1        6 Batch loss: 0.787577 Batch F1: 0.0
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Train Avg Loss    1: 0.781581
#
# Train Avg F1    1: 0.05555555555555556
#
# Val Avg Loss    1: 0.523471
#
# Val Avg F1    1:  0.0
#
# Optimal Val loss (Epoch 1): 0.5234706550836563
#
# Epoch 2
# --------------------------------------------------------------
# Epoch:    2        1 Batch loss: 0.681298 Batch F1: 0.16666666666666669
# Epoch:    2        2 Batch loss: 0.661879 Batch F1: 0.35714285714285715
# Epoch:    2        3 Batch loss: 0.689164 Batch F1: 0.5882352941176471
# Epoch:    2        4 Batch loss: 0.710088 Batch F1: 0.1935483870967742
# Epoch:    2        5 Batch loss: 0.659364 Batch F1: 0.6037735849056604
# Epoch:    2        6 Batch loss: 0.681440 Batch F1: 0.7555555555555556
# Train Avg Loss    2: 0.680538
#
# Train Avg F1    2: 0.44415372424752686
#
# Val Avg Loss    2: 0.245746
#
# Val Avg F1    2:  0.7391181458451102
#
# Optimal Val loss (Epoch 2): 0.24574600160121918
#
# Epoch 3
# --------------------------------------------------------------
# Epoch:    3        1 Batch loss: 0.679861 Batch F1: 0.6440677966101696
# Epoch:    3        2 Batch loss: 0.568464 Batch F1: 0.7599999999999999
# Epoch:    3        3 Batch loss: 0.630341 Batch F1: 0.6530612244897959
# Epoch:    3        4 Batch loss: 0.660786 Batch F1: 0.4444444444444444
# Epoch:    3        5 Batch loss: 0.617377 Batch F1: 0.65
# Epoch:    3        6 Batch loss: 0.607622 Batch F1: 0.6666666666666666
# Train Avg Loss    3: 0.627409
#
# Train Avg F1    3: 0.6363733553685127
#
# Val Avg Loss    3: 0.289962
#
# Val Avg F1    3:  0.7136363636363636
#
# Optimal Val loss (Epoch 2): 0.24574600160121918
#
# Epoch 4
# --------------------------------------------------------------
# Epoch:    4        1 Batch loss: 0.580826 Batch F1: 0.75
# Epoch:    4        2 Batch loss: 0.648778 Batch F1: 0.6545454545454545
# Epoch:    4        3 Batch loss: 0.584974 Batch F1: 0.76
# Epoch:    4        4 Batch loss: 0.605754 Batch F1: 0.6521739130434783
# Epoch:    4        5 Batch loss: 0.587436 Batch F1: 0.75
# Epoch:    4        6 Batch loss: 0.610154 Batch F1: 0.5999999999999999
# Train Avg Loss    4: 0.602987
#
# Train Avg F1    4: 0.6944532279314887
#
# Val Avg Loss    4: 0.285711
#
# Val Avg F1    4:  0.5637472283813747
#
# Optimal Val loss (Epoch 2): 0.24574600160121918
#
# Epoch 5
# --------------------------------------------------------------
# Epoch:    5        1 Batch loss: 0.574586 Batch F1: 0.7346938775510203
# Epoch:    5        2 Batch loss: 0.583368 Batch F1: 0.7058823529411765
# Epoch:    5        3 Batch loss: 0.514913 Batch F1: 0.8666666666666665
# Epoch:    5        4 Batch loss: 0.713132 Batch F1: 0.6428571428571428
# Epoch:    5        5 Batch loss: 0.677542 Batch F1: 0.64
# Epoch:    5        6 Batch loss: 0.549024 Batch F1: 0.7567567567567567
# Train Avg Loss    5: 0.602094
#
# Train Avg F1    5: 0.7244761327954605
#
# Val Avg Loss    5: 0.256885
#
# Val Avg F1    5:  0.7113095238095237
#
# Optimal Val loss (Epoch 2): 0.24574600160121918
#
# Epoch 6
# --------------------------------------------------------------
# Epoch:    6        1 Batch loss: 0.596517 Batch F1: 0.6530612244897959
# Epoch:    6        2 Batch loss: 0.517770 Batch F1: 0.7804878048780488
# Epoch:    6        3 Batch loss: 0.678746 Batch F1: 0.6666666666666666
# Epoch:    6        4 Batch loss: 0.595966 Batch F1: 0.48275862068965514
# Epoch:    6        5 Batch loss: 0.621467 Batch F1: 0.2857142857142857
# Epoch:    6        6 Batch loss: 0.565470 Batch F1: 0.7272727272727272
# Train Avg Loss    6: 0.595989
#
# Train Avg F1    6: 0.5993268882851965
#
# Val Avg Loss    6: 0.259406
#
# Val Avg F1    6:  0.7336700336700337
#
# Optimal Val loss (Epoch 2): 0.24574600160121918
#
# Epoch 7
# --------------------------------------------------------------
# Epoch:    7        1 Batch loss: 0.611544 Batch F1: 0.7037037037037037
# Epoch:    7        2 Batch loss: 0.599576 Batch F1: 0.7368421052631579
# Epoch:    7        3 Batch loss: 0.568367 Batch F1: 0.7346938775510204
# Epoch:    7        4 Batch loss: 0.571409 Batch F1: 0.7796610169491526
# Epoch:    7        5 Batch loss: 0.548711 Batch F1: 0.7317073170731706
# Epoch:    7        6 Batch loss: 0.579564 Batch F1: 0.7368421052631577
# Train Avg Loss    7: 0.579862
#
# Train Avg F1    7: 0.7372416876338939
#
# Val Avg Loss    7: 0.252742
#
# Val Avg F1    7:  0.7375565610859728
#
# Optimal Val loss (Epoch 2): 0.24574600160121918
#
# Epoch 8
# --------------------------------------------------------------
# Epoch:    8        1 Batch loss: 0.526223 Batch F1: 0.8076923076923077
# Epoch:    8        2 Batch loss: 0.620150 Batch F1: 0.64
# Epoch:    8        3 Batch loss: 0.544014 Batch F1: 0.761904761904762
# Epoch:    8        4 Batch loss: 0.518002 Batch F1: 0.7755102040816326
# Epoch:    8        5 Batch loss: 0.527917 Batch F1: 0.6285714285714286
# Epoch:    8        6 Batch loss: 0.647313 Batch F1: 0.5
# Train Avg Loss    8: 0.563937
#
# Train Avg F1    8: 0.6856131170416884
#
# Val Avg Loss    8: 0.290958
#
# Val Avg F1    8:  0.5201465201465201
#
# Optimal Val loss (Epoch 2): 0.24574600160121918
#
# Epoch 9
# --------------------------------------------------------------
# Epoch:    9        1 Batch loss: 0.558689 Batch F1: 0.6153846153846153
# Epoch:    9        2 Batch loss: 0.588871 Batch F1: 0.6
# Epoch:    9        3 Batch loss: 0.492449 Batch F1: 0.7916666666666666
# Epoch:    9        4 Batch loss: 0.574500 Batch F1: 0.72
# Epoch:    9        5 Batch loss: 0.575199 Batch F1: 0.72
# Epoch:    9        6 Batch loss: 0.585503 Batch F1: 0.717948717948718
# Train Avg Loss    9: 0.562535
#
# Train Avg F1    9: 0.6941666666666667
#
# Val Avg Loss    9: 0.241779
#
# Val Avg F1    9:  0.7557932263814616
#
# Optimal Val loss (Epoch 9): 0.241779163479805
#
# Epoch 10
# --------------------------------------------------------------
# Epoch:   10        1 Batch loss: 0.425843 Batch F1: 0.8813559322033898
# Epoch:   10        2 Batch loss: 0.620749 Batch F1: 0.47058823529411764
# Epoch:   10        3 Batch loss: 0.541607 Batch F1: 0.6666666666666666
# Epoch:   10        4 Batch loss: 0.623801 Batch F1: 0.6046511627906976
# Epoch:   10        5 Batch loss: 0.570497 Batch F1: 0.6666666666666666
# Epoch:   10        6 Batch loss: 0.541914 Batch F1: 0.7894736842105262
# Train Avg Loss   10: 0.554069
#
# Train Avg F1   10: 0.6799003913053441
#
# Val Avg Loss   10: 0.257074
#
# Val Avg F1   10:  0.7484035759897829
#
# Optimal Val loss (Epoch 9): 0.241779163479805
#
# Epoch 11
# --------------------------------------------------------------
# Epoch:   11        1 Batch loss: 0.500780 Batch F1: 0.8571428571428571
# Epoch:   11        2 Batch loss: 0.566557 Batch F1: 0.7636363636363636
# Epoch:   11        3 Batch loss: 0.525044 Batch F1: 0.7755102040816326
# Epoch:   11        4 Batch loss: 0.526155 Batch F1: 0.7692307692307692
# Epoch:   11        5 Batch loss: 0.616191 Batch F1: 0.5142857142857142
# Epoch:   11        6 Batch loss: 0.681425 Batch F1: 0.34782608695652173
# Train Avg Loss   11: 0.569359
#
# Train Avg F1   11: 0.6712719992223097
#
# Val Avg Loss   11: 0.365473
#
# Val Avg F1   11:  0.45945945945945943
#
# Optimal Val loss (Epoch 9): 0.241779163479805
#
# Epoch 12
# --------------------------------------------------------------
# Epoch:   12        1 Batch loss: 0.460742 Batch F1: 0.8695652173913044
# Epoch:   12        2 Batch loss: 0.558949 Batch F1: 0.5333333333333333
# Epoch:   12        3 Batch loss: 0.492358 Batch F1: 0.7567567567567568
# Epoch:   12        4 Batch loss: 0.633542 Batch F1: 0.6222222222222222
# Epoch:   12        5 Batch loss: 0.594588 Batch F1: 0.7419354838709677
# Epoch:   12        6 Batch loss: 0.497616 Batch F1: 0.8205128205128205
# Train Avg Loss   12: 0.539632
#
# Train Avg F1   12: 0.7240543056812342
#
# Val Avg Loss   12: 0.235312
#
# Val Avg F1   12:  0.7543859649122806
#
# Optimal Val loss (Epoch 12): 0.23531199991703033
#
# Epoch 13
# --------------------------------------------------------------
# Epoch:   13        1 Batch loss: 0.540189 Batch F1: 0.76
# Epoch:   13        2 Batch loss: 0.504797 Batch F1: 0.7857142857142857
# Epoch:   13        3 Batch loss: 0.567347 Batch F1: 0.7317073170731706
# Epoch:   13        4 Batch loss: 0.494217 Batch F1: 0.8108108108108109
# Epoch:   13        5 Batch loss: 0.571489 Batch F1: 0.6341463414634146
# Epoch:   13        6 Batch loss: 0.547912 Batch F1: 0.6896551724137931
# Train Avg Loss   13: 0.537659
#
# Train Avg F1   13: 0.7353389879125792
#
# Val Avg Loss   13: 0.304066
#
# Val Avg F1   13:  0.4571428571428571
#
# Optimal Val loss (Epoch 12): 0.23531199991703033
#
# Epoch 14
# --------------------------------------------------------------
# Epoch:   14        1 Batch loss: 0.556696 Batch F1: 0.5161290322580645
# Epoch:   14        2 Batch loss: 0.495970 Batch F1: 0.8095238095238095
# Epoch:   14        3 Batch loss: 0.500393 Batch F1: 0.816326530612245
# Epoch:   14        4 Batch loss: 0.508444 Batch F1: 0.8275862068965517
# Epoch:   14        5 Batch loss: 0.571669 Batch F1: 0.7083333333333333
# Epoch:   14        6 Batch loss: 0.562479 Batch F1: 0.7567567567567567
# Train Avg Loss   14: 0.532608
#
# Train Avg F1   14: 0.7391092782301268
#
# Val Avg Loss   14: 0.232398
#
# Val Avg F1   14:  0.7639257294429709
#
# Optimal Val loss (Epoch 14): 0.23239809274673462
#
# Epoch 15
# --------------------------------------------------------------
# Epoch:   15        1 Batch loss: 0.518037 Batch F1: 0.7441860465116279
# Epoch:   15        2 Batch loss: 0.466087 Batch F1: 0.8461538461538461
# Epoch:   15        3 Batch loss: 0.457398 Batch F1: 0.8571428571428572
# Epoch:   15        4 Batch loss: 0.531476 Batch F1: 0.7916666666666666
# Epoch:   15        5 Batch loss: 0.652467 Batch F1: 0.5581395348837209
# Epoch:   15        6 Batch loss: 0.567294 Batch F1: 0.7096774193548386
# Train Avg Loss   15: 0.532127
#
# Train Avg F1   15: 0.7511610617855929
#
# Val Avg Loss   15: 0.242648
#
# Val Avg F1   15:  0.691304347826087
#
# Optimal Val loss (Epoch 14): 0.23239809274673462
#
# Epoch 16
# --------------------------------------------------------------
# Epoch:   16        1 Batch loss: 0.487356 Batch F1: 0.7894736842105263
# Epoch:   16        2 Batch loss: 0.511860 Batch F1: 0.7906976744186047
# Epoch:   16        3 Batch loss: 0.551178 Batch F1: 0.7
# Epoch:   16        4 Batch loss: 0.508087 Batch F1: 0.8076923076923077
# Epoch:   16        5 Batch loss: 0.546484 Batch F1: 0.7999999999999999
# Epoch:   16        6 Batch loss: 0.509818 Batch F1: 0.8205128205128205
# Train Avg Loss   16: 0.519130
#
# Train Avg F1   16: 0.7847294144723764
#
# Val Avg Loss   16: 0.248872
#
# Val Avg F1   16:  0.650670794633643
#
# Optimal Val loss (Epoch 14): 0.23239809274673462
#
# Epoch 17
# --------------------------------------------------------------
# Epoch:   17        1 Batch loss: 0.484005 Batch F1: 0.8
# Epoch:   17        2 Batch loss: 0.540212 Batch F1: 0.7272727272727274
# Epoch:   17        3 Batch loss: 0.486437 Batch F1: 0.8292682926829269
# Epoch:   17        4 Batch loss: 0.540162 Batch F1: 0.7450980392156863
# Epoch:   17        5 Batch loss: 0.512985 Batch F1: 0.7826086956521738
# Epoch:   17        6 Batch loss: 0.554266 Batch F1: 0.7272727272727272
# Train Avg Loss   17: 0.519678
#
# Train Avg F1   17: 0.7685867470160402
#
# Val Avg Loss   17: 0.231257
#
# Val Avg F1   17:  0.7603485838779956
#
# Optimal Val loss (Epoch 17): 0.2312573567032814
#
# Epoch 18
# --------------------------------------------------------------
# Epoch:   18        1 Batch loss: 0.470454 Batch F1: 0.8571428571428571
# Epoch:   18        2 Batch loss: 0.481507 Batch F1: 0.816326530612245
# Epoch:   18        3 Batch loss: 0.629959 Batch F1: 0.679245283018868
# Epoch:   18        4 Batch loss: 0.452315 Batch F1: 0.8205128205128205
# Epoch:   18        5 Batch loss: 0.545838 Batch F1: 0.6666666666666667
# Epoch:   18        6 Batch loss: 0.522778 Batch F1: 0.7999999999999999
# Train Avg Loss   18: 0.517142
#
# Train Avg F1   18: 0.7733156929922429
#
# Val Avg Loss   18: 0.276171
#
# Val Avg F1   18:  0.682170542635659
#
# Optimal Val loss (Epoch 17): 0.2312573567032814
#
# Epoch 19
# --------------------------------------------------------------
# Epoch:   19        1 Batch loss: 0.555959 Batch F1: 0.7234042553191491
# Epoch:   19        2 Batch loss: 0.468401 Batch F1: 0.7999999999999999
# Epoch:   19        3 Batch loss: 0.535587 Batch F1: 0.7179487179487181
# Epoch:   19        4 Batch loss: 0.483294 Batch F1: 0.830188679245283
# Epoch:   19        5 Batch loss: 0.527708 Batch F1: 0.7272727272727272
# Epoch:   19        6 Batch loss: 0.537707 Batch F1: 0.7999999999999999
# Train Avg Loss   19: 0.518110
#
# Train Avg F1   19: 0.7664690632976462
#
# Val Avg Loss   19: 0.239556
#
# Val Avg F1   19:  0.729020979020979
#
# Optimal Val loss (Epoch 17): 0.2312573567032814
#
# Epoch 20
# --------------------------------------------------------------
# Epoch:   20        1 Batch loss: 0.432167 Batch F1: 0.875
# Epoch:   20        2 Batch loss: 0.569919 Batch F1: 0.6666666666666667
# Epoch:   20        3 Batch loss: 0.570050 Batch F1: 0.6829268292682927
# Epoch:   20        4 Batch loss: 0.540932 Batch F1: 0.7755102040816326
# Epoch:   20        5 Batch loss: 0.519385 Batch F1: 0.7567567567567567
# Epoch:   20        6 Batch loss: 0.499035 Batch F1: 0.8000000000000002
# Train Avg Loss   20: 0.521915
#
# Train Avg F1   20: 0.7594767427955581
#
# Val Avg Loss   20: 0.226604
#
# Val Avg F1   20:  0.7398305084745763
#
# Optimal Val loss (Epoch 20): 0.22660350799560547
#
# Epoch 21
# --------------------------------------------------------------
# Epoch:   21        1 Batch loss: 0.491953 Batch F1: 0.7999999999999999
# Epoch:   21        2 Batch loss: 0.475756 Batch F1: 0.8620689655172413
# Epoch:   21        3 Batch loss: 0.509889 Batch F1: 0.7659574468085107
# Epoch:   21        4 Batch loss: 0.587788 Batch F1: 0.631578947368421
# Epoch:   21        5 Batch loss: 0.478144 Batch F1: 0.7894736842105262
# Epoch:   21        6 Batch loss: 0.490059 Batch F1: 0.823529411764706
# Train Avg Loss   21: 0.505598
#
# Train Avg F1   21: 0.7787680759449009
#
# Val Avg Loss   21: 0.234759
#
# Val Avg F1   21:  0.7250100361300683
#
# Optimal Val loss (Epoch 20): 0.22660350799560547
#
# Epoch 22
# --------------------------------------------------------------
# Epoch:   22        1 Batch loss: 0.470911 Batch F1: 0.8444444444444444
# Epoch:   22        2 Batch loss: 0.527805 Batch F1: 0.7391304347826088
# Epoch:   22        3 Batch loss: 0.543639 Batch F1: 0.6818181818181818
# Epoch:   22        4 Batch loss: 0.437171 Batch F1: 0.9019607843137256
# Epoch:   22        5 Batch loss: 0.491990 Batch F1: 0.8235294117647058
# Epoch:   22        6 Batch loss: 0.570544 Batch F1: 0.7142857142857143
# Train Avg Loss   22: 0.507010
#
# Train Avg F1   22: 0.7841948285682302
#
# Val Avg Loss   22: 0.227883
#
# Val Avg F1   22:  0.7525252525252525
#
# Optimal Val loss (Epoch 20): 0.22660350799560547
#
# Epoch 23
# --------------------------------------------------------------
# Epoch:   23        1 Batch loss: 0.470254 Batch F1: 0.8205128205128205
# Epoch:   23        2 Batch loss: 0.464976 Batch F1: 0.8181818181818182
# Epoch:   23        3 Batch loss: 0.489981 Batch F1: 0.8085106382978723
# Epoch:   23        4 Batch loss: 0.528467 Batch F1: 0.7843137254901961
# Epoch:   23        5 Batch loss: 0.547855 Batch F1: 0.76
# Epoch:   23        6 Batch loss: 0.474313 Batch F1: 0.8125
# Train Avg Loss   23: 0.495974
#
# Train Avg F1   23: 0.8006698337471178
#
# Val Avg Loss   23: 0.220025
#
# Val Avg F1   23:  0.7595038015206081
#
# Optimal Val loss (Epoch 23): 0.22002538293600082
#
# Epoch 24
# --------------------------------------------------------------
# Epoch:   24        1 Batch loss: 0.523468 Batch F1: 0.7441860465116279
# Epoch:   24        2 Batch loss: 0.583752 Batch F1: 0.7083333333333333
# Epoch:   24        3 Batch loss: 0.427956 Batch F1: 0.912280701754386
# Epoch:   24        4 Batch loss: 0.522028 Batch F1: 0.8076923076923077
# Epoch:   24        5 Batch loss: 0.412087 Batch F1: 0.9166666666666666
# Epoch:   24        6 Batch loss: 0.528177 Batch F1: 0.608695652173913
# Train Avg Loss   24: 0.499578
#
# Train Avg F1   24: 0.7829757846887059
#
# Val Avg Loss   24: 0.221029
#
# Val Avg F1   24:  0.7568181818181818
#
# Optimal Val loss (Epoch 23): 0.22002538293600082
#
# Epoch 25
# --------------------------------------------------------------
# Epoch:   25        1 Batch loss: 0.419353 Batch F1: 0.8749999999999999
# Epoch:   25        2 Batch loss: 0.487207 Batch F1: 0.8085106382978724
# Epoch:   25        3 Batch loss: 0.528195 Batch F1: 0.7555555555555555
# Epoch:   25        4 Batch loss: 0.446209 Batch F1: 0.823529411764706
# Epoch:   25        5 Batch loss: 0.550906 Batch F1: 0.7346938775510203
# Epoch:   25        6 Batch loss: 0.563548 Batch F1: 0.7567567567567567
# Train Avg Loss   25: 0.499236
#
# Train Avg F1   25: 0.7923410399876518
#
# Val Avg Loss   25: 0.235300
#
# Val Avg F1   25:  0.7537037037037038
#
# Optimal Val loss (Epoch 23): 0.22002538293600082
#
# Epoch 26
# --------------------------------------------------------------
# Epoch:   26        1 Batch loss: 0.555675 Batch F1: 0.7
# Epoch:   26        2 Batch loss: 0.503950 Batch F1: 0.8421052631578947
# Epoch:   26        3 Batch loss: 0.471728 Batch F1: 0.84
# Epoch:   26        4 Batch loss: 0.453878 Batch F1: 0.8372093023255814
# Epoch:   26        5 Batch loss: 0.549656 Batch F1: 0.7999999999999999
# Epoch:   26        6 Batch loss: 0.460583 Batch F1: 0.8000000000000002
# Train Avg Loss   26: 0.499245
#
# Train Avg F1   26: 0.803219094247246
#
# Val Avg Loss   26: 0.272976
#
# Val Avg F1   26:  0.6434511434511434
#
# Optimal Val loss (Epoch 23): 0.22002538293600082
#
# Epoch 27
# --------------------------------------------------------------
# Epoch:   27        1 Batch loss: 0.495017 Batch F1: 0.7222222222222222
# Epoch:   27        2 Batch loss: 0.518364 Batch F1: 0.7843137254901961
# Epoch:   27        3 Batch loss: 0.555639 Batch F1: 0.7
# Epoch:   27        4 Batch loss: 0.538839 Batch F1: 0.7924528301886793
# Epoch:   27        5 Batch loss: 0.445455 Batch F1: 0.8510638297872342
# Epoch:   27        6 Batch loss: 0.449670 Batch F1: 0.8500000000000001
# Train Avg Loss   27: 0.500497
#
# Train Avg F1   27: 0.7833421012813888
#
# Val Avg Loss   27: 0.227025
#
# Val Avg F1   27:  0.7210884353741496
#
# Optimal Val loss (Epoch 23): 0.22002538293600082
#
# Epoch 28
# --------------------------------------------------------------
# Epoch:   28        1 Batch loss: 0.528754 Batch F1: 0.7916666666666667
# Epoch:   28        2 Batch loss: 0.463526 Batch F1: 0.8205128205128205
# Epoch:   28        3 Batch loss: 0.580377 Batch F1: 0.6
# Epoch:   28        4 Batch loss: 0.469022 Batch F1: 0.8571428571428572
# Epoch:   28        5 Batch loss: 0.461187 Batch F1: 0.8260869565217391
# Epoch:   28        6 Batch loss: 0.549333 Batch F1: 0.7096774193548386
# Train Avg Loss   28: 0.508700
#
# Train Avg F1   28: 0.7675144533664872
#
# Val Avg Loss   28: 0.242058
#
# Val Avg F1   28:  0.7691007437457742
#
# Optimal Val loss (Epoch 23): 0.22002538293600082
#
# Epoch 29
# --------------------------------------------------------------
# Epoch:   29        1 Batch loss: 0.563701 Batch F1: 0.6818181818181819
# Epoch:   29        2 Batch loss: 0.498666 Batch F1: 0.8620689655172413
# Epoch:   29        3 Batch loss: 0.425349 Batch F1: 0.8979591836734694
# Epoch:   29        4 Batch loss: 0.528527 Batch F1: 0.7000000000000001
# Epoch:   29        5 Batch loss: 0.432908 Batch F1: 0.9019607843137256
# Epoch:   29        6 Batch loss: 0.504614 Batch F1: 0.7692307692307692
# Train Avg Loss   29: 0.492294
#
# Train Avg F1   29: 0.8021729807588979
#
# Val Avg Loss   29: 0.312607
#
# Val Avg F1   29:  0.5222013758599124
#
# Optimal Val loss (Epoch 23): 0.22002538293600082
#
# Epoch 30
# --------------------------------------------------------------
# Epoch:   30        1 Batch loss: 0.475064 Batch F1: 0.7567567567567568
# Epoch:   30        2 Batch loss: 0.465567 Batch F1: 0.8333333333333334
# Epoch:   30        3 Batch loss: 0.524202 Batch F1: 0.7368421052631577
# Epoch:   30        4 Batch loss: 0.545773 Batch F1: 0.76
# Epoch:   30        5 Batch loss: 0.580190 Batch F1: 0.7540983606557377
# Epoch:   30        6 Batch loss: 0.559832 Batch F1: 0.7428571428571428
# Train Avg Loss   30: 0.525105
#
# Train Avg F1   30: 0.7639812831443545
#
# Val Avg Loss   30: 0.221643
#
# Val Avg F1   30:  0.771764705882353
#
# Optimal Val loss (Epoch 23): 0.22002538293600082
#
# Epoch 31
# --------------------------------------------------------------
# Epoch:   31        1 Batch loss: 0.468762 Batch F1: 0.8444444444444444
# Epoch:   31        2 Batch loss: 0.438966 Batch F1: 0.888888888888889
# Epoch:   31        3 Batch loss: 0.551167 Batch F1: 0.7000000000000001
# Epoch:   31        4 Batch loss: 0.546169 Batch F1: 0.7142857142857143
# Epoch:   31        5 Batch loss: 0.504244 Batch F1: 0.7804878048780488
# Epoch:   31        6 Batch loss: 0.559539 Batch F1: 0.7692307692307693
# Train Avg Loss   31: 0.511474
#
# Train Avg F1   31: 0.782889603621311
#
# Val Avg Loss   31: 0.231035
#
# Val Avg F1   31:  0.75
#
# Optimal Val loss (Epoch 23): 0.22002538293600082
#
# Epoch 32
# --------------------------------------------------------------
# Epoch:   32        1 Batch loss: 0.521383 Batch F1: 0.744186046511628
# Epoch:   32        2 Batch loss: 0.513537 Batch F1: 0.8076923076923076
# Epoch:   32        3 Batch loss: 0.582358 Batch F1: 0.7169811320754716
# Epoch:   32        4 Batch loss: 0.581325 Batch F1: 0.7540983606557377
# Epoch:   32        5 Batch loss: 0.490714 Batch F1: 0.7916666666666666
# Epoch:   32        6 Batch loss: 0.486232 Batch F1: 0.7999999999999999
# Train Avg Loss   32: 0.529258
#
# Train Avg F1   32: 0.769104085600302
#
# Val Avg Loss   32: 0.274384
#
# Val Avg F1   32:  0.6878478664192951
#
# Optimal Val loss (Epoch 23): 0.22002538293600082
#
# Epoch 33
# --------------------------------------------------------------
# Epoch:   33        1 Batch loss: 0.569243 Batch F1: 0.6818181818181819
# Epoch:   33        2 Batch loss: 0.531191 Batch F1: 0.7368421052631579
# Epoch:   33        3 Batch loss: 0.437531 Batch F1: 0.8636363636363635
# Epoch:   33        4 Batch loss: 0.496529 Batch F1: 0.8363636363636363
# Epoch:   33        5 Batch loss: 0.561322 Batch F1: 0.7272727272727272
# Epoch:   33        6 Batch loss: 0.571043 Batch F1: 0.7058823529411765
# Train Avg Loss   33: 0.527810
#
# Train Avg F1   33: 0.7586358945492072
#
# Val Avg Loss   33: 0.250613
#
# Val Avg F1   33:  0.763124604680582
#
# Optimal Val loss (Epoch 23): 0.22002538293600082
#
# Epoch 34
# --------------------------------------------------------------
# Epoch:   34        1 Batch loss: 0.587776 Batch F1: 0.7457627118644068
# Epoch:   34        2 Batch loss: 0.511063 Batch F1: 0.7924528301886792
# Epoch:   34        3 Batch loss: 0.538082 Batch F1: 0.6470588235294118
# Epoch:   34        4 Batch loss: 0.454723 Batch F1: 0.8108108108108109
# Epoch:   34        5 Batch loss: 0.480062 Batch F1: 0.8620689655172413
# Epoch:   34        6 Batch loss: 0.519203 Batch F1: 0.7741935483870968
# Train Avg Loss   34: 0.515152
#
# Train Avg F1   34: 0.7720579483829412
#
# Val Avg Loss   34: 0.269218
#
# Val Avg F1   34:  0.7165775401069518
#
# Optimal Val loss (Epoch 23): 0.22002538293600082
#
# Epoch 35
# --------------------------------------------------------------
# Epoch:   35        1 Batch loss: 0.454654 Batch F1: 0.8205128205128205
# Epoch:   35        2 Batch loss: 0.585010 Batch F1: 0.7450980392156864
# Epoch:   35        3 Batch loss: 0.505616 Batch F1: 0.8214285714285714
# Epoch:   35        4 Batch loss: 0.467197 Batch F1: 0.8181818181818182
# Epoch:   35        5 Batch loss: 0.502121 Batch F1: 0.7368421052631577
# Epoch:   35        6 Batch loss: 0.508846 Batch F1: 0.7741935483870969
# Train Avg Loss   35: 0.503907
#
# Train Avg F1   35: 0.7860428171648586
#
# Val Avg Loss   35: 0.245276
#
# Val Avg F1   35:  0.7670654468684025
#
# Optimal Val loss (Epoch 23): 0.22002538293600082
#
# Epoch 36
# --------------------------------------------------------------
# Epoch:   36        1 Batch loss: 0.440944 Batch F1: 0.8444444444444444
# Epoch:   36        2 Batch loss: 0.534544 Batch F1: 0.7659574468085107
# Epoch:   36        3 Batch loss: 0.551484 Batch F1: 0.7719298245614036
# Epoch:   36        4 Batch loss: 0.522877 Batch F1: 0.761904761904762
# Epoch:   36        5 Batch loss: 0.497711 Batch F1: 0.7391304347826089
# Epoch:   36        6 Batch loss: 0.587666 Batch F1: 0.6874999999999999
# Train Avg Loss   36: 0.522538
#
# Train Avg F1   36: 0.7618111520836215
#
# Val Avg Loss   36: 0.257499
#
# Val Avg F1   36:  0.6576576576576576
#
# Optimal Val loss (Epoch 23): 0.22002538293600082
#
# Epoch 37
# --------------------------------------------------------------
# Epoch:   37        1 Batch loss: 0.488678 Batch F1: 0.7894736842105262
# Epoch:   37        2 Batch loss: 0.520910 Batch F1: 0.7727272727272727
# Epoch:   37        3 Batch loss: 0.515516 Batch F1: 0.7222222222222222
# Epoch:   37        4 Batch loss: 0.449645 Batch F1: 0.8846153846153847
# Epoch:   37        5 Batch loss: 0.514019 Batch F1: 0.8
# Epoch:   37        6 Batch loss: 0.467523 Batch F1: 0.8421052631578948
# Train Avg Loss   37: 0.492715
#
# Train Avg F1   37: 0.8018573044888835
#
# Val Avg Loss   37: 0.220281
#
# Val Avg F1   37:  0.7706146926536732
#
# Optimal Val loss (Epoch 23): 0.22002538293600082
#
# Epoch 38
# --------------------------------------------------------------
# Epoch:   38        1 Batch loss: 0.554689 Batch F1: 0.7391304347826085
# Epoch:   38        2 Batch loss: 0.461303 Batch F1: 0.8727272727272727
# Epoch:   38        3 Batch loss: 0.511144 Batch F1: 0.7368421052631577
# Epoch:   38        4 Batch loss: 0.496101 Batch F1: 0.8085106382978724
# Epoch:   38        5 Batch loss: 0.532659 Batch F1: 0.7857142857142857
# Epoch:   38        6 Batch loss: 0.485359 Batch F1: 0.8333333333333334
# Train Avg Loss   38: 0.506876
#
# Train Avg F1   38: 0.7960430116864217
#
# Val Avg Loss   38: 0.258799
#
# Val Avg F1   38:  0.7342799188640974
#
# Optimal Val loss (Epoch 23): 0.22002538293600082
#
# Epoch 39
# --------------------------------------------------------------
# Epoch:   39        1 Batch loss: 0.503991 Batch F1: 0.7368421052631577
# Epoch:   39        2 Batch loss: 0.535488 Batch F1: 0.7619047619047621
# Epoch:   39        3 Batch loss: 0.512152 Batch F1: 0.7441860465116279
# Epoch:   39        4 Batch loss: 0.489670 Batch F1: 0.7999999999999999
# Epoch:   39        5 Batch loss: 0.526446 Batch F1: 0.7826086956521738
# Epoch:   39        6 Batch loss: 0.556609 Batch F1: 0.7692307692307692
# Train Avg Loss   39: 0.520726
#
# Train Avg F1   39: 0.7657953964270817
#
# Val Avg Loss   39: 0.252594
#
# Val Avg F1   39:  0.7290209790209791
#
# Optimal Val loss (Epoch 23): 0.22002538293600082
#
# Epoch 40
# --------------------------------------------------------------
# Epoch:   40        1 Batch loss: 0.509326 Batch F1: 0.8333333333333334
# Epoch:   40        2 Batch loss: 0.560040 Batch F1: 0.7234042553191489
# Epoch:   40        3 Batch loss: 0.457291 Batch F1: 0.8372093023255814
# Epoch:   40        4 Batch loss: 0.553976 Batch F1: 0.7083333333333333
# Epoch:   40        5 Batch loss: 0.480461 Batch F1: 0.816326530612245
# Epoch:   40        6 Batch loss: 0.438255 Batch F1: 0.8749999999999999
# Train Avg Loss   40: 0.499892
#
# Train Avg F1   40: 0.7989344591539403
#
# Val Avg Loss   40: 0.260288
#
# Val Avg F1   40:  0.6878478664192951
#
# Optimal Val loss (Epoch 23): 0.22002538293600082
#
# Epoch 41
# --------------------------------------------------------------
# Epoch:   41        1 Batch loss: 0.550902 Batch F1: 0.7234042553191491
# Epoch:   41        2 Batch loss: 0.514663 Batch F1: 0.761904761904762
# Epoch:   41        3 Batch loss: 0.393409 Batch F1: 0.9189189189189189
# Epoch:   41        4 Batch loss: 0.544341 Batch F1: 0.7111111111111111
# Epoch:   41        5 Batch loss: 0.470337 Batch F1: 0.8260869565217391
# Epoch:   41        6 Batch loss: 0.540700 Batch F1: 0.7777777777777777
# Train Avg Loss   41: 0.502392
#
# Train Avg F1   41: 0.7865339635922431
#
# Val Avg Loss   41: 0.237746
#
# Val Avg F1   41:  0.7218078104431769
#
# Optimal Val loss (Epoch 23): 0.22002538293600082
#
# Epoch 42
# --------------------------------------------------------------
# Epoch:   42        1 Batch loss: 0.527886 Batch F1: 0.8
# Epoch:   42        2 Batch loss: 0.434446 Batch F1: 0.8571428571428571
# Epoch:   42        3 Batch loss: 0.478346 Batch F1: 0.8363636363636363
# Epoch:   42        4 Batch loss: 0.512798 Batch F1: 0.8085106382978724
# Epoch:   42        5 Batch loss: 0.520357 Batch F1: 0.7222222222222222
# Epoch:   42        6 Batch loss: 0.496222 Batch F1: 0.8000000000000002
# Train Avg Loss   42: 0.495009
#
# Train Avg F1   42: 0.8040398923377646
#
# Val Avg Loss   42: 0.221898
#
# Val Avg F1   42:  0.7737315875613747
#
# Optimal Val loss (Epoch 23): 0.22002538293600082
#
# Epoch 43
# --------------------------------------------------------------
# Epoch:   43        1 Batch loss: 0.480048 Batch F1: 0.8235294117647058
# Epoch:   43        2 Batch loss: 0.475721 Batch F1: 0.8400000000000001
# Epoch:   43        3 Batch loss: 0.453776 Batch F1: 0.8510638297872342
# Epoch:   43        4 Batch loss: 0.505109 Batch F1: 0.7222222222222222
# Epoch:   43        5 Batch loss: 0.491793 Batch F1: 0.8400000000000001
# Epoch:   43        6 Batch loss: 0.506947 Batch F1: 0.7741935483870969
# Train Avg Loss   43: 0.485566
#
# Train Avg F1   43: 0.8085015020268765
#
# Val Avg Loss   43: 0.257540
#
# Val Avg F1   43:  0.6861111111111111
#
# Optimal Val loss (Epoch 23): 0.22002538293600082
#
# Epoch 44
# --------------------------------------------------------------
# Epoch:   44        1 Batch loss: 0.551306 Batch F1: 0.7450980392156863
# Epoch:   44        2 Batch loss: 0.461817 Batch F1: 0.7777777777777778
# Epoch:   44        3 Batch loss: 0.453540 Batch F1: 0.8444444444444444
# Epoch:   44        4 Batch loss: 0.500044 Batch F1: 0.7804878048780488
# Epoch:   44        5 Batch loss: 0.601189 Batch F1: 0.7169811320754716
# Epoch:   44        6 Batch loss: 0.437252 Batch F1: 0.8571428571428572
# Train Avg Loss   44: 0.500858
#
# Train Avg F1   44: 0.7869886759223811
#
# Val Avg Loss   44: 0.240280
#
# Val Avg F1   44:  0.7705802968960863
#
# Optimal Val loss (Epoch 23): 0.22002538293600082
#
# Epoch 45
# --------------------------------------------------------------
# Epoch:   45        1 Batch loss: 0.398631 Batch F1: 0.8936170212765958
# Epoch:   45        2 Batch loss: 0.513366 Batch F1: 0.6829268292682927
# Epoch:   45        3 Batch loss: 0.491892 Batch F1: 0.823529411764706
# Epoch:   45        4 Batch loss: 0.564113 Batch F1: 0.7692307692307693
# Epoch:   45        5 Batch loss: 0.535204 Batch F1: 0.7924528301886793
# Epoch:   45        6 Batch loss: 0.475354 Batch F1: 0.7692307692307692
# Train Avg Loss   45: 0.496427
#
# Train Avg F1   45: 0.7884979384933021
#
# Val Avg Loss   45: 0.255728
#
# Val Avg F1   45:  0.7057502246181492
#
# Optimal Val loss (Epoch 23): 0.22002538293600082
#
# Epoch 46
# --------------------------------------------------------------
# Epoch:   46        1 Batch loss: 0.447801 Batch F1: 0.8888888888888888
# Epoch:   46        2 Batch loss: 0.549233 Batch F1: 0.6486486486486486
# Epoch:   46        3 Batch loss: 0.460730 Batch F1: 0.8372093023255814
# Epoch:   46        4 Batch loss: 0.510661 Batch F1: 0.7222222222222222
# Epoch:   46        5 Batch loss: 0.464432 Batch F1: 0.8571428571428572
# Epoch:   46        6 Batch loss: 0.584566 Batch F1: 0.7441860465116279
# Train Avg Loss   46: 0.502904
#
# Train Avg F1   46: 0.7830496609566376
#
# Val Avg Loss   46: 0.223733
#
# Val Avg F1   46:  0.7677551020408163
#
# Optimal Val loss (Epoch 23): 0.22002538293600082
#
# Epoch 47
# --------------------------------------------------------------
# Epoch:   47        1 Batch loss: 0.428845 Batch F1: 0.8936170212765958
# Epoch:   47        2 Batch loss: 0.532159 Batch F1: 0.717948717948718
# Epoch:   47        3 Batch loss: 0.476495 Batch F1: 0.8
# Epoch:   47        4 Batch loss: 0.498208 Batch F1: 0.7906976744186046
# Epoch:   47        5 Batch loss: 0.453535 Batch F1: 0.8444444444444443
# Epoch:   47        6 Batch loss: 0.571553 Batch F1: 0.7916666666666666
# Train Avg Loss   47: 0.493466
#
# Train Avg F1   47: 0.8063957541258383
#
# Val Avg Loss   47: 0.252113
#
# Val Avg F1   47:  0.6929283341243475
#
# Optimal Val loss (Epoch 23): 0.22002538293600082
#
# Epoch 48
# --------------------------------------------------------------
# Epoch:   48        1 Batch loss: 0.410846 Batch F1: 0.8571428571428572
# Epoch:   48        2 Batch loss: 0.438627 Batch F1: 0.8695652173913043
# Epoch:   48        3 Batch loss: 0.549189 Batch F1: 0.7777777777777779
# Epoch:   48        4 Batch loss: 0.519490 Batch F1: 0.7368421052631577
# Epoch:   48        5 Batch loss: 0.590199 Batch F1: 0.6341463414634146
# Epoch:   48        6 Batch loss: 0.397678 Batch F1: 0.9565217391304348
# Train Avg Loss   48: 0.484338
#
# Train Avg F1   48: 0.8053326730281577
#
# Val Avg Loss   48: 0.214825
#
# Val Avg F1   48:  0.7767722473604826
#
# Optimal Val loss (Epoch 48): 0.21482473611831665
#
# Epoch 49
# --------------------------------------------------------------
# Epoch:   49        1 Batch loss: 0.458761 Batch F1: 0.8771929824561403
# Epoch:   49        2 Batch loss: 0.511216 Batch F1: 0.8275862068965517
# Epoch:   49        3 Batch loss: 0.577989 Batch F1: 0.5714285714285715
# Epoch:   49        4 Batch loss: 0.476275 Batch F1: 0.8571428571428572
# Epoch:   49        5 Batch loss: 0.490084 Batch F1: 0.8085106382978724
# Epoch:   49        6 Batch loss: 0.420107 Batch F1: 0.888888888888889
# Train Avg Loss   49: 0.489072
#
# Train Avg F1   49: 0.8051250241851471
#
# Val Avg Loss   49: 0.227237
#
# Val Avg F1   49:  0.7151515151515152
#
# Optimal Val loss (Epoch 48): 0.21482473611831665
#
# Epoch 50
# --------------------------------------------------------------
# Epoch:   50        1 Batch loss: 0.547496 Batch F1: 0.7111111111111111
# Epoch:   50        2 Batch loss: 0.564144 Batch F1: 0.7307692307692307
# Epoch:   50        3 Batch loss: 0.426397 Batch F1: 0.878048780487805
# Epoch:   50        4 Batch loss: 0.483051 Batch F1: 0.8260869565217391
# Epoch:   50        5 Batch loss: 0.481624 Batch F1: 0.7222222222222223
# Epoch:   50        6 Batch loss: 0.439287 Batch F1: 0.8823529411764706
# Train Avg Loss   50: 0.490333
#
# Train Avg F1   50: 0.7917652070480964
#
# Val Avg Loss   50: 0.218778
#
# Val Avg F1   50:  0.7566158781074579
#
# Optimal Val loss (Epoch 48): 0.21482473611831665
#
# Epoch 51
# --------------------------------------------------------------
# Epoch:   51        1 Batch loss: 0.474982 Batch F1: 0.8333333333333333
# Epoch:   51        2 Batch loss: 0.526969 Batch F1: 0.744186046511628
# Epoch:   51        3 Batch loss: 0.458863 Batch F1: 0.787878787878788
# Epoch:   51        4 Batch loss: 0.559875 Batch F1: 0.7346938775510203
# Epoch:   51        5 Batch loss: 0.505836 Batch F1: 0.8363636363636364
# Epoch:   51        6 Batch loss: 0.392621 Batch F1: 0.9523809523809523
# Train Avg Loss   51: 0.486524
#
# Train Avg F1   51: 0.8148061056698931
#
# Val Avg Loss   51: 0.226070
#
# Val Avg F1   51:  0.7555277430120986
#
# Optimal Val loss (Epoch 48): 0.21482473611831665
#
# Epoch 52
# --------------------------------------------------------------
# Epoch:   52        1 Batch loss: 0.425925 Batch F1: 0.8979591836734694
# Epoch:   52        2 Batch loss: 0.449084 Batch F1: 0.8292682926829269
# Epoch:   52        3 Batch loss: 0.533088 Batch F1: 0.7924528301886793
# Epoch:   52        4 Batch loss: 0.494032 Batch F1: 0.7567567567567567
# Epoch:   52        5 Batch loss: 0.561358 Batch F1: 0.6486486486486486
# Epoch:   52        6 Batch loss: 0.502239 Batch F1: 0.7777777777777778
# Train Avg Loss   52: 0.494288
#
# Train Avg F1   52: 0.7838105816213764
#
# Val Avg Loss   52: 0.228455
#
# Val Avg F1   52:  0.7442553191489361
#
# Optimal Val loss (Epoch 48): 0.21482473611831665
#
# Epoch 53
# --------------------------------------------------------------
# Epoch:   53        1 Batch loss: 0.503117 Batch F1: 0.8163265306122449
# Epoch:   53        2 Batch loss: 0.526692 Batch F1: 0.7659574468085107
# Epoch:   53        3 Batch loss: 0.467473 Batch F1: 0.8679245283018868
# Epoch:   53        4 Batch loss: 0.463268 Batch F1: 0.8372093023255814
# Epoch:   53        5 Batch loss: 0.491527 Batch F1: 0.7692307692307692
# Epoch:   53        6 Batch loss: 0.575382 Batch F1: 0.7428571428571428
# Train Avg Loss   53: 0.504576
#
# Train Avg F1   53: 0.7999176200226894
#
# Val Avg Loss   53: 0.217845
#
# Val Avg F1   53:  0.7824074074074074
#
# Optimal Val loss (Epoch 48): 0.21482473611831665
#
# Epoch 54
# --------------------------------------------------------------
# Epoch:   54        1 Batch loss: 0.511749 Batch F1: 0.8
# Epoch:   54        2 Batch loss: 0.476217 Batch F1: 0.7333333333333334
# Epoch:   54        3 Batch loss: 0.448406 Batch F1: 0.8749999999999999
# Epoch:   54        4 Batch loss: 0.489482 Batch F1: 0.816326530612245
# Epoch:   54        5 Batch loss: 0.484583 Batch F1: 0.8620689655172413
# Epoch:   54        6 Batch loss: 0.493948 Batch F1: 0.7199999999999999
# Train Avg Loss   54: 0.484064
#
# Train Avg F1   54: 0.8011214715771365
#
# Val Avg Loss   54: 0.232251
#
# Val Avg F1   54:  0.7291666666666666
#
# Optimal Val loss (Epoch 48): 0.21482473611831665
#
# Epoch 55
# --------------------------------------------------------------
# Epoch:   55        1 Batch loss: 0.505277 Batch F1: 0.782608695652174
# Epoch:   55        2 Batch loss: 0.567948 Batch F1: 0.7868852459016393
# Epoch:   55        3 Batch loss: 0.513772 Batch F1: 0.7916666666666666
# Epoch:   55        4 Batch loss: 0.428608 Batch F1: 0.8636363636363636
# Epoch:   55        5 Batch loss: 0.465887 Batch F1: 0.8292682926829269
# Epoch:   55        6 Batch loss: 0.452160 Batch F1: 0.8387096774193549
# Train Avg Loss   55: 0.488942
#
# Train Avg F1   55: 0.8154624903265209
#
# Val Avg Loss   55: 0.221551
#
# Val Avg F1   55:  0.7883832778394377
#
# Optimal Val loss (Epoch 48): 0.21482473611831665
#
# Epoch 56
# --------------------------------------------------------------
# Epoch:   56        1 Batch loss: 0.470067 Batch F1: 0.8444444444444444
# Epoch:   56        2 Batch loss: 0.405763 Batch F1: 0.8837209302325582
# Epoch:   56        3 Batch loss: 0.488719 Batch F1: 0.8235294117647057
# Epoch:   56        4 Batch loss: 0.446941 Batch F1: 0.8799999999999999
# Epoch:   56        5 Batch loss: 0.559872 Batch F1: 0.7450980392156864
# Epoch:   56        6 Batch loss: 0.568498 Batch F1: 0.6666666666666666
# Train Avg Loss   56: 0.489977
#
# Train Avg F1   56: 0.807243248720677
#
# Val Avg Loss   56: 0.234709
#
# Val Avg F1   56:  0.6824074074074075
#
# Optimal Val loss (Epoch 48): 0.21482473611831665
#
# Epoch 57
# --------------------------------------------------------------
# Epoch:   57        1 Batch loss: 0.513176 Batch F1: 0.7317073170731708
# Epoch:   57        2 Batch loss: 0.549961 Batch F1: 0.75
# Epoch:   57        3 Batch loss: 0.456971 Batch F1: 0.8571428571428571
# Epoch:   57        4 Batch loss: 0.513148 Batch F1: 0.8
# Epoch:   57        5 Batch loss: 0.473494 Batch F1: 0.8095238095238095
# Epoch:   57        6 Batch loss: 0.366407 Batch F1: 0.9473684210526315
# Train Avg Loss   57: 0.478860
#
# Train Avg F1   57: 0.8159570674654115
#
# Val Avg Loss   57: 0.220108
#
# Val Avg F1   57:  0.7655482815057283
#
# Optimal Val loss (Epoch 48): 0.21482473611831665
#
# Epoch 58
# --------------------------------------------------------------
# Epoch:   58        1 Batch loss: 0.464306 Batch F1: 0.8181818181818182
# Epoch:   58        2 Batch loss: 0.438842 Batch F1: 0.88
# Epoch:   58        3 Batch loss: 0.535436 Batch F1: 0.7027027027027027
# Epoch:   58        4 Batch loss: 0.435780 Batch F1: 0.8749999999999999
# Epoch:   58        5 Batch loss: 0.573565 Batch F1: 0.7111111111111111
# Epoch:   58        6 Batch loss: 0.437705 Batch F1: 0.9
# Train Avg Loss   58: 0.480939
#
# Train Avg F1   58: 0.8144992719992721
#
# Val Avg Loss   58: 0.223271
#
# Val Avg F1   58:  0.7505214851898205
#
# Optimal Val loss (Epoch 48): 0.21482473611831665
#
# Epoch 59
# --------------------------------------------------------------
# Epoch:   59        1 Batch loss: 0.489901 Batch F1: 0.7906976744186046
# Epoch:   59        2 Batch loss: 0.526355 Batch F1: 0.7317073170731707
# Epoch:   59        3 Batch loss: 0.475764 Batch F1: 0.7999999999999999
# Epoch:   59        4 Batch loss: 0.516517 Batch F1: 0.7916666666666666
# Epoch:   59        5 Batch loss: 0.461565 Batch F1: 0.8333333333333333
# Epoch:   59        6 Batch loss: 0.424227 Batch F1: 0.8823529411764706
# Train Avg Loss   59: 0.482388
#
# Train Avg F1   59: 0.8049596554447076
#
# Val Avg Loss   59: 0.215690
#
# Val Avg F1   59:  0.7771493212669683
#
# Optimal Val loss (Epoch 48): 0.21482473611831665
#
# Epoch 60
# --------------------------------------------------------------
# Epoch:   60        1 Batch loss: 0.455400 Batch F1: 0.8571428571428572
# Epoch:   60        2 Batch loss: 0.533454 Batch F1: 0.8
# Epoch:   60        3 Batch loss: 0.447234 Batch F1: 0.85
# Epoch:   60        4 Batch loss: 0.447615 Batch F1: 0.8627450980392156
# Epoch:   60        5 Batch loss: 0.528400 Batch F1: 0.7555555555555556
# Epoch:   60        6 Batch loss: 0.496532 Batch F1: 0.7878787878787877
# Train Avg Loss   60: 0.484772
#
# Train Avg F1   60: 0.8188870497694029
#
# Val Avg Loss   60: 0.252711
#
# Val Avg F1   60:  0.6846846846846846
#
# Optimal Val loss (Epoch 48): 0.21482473611831665
#
# Epoch 61
# --------------------------------------------------------------
# Epoch:   61        1 Batch loss: 0.479338 Batch F1: 0.823529411764706
# Epoch:   61        2 Batch loss: 0.485035 Batch F1: 0.8095238095238095
# Epoch:   61        3 Batch loss: 0.491592 Batch F1: 0.7555555555555555
# Epoch:   61        4 Batch loss: 0.506860 Batch F1: 0.8076923076923077
# Epoch:   61        5 Batch loss: 0.457824 Batch F1: 0.8181818181818182
# Epoch:   61        6 Batch loss: 0.572112 Batch F1: 0.608695652173913
# Train Avg Loss   61: 0.498794
#
# Train Avg F1   61: 0.770529759148685
#
# Val Avg Loss   61: 0.214148
#
# Val Avg F1   61:  0.7767722473604826
#
# Optimal Val loss (Epoch 61): 0.21414755284786224
#
# Epoch 62
# --------------------------------------------------------------
# Epoch:   62        1 Batch loss: 0.479074 Batch F1: 0.8260869565217391
# Epoch:   62        2 Batch loss: 0.428408 Batch F1: 0.8837209302325583
# Epoch:   62        3 Batch loss: 0.480160 Batch F1: 0.8260869565217391
# Epoch:   62        4 Batch loss: 0.557168 Batch F1: 0.7857142857142857
# Epoch:   62        5 Batch loss: 0.508508 Batch F1: 0.7555555555555555
# Epoch:   62        6 Batch loss: 0.455050 Batch F1: 0.7692307692307693
# Train Avg Loss   62: 0.484728
#
# Train Avg F1   62: 0.8077325756294411
#
# Val Avg Loss   62: 0.252574
#
# Val Avg F1   62:  0.7030038759689923
#
# Optimal Val loss (Epoch 61): 0.21414755284786224
#
# Epoch 63
# --------------------------------------------------------------
# Epoch:   63        1 Batch loss: 0.454033 Batch F1: 0.8571428571428572
# Epoch:   63        2 Batch loss: 0.538272 Batch F1: 0.7755102040816326
# Epoch:   63        3 Batch loss: 0.518156 Batch F1: 0.7755102040816326
# Epoch:   63        4 Batch loss: 0.522432 Batch F1: 0.761904761904762
# Epoch:   63        5 Batch loss: 0.428166 Batch F1: 0.8837209302325583
# Epoch:   63        6 Batch loss: 0.508639 Batch F1: 0.7407407407407408
# Train Avg Loss   63: 0.494950
#
# Train Avg F1   63: 0.7990882830306972
#
# Val Avg Loss   63: 0.232634
#
# Val Avg F1   63:  0.7429467084639498
#
# Optimal Val loss (Epoch 61): 0.21414755284786224
#
# Epoch 64
# --------------------------------------------------------------
# Epoch:   64        1 Batch loss: 0.512082 Batch F1: 0.8076923076923077
# Epoch:   64        2 Batch loss: 0.474527 Batch F1: 0.846153846153846
# Epoch:   64        3 Batch loss: 0.481506 Batch F1: 0.7500000000000001
# Epoch:   64        4 Batch loss: 0.409511 Batch F1: 0.9
# Epoch:   64        5 Batch loss: 0.456738 Batch F1: 0.8571428571428572
# Epoch:   64        6 Batch loss: 0.601451 Batch F1: 0.7368421052631577
# Train Avg Loss   64: 0.489302
#
# Train Avg F1   64: 0.8163051860420282
#
# Val Avg Loss   64: 0.238691
#
# Val Avg F1   64:  0.7298456260720412
#
# Optimal Val loss (Epoch 61): 0.21414755284786224
#
# Epoch 65
# --------------------------------------------------------------
# Epoch:   65        1 Batch loss: 0.501651 Batch F1: 0.7906976744186046
# Epoch:   65        2 Batch loss: 0.477662 Batch F1: 0.7272727272727274
# Epoch:   65        3 Batch loss: 0.488597 Batch F1: 0.851851851851852
# Epoch:   65        4 Batch loss: 0.468653 Batch F1: 0.8461538461538461
# Epoch:   65        5 Batch loss: 0.484565 Batch F1: 0.8421052631578947
# Epoch:   65        6 Batch loss: 0.460655 Batch F1: 0.7826086956521738
# Train Avg Loss   65: 0.480297
#
# Train Avg F1   65: 0.8067816764178497
#
# Val Avg Loss   65: 0.216575
#
# Val Avg F1   65:  0.799342105263158
#
# Optimal Val loss (Epoch 61): 0.21414755284786224
#
# Epoch 66
# --------------------------------------------------------------
# Epoch:   66        1 Batch loss: 0.503109 Batch F1: 0.823529411764706
# Epoch:   66        2 Batch loss: 0.439296 Batch F1: 0.8372093023255814
# Epoch:   66        3 Batch loss: 0.537768 Batch F1: 0.8000000000000002
# Epoch:   66        4 Batch loss: 0.467720 Batch F1: 0.7999999999999999
# Epoch:   66        5 Batch loss: 0.461071 Batch F1: 0.787878787878788
# Epoch:   66        6 Batch loss: 0.477567 Batch F1: 0.8108108108108109
# Train Avg Loss   66: 0.481088
#
# Train Avg F1   66: 0.8099047187966476
#
# Val Avg Loss   66: 0.258435
#
# Val Avg F1   66:  0.6753678215472236
#
# Optimal Val loss (Epoch 61): 0.21414755284786224
#
# Epoch 67
# --------------------------------------------------------------
# Epoch:   67        1 Batch loss: 0.503811 Batch F1: 0.7179487179487181
# Epoch:   67        2 Batch loss: 0.539247 Batch F1: 0.7555555555555555
# Epoch:   67        3 Batch loss: 0.513204 Batch F1: 0.7727272727272727
# Epoch:   67        4 Batch loss: 0.406344 Batch F1: 0.8947368421052632
# Epoch:   67        5 Batch loss: 0.401876 Batch F1: 0.92
# Epoch:   67        6 Batch loss: 0.505670 Batch F1: 0.8205128205128205
# Train Avg Loss   67: 0.478359
#
# Train Avg F1   67: 0.8135802014749384
#
# Val Avg Loss   67: 0.221562
#
# Val Avg F1   67:  0.7766439909297052
#
# Optimal Val loss (Epoch 61): 0.21414755284786224
#
# Epoch 68
# --------------------------------------------------------------
# ...
# Epoch:   77        4 Batch loss: 0.488410 Batch F1: 0.816326530612245
# Epoch:   77        5 Batch loss: 0.494046 Batch F1: 0.7368421052631577
# Epoch:   77        6 Batch loss: 0.414826 Batch F1: 0.8823529411764706
# Train Avg Loss   77: 0.474277
#
# Train Avg F1   77: 0.8185372338984429
#
# Val Avg Loss   77: 0.248087
#
# Val Avg F1   77:  0.6877890841813136
#
# Optimal Val loss (Epoch 61): 0.21414755284786224
#
# Epoch 78
# --------------------------------------------------------------
# Epoch:   78        1 Batch loss: 0.493676 Batch F1: 0.830188679245283
# Epoch:   78        2 Batch loss: 0.452955 Batch F1: 0.8292682926829269
# Epoch:   78        3 Batch loss: 0.398269 Batch F1: 0.9130434782608696
# Epoch:   78        4 Batch loss: 0.505052 Batch F1: 0.7428571428571429
# Epoch:   78        5 Batch loss: 0.581935 Batch F1: 0.693877551020408
# Epoch:   78        6 Batch loss: 0.516789 Batch F1: 0.742857142857143
# Train Avg Loss   78: 0.491446
#
# Train Avg F1   78: 0.7920153811539623
#
# Val Avg Loss   78: 0.235594
#
# Val Avg F1   78:  0.7305835892935498
#
# Optimal Val loss (Epoch 61): 0.21414755284786224
#
# Epoch 79
# --------------------------------------------------------------
# Epoch:   79        1 Batch loss: 0.512904 Batch F1: 0.7000000000000001
# Epoch:   79        2 Batch loss: 0.498584 Batch F1: 0.7826086956521738
# Epoch:   79        3 Batch loss: 0.479622 Batch F1: 0.8181818181818182
# Epoch:   79        4 Batch loss: 0.604746 Batch F1: 0.6190476190476191
# Epoch:   79        5 Batch loss: 0.458285 Batch F1: 0.84
# Epoch:   79        6 Batch loss: 0.455397 Batch F1: 0.846153846153846
# Train Avg Loss   79: 0.501590
#
# Train Avg F1   79: 0.767665329839243
#
# Val Avg Loss   79: 0.252933
#
# Val Avg F1   79:  0.7227272727272727
#
# Optimal Val loss (Epoch 61): 0.21414755284786224
#
# Epoch 80
# --------------------------------------------------------------
# Epoch:   80        1 Batch loss: 0.509739 Batch F1: 0.823529411764706
# Epoch:   80        2 Batch loss: 0.526835 Batch F1: 0.7391304347826088
# Epoch:   80        3 Batch loss: 0.415531 Batch F1: 0.8648648648648649
# Epoch:   80        4 Batch loss: 0.434895 Batch F1: 0.88
# Epoch:   80        5 Batch loss: 0.560332 Batch F1: 0.7111111111111111
# Epoch:   80        6 Batch loss: 0.493005 Batch F1: 0.8421052631578947
# Train Avg Loss   80: 0.490056
#
# Train Avg F1   80: 0.8101235142801976
#
# Val Avg Loss   80: 0.231421
#
# Val Avg F1   80:  0.7219387755102041
#
# Optimal Val loss (Epoch 61): 0.21414755284786224
#
# Epoch 81
# --------------------------------------------------------------
# Epoch:   81        1 Batch loss: 0.481427 Batch F1: 0.8333333333333333
# Epoch:   81        2 Batch loss: 0.440140 Batch F1: 0.88
# Epoch:   81        3 Batch loss: 0.543374 Batch F1: 0.76
# Epoch:   81        4 Batch loss: 0.495261 Batch F1: 0.6896551724137931
# Epoch:   81        5 Batch loss: 0.532243 Batch F1: 0.7317073170731706
# Epoch:   81        6 Batch loss: 0.453879 Batch F1: 0.8571428571428572
# Train Avg Loss   81: 0.491054
#
# Train Avg F1   81: 0.7919731133271924
#
# Val Avg Loss   81: 0.235078
#
# Val Avg F1   81:  0.7290490664350846
#
# Optimal Val loss (Epoch 61): 0.21414755284786224
#
# Epoch 82
# --------------------------------------------------------------
# Epoch:   82        1 Batch loss: 0.493013 Batch F1: 0.8
# Epoch:   82        2 Batch loss: 0.474454 Batch F1: 0.8292682926829269
# Epoch:   82        3 Batch loss: 0.486356 Batch F1: 0.8363636363636363
# Epoch:   82        4 Batch loss: 0.454213 Batch F1: 0.7333333333333334
# Epoch:   82        5 Batch loss: 0.543764 Batch F1: 0.75
# Epoch:   82        6 Batch loss: 0.512295 Batch F1: 0.787878787878788
# Train Avg Loss   82: 0.494016
#
# Train Avg F1   82: 0.7894740083764474
#
# Val Avg Loss   82: 0.236128
#
# Val Avg F1   82:  0.7291666666666666
#
# Optimal Val loss (Epoch 61): 0.21414755284786224
#
# Epoch 83
# --------------------------------------------------------------
# Epoch:   83        1 Batch loss: 0.513071 Batch F1: 0.7916666666666667
# Epoch:   83        2 Batch loss: 0.472328 Batch F1: 0.7906976744186047
# Epoch:   83        3 Batch loss: 0.507172 Batch F1: 0.7826086956521738
# Epoch:   83        4 Batch loss: 0.471178 Batch F1: 0.8260869565217391
# Epoch:   83        5 Batch loss: 0.473310 Batch F1: 0.8813559322033899
# Epoch:   83        6 Batch loss: 0.513942 Batch F1: 0.7586206896551724
# Train Avg Loss   83: 0.491834
#
# Train Avg F1   83: 0.8051727691862912
#
# Val Avg Loss   83: 0.242121
#
# Val Avg F1   83:  0.7082560296846011
#
# Optimal Val loss (Epoch 61): 0.21414755284786224
#
# Epoch 84
# --------------------------------------------------------------
# Epoch:   84        1 Batch loss: 0.434890 Batch F1: 0.8571428571428571
# Epoch:   84        2 Batch loss: 0.510573 Batch F1: 0.75
# Epoch:   84        3 Batch loss: 0.496448 Batch F1: 0.7826086956521738
# Epoch:   84        4 Batch loss: 0.517019 Batch F1: 0.7916666666666666
# Epoch:   84        5 Batch loss: 0.589460 Batch F1: 0.6341463414634146
# Epoch:   84        6 Batch loss: 0.382072 Batch F1: 0.9523809523809523
# Train Avg Loss   84: 0.488410
#
# Train Avg F1   84: 0.7946575855510107
#
# Val Avg Loss   84: 0.228649
#
# Val Avg F1   84:  0.746317512274959
#
# Optimal Val loss (Epoch 61): 0.21414755284786224
#
# Epoch 85
# --------------------------------------------------------------
# Epoch:   85        1 Batch loss: 0.459104 Batch F1: 0.8372093023255814
# Epoch:   85        2 Batch loss: 0.550411 Batch F1: 0.7142857142857143
# Epoch:   85        3 Batch loss: 0.503811 Batch F1: 0.8076923076923077
# Epoch:   85        4 Batch loss: 0.507268 Batch F1: 0.8148148148148148
# Epoch:   85        5 Batch loss: 0.395436 Batch F1: 0.9387755102040817
# Epoch:   85        6 Batch loss: 0.502695 Batch F1: 0.7741935483870969
# Train Avg Loss   85: 0.486454
#
# Train Avg F1   85: 0.8144951996182662
#
# Val Avg Loss   85: 0.253321
#
# Val Avg F1   85:  0.7263636363636363
#
# Optimal Val loss (Epoch 61): 0.21414755284786224
#
# Epoch 86
# --------------------------------------------------------------
# Epoch:   86        1 Batch loss: 0.465087 Batch F1: 0.8333333333333334
# Epoch:   86        2 Batch loss: 0.477952 Batch F1: 0.7567567567567567
# Epoch:   86        3 Batch loss: 0.525690 Batch F1: 0.7692307692307692
# Epoch:   86        4 Batch loss: 0.544771 Batch F1: 0.6976744186046512
# Epoch:   86        5 Batch loss: 0.510823 Batch F1: 0.761904761904762
# Epoch:   86        6 Batch loss: 0.399880 Batch F1: 0.8947368421052632
# Train Avg Loss   86: 0.487367
#
# Train Avg F1   86: 0.7856061469892559
#
# Val Avg Loss   86: 0.260559
#
# Val Avg F1   86:  0.723731884057971
#
# Optimal Val loss (Epoch 61): 0.21414755284786224
#
# Epoch 87
# --------------------------------------------------------------
# Epoch:   87        1 Batch loss: 0.543326 Batch F1: 0.717948717948718
# Epoch:   87        2 Batch loss: 0.476372 Batch F1: 0.851063829787234
# Epoch:   87        3 Batch loss: 0.433877 Batch F1: 0.7878787878787878
# Epoch:   87        4 Batch loss: 0.507947 Batch F1: 0.7843137254901961
# Epoch:   87        5 Batch loss: 0.529427 Batch F1: 0.7843137254901961
# Epoch:   87        6 Batch loss: 0.405266 Batch F1: 0.896551724137931
# Train Avg Loss   87: 0.482703
#
# Train Avg F1   87: 0.8036784184555105
#
# Val Avg Loss   87: 0.220070
#
# Val Avg F1   87:  0.7717996289424862
#
# Optimal Val loss (Epoch 61): 0.21414755284786224
#
# Epoch 88
# --------------------------------------------------------------
# Epoch:   88        1 Batch loss: 0.545407 Batch F1: 0.7692307692307692
# Epoch:   88        2 Batch loss: 0.409526 Batch F1: 0.9047619047619048
# Epoch:   88        3 Batch loss: 0.475294 Batch F1: 0.8518518518518519
# Epoch:   88        4 Batch loss: 0.457175 Batch F1: 0.8627450980392156
# Epoch:   88        5 Batch loss: 0.530192 Batch F1: 0.7142857142857143
# Epoch:   88        6 Batch loss: 0.500447 Batch F1: 0.6956521739130435
# Train Avg Loss   88: 0.486340
#
# Train Avg F1   88: 0.7997545853470832
#
# Val Avg Loss   88: 0.290968
#
# Val Avg F1   88:  0.6606123508043591
#
# Optimal Val loss (Epoch 61): 0.21414755284786224
#
# Epoch 89
# --------------------------------------------------------------
# Epoch:   89        1 Batch loss: 0.528648 Batch F1: 0.8076923076923077
# Epoch:   89        2 Batch loss: 0.545219 Batch F1: 0.7027027027027027
# Epoch:   89        3 Batch loss: 0.498275 Batch F1: 0.7428571428571429
# Epoch:   89        4 Batch loss: 0.501408 Batch F1: 0.7916666666666667
# Epoch:   89        5 Batch loss: 0.449159 Batch F1: 0.8444444444444444
# Epoch:   89        6 Batch loss: 0.443555 Batch F1: 0.8823529411764706
# Train Avg Loss   89: 0.494377
#
# Train Avg F1   89: 0.7952860342566225
#
# Val Avg Loss   89: 0.210159
#
# Val Avg F1   89:  0.7817982456140351
#
# Optimal Val loss (Epoch 89): 0.21015885472297668
#
# Epoch 90
# --------------------------------------------------------------
# Epoch:   90        1 Batch loss: 0.555703 Batch F1: 0.7234042553191489
# Epoch:   90        2 Batch loss: 0.493966 Batch F1: 0.7647058823529412
# Epoch:   90        3 Batch loss: 0.499313 Batch F1: 0.8363636363636364
# Epoch:   90        4 Batch loss: 0.435725 Batch F1: 0.8695652173913043
# Epoch:   90        5 Batch loss: 0.518977 Batch F1: 0.761904761904762
# Epoch:   90        6 Batch loss: 0.535883 Batch F1: 0.7777777777777778
# Train Avg Loss   90: 0.506595
#
# Train Avg F1   90: 0.7889535885182618
#
# Val Avg Loss   90: 0.295150
#
# Val Avg F1   90:  0.6515151515151516
#
# Optimal Val loss (Epoch 89): 0.21015885472297668
#
# Epoch 91
# --------------------------------------------------------------
# Epoch:   91        1 Batch loss: 0.432206 Batch F1: 0.8636363636363635
# Epoch:   91        2 Batch loss: 0.508867 Batch F1: 0.75
# Epoch:   91        3 Batch loss: 0.477498 Batch F1: 0.8400000000000001
# Epoch:   91        4 Batch loss: 0.531769 Batch F1: 0.7000000000000001
# Epoch:   91        5 Batch loss: 0.477078 Batch F1: 0.8400000000000001
# Epoch:   91        6 Batch loss: 0.494651 Batch F1: 0.8
# Train Avg Loss   91: 0.487012
#
# Train Avg F1   91: 0.798939393939394
#
# Val Avg Loss   91: 0.238955
#
# Val Avg F1   91:  0.7337662337662337
#
# Optimal Val loss (Epoch 89): 0.21015885472297668
#
# Epoch 92
# --------------------------------------------------------------
# Epoch:   92        1 Batch loss: 0.512241 Batch F1: 0.8148148148148148
# Epoch:   92        2 Batch loss: 0.446411 Batch F1: 0.8627450980392156
# Epoch:   92        3 Batch loss: 0.506857 Batch F1: 0.7222222222222222
# Epoch:   92        4 Batch loss: 0.471741 Batch F1: 0.8260869565217391
# Epoch:   92        5 Batch loss: 0.500118 Batch F1: 0.8085106382978724
# Epoch:   92        6 Batch loss: 0.467226 Batch F1: 0.8387096774193549
# Train Avg Loss   92: 0.484099
#
# Train Avg F1   92: 0.8121815678858698
#
# Val Avg Loss   92: 0.252056
#
# Val Avg F1   92:  0.7401709401709402
#
# Optimal Val loss (Epoch 89): 0.21015885472297668
#
# Epoch 93
# --------------------------------------------------------------
# Epoch:   93        1 Batch loss: 0.456638 Batch F1: 0.8260869565217391
# Epoch:   93        2 Batch loss: 0.434472 Batch F1: 0.9
# Epoch:   93        3 Batch loss: 0.455119 Batch F1: 0.8181818181818181
# Epoch:   93        4 Batch loss: 0.469687 Batch F1: 0.7894736842105263
# Epoch:   93        5 Batch loss: 0.591114 Batch F1: 0.6666666666666666
# Epoch:   93        6 Batch loss: 0.494072 Batch F1: 0.7407407407407408
# Train Avg Loss   93: 0.483517
#
# Train Avg F1   93: 0.7901916443869151
#
# Val Avg Loss   93: 0.234046
#
# Val Avg F1   93:  0.7429787234042553
#
# Optimal Val loss (Epoch 89): 0.21015885472297668
#
# Epoch 94
# --------------------------------------------------------------
# Epoch:   94        1 Batch loss: 0.426859 Batch F1: 0.8571428571428571
# Epoch:   94        2 Batch loss: 0.505225 Batch F1: 0.8085106382978724
# Epoch:   94        3 Batch loss: 0.451044 Batch F1: 0.8510638297872342
# Epoch:   94        4 Batch loss: 0.485691 Batch F1: 0.8333333333333333
# Epoch:   94        5 Batch loss: 0.476889 Batch F1: 0.8333333333333334
# Epoch:   94        6 Batch loss: 0.570209 Batch F1: 0.75
# Train Avg Loss   94: 0.485986
#
# Train Avg F1   94: 0.8222306653157716
#
# Val Avg Loss   94: 0.245930
#
# Val Avg F1   94:  0.7417021276595744
#
# Optimal Val loss (Epoch 89): 0.21015885472297668
#
# Epoch 95
# --------------------------------------------------------------
# Epoch:   95        1 Batch loss: 0.487860 Batch F1: 0.7804878048780488
# Epoch:   95        2 Batch loss: 0.459171 Batch F1: 0.8813559322033899
# Epoch:   95        3 Batch loss: 0.488313 Batch F1: 0.7567567567567567
# Epoch:   95        4 Batch loss: 0.478273 Batch F1: 0.8461538461538461
# Epoch:   95        5 Batch loss: 0.468938 Batch F1: 0.8181818181818182
# Epoch:   95        6 Batch loss: 0.486578 Batch F1: 0.7857142857142857
# Train Avg Loss   95: 0.478189
#
# Train Avg F1   95: 0.8114417406480242
#
# Val Avg Loss   95: 0.258851
#
# Val Avg F1   95:  0.7021276595744681
#
# Optimal Val loss (Epoch 89): 0.21015885472297668
#
# Epoch 96
# --------------------------------------------------------------
# Epoch:   96        1 Batch loss: 0.549278 Batch F1: 0.6666666666666666
# Epoch:   96        2 Batch loss: 0.464213 Batch F1: 0.8627450980392156
# Epoch:   96        3 Batch loss: 0.508493 Batch F1: 0.8
# Epoch:   96        4 Batch loss: 0.428963 Batch F1: 0.8500000000000001
# Epoch:   96        5 Batch loss: 0.482519 Batch F1: 0.8518518518518519
# Epoch:   96        6 Batch loss: 0.411575 Batch F1: 0.888888888888889
# Train Avg Loss   96: 0.474174
#
# Train Avg F1   96: 0.8200254175744371
#
# Val Avg Loss   96: 0.236522
#
# Val Avg F1   96:  0.7424242424242424
#
# Optimal Val loss (Epoch 89): 0.21015885472297668
#
# Epoch 97
# --------------------------------------------------------------
# Epoch:   97        1 Batch loss: 0.536318 Batch F1: 0.7755102040816326
# Epoch:   97        2 Batch loss: 0.450287 Batch F1: 0.8627450980392156
# Epoch:   97        3 Batch loss: 0.440427 Batch F1: 0.8727272727272727
# Epoch:   97        4 Batch loss: 0.436628 Batch F1: 0.8333333333333333
# Epoch:   97        5 Batch loss: 0.490112 Batch F1: 0.7727272727272727
# Epoch:   97        6 Batch loss: 0.529946 Batch F1: 0.7878787878787877
# Train Avg Loss   97: 0.480620
#
# Train Avg F1   97: 0.8174869947979192
#
# Val Avg Loss   97: 0.246888
#
# Val Avg F1   97:  0.7403846153846154
#
# Optimal Val loss (Epoch 89): 0.21015885472297668
#
# Epoch 98
# --------------------------------------------------------------
# Epoch:   98        1 Batch loss: 0.392443 Batch F1: 0.9230769230769231
# Epoch:   98        2 Batch loss: 0.489349 Batch F1: 0.816326530612245
# Epoch:   98        3 Batch loss: 0.477924 Batch F1: 0.8461538461538461
# Epoch:   98        4 Batch loss: 0.457172 Batch F1: 0.7999999999999999
# Epoch:   98        5 Batch loss: 0.529291 Batch F1: 0.8
# Epoch:   98        6 Batch loss: 0.514005 Batch F1: 0.8000000000000002
# Train Avg Loss   98: 0.476697
#
# Train Avg F1   98: 0.8309262166405024
#
# Val Avg Loss   98: 0.230071
#
# Val Avg F1   98:  0.7653846153846154
#
# Optimal Val loss (Epoch 89): 0.21015885472297668
#
# Epoch 99
# --------------------------------------------------------------
# Epoch:   99        1 Batch loss: 0.463085 Batch F1: 0.8372093023255814
# Epoch:   99        2 Batch loss: 0.470058 Batch F1: 0.8260869565217391
# Epoch:   99        3 Batch loss: 0.447953 Batch F1: 0.8571428571428572
# Epoch:   99        4 Batch loss: 0.556842 Batch F1: 0.7317073170731708
# Epoch:   99        5 Batch loss: 0.457188 Batch F1: 0.8461538461538461
# Epoch:   99        6 Batch loss: 0.431652 Batch F1: 0.8947368421052632
# Train Avg Loss   99: 0.471130
#
# Train Avg F1   99: 0.832172853553743
#
# Val Avg Loss   99: 0.256758
#
# Val Avg F1   99:  0.7299174989144595
#
# Optimal Val loss (Epoch 89): 0.21015885472297668
#
# Epoch 100
# --------------------------------------------------------------
# Epoch:  100        1 Batch loss: 0.444248 Batch F1: 0.8108108108108107
# Epoch:  100        2 Batch loss: 0.469532 Batch F1: 0.8571428571428572
# Epoch:  100        3 Batch loss: 0.504419 Batch F1: 0.7999999999999999
# Epoch:  100        4 Batch loss: 0.445677 Batch F1: 0.8333333333333334
# Epoch:  100        5 Batch loss: 0.505082 Batch F1: 0.782608695652174
# Epoch:  100        6 Batch loss: 0.494516 Batch F1: 0.823529411764706
# Train Avg Loss  100: 0.477246
#
# Train Avg F1  100: 0.8179041847839802
#
# Val Avg Loss  100: 0.226743
#
# Val Avg F1  100:  0.7693486590038314
#
# Optimal Val loss (Epoch 89): 0.21015885472297668
#
# Done!
# ''

# %%
import json

# %%
results = json.load(open(path_to_res))

# %%
#print('best f1', np.max(results['val_f1']), np.argmax(results['val_f1']))
print('best f1 val', results['val_f1'][np.argmax(results['val_f1'])])
print('corr f1 train', results['train_f1'][np.argmax(results['val_f1'])])
print('corr f1 test', results['test_f1'][np.argmax(results['val_f1'])])
#print('best f1 train', np.max(results['train_f1']), np.argmax(results['train_f1']))
# Out:
# best f1 val 0.799342105263158
# corr f1 train 0.8067816764178497
# corr f1 test 0.6540880503144655

# %%
import matplotlib.pyplot as plt

# %%
plt.title('F1 score plot 5% RE threshold')
plt.ylabel('F1')
plt.xlabel('Epochs')
plt.plot(results['train_f1'],'-g', label='Train F1')
plt.plot(results['val_f1'],'-b', label='Val F1')
plt.legend(loc='upper left')
plt.ylim([0.0,1.0])
# Out:
# (0.0, 1.0)

# %%
list(results.keys())
# Out:
# ['train_loss',
#  'val_loss',
#  'test_loss',
#  'train_f1',
#  'val_f1',
#  'test_f1',
#  'train_prec',
#  'val_prec',
#  'test_prec',
#  'train_recall',
#  'val_recall',
#  'test_recall']

# %%
plt.title('Precision score plot 5% RE threshold')
plt.ylabel('Precision')
plt.xlabel('Epochs')
plt.plot(results['train_prec'],'-g', label='Train Precision')
plt.plot(results['val_prec'],'-b', label='Val Precision')
plt.legend(loc='upper left')
plt.ylim([0.0,1.0])
# Out:
# (0.0, 1.0)

# %%
plt.title('Recall score plot 5% RE threshold')
plt.ylabel('Recall')
plt.xlabel('Epochs')
plt.plot(results['train_recall'],'-g', label='Train Recall')
plt.plot(results['val_recall'],'-b', label='Val Recall')
plt.legend(loc='upper left')
plt.ylim([0.0,1.0])
# Out:
# (0.0, 1.0)

# %%
import torch
model = torch.load(best_model_path)
model.eval()
model
# Out:
# Classifier(
#   (conv1): RelGraphConv(
#     (linear_r): TypedLinear(in_size=117, out_size=64, num_types=8)
#     (dropout): Dropout(p=0.0, inplace=False)
#   )
#   (conv2): RelGraphConv(
#     (linear_r): TypedLinear(in_size=64, out_size=64, num_types=8)
#     (dropout): Dropout(p=0.0, inplace=False)
#   )
#   (classify): Linear(in_features=64, out_features=2, bias=True)
# )

# %%
from dgl_classifier. trainer import predict2samples
print(train_file)
train_data, val_data,test_data = predict2samples(model,train_file, val_file, test_file, community_no=10, verbose=True, clust_verbose=False, clust_load_path='/work/data/confs/May2/pred_clust.json')
# Out:
# /work/data/splits/splits_0.05/train.json

# %%
for k in train_data.keys():
    print(train_data[k])
    break
# Out:
# {'bloom_runtime': 0.087360461, 'jena_runtime': 0.084558884, 'gt': False, 'bgp_construction_duration': 7.557868957519531e-05, 'tps_const_duration': 0.00021219253540039062, 'prediction': 1, 'inference_time': 0.010785579681396484}

# %%
from dgl_classifier.post import *
train_rt, avg_train = avg_runtime(train_data)
_,_, avg_train_jena,avg_train_blf = avg_runtime_type(train_data)
val_rt, avg_val = avg_runtime(val_data)
_,_, avg_val_jena,avg_val_blf = avg_runtime_type(val_data)
test_rt, avg_test = avg_runtime(test_data)
_,_, avg_test_jena,avg_test_blf = avg_runtime_type(test_data)

# %%
print('Train\n','\tWith Predictions ',round(avg_train,3),', Jena: ', round(avg_train_jena,3), ', Bloom Filter',round(avg_train_blf,3))
print('Validation\n','\tWith Predictions ',round(avg_val,3),', Jena: ', round(avg_val_jena,3), ', Bloom Filter',round(avg_val_blf,3))
print('Test\n','\tWith Predictions ',round(avg_test,3),', Jena: ', round(avg_test_jena,3), ', Bloom Filter',round(avg_test_blf,3))
#print(avg_val,avg_val_jena,avg_val_blf)
#print(avg_test,avg_test_jena,avg_test_blf)
# Out:
# Train
#  	With Predictions  3.29 , Jena:  3.287 , Bloom Filter 3.972
# Validation
#  	With Predictions  5.972 , Jena:  5.971 , Bloom Filter 6.59
# Test
#  	With Predictions  3.843 , Jena:  3.806 , Bloom Filter 4.344
