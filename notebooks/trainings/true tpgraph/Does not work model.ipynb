# %% [markdown]
# file paths

# %%
train_file = '/work/data/splits/splits_0.05/train.json'
val_file = '/work/data/splits/splits_0.05/val.json'
test_file = '/work/data/splits/splits_0.05/test.json'
import os

path_to_save = '/work/data/models2_6'
os.system(f'mkdir -p {path_to_save}')
path_to_res = '/work/data/results/2_6_2023_tp_graph_5re.txt'
neurons = 64

# %% [markdown]
# import

# %%
# %load_ext autoreload
# %autoreload 2
import json
import dgl
from sklearn.metrics import f1_score
import torch as th
import dgl.nn.pytorch as dglnn
import torch.nn as nn
from dgl.dataloading import GraphDataLoader
import torch.nn.functional as F
import networkx as nx
import warnings
from feature_extraction.base_featurizer import BaseFeaturizer
import torch
from graph_construction.tps_graph import create_dummy_dgl_graph, tps_graph
import numpy as np

from dgl_classifier.trainer import GraphDataset,snap_pred, tps_to_dgl, get_clasification_vec,\
tps_graph_const, extract_data, runner


import warnings

from preprocessing.utils import load_BGPS_from_json
warnings.filterwarnings('ignore', category=UserWarning, message='TypedStorage is deprecated')

# %%
#seed
dgl.seed(1223)

# %% [markdown]
# Model

# %%
class Classifier(nn.Module):
    def __init__(self, in_dim, hidden_dim, n_classes):
        super(Classifier, self).__init__()
        self.conv1 = dglnn.RelGraphConv(in_dim, hidden_dim, 8)
        #self.conv1 = dglnn.GraphConv(in_dim, hidden_ˇdim)
        self.conv2 = dglnn.RelGraphConv(hidden_dim, hidden_dim, 8)
        #self.conv2 = dglnn.GraphConv(hidden_dim, hidden_dim)
        self.lin = nn.Linear(hidden_dim, hidden_dim)
        self.classify = nn.Linear(hidden_dim, n_classes)

    def forward(self, g, h, rel_types):
        # Apply graph convolution and activation.
        h = F.relu(self.conv1(g, h, rel_types))
        h = F.relu(self.conv2(g, h, rel_types))
        with g.local_scope():
            g.ndata['h'] = h
            # Calculate graph representation by average readout.
            hg = 0
            for ntype in g.ntypes:
                hg = hg + dgl.mean_nodes(g, 'h', ntype=ntype)
            #hg = dgl.mean_nodes(g, 'node_features')
            hg = F.relu( self.lin(hg))
            return F.softmax( self.classify(hg), dim=1)
model = Classifier(113, 20, 2)

# %% [markdown]
# hyperparameters

# %%
early_stop =100
model = Classifier(113, neurons, 2)
lr = 0.01
wd = 5e-4
epochs = 100

# %%
train_dataloader, val_dataloader, test_dataloader = extract_data(train_file, val_file, test_file, community_no=30, batch_size = 50, verbose=True)
# Out:
# /usr/local/lib/python3.10/dist-packages/dgl/backend/pytorch/tensor.py:52: UserWarning: Creating a tensor from a list of numpy.ndarrays is extremely slow. Please consider converting the list to a single numpy.ndarray with numpy.array() before converting to a tensor. (Triggered internally at ../torch/csrc/utils/tensor_new.cpp:245.)
#   return th.as_tensor(data, dtype=dtype)
# # of catesian products: 0
# # of catesian products: 0
# # of catesian products: 0
# # of predicate feats not in validation 53
# # of predicate feats not in test 7
# Training dataset size 286
# Validation dataset size 96
# Test dataset size 96

# %%
best_model_path = runner(train_dataloader,val_dataloader,test_dataloader,model, early_stop, lr, wd, epochs, path_to_res, path_to_save=path_to_save)
;
# Out:
# Epoch 1
# --------------------------------------------------------------
# Epoch:    1        1 Batch loss: 0.682372 Batch F1: 0.3225806451612903
# Epoch:    1        2 Batch loss: 0.659621 Batch F1: 0.22222222222222218
# Epoch:    1        3 Batch loss: 0.707852 Batch F1: 0.6666666666666666
# Epoch:    1        4 Batch loss: 0.680538 Batch F1: 0.43243243243243246
# Epoch:    1        5 Batch loss: 0.617961 Batch F1: 0.6976744186046512
# Epoch:    1        6 Batch loss: 0.635043 Batch F1: 0.36363636363636365
# Train Avg Loss    1: 0.663898
#
# Train Avg F1    1: 0.45086879145393777
#
# Val Avg Loss    1: 0.338179
#
# Val Avg F1    1:  0.3571428571428571
#
# Optimal Val loss (Epoch 1): 0.3381788730621338
#
# Epoch 2
# --------------------------------------------------------------
# Epoch:    2        1 Batch loss: 0.581402 Batch F1: 0.5882352941176471
# Epoch:    2        2 Batch loss: 0.654268 Batch F1: 0.3783783783783784
# Epoch:    2        3 Batch loss: 0.548521 Batch F1: 0.7659574468085107
# Epoch:    2        4 Batch loss: 0.604318 Batch F1: 0.7037037037037037
# Epoch:    2        5 Batch loss: 0.639610 Batch F1: 0.7118644067796609
# Epoch:    2        6 Batch loss: 0.713116 Batch F1: 0.5
# Train Avg Loss    2: 0.623539
#
# Train Avg F1    2: 0.6080232049646501
#
# Val Avg Loss    2: 0.254943
#
# Val Avg F1    2:  0.7332506203473945
#
# Optimal Val loss (Epoch 2): 0.2549433037638664
#
# Epoch 3
# --------------------------------------------------------------
# Epoch:    3        1 Batch loss: 0.613890 Batch F1: 0.6956521739130435
# Epoch:    3        2 Batch loss: 0.604292 Batch F1: 0.5714285714285714
# Epoch:    3        3 Batch loss: 0.657745 Batch F1: 0.5405405405405406
# Epoch:    3        4 Batch loss: 0.555000 Batch F1: 0.6341463414634146
# Epoch:    3        5 Batch loss: 0.602473 Batch F1: 0.7142857142857142
# Epoch:    3        6 Batch loss: 0.620862 Batch F1: 0.6857142857142857
# Train Avg Loss    3: 0.609044
#
# Train Avg F1    3: 0.640294604557595
#
# Val Avg Loss    3: 0.245498
#
# Val Avg F1    3:  0.7404812671337192
#
# Optimal Val loss (Epoch 3): 0.2454976886510849
#
# Epoch 4
# --------------------------------------------------------------
# Epoch:    4        1 Batch loss: 0.633015 Batch F1: 0.7
# Epoch:    4        2 Batch loss: 0.523818 Batch F1: 0.8181818181818182
# Epoch:    4        3 Batch loss: 0.547641 Batch F1: 0.723404255319149
# Epoch:    4        4 Batch loss: 0.558051 Batch F1: 0.6153846153846154
# Epoch:    4        5 Batch loss: 0.587724 Batch F1: 0.6153846153846154
# Epoch:    4        6 Batch loss: 0.565084 Batch F1: 0.6451612903225806
# Train Avg Loss    4: 0.569222
#
# Train Avg F1    4: 0.6862527657654631
#
# Val Avg Loss    4: 0.292718
#
# Val Avg F1    4:  0.4961636828644502
#
# Optimal Val loss (Epoch 3): 0.2454976886510849
#
# Epoch 5
# --------------------------------------------------------------
# Epoch:    5        1 Batch loss: 0.540254 Batch F1: 0.6666666666666666
# Epoch:    5        2 Batch loss: 0.550843 Batch F1: 0.5882352941176471
# Epoch:    5        3 Batch loss: 0.623112 Batch F1: 0.5641025641025641
# Epoch:    5        4 Batch loss: 0.559350 Batch F1: 0.711111111111111
# Epoch:    5        5 Batch loss: 0.554138 Batch F1: 0.7719298245614035
# Epoch:    5        6 Batch loss: 0.534994 Batch F1: 0.7142857142857143
# Train Avg Loss    5: 0.560448
#
# Train Avg F1    5: 0.6693885291408511
#
# Val Avg Loss    5: 0.224701
#
# Val Avg F1    5:  0.7307814992025519
#
# Optimal Val loss (Epoch 5): 0.2247009351849556
#
# Epoch 6
# --------------------------------------------------------------
# Epoch:    6        1 Batch loss: 0.537908 Batch F1: 0.7692307692307692
# Epoch:    6        2 Batch loss: 0.546645 Batch F1: 0.7599999999999999
# Epoch:    6        3 Batch loss: 0.593008 Batch F1: 0.7666666666666667
# Epoch:    6        4 Batch loss: 0.529954 Batch F1: 0.7499999999999999
# Epoch:    6        5 Batch loss: 0.576558 Batch F1: 0.5555555555555556
# Epoch:    6        6 Batch loss: 0.499947 Batch F1: 0.7407407407407408
# Train Avg Loss    6: 0.547336
#
# Train Avg F1    6: 0.7236989553656219
#
# Val Avg Loss    6: 0.293200
#
# Val Avg F1    6:  0.47937411095305826
#
# Optimal Val loss (Epoch 5): 0.2247009351849556
#
# Epoch 7
# --------------------------------------------------------------
# Epoch:    7        1 Batch loss: 0.539348 Batch F1: 0.7142857142857143
# Epoch:    7        2 Batch loss: 0.562555 Batch F1: 0.5333333333333333
# Epoch:    7        3 Batch loss: 0.562303 Batch F1: 0.5454545454545454
# Epoch:    7        4 Batch loss: 0.533507 Batch F1: 0.816326530612245
# Epoch:    7        5 Batch loss: 0.555352 Batch F1: 0.7719298245614034
# Epoch:    7        6 Batch loss: 0.539042 Batch F1: 0.7777777777777777
# Train Avg Loss    7: 0.548684
#
# Train Avg F1    7: 0.6931846210041698
#
# Val Avg Loss    7: 0.221165
#
# Val Avg F1    7:  0.7557932263814616
#
# Optimal Val loss (Epoch 7): 0.22116457670927048
#
# Epoch 8
# --------------------------------------------------------------
# Epoch:    8        1 Batch loss: 0.550460 Batch F1: 0.76
# Epoch:    8        2 Batch loss: 0.538443 Batch F1: 0.7
# Epoch:    8        3 Batch loss: 0.638675 Batch F1: 0.5
# Epoch:    8        4 Batch loss: 0.497371 Batch F1: 0.6875
# Epoch:    8        5 Batch loss: 0.522416 Batch F1: 0.6976744186046512
# Epoch:    8        6 Batch loss: 0.433072 Batch F1: 0.8648648648648648
# Train Avg Loss    8: 0.530073
#
# Train Avg F1    8: 0.7016732139115859
#
# Val Avg Loss    8: 0.210969
#
# Val Avg F1    8:  0.7400847131305353
#
# Optimal Val loss (Epoch 8): 0.2109687179327011
#
# Epoch 9
# --------------------------------------------------------------
# Epoch:    9        1 Batch loss: 0.559490 Batch F1: 0.7083333333333334
# Epoch:    9        2 Batch loss: 0.489881 Batch F1: 0.7906976744186046
# Epoch:    9        3 Batch loss: 0.498159 Batch F1: 0.8333333333333333
# Epoch:    9        4 Batch loss: 0.500506 Batch F1: 0.8260869565217391
# Epoch:    9        5 Batch loss: 0.557671 Batch F1: 0.6808510638297872
# Epoch:    9        6 Batch loss: 0.532358 Batch F1: 0.7586206896551724
# Train Avg Loss    9: 0.523011
#
# Train Avg F1    9: 0.7663205085153284
#
# Val Avg Loss    9: 0.257817
#
# Val Avg F1    9:  0.6076086956521739
#
# Optimal Val loss (Epoch 8): 0.2109687179327011
#
# Epoch 10
# --------------------------------------------------------------
# Epoch:   10        1 Batch loss: 0.534464 Batch F1: 0.6976744186046512
# Epoch:   10        2 Batch loss: 0.551617 Batch F1: 0.6486486486486487
# Epoch:   10        3 Batch loss: 0.492953 Batch F1: 0.7317073170731708
# Epoch:   10        4 Batch loss: 0.529191 Batch F1: 0.75
# Epoch:   10        5 Batch loss: 0.488752 Batch F1: 0.8260869565217391
# Epoch:   10        6 Batch loss: 0.520190 Batch F1: 0.7333333333333334
# Train Avg Loss   10: 0.519528
#
# Train Avg F1   10: 0.7312417790302573
#
# Val Avg Loss   10: 0.228082
#
# Val Avg F1   10:  0.7683823529411765
#
# Optimal Val loss (Epoch 8): 0.2109687179327011
#
# Epoch 11
# --------------------------------------------------------------
# Epoch:   11        1 Batch loss: 0.500851 Batch F1: 0.782608695652174
# Epoch:   11        2 Batch loss: 0.484413 Batch F1: 0.7999999999999999
# Epoch:   11        3 Batch loss: 0.544426 Batch F1: 0.7499999999999999
# Epoch:   11        4 Batch loss: 0.515755 Batch F1: 0.7368421052631577
# Epoch:   11        5 Batch loss: 0.511445 Batch F1: 0.7272727272727272
# Epoch:   11        6 Batch loss: 0.469696 Batch F1: 0.8571428571428571
# Train Avg Loss   11: 0.504431
#
# Train Avg F1   11: 0.7756443975551526
#
# Val Avg Loss   11: 0.251643
#
# Val Avg F1   11:  0.7290490664350846
#
# Optimal Val loss (Epoch 8): 0.2109687179327011
#
# Epoch 12
# --------------------------------------------------------------
# Epoch:   12        1 Batch loss: 0.448734 Batch F1: 0.8800000000000001
# Epoch:   12        2 Batch loss: 0.513053 Batch F1: 0.7906976744186046
# Epoch:   12        3 Batch loss: 0.497361 Batch F1: 0.7692307692307692
# Epoch:   12        4 Batch loss: 0.575346 Batch F1: 0.7083333333333334
# Epoch:   12        5 Batch loss: 0.528131 Batch F1: 0.7391304347826089
# Epoch:   12        6 Batch loss: 0.446687 Batch F1: 0.8387096774193549
# Train Avg Loss   12: 0.501552
#
# Train Avg F1   12: 0.7876836481974451
#
# Val Avg Loss   12: 0.264167
#
# Val Avg F1   12:  0.7083333333333334
#
# Optimal Val loss (Epoch 8): 0.2109687179327011
#
# Epoch 13
# --------------------------------------------------------------
# Epoch:   13        1 Batch loss: 0.516950 Batch F1: 0.7727272727272727
# Epoch:   13        2 Batch loss: 0.540488 Batch F1: 0.7317073170731706
# Epoch:   13        3 Batch loss: 0.485316 Batch F1: 0.7692307692307692
# Epoch:   13        4 Batch loss: 0.473811 Batch F1: 0.8260869565217392
# Epoch:   13        5 Batch loss: 0.455266 Batch F1: 0.8571428571428572
# Epoch:   13        6 Batch loss: 0.517288 Batch F1: 0.787878787878788
# Train Avg Loss   13: 0.498186
#
# Train Avg F1   13: 0.7907956600957662
#
# Val Avg Loss   13: 0.226498
#
# Val Avg F1   13:  0.778061224489796
#
# Optimal Val loss (Epoch 8): 0.2109687179327011
#
# Epoch 14
# --------------------------------------------------------------
# Epoch:   14        1 Batch loss: 0.564121 Batch F1: 0.7692307692307692
# Epoch:   14        2 Batch loss: 0.526377 Batch F1: 0.7391304347826085
# Epoch:   14        3 Batch loss: 0.436947 Batch F1: 0.7999999999999999
# Epoch:   14        4 Batch loss: 0.525578 Batch F1: 0.7727272727272727
# Epoch:   14        5 Batch loss: 0.503338 Batch F1: 0.7500000000000001
# Epoch:   14        6 Batch loss: 0.479144 Batch F1: 0.8571428571428572
# Train Avg Loss   14: 0.505917
#
# Train Avg F1   14: 0.7813718889805846
#
# Val Avg Loss   14: 0.243626
#
# Val Avg F1   14:  0.737460815047022
#
# Optimal Val loss (Epoch 8): 0.2109687179327011
#
# Epoch 15
# --------------------------------------------------------------
# Epoch:   15        1 Batch loss: 0.464183 Batch F1: 0.7647058823529411
# Epoch:   15        2 Batch loss: 0.480686 Batch F1: 0.7567567567567568
# Epoch:   15        3 Batch loss: 0.504450 Batch F1: 0.8235294117647057
# Epoch:   15        4 Batch loss: 0.630680 Batch F1: 0.6666666666666666
# Epoch:   15        5 Batch loss: 0.423856 Batch F1: 0.9019607843137256
# Epoch:   15        6 Batch loss: 0.458973 Batch F1: 0.8333333333333334
# Train Avg Loss   15: 0.493805
#
# Train Avg F1   15: 0.7911588058646881
#
# Val Avg Loss   15: 0.251231
#
# Val Avg F1   15:  0.7032967032967032
#
# Optimal Val loss (Epoch 8): 0.2109687179327011
#
# Epoch 16
# --------------------------------------------------------------
# Epoch:   16        1 Batch loss: 0.509196 Batch F1: 0.7727272727272727
# Epoch:   16        2 Batch loss: 0.536343 Batch F1: 0.7
# Epoch:   16        3 Batch loss: 0.428292 Batch F1: 0.8846153846153846
# Epoch:   16        4 Batch loss: 0.452388 Batch F1: 0.8181818181818182
# Epoch:   16        5 Batch loss: 0.501050 Batch F1: 0.8235294117647057
# Epoch:   16        6 Batch loss: 0.470759 Batch F1: 0.8484848484848485
# Train Avg Loss   16: 0.483005
#
# Train Avg F1   16: 0.8079231226290049
#
# Val Avg Loss   16: 0.265842
#
# Val Avg F1   16:  0.7106918238993711
#
# Optimal Val loss (Epoch 8): 0.2109687179327011
#
# Epoch 17
# --------------------------------------------------------------
# Epoch:   17        1 Batch loss: 0.632652 Batch F1: 0.6938775510204083
# Epoch:   17        2 Batch loss: 0.493399 Batch F1: 0.7272727272727272
# Epoch:   17        3 Batch loss: 0.451223 Batch F1: 0.8095238095238096
# Epoch:   17        4 Batch loss: 0.439165 Batch F1: 0.8695652173913043
# Epoch:   17        5 Batch loss: 0.504808 Batch F1: 0.8148148148148148
# Epoch:   17        6 Batch loss: 0.455328 Batch F1: 0.8275862068965517
# Train Avg Loss   17: 0.496096
#
# Train Avg F1   17: 0.7904400544866027
#
# Val Avg Loss   17: 0.277364
#
# Val Avg F1   17:  0.7032679738562091
#
# Optimal Val loss (Epoch 8): 0.2109687179327011
#
# Epoch 18
# --------------------------------------------------------------
# Epoch:   18        1 Batch loss: 0.568068 Batch F1: 0.6486486486486486
# Epoch:   18        2 Batch loss: 0.435158 Batch F1: 0.9152542372881356
# Epoch:   18        3 Batch loss: 0.441953 Batch F1: 0.8292682926829269
# Epoch:   18        4 Batch loss: 0.416228 Batch F1: 0.8780487804878049
# Epoch:   18        5 Batch loss: 0.487355 Batch F1: 0.8333333333333333
# Epoch:   18        6 Batch loss: 0.608656 Batch F1: 0.5714285714285715
# Train Avg Loss   18: 0.492903
#
# Train Avg F1   18: 0.7793303106449033
#
# Val Avg Loss   18: 0.458737
#
# Val Avg F1   18:  0.29679144385026734
#
# Optimal Val loss (Epoch 8): 0.2109687179327011
#
# Epoch 19
# --------------------------------------------------------------
# Epoch:   19        1 Batch loss: 0.577076 Batch F1: 0.5882352941176471
# Epoch:   19        2 Batch loss: 0.615228 Batch F1: 0.5
# Epoch:   19        3 Batch loss: 0.623666 Batch F1: 0.5789473684210525
# Epoch:   19        4 Batch loss: 0.540240 Batch F1: 0.6285714285714286
# Epoch:   19        5 Batch loss: 0.472937 Batch F1: 0.8260869565217391
# Epoch:   19        6 Batch loss: 0.757828 Batch F1: 0.64
# Train Avg Loss   19: 0.597829
#
# Train Avg F1   19: 0.6269735079386446
#
# Val Avg Loss   19: 0.297374
#
# Val Avg F1   19:  0.7519600855310049
#
# Optimal Val loss (Epoch 8): 0.2109687179327011
#
# Epoch 20
# --------------------------------------------------------------
# Epoch:   20        1 Batch loss: 0.700006 Batch F1: 0.6181818181818182
# Epoch:   20        2 Batch loss: 0.574590 Batch F1: 0.7450980392156863
# Epoch:   20        3 Batch loss: 0.435365 Batch F1: 0.8695652173913043
# Epoch:   20        4 Batch loss: 0.669491 Batch F1: 0.4878048780487805
# Epoch:   20        5 Batch loss: 0.534747 Batch F1: 0.7826086956521738
# Epoch:   20        6 Batch loss: 0.436711 Batch F1: 0.8148148148148148
# Train Avg Loss   20: 0.558485
#
# Train Avg F1   20: 0.7196789105507629
#
# Val Avg Loss   20: 0.317566
#
# Val Avg F1   20:  0.6499493414387032
#
# Optimal Val loss (Epoch 8): 0.2109687179327011
#
# Epoch 21
# --------------------------------------------------------------
# Epoch:   21        1 Batch loss: 0.482487 Batch F1: 0.7906976744186046
# Epoch:   21        2 Batch loss: 0.586577 Batch F1: 0.6666666666666666
# Epoch:   21        3 Batch loss: 0.556182 Batch F1: 0.7346938775510204
# Epoch:   21        4 Batch loss: 0.525882 Batch F1: 0.7636363636363636
# Epoch:   21        5 Batch loss: 0.506520 Batch F1: 0.7916666666666666
# Epoch:   21        6 Batch loss: 0.475370 Batch F1: 0.7741935483870969
# Train Avg Loss   21: 0.522170
#
# Train Avg F1   21: 0.7535924662210697
#
# Val Avg Loss   21: 0.247274
#
# Val Avg F1   21:  0.7191919191919192
#
# Optimal Val loss (Epoch 8): 0.2109687179327011
#
# Epoch 22
# --------------------------------------------------------------
# Epoch:   22        1 Batch loss: 0.514082 Batch F1: 0.7906976744186046
# Epoch:   22        2 Batch loss: 0.527643 Batch F1: 0.7555555555555556
# Epoch:   22        3 Batch loss: 0.526627 Batch F1: 0.7916666666666667
# Epoch:   22        4 Batch loss: 0.476964 Batch F1: 0.8461538461538461
# Epoch:   22        5 Batch loss: 0.491571 Batch F1: 0.7804878048780488
# Epoch:   22        6 Batch loss: 0.485906 Batch F1: 0.7692307692307692
# Train Avg Loss   22: 0.503799
#
# Train Avg F1   22: 0.7889653861505819
#
# Val Avg Loss   22: 0.266975
#
# Val Avg F1   22:  0.6594097726173198
#
# Optimal Val loss (Epoch 8): 0.2109687179327011
#
# Epoch 23
# --------------------------------------------------------------
# Epoch:   23        1 Batch loss: 0.552399 Batch F1: 0.6666666666666667
# Epoch:   23        2 Batch loss: 0.548718 Batch F1: 0.7499999999999999
# Epoch:   23        3 Batch loss: 0.379168 Batch F1: 0.9615384615384615
# Epoch:   23        4 Batch loss: 0.582826 Batch F1: 0.7450980392156864
# Epoch:   23        5 Batch loss: 0.451296 Batch F1: 0.851063829787234
# Epoch:   23        6 Batch loss: 0.514441 Batch F1: 0.7200000000000001
# Train Avg Loss   23: 0.504808
#
# Train Avg F1   23: 0.7823944995346747
#
# Val Avg Loss   23: 0.244309
#
# Val Avg F1   23:  0.72818063395571
#
# Optimal Val loss (Epoch 8): 0.2109687179327011
#
# Epoch 24
# --------------------------------------------------------------
# Epoch:   24        1 Batch loss: 0.437787 Batch F1: 0.875
# Epoch:   24        2 Batch loss: 0.426986 Batch F1: 0.8936170212765958
# Epoch:   24        3 Batch loss: 0.495387 Batch F1: 0.7906976744186046
# Epoch:   24        4 Batch loss: 0.578500 Batch F1: 0.631578947368421
# Epoch:   24        5 Batch loss: 0.532605 Batch F1: 0.7659574468085106
# Epoch:   24        6 Batch loss: 0.476865 Batch F1: 0.8235294117647058
# Train Avg Loss   24: 0.491355
#
# Train Avg F1   24: 0.7967300836061396
#
# Val Avg Loss   24: 0.241680
#
# Val Avg F1   24:  0.713458110516934
#
# Optimal Val loss (Epoch 8): 0.2109687179327011
#
# Epoch 25
# --------------------------------------------------------------
# Epoch:   25        1 Batch loss: 0.462630 Batch F1: 0.8292682926829269
# Epoch:   25        2 Batch loss: 0.439469 Batch F1: 0.8421052631578947
# Epoch:   25        3 Batch loss: 0.494654 Batch F1: 0.816326530612245
# Epoch:   25        4 Batch loss: 0.587479 Batch F1: 0.7741935483870968
# Epoch:   25        5 Batch loss: 0.459588 Batch F1: 0.8292682926829269
# Epoch:   25        6 Batch loss: 0.523475 Batch F1: 0.7333333333333334
# Train Avg Loss   25: 0.494549
#
# Train Avg F1   25: 0.8040825434760706
#
# Val Avg Loss   25: 0.251221
#
# Val Avg F1   25:  0.7447054293415478
#
# Optimal Val loss (Epoch 8): 0.2109687179327011
#
# Epoch 26
# --------------------------------------------------------------
# Epoch:   26        1 Batch loss: 0.432664 Batch F1: 0.8695652173913043
# Epoch:   26        2 Batch loss: 0.451849 Batch F1: 0.8571428571428572
# Epoch:   26        3 Batch loss: 0.507406 Batch F1: 0.782608695652174
# Epoch:   26        4 Batch loss: 0.576833 Batch F1: 0.7234042553191489
# Epoch:   26        5 Batch loss: 0.517276 Batch F1: 0.7368421052631579
# Epoch:   26        6 Batch loss: 0.473313 Batch F1: 0.8125000000000001
# Train Avg Loss   26: 0.493224
#
# Train Avg F1   26: 0.7970105217947737
#
# Val Avg Loss   26: 0.266658
#
# Val Avg F1   26:  0.6782154722354059
#
# Optimal Val loss (Epoch 8): 0.2109687179327011
#
# Epoch 27
# --------------------------------------------------------------
# Epoch:   27        1 Batch loss: 0.486487 Batch F1: 0.7692307692307692
# Epoch:   27        2 Batch loss: 0.489528 Batch F1: 0.8474576271186439
# Epoch:   27        3 Batch loss: 0.494831 Batch F1: 0.8260869565217391
# Epoch:   27        4 Batch loss: 0.468991 Batch F1: 0.8260869565217391
# Epoch:   27        5 Batch loss: 0.528236 Batch F1: 0.7659574468085107
# Epoch:   27        6 Batch loss: 0.534561 Batch F1: 0.7777777777777778
# Train Avg Loss   27: 0.500439
#
# Train Avg F1   27: 0.80209958899653
#
# Val Avg Loss   27: 0.243194
#
# Val Avg F1   27:  0.7210884353741496
#
# Optimal Val loss (Epoch 8): 0.2109687179327011
#
# Epoch 28
# --------------------------------------------------------------
# Epoch:   28        1 Batch loss: 0.415536 Batch F1: 0.8749999999999999
# Epoch:   28        2 Batch loss: 0.525485 Batch F1: 0.8070175438596492
# Epoch:   28        3 Batch loss: 0.539548 Batch F1: 0.7659574468085107
# Epoch:   28        4 Batch loss: 0.465320 Batch F1: 0.8444444444444444
# Epoch:   28        5 Batch loss: 0.552792 Batch F1: 0.7000000000000001
# Epoch:   28        6 Batch loss: 0.456409 Batch F1: 0.8387096774193549
# Train Avg Loss   28: 0.492515
#
# Train Avg F1   28: 0.8051881854219932
#
# Val Avg Loss   28: 0.264724
#
# Val Avg F1   28:  0.7008060692271219
#
# Optimal Val loss (Epoch 8): 0.2109687179327011
#
# Epoch 29
# --------------------------------------------------------------
# Epoch:   29        1 Batch loss: 0.563214 Batch F1: 0.7500000000000001
# Epoch:   29        2 Batch loss: 0.486788 Batch F1: 0.8181818181818181
# Epoch:   29        3 Batch loss: 0.514514 Batch F1: 0.7368421052631577
# Epoch:   29        4 Batch loss: 0.494229 Batch F1: 0.8235294117647058
# Epoch:   29        5 Batch loss: 0.482160 Batch F1: 0.7999999999999999
# Epoch:   29        6 Batch loss: 0.426392 Batch F1: 0.8947368421052632
# Train Avg Loss   29: 0.494550
#
# Train Avg F1   29: 0.8038816962191574
#
# Val Avg Loss   29: 0.241296
#
# Val Avg F1   29:  0.7461988304093568
#
# Optimal Val loss (Epoch 8): 0.2109687179327011
#
# Epoch 30
# --------------------------------------------------------------
# Epoch:   30        1 Batch loss: 0.469582 Batch F1: 0.8399999999999999
# Epoch:   30        2 Batch loss: 0.501942 Batch F1: 0.8163265306122449
# Epoch:   30        3 Batch loss: 0.503744 Batch F1: 0.7555555555555555
# Epoch:   30        4 Batch loss: 0.410789 Batch F1: 0.888888888888889
# Epoch:   30        5 Batch loss: 0.558758 Batch F1: 0.6976744186046512
# Epoch:   30        6 Batch loss: 0.511097 Batch F1: 0.7586206896551724
# Train Avg Loss   30: 0.492652
#
# Train Avg F1   30: 0.7928443472194188
#
# Val Avg Loss   30: 0.245967
#
# Val Avg F1   30:  0.754180602006689
#
# Optimal Val loss (Epoch 8): 0.2109687179327011
#
# Epoch 31
# --------------------------------------------------------------
# Epoch:   31        1 Batch loss: 0.462404 Batch F1: 0.8108108108108109
# Epoch:   31        2 Batch loss: 0.561327 Batch F1: 0.6976744186046512
# Epoch:   31        3 Batch loss: 0.429293 Batch F1: 0.8571428571428572
# Epoch:   31        4 Batch loss: 0.436026 Batch F1: 0.8695652173913043
# Epoch:   31        5 Batch loss: 0.487692 Batch F1: 0.816326530612245
# Epoch:   31        6 Batch loss: 0.549171 Batch F1: 0.8095238095238096
# Train Avg Loss   31: 0.487652
#
# Train Avg F1   31: 0.8101739406809463
#
# Val Avg Loss   31: 0.244219
#
# Val Avg F1   31:  0.750784929356358
#
# Optimal Val loss (Epoch 8): 0.2109687179327011
#
# Epoch 32
# --------------------------------------------------------------
# Epoch:   32        1 Batch loss: 0.491397 Batch F1: 0.7567567567567567
# Epoch:   32        2 Batch loss: 0.458794 Batch F1: 0.875
# Epoch:   32        3 Batch loss: 0.484174 Batch F1: 0.7906976744186046
# Epoch:   32        4 Batch loss: 0.508005 Batch F1: 0.8
# Epoch:   32        5 Batch loss: 0.528504 Batch F1: 0.6
# Epoch:   32        6 Batch loss: 0.525276 Batch F1: 0.7999999999999999
# Train Avg Loss   32: 0.499358
#
# Train Avg F1   32: 0.7704090718625602
#
# Val Avg Loss   32: 0.248407
#
# Val Avg F1   32:  0.7427431059506533
#
# Optimal Val loss (Epoch 8): 0.2109687179327011
#
# Epoch 33
# --------------------------------------------------------------
# Epoch:   33        1 Batch loss: 0.488425 Batch F1: 0.7727272727272727
# Epoch:   33        2 Batch loss: 0.527718 Batch F1: 0.8135593220338982
# Epoch:   33        3 Batch loss: 0.513765 Batch F1: 0.8085106382978724
# Epoch:   33        4 Batch loss: 0.532381 Batch F1: 0.7317073170731706
# Epoch:   33        5 Batch loss: 0.470341 Batch F1: 0.8627450980392156
# Epoch:   33        6 Batch loss: 0.428558 Batch F1: 0.8484848484848485
# Train Avg Loss   33: 0.493531
#
# Train Avg F1   33: 0.8062890827760464
#
# Val Avg Loss   33: 0.255990
#
# Val Avg F1   33:  0.7054763000460192
#
# Optimal Val loss (Epoch 8): 0.2109687179327011
#
# Epoch 34
# --------------------------------------------------------------
# Epoch:   34        1 Batch loss: 0.508370 Batch F1: 0.7916666666666666
# Epoch:   34        2 Batch loss: 0.502965 Batch F1: 0.7906976744186046
# Epoch:   34        3 Batch loss: 0.473239 Batch F1: 0.7999999999999999
# Epoch:   34        4 Batch loss: 0.514643 Batch F1: 0.75
# Epoch:   34        5 Batch loss: 0.511078 Batch F1: 0.8363636363636363
# Epoch:   34        6 Batch loss: 0.423360 Batch F1: 0.8571428571428571
# Train Avg Loss   34: 0.488943
#
# Train Avg F1   34: 0.8043118057652942
#
# Val Avg Loss   34: 0.236018
#
# Val Avg F1   34:  0.7469387755102042
#
# Optimal Val loss (Epoch 8): 0.2109687179327011
#
# Epoch 35
# --------------------------------------------------------------
# Epoch:   35        1 Batch loss: 0.567461 Batch F1: 0.7857142857142856
# Epoch:   35        2 Batch loss: 0.624715 Batch F1: 0.7037037037037037
# Epoch:   35        3 Batch loss: 0.637270 Batch F1: 0.6538461538461537
# Epoch:   35        4 Batch loss: 0.678985 Batch F1: 0.6545454545454545
# Epoch:   35        5 Batch loss: 0.546516 Batch F1: 0.7500000000000001
# Epoch:   35        6 Batch loss: 0.668599 Batch F1: 0.6829268292682926
# Train Avg Loss   35: 0.620591
#
# Train Avg F1   35: 0.705122737846315
#
# Val Avg Loss   35: 0.316753
#
# Val Avg F1   35:  0.7083333333333333
#
# Optimal Val loss (Epoch 8): 0.2109687179327011
#
# Epoch 36
# --------------------------------------------------------------
# Epoch:   36        1 Batch loss: 0.649830 Batch F1: 0.6666666666666666
# Epoch:   36        2 Batch loss: 0.559428 Batch F1: 0.7450980392156863
# Epoch:   36        3 Batch loss: 0.559545 Batch F1: 0.7234042553191491
# Epoch:   36        4 Batch loss: 0.494627 Batch F1: 0.8085106382978724
# Epoch:   36        5 Batch loss: 0.506384 Batch F1: 0.7906976744186046
# Epoch:   36        6 Batch loss: 0.527320 Batch F1: 0.7333333333333334
# Train Avg Loss   36: 0.549522
#
# Train Avg F1   36: 0.7446184345418855
#
# Val Avg Loss   36: 0.273079
#
# Val Avg F1   36:  0.700952380952381
#
# Optimal Val loss (Epoch 8): 0.2109687179327011
#
# Epoch 37
# --------------------------------------------------------------
# Epoch:   37        1 Batch loss: 0.425038 Batch F1: 0.8837209302325583
# Epoch:   37        2 Batch loss: 0.432013 Batch F1: 0.8235294117647058
# Epoch:   37        3 Batch loss: 0.605090 Batch F1: 0.6521739130434783
# Epoch:   37        4 Batch loss: 0.629948 Batch F1: 0.7037037037037038
# Epoch:   37        5 Batch loss: 0.478721 Batch F1: 0.7567567567567567
# Epoch:   37        6 Batch loss: 0.510836 Batch F1: 0.7999999999999999
# Train Avg Loss   37: 0.513608
#
# Train Avg F1   37: 0.769980785916867
#
# Val Avg Loss   37: 0.285991
#
# Val Avg F1   37:  0.7146226415094339
#
# Optimal Val loss (Epoch 8): 0.2109687179327011
#
# Epoch 38
# --------------------------------------------------------------
# Epoch:   38        1 Batch loss: 0.516721 Batch F1: 0.823529411764706
# Epoch:   38        2 Batch loss: 0.492058 Batch F1: 0.7999999999999999
# Epoch:   38        3 Batch loss: 0.489263 Batch F1: 0.8461538461538461
# Epoch:   38        4 Batch loss: 0.440906 Batch F1: 0.8749999999999999
# Epoch:   38        5 Batch loss: 0.483848 Batch F1: 0.7804878048780488
# Epoch:   38        6 Batch loss: 0.490616 Batch F1: 0.8125000000000001
# Train Avg Loss   38: 0.485569
#
# Train Avg F1   38: 0.8229451771327668
#
# Val Avg Loss   38: 0.279313
#
# Val Avg F1   38:  0.6833333333333333
#
# Optimal Val loss (Epoch 8): 0.2109687179327011
#
# Epoch 39
# --------------------------------------------------------------
# Epoch:   39        1 Batch loss: 0.420709 Batch F1: 0.8936170212765957
# Epoch:   39        2 Batch loss: 0.499515 Batch F1: 0.7272727272727273
# Epoch:   39        3 Batch loss: 0.495793 Batch F1: 0.8095238095238095
# Epoch:   39        4 Batch loss: 0.510078 Batch F1: 0.8085106382978724
# Epoch:   39        5 Batch loss: 0.605265 Batch F1: 0.6808510638297872
# Epoch:   39        6 Batch loss: 0.554058 Batch F1: 0.7499999999999999
# Train Avg Loss   39: 0.514236
#
# Train Avg F1   39: 0.778295876700132
#
# Val Avg Loss   39: 0.296955
#
# Val Avg F1   39:  0.6780626780626781
#
# Optimal Val loss (Epoch 8): 0.2109687179327011
#
# Epoch 40
# --------------------------------------------------------------
# Epoch:   40        1 Batch loss: 0.494005 Batch F1: 0.7096774193548386
# Epoch:   40        2 Batch loss: 0.526323 Batch F1: 0.7441860465116279
# Epoch:   40        3 Batch loss: 0.417044 Batch F1: 0.9152542372881356
# Epoch:   40        4 Batch loss: 0.522232 Batch F1: 0.7755102040816326
# Epoch:   40        5 Batch loss: 0.556204 Batch F1: 0.76
# Epoch:   40        6 Batch loss: 0.667717 Batch F1: 0.6666666666666666
# Train Avg Loss   40: 0.530588
#
# Train Avg F1   40: 0.761882428983817
#
# Val Avg Loss   40: 0.352598
#
# Val Avg F1   40:  0.6794871794871795
#
# Optimal Val loss (Epoch 8): 0.2109687179327011
#
# Epoch 41
# --------------------------------------------------------------
# Epoch:   41        1 Batch loss: 0.612365 Batch F1: 0.6938775510204083
# Epoch:   41        2 Batch loss: 0.483986 Batch F1: 0.830188679245283
# Epoch:   41        3 Batch loss: 0.518470 Batch F1: 0.7368421052631577
# Epoch:   41        4 Batch loss: 0.545252 Batch F1: 0.8070175438596491
# Epoch:   41        5 Batch loss: 0.567023 Batch F1: 0.711111111111111
# Epoch:   41        6 Batch loss: 0.484091 Batch F1: 0.7999999999999999
# Train Avg Loss   41: 0.535198
#
# Train Avg F1   41: 0.7631728317499348
#
# Val Avg Loss   41: 0.291448
#
# Val Avg F1   41:  0.6728130360205832
#
# Optimal Val loss (Epoch 8): 0.2109687179327011
#
# Epoch 42
# --------------------------------------------------------------
# Epoch:   42        1 Batch loss: 0.497442 Batch F1: 0.8
# Epoch:   42        2 Batch loss: 0.454754 Batch F1: 0.8292682926829269
# Epoch:   42        3 Batch loss: 0.534300 Batch F1: 0.7755102040816326
# Epoch:   42        4 Batch loss: 0.596232 Batch F1: 0.6666666666666665
# Epoch:   42        5 Batch loss: 0.489184 Batch F1: 0.8085106382978724
# Epoch:   42        6 Batch loss: 0.484254 Batch F1: 0.8235294117647058
# Train Avg Loss   42: 0.509361
#
# Train Avg F1   42: 0.7839142022489675
#
# Val Avg Loss   42: 0.401243
#
# Val Avg F1   42:  0.4677871148459384
#
# Optimal Val loss (Epoch 8): 0.2109687179327011
#
# Epoch 43
# --------------------------------------------------------------
# Epoch:   43        1 Batch loss: 0.512634 Batch F1: 0.7058823529411764
# Epoch:   43        2 Batch loss: 0.593684 Batch F1: 0.5333333333333333
# Epoch:   43        3 Batch loss: 0.751304 Batch F1: 0.45000000000000007
# Epoch:   43        4 Batch loss: 0.535440 Batch F1: 0.6666666666666667
# Epoch:   43        5 Batch loss: 0.626351 Batch F1: 0.6153846153846153
# Epoch:   43        6 Batch loss: 0.616676 Batch F1: 0.6206896551724138
# Train Avg Loss   43: 0.606015
#
# Train Avg F1   43: 0.598659437249701
#
# Val Avg Loss   43: 0.411090
#
# Val Avg F1   43:  0.478796169630643
#
# Optimal Val loss (Epoch 8): 0.2109687179327011
#
# Epoch 44
# --------------------------------------------------------------
# Epoch:   44        1 Batch loss: 0.557666 Batch F1: 0.6666666666666665
# Epoch:   44        2 Batch loss: 0.532207 Batch F1: 0.6451612903225806
# Epoch:   44        3 Batch loss: 0.613924 Batch F1: 0.5789473684210527
# Epoch:   44        4 Batch loss: 0.548360 Batch F1: 0.723404255319149
# Epoch:   44        5 Batch loss: 0.653209 Batch F1: 0.7605633802816901
# Epoch:   44        6 Batch loss: 0.722193 Batch F1: 0.7169811320754718
# Train Avg Loss   44: 0.604593
#
# Train Avg F1   44: 0.6819540155144351
#
# Val Avg Loss   44: 0.407362
#
# Val Avg F1   44:  0.7130801687763714
#
# Optimal Val loss (Epoch 8): 0.2109687179327011
#
# Epoch 45
# --------------------------------------------------------------
# Epoch:   45        1 Batch loss: 0.750875 Batch F1: 0.6944444444444445
# Epoch:   45        2 Batch loss: 0.771708 Batch F1: 0.6933333333333334
# Epoch:   45        3 Batch loss: 0.883328 Batch F1: 0.5757575757575758
# Epoch:   45        4 Batch loss: 0.767666 Batch F1: 0.6229508196721312
# Epoch:   45        5 Batch loss: 0.739873 Batch F1: 0.6944444444444444
# Epoch:   45        6 Batch loss: 0.591151 Batch F1: 0.7727272727272727
# Train Avg Loss   45: 0.750767
#
# Train Avg F1   45: 0.6756096483965336
#
# Val Avg Loss   45: 0.372398
#
# Val Avg F1   45:  0.6808100289296046
#
# Optimal Val loss (Epoch 8): 0.2109687179327011
#
# Epoch 46
# --------------------------------------------------------------
# Epoch:   46        1 Batch loss: 0.539861 Batch F1: 0.8333333333333334
# Epoch:   46        2 Batch loss: 0.536972 Batch F1: 0.75
# Epoch:   46        3 Batch loss: 0.531308 Batch F1: 0.7027027027027027
# Epoch:   46        4 Batch loss: 0.590526 Batch F1: 0.6060606060606061
# Epoch:   46        5 Batch loss: 0.626932 Batch F1: 0.5714285714285714
# Epoch:   46        6 Batch loss: 0.716456 Batch F1: 0.4
# Train Avg Loss   46: 0.590343
#
# Train Avg F1   46: 0.6439208689208689
#
# Val Avg Loss   46: 0.436234
#
# Val Avg F1   46:  0.3982371794871795
#
# Optimal Val loss (Epoch 8): 0.2109687179327011
#
# Epoch 47
# --------------------------------------------------------------
# Epoch:   47        1 Batch loss: 0.608670 Batch F1: 0.5714285714285715
# Epoch:   47        2 Batch loss: 0.657738 Batch F1: 0.5909090909090909
# Epoch:   47        3 Batch loss: 0.632728 Batch F1: 0.68
# Epoch:   47        4 Batch loss: 0.547160 Batch F1: 0.711111111111111
# Epoch:   47        5 Batch loss: 0.596552 Batch F1: 0.6956521739130435
# Epoch:   47        6 Batch loss: 0.523271 Batch F1: 0.7500000000000001
# Train Avg Loss   47: 0.594353
#
# Train Avg F1   47: 0.6665168245603029
#
# Val Avg Loss   47: 0.282163
#
# Val Avg F1   47:  0.7239766081871345
#
# Optimal Val loss (Epoch 8): 0.2109687179327011
#
# Epoch 48
# --------------------------------------------------------------
# Epoch:   48        1 Batch loss: 0.577405 Batch F1: 0.7111111111111111
# Epoch:   48        2 Batch loss: 0.515551 Batch F1: 0.7843137254901961
# Epoch:   48        3 Batch loss: 0.509708 Batch F1: 0.7916666666666666
# Epoch:   48        4 Batch loss: 0.552514 Batch F1: 0.7272727272727272
# Epoch:   48        5 Batch loss: 0.497002 Batch F1: 0.7906976744186046
# Epoch:   48        6 Batch loss: 0.479514 Batch F1: 0.8235294117647058
# Train Avg Loss   48: 0.521949
#
# Train Avg F1   48: 0.7714318861206686
#
# Val Avg Loss   48: 0.277702
#
# Val Avg F1   48:  0.728877679697352
#
# Optimal Val loss (Epoch 8): 0.2109687179327011
#
# Epoch 49
# --------------------------------------------------------------
# Epoch:   49        1 Batch loss: 0.515411 Batch F1: 0.7727272727272727
# Epoch:   49        2 Batch loss: 0.433402 Batch F1: 0.8695652173913043
# Epoch:   49        3 Batch loss: 0.528056 Batch F1: 0.7317073170731706
# Epoch:   49        4 Batch loss: 0.506367 Batch F1: 0.7619047619047619
# Epoch:   49        5 Batch loss: 0.626321 Batch F1: 0.7142857142857142
# Epoch:   49        6 Batch loss: 0.481642 Batch F1: 0.8000000000000002
# Train Avg Loss   49: 0.515200
#
# Train Avg F1   49: 0.7750317138970373
#
# Val Avg Loss   49: 0.264211
#
# Val Avg F1   49:  0.7261956998683633
#
# Optimal Val loss (Epoch 8): 0.2109687179327011
#
# Epoch 50
# --------------------------------------------------------------
# Epoch:   50        1 Batch loss: 0.532823 Batch F1: 0.7500000000000001
# Epoch:   50        2 Batch loss: 0.455534 Batch F1: 0.8292682926829269
# Epoch:   50        3 Batch loss: 0.486330 Batch F1: 0.7692307692307692
# Epoch:   50        4 Batch loss: 0.535594 Batch F1: 0.7924528301886793
# Epoch:   50        5 Batch loss: 0.552028 Batch F1: 0.7777777777777777
# Epoch:   50        6 Batch loss: 0.589918 Batch F1: 0.7058823529411764
# Train Avg Loss   50: 0.525371
#
# Train Avg F1   50: 0.7707686704702216
#
# Val Avg Loss   50: 0.264441
#
# Val Avg F1   50:  0.7445652173913044
#
# Optimal Val loss (Epoch 8): 0.2109687179327011
#
# Epoch 51
# --------------------------------------------------------------
# Epoch:   51        1 Batch loss: 0.564905 Batch F1: 0.7547169811320756
# Epoch:   51        2 Batch loss: 0.524376 Batch F1: 0.744186046511628
# Epoch:   51        3 Batch loss: 0.506771 Batch F1: 0.7222222222222222
# Epoch:   51        4 Batch loss: 0.493220 Batch F1: 0.8163265306122449
# Epoch:   51        5 Batch loss: 0.534578 Batch F1: 0.7755102040816326
# Epoch:   51        6 Batch loss: 0.435174 Batch F1: 0.8823529411764706
# Train Avg Loss   51: 0.509837
#
# Train Avg F1   51: 0.7825524876227123
#
# Val Avg Loss   51: 0.271951
#
# Val Avg F1   51:  0.7278260869565216
#
# Optimal Val loss (Epoch 8): 0.2109687179327011
#
# Epoch 52
# --------------------------------------------------------------
# Epoch:   52        1 Batch loss: 0.495689 Batch F1: 0.7567567567567567
# Epoch:   52        2 Batch loss: 0.549133 Batch F1: 0.7391304347826089
# Epoch:   52        3 Batch loss: 0.501300 Batch F1: 0.7906976744186046
# Epoch:   52        4 Batch loss: 0.526745 Batch F1: 0.782608695652174
# Epoch:   52        5 Batch loss: 0.574116 Batch F1: 0.7346938775510203
# Epoch:   52        6 Batch loss: 0.419192 Batch F1: 0.8717948717948718
# Train Avg Loss   52: 0.511029
#
# Train Avg F1   52: 0.7792803851593394
#
# Val Avg Loss   52: 0.264930
#
# Val Avg F1   52:  0.7299174989144595
#
# Optimal Val loss (Epoch 8): 0.2109687179327011
#
# Epoch 53
# --------------------------------------------------------------
# Epoch:   53        1 Batch loss: 0.450603 Batch F1: 0.8108108108108109
# Epoch:   53        2 Batch loss: 0.600082 Batch F1: 0.7083333333333333
# Epoch:   53        3 Batch loss: 0.523007 Batch F1: 0.8235294117647057
# Epoch:   53        4 Batch loss: 0.474358 Batch F1: 0.7777777777777778
# Epoch:   53        5 Batch loss: 0.512147 Batch F1: 0.8148148148148148
# Epoch:   53        6 Batch loss: 0.536451 Batch F1: 0.75
# Train Avg Loss   53: 0.516108
#
# Train Avg F1   53: 0.7808776914169071
#
# Val Avg Loss   53: 0.260185
#
# Val Avg F1   53:  0.729020979020979
#
# Optimal Val loss (Epoch 8): 0.2109687179327011
#
# Epoch 54
# --------------------------------------------------------------
# Epoch:   54        1 Batch loss: 0.601116 Batch F1: 0.6818181818181818
# Epoch:   54        2 Batch loss: 0.513980 Batch F1: 0.7916666666666667
# Epoch:   54        3 Batch loss: 0.481155 Batch F1: 0.823529411764706
# Epoch:   54        4 Batch loss: 0.394628 Batch F1: 0.8947368421052632
# Epoch:   54        5 Batch loss: 0.513116 Batch F1: 0.7727272727272727
# Epoch:   54        6 Batch loss: 0.587849 Batch F1: 0.6875000000000001
# Train Avg Loss   54: 0.515307
#
# Train Avg F1   54: 0.7753297291803484
#
# Val Avg Loss   54: 0.279402
#
# Val Avg F1   54:  0.701688555347092
#
# Optimal Val loss (Epoch 8): 0.2109687179327011
#
# Epoch 55
# --------------------------------------------------------------
# Epoch:   55        1 Batch loss: 0.561452 Batch F1: 0.7111111111111111
# Epoch:   55        2 Batch loss: 0.497331 Batch F1: 0.8235294117647058
# Epoch:   55        3 Batch loss: 0.513874 Batch F1: 0.7916666666666667
# Epoch:   55        4 Batch loss: 0.434254 Batch F1: 0.8333333333333333
# Epoch:   55        5 Batch loss: 0.475406 Batch F1: 0.7777777777777778
# Epoch:   55        6 Batch loss: 0.561367 Batch F1: 0.7692307692307692
# Train Avg Loss   55: 0.507280
#
# Train Avg F1   55: 0.784441511647394
#
# Val Avg Loss   55: 0.257762
#
# Val Avg F1   55:  0.7421142369991476
#
# Optimal Val loss (Epoch 8): 0.2109687179327011
#
# Epoch 56
# --------------------------------------------------------------
# Epoch:   56        1 Batch loss: 0.491662 Batch F1: 0.8085106382978724
# Epoch:   56        2 Batch loss: 0.495034 Batch F1: 0.8163265306122449
# Epoch:   56        3 Batch loss: 0.513074 Batch F1: 0.761904761904762
# Epoch:   56        4 Batch loss: 0.511589 Batch F1: 0.7999999999999999
# Epoch:   56        5 Batch loss: 0.491604 Batch F1: 0.7906976744186046
# Epoch:   56        6 Batch loss: 0.580186 Batch F1: 0.6428571428571429
# Train Avg Loss   56: 0.513858
#
# Train Avg F1   56: 0.7700494580151044
#
# Val Avg Loss   56: 0.257686
#
# Val Avg F1   56:  0.7382847038019453
#
# Optimal Val loss (Epoch 8): 0.2109687179327011
#
# Epoch 57
# --------------------------------------------------------------
# Epoch:   57        1 Batch loss: 0.491161 Batch F1: 0.7906976744186046
# Epoch:   57        2 Batch loss: 0.602347 Batch F1: 0.6153846153846153
# Epoch:   57        3 Batch loss: 0.529483 Batch F1: 0.7924528301886793
# Epoch:   57        4 Batch loss: 0.517316 Batch F1: 0.761904761904762
# Epoch:   57        5 Batch loss: 0.454217 Batch F1: 0.8510638297872339
# Epoch:   57        6 Batch loss: 0.404454 Batch F1: 0.9090909090909091
# Train Avg Loss   57: 0.499830
#
# Train Avg F1   57: 0.7867657701291341
#
# Val Avg Loss   57: 0.267337
#
# Val Avg F1   57:  0.7095282146160962
#
# Optimal Val loss (Epoch 8): 0.2109687179327011
#
# Epoch 58
# --------------------------------------------------------------
# Epoch:   58        1 Batch loss: 0.514705 Batch F1: 0.7727272727272727
# Epoch:   58        2 Batch loss: 0.537400 Batch F1: 0.6842105263157895
# Epoch:   58        3 Batch loss: 0.459090 Batch F1: 0.8372093023255814
# Epoch:   58        4 Batch loss: 0.454116 Batch F1: 0.8627450980392156
# Epoch:   58        5 Batch loss: 0.549074 Batch F1: 0.7499999999999999
# Epoch:   58        6 Batch loss: 0.517060 Batch F1: 0.7999999999999999
# Train Avg Loss   58: 0.505241
#
# Train Avg F1   58: 0.7844820332346433
#
# Val Avg Loss   58: 0.256643
#
# Val Avg F1   58:  0.7435203094777563
#
# Optimal Val loss (Epoch 8): 0.2109687179327011
#
# Epoch 59
# --------------------------------------------------------------
# Epoch:   59        1 Batch loss: 0.491055 Batch F1: 0.816326530612245
# Epoch:   59        2 Batch loss: 0.518578 Batch F1: 0.8076923076923077
# Epoch:   59        3 Batch loss: 0.540714 Batch F1: 0.793103448275862
# Epoch:   59        4 Batch loss: 0.454761 Batch F1: 0.8372093023255814
# Epoch:   59        5 Batch loss: 0.508263 Batch F1: 0.761904761904762
# Epoch:   59        6 Batch loss: 0.542622 Batch F1: 0.6666666666666666
# Train Avg Loss   59: 0.509332
#
# Train Avg F1   59: 0.7804838362462375
#
# Val Avg Loss   59: 0.261506
#
# Val Avg F1   59:  0.7346938775510204
#
# Optimal Val loss (Epoch 8): 0.2109687179327011
#
# Epoch 60
# --------------------------------------------------------------
# Epoch:   60        1 Batch loss: 0.496186 Batch F1: 0.7804878048780488
# Epoch:   60        2 Batch loss: 0.499738 Batch F1: 0.830188679245283
# Epoch:   60        3 Batch loss: 0.490325 Batch F1: 0.7906976744186046
# Epoch:   60        4 Batch loss: 0.538646 Batch F1: 0.717948717948718
# Epoch:   60        5 Batch loss: 0.612599 Batch F1: 0.7272727272727273
# Epoch:   60        6 Batch loss: 0.407650 Batch F1: 0.888888888888889
# Train Avg Loss   60: 0.507524
#
# Train Avg F1   60: 0.7892474154420452
#
# Val Avg Loss   60: 0.267621
#
# Val Avg F1   60:  0.7307189542483661
#
# Optimal Val loss (Epoch 8): 0.2109687179327011
#
# Epoch 61
# --------------------------------------------------------------
# Epoch:   61        1 Batch loss: 0.575159 Batch F1: 0.7450980392156864
# Epoch:   61        2 Batch loss: 0.478666 Batch F1: 0.8461538461538461
# Epoch:   61        3 Batch loss: 0.494181 Batch F1: 0.7999999999999999
# Epoch:   61        4 Batch loss: 0.492685 Batch F1: 0.7272727272727272
# Epoch:   61        5 Batch loss: 0.531072 Batch F1: 0.7659574468085107
# Epoch:   61        6 Batch loss: 0.479569 Batch F1: 0.8000000000000002
# Train Avg Loss   61: 0.508556
#
# Train Avg F1   61: 0.7807470099084618
#
# Val Avg Loss   61: 0.267055
#
# Val Avg F1   61:  0.7281045751633988
#
# Optimal Val loss (Epoch 8): 0.2109687179327011
#
# Epoch 62
# --------------------------------------------------------------
# Epoch:   62        1 Batch loss: 0.493174 Batch F1: 0.7906976744186046
# Epoch:   62        2 Batch loss: 0.456204 Batch F1: 0.8727272727272727
# Epoch:   62        3 Batch loss: 0.533406 Batch F1: 0.7441860465116279
# Epoch:   62        4 Batch loss: 0.598634 Batch F1: 0.6956521739130435
# Epoch:   62        5 Batch loss: 0.434835 Batch F1: 0.8571428571428572
# Epoch:   62        6 Batch loss: 0.534045 Batch F1: 0.7142857142857143
# Train Avg Loss   62: 0.508383
#
# Train Avg F1   62: 0.7791152898331867
#
# Val Avg Loss   62: 0.271554
#
# Val Avg F1   62:  0.722027972027972
#
# Optimal Val loss (Epoch 8): 0.2109687179327011
#
# Epoch 63
# --------------------------------------------------------------
# Epoch:   63        1 Batch loss: 0.455627 Batch F1: 0.8372093023255814
# Epoch:   63        2 Batch loss: 0.569901 Batch F1: 0.7234042553191489
# Epoch:   63        3 Batch loss: 0.497816 Batch F1: 0.7804878048780488
# Epoch:   63        4 Batch loss: 0.532974 Batch F1: 0.7659574468085107
# Epoch:   63        5 Batch loss: 0.477616 Batch F1: 0.8461538461538461
# Epoch:   63        6 Batch loss: 0.534193 Batch F1: 0.6666666666666666
# Train Avg Loss   63: 0.511355
#
# Train Avg F1   63: 0.7699798870253005
#
# Val Avg Loss   63: 0.265868
#
# Val Avg F1   63:  0.730718954248366
#
# Optimal Val loss (Epoch 8): 0.2109687179327011
#
# Epoch 64
# --------------------------------------------------------------
# Epoch:   64        1 Batch loss: 0.482935 Batch F1: 0.7272727272727274
# Epoch:   64        2 Batch loss: 0.525818 Batch F1: 0.7659574468085106
# Epoch:   64        3 Batch loss: 0.572990 Batch F1: 0.7450980392156864
# Epoch:   64        4 Batch loss: 0.454526 Batch F1: 0.8372093023255814
# Epoch:   64        5 Batch loss: 0.555131 Batch F1: 0.75
# Epoch:   64        6 Batch loss: 0.421193 Batch F1: 0.8749999999999999
# Train Avg Loss   64: 0.502099
#
# Train Avg F1   64: 0.7834229192704175
#
# Val Avg Loss   64: 0.258900
#
# Val Avg F1   64:  0.7181964573268922
#
# Optimal Val loss (Epoch 8): 0.2109687179327011
#
# Epoch 65
# --------------------------------------------------------------
# Epoch:   65        1 Batch loss: 0.597213 Batch F1: 0.6818181818181819
# Epoch:   65        2 Batch loss: 0.506024 Batch F1: 0.8181818181818182
# Epoch:   65        3 Batch loss: 0.462206 Batch F1: 0.8205128205128205
# Epoch:   65        4 Batch loss: 0.521087 Batch F1: 0.7999999999999999
# Epoch:   65        5 Batch loss: 0.489941 Batch F1: 0.830188679245283
# Epoch:   65        6 Batch loss: 0.477199 Batch F1: 0.8125
# Train Avg Loss   65: 0.508945
#
# Train Avg F1   65: 0.7938669166263504
#
# Val Avg Loss   65: 0.255073
#
# Val Avg F1   65:  0.7329140461215933
#
# Optimal Val loss (Epoch 8): 0.2109687179327011
#
# Epoch 66
# --------------------------------------------------------------
# Epoch:   66        1 Batch loss: 0.495486 Batch F1: 0.782608695652174
# Epoch:   66        2 Batch loss: 0.532745 Batch F1: 0.744186046511628
# Epoch:   66        3 Batch loss: 0.543963 Batch F1: 0.6470588235294118
# Epoch:   66        4 Batch loss: 0.436946 Batch F1: 0.8846153846153846
# Epoch:   66        5 Batch loss: 0.511681 Batch F1: 0.7555555555555555
# Epoch:   66        6 Batch loss: 0.522706 Batch F1: 0.7894736842105262
# Train Avg Loss   66: 0.507255
#
# Train Avg F1   66: 0.76724969834578
#
# Val Avg Loss   66: 0.233073
#
# Val Avg F1   66:  0.767156862745098
#
# Optimal Val loss (Epoch 8): 0.2109687179327011
#
# Epoch 67
# --------------------------------------------------------------
# Epoch:   67        1 Batch loss: 0.439318 Batch F1: 0.8636363636363636
# Epoch:   67        2 Batch loss: 0.521392 Batch F1: 0.8196721311475409
# Epoch:   67        3 Batch loss: 0.497576 Batch F1: 0.7804878048780488
# Epoch:   67        4 Batch loss: 0.652727 Batch F1: 0.5
# Epoch:   67        5 Batch loss: 0.356322 Batch F1: 0.9523809523809523
# Epoch:   67        6 Batch loss: 0.487394 Batch F1: 0.8333333333333333
# Train Avg Loss   67: 0.492455
#
# Train Avg F1   67: 0.7915850975627065
#
# Val Avg Loss   67: 0.238630
#
# Val Avg F1   67:  0.7766439909297052
#
# Optimal Val loss (Epoch 8): 0.2109687179327011
#
# Epoch 68
# --------------------------------------------------------------
# Epoch:   68        1 Batch loss: 0.459558 Batch F1: 0.8333333333333333
# Epoch:   68        2 Batch loss: 0.591715 Batch F1: 0.711111111111111
# Epoch:   68        3 Batch loss: 0.492698 Batch F1: 0.7999999999999999
# Epoch:   68        4 Batch loss: 0.435027 Batch F1: 0.888888888888889
# Epoch:   68        5 Batch loss: 0.513601 Batch F1: 0.7441860465116279
# Epoch:   68        6 Batch loss: 0.501984 Batch F1: 0.7200000000000001
# Train Avg Loss   68: 0.499097
#
# Train Avg F1   68: 0.7829198966408267
#
# Val Avg Loss   68: 0.258441
#
# Val Avg F1   68:  0.7082560296846011
#
# Optimal Val loss (Epoch 8): 0.2109687179327011
#
# Epoch 69
# --------------------------------------------------------------
# Epoch:   69        1 Batch loss: 0.418549 Batch F1: 0.8695652173913043
# Epoch:   69        2 Batch loss: 0.482625 Batch F1: 0.8235294117647058
# Epoch:   69        3 Batch loss: 0.535221 Batch F1: 0.7317073170731707
# Epoch:   69        4 Batch loss: 0.507298 Batch F1: 0.7727272727272727
# Epoch:   69        5 Batch loss: 0.503416 Batch F1: 0.7999999999999999
# Epoch:   69        6 Batch loss: 0.565289 Batch F1: 0.7272727272727274
# Train Avg Loss   69: 0.502066
#
# Train Avg F1   69: 0.7874669910381967
#
# Val Avg Loss   69: 0.240254
#
# Val Avg F1   69:  0.7747543461829176
#
# Optimal Val loss (Epoch 8): 0.2109687179327011
#
# Epoch 70
# --------------------------------------------------------------
# Epoch:   70        1 Batch loss: 0.589675 Batch F1: 0.6666666666666666
# Epoch:   70        2 Batch loss: 0.468261 Batch F1: 0.8095238095238095
# Epoch:   70        3 Batch loss: 0.489646 Batch F1: 0.8571428571428571
# Epoch:   70        4 Batch loss: 0.499234 Batch F1: 0.7906976744186046
# Epoch:   70        5 Batch loss: 0.493865 Batch F1: 0.7804878048780488
# Epoch:   70        6 Batch loss: 0.386874 Batch F1: 0.9090909090909091
# Train Avg Loss   70: 0.487926
#
# Train Avg F1   70: 0.8022682869534826
#
# Val Avg Loss   70: 0.252146
#
# Val Avg F1   70:  0.7196969696969697
#
# Optimal Val loss (Epoch 8): 0.2109687179327011
#
# Epoch 71
# --------------------------------------------------------------
# Epoch:   71        1 Batch loss: 0.565949 Batch F1: 0.6285714285714286
# Epoch:   71        2 Batch loss: 0.496009 Batch F1: 0.7804878048780488
# Epoch:   71        3 Batch loss: 0.403152 Batch F1: 0.9090909090909091
# Epoch:   71        4 Batch loss: 0.469426 Batch F1: 0.7647058823529413
# Epoch:   71        5 Batch loss: 0.467640 Batch F1: 0.8518518518518519
# Epoch:   71        6 Batch loss: 0.584399 Batch F1: 0.7058823529411765
# Train Avg Loss   71: 0.497763
#
# Train Avg F1   71: 0.7734317049477261
#
# ...
# Epoch:   77        3 Batch loss: 0.491525 Batch F1: 0.8163265306122449
# Epoch:   77        4 Batch loss: 0.511318 Batch F1: 0.7500000000000001
# Epoch:   77        5 Batch loss: 0.459137 Batch F1: 0.8108108108108109
# Epoch:   77        6 Batch loss: 0.480001 Batch F1: 0.8421052631578948
# Train Avg Loss   77: 0.505213
#
# Train Avg F1   77: 0.7783704994563023
#
# Val Avg Loss   77: 0.263362
#
# Val Avg F1   77:  0.740754716981132
#
# Optimal Val loss (Epoch 8): 0.2109687179327011
#
# Epoch 78
# --------------------------------------------------------------
# Epoch:   78        1 Batch loss: 0.537705 Batch F1: 0.7027027027027027
# Epoch:   78        2 Batch loss: 0.586176 Batch F1: 0.5714285714285714
# Epoch:   78        3 Batch loss: 0.396186 Batch F1: 0.9
# Epoch:   78        4 Batch loss: 0.412110 Batch F1: 0.9056603773584906
# Epoch:   78        5 Batch loss: 0.536392 Batch F1: 0.819672131147541
# Epoch:   78        6 Batch loss: 0.558665 Batch F1: 0.7692307692307693
# Train Avg Loss   78: 0.504539
#
# Train Avg F1   78: 0.7781157586446792
#
# Val Avg Loss   78: 0.348918
#
# Val Avg F1   78:  0.5513115508513575
#
# Optimal Val loss (Epoch 8): 0.2109687179327011
#
# Epoch 79
# --------------------------------------------------------------
# Epoch:   79        1 Batch loss: 0.562785 Batch F1: 0.7346938775510203
# Epoch:   79        2 Batch loss: 0.546289 Batch F1: 0.7083333333333334
# Epoch:   79        3 Batch loss: 0.505702 Batch F1: 0.7916666666666667
# Epoch:   79        4 Batch loss: 0.533599 Batch F1: 0.6857142857142857
# Epoch:   79        5 Batch loss: 0.508211 Batch F1: 0.8
# Epoch:   79        6 Batch loss: 0.495256 Batch F1: 0.8000000000000002
# Train Avg Loss   79: 0.525307
#
# Train Avg F1   79: 0.7534013605442177
#
# Val Avg Loss   79: 0.239990
#
# Val Avg F1   79:  0.7531397174254317
#
# Optimal Val loss (Epoch 8): 0.2109687179327011
#
# Epoch 80
# --------------------------------------------------------------
# Epoch:   80        1 Batch loss: 0.532170 Batch F1: 0.7555555555555556
# Epoch:   80        2 Batch loss: 0.413705 Batch F1: 0.8837209302325582
# Epoch:   80        3 Batch loss: 0.578787 Batch F1: 0.6500000000000001
# Epoch:   80        4 Batch loss: 0.575608 Batch F1: 0.7083333333333334
# Epoch:   80        5 Batch loss: 0.409642 Batch F1: 0.9047619047619048
# Epoch:   80        6 Batch loss: 0.505854 Batch F1: 0.7777777777777778
# Train Avg Loss   80: 0.502628
#
# Train Avg F1   80: 0.7800249169435216
#
# Val Avg Loss   80: 0.247448
#
# Val Avg F1   80:  0.7083333333333333
#
# Optimal Val loss (Epoch 8): 0.2109687179327011
#
# Epoch 81
# --------------------------------------------------------------
# Epoch:   81        1 Batch loss: 0.511988 Batch F1: 0.75
# Epoch:   81        2 Batch loss: 0.459791 Batch F1: 0.8260869565217392
# Epoch:   81        3 Batch loss: 0.542401 Batch F1: 0.7391304347826088
# Epoch:   81        4 Batch loss: 0.543161 Batch F1: 0.7857142857142857
# Epoch:   81        5 Batch loss: 0.431491 Batch F1: 0.7878787878787878
# Epoch:   81        6 Batch loss: 0.505742 Batch F1: 0.8292682926829269
# Train Avg Loss   81: 0.499096
#
# Train Avg F1   81: 0.7863464595967247
#
# Val Avg Loss   81: 0.260089
#
# Val Avg F1   81:  0.6527777777777777
#
# Optimal Val loss (Epoch 8): 0.2109687179327011
#
# Epoch 82
# --------------------------------------------------------------
# Epoch:   82        1 Batch loss: 0.432604 Batch F1: 0.8627450980392156
# Epoch:   82        2 Batch loss: 0.572679 Batch F1: 0.7111111111111111
# Epoch:   82        3 Batch loss: 0.424796 Batch F1: 0.8571428571428571
# Epoch:   82        4 Batch loss: 0.522467 Batch F1: 0.7727272727272727
# Epoch:   82        5 Batch loss: 0.529969 Batch F1: 0.7659574468085106
# Epoch:   82        6 Batch loss: 0.472368 Batch F1: 0.823529411764706
# Train Avg Loss   82: 0.492481
#
# Train Avg F1   82: 0.7988688662656122
#
# Val Avg Loss   82: 0.282703
#
# Val Avg F1   82:  0.6640277090549234
#
# Optimal Val loss (Epoch 8): 0.2109687179327011
#
# Epoch 83
# --------------------------------------------------------------
# Epoch:   83        1 Batch loss: 0.561718 Batch F1: 0.76
# Epoch:   83        2 Batch loss: 0.477551 Batch F1: 0.8461538461538461
# Epoch:   83        3 Batch loss: 0.497503 Batch F1: 0.7906976744186046
# Epoch:   83        4 Batch loss: 0.462040 Batch F1: 0.8
# Epoch:   83        5 Batch loss: 0.480571 Batch F1: 0.7777777777777777
# Epoch:   83        6 Batch loss: 0.482774 Batch F1: 0.7999999999999999
# Train Avg Loss   83: 0.493693
#
# Train Avg F1   83: 0.795771549725038
#
# Val Avg Loss   83: 0.279679
#
# Val Avg F1   83:  0.6860869565217391
#
# Optimal Val loss (Epoch 8): 0.2109687179327011
#
# Epoch 84
# --------------------------------------------------------------
# Epoch:   84        1 Batch loss: 0.424776 Batch F1: 0.8780487804878048
# Epoch:   84        2 Batch loss: 0.605494 Batch F1: 0.68
# Epoch:   84        3 Batch loss: 0.422284 Batch F1: 0.8837209302325583
# Epoch:   84        4 Batch loss: 0.479669 Batch F1: 0.8095238095238095
# Epoch:   84        5 Batch loss: 0.553609 Batch F1: 0.7547169811320756
# Epoch:   84        6 Batch loss: 0.466313 Batch F1: 0.8235294117647058
# Train Avg Loss   84: 0.492024
#
# Train Avg F1   84: 0.8049233188568256
#
# Val Avg Loss   84: 0.291694
#
# Val Avg F1   84:  0.670041417395306
#
# Optimal Val loss (Epoch 8): 0.2109687179327011
#
# Epoch 85
# --------------------------------------------------------------
# Epoch:   85        1 Batch loss: 0.518968 Batch F1: 0.7999999999999999
# Epoch:   85        2 Batch loss: 0.417868 Batch F1: 0.8648648648648649
# Epoch:   85        3 Batch loss: 0.505938 Batch F1: 0.7924528301886793
# Epoch:   85        4 Batch loss: 0.477465 Batch F1: 0.8235294117647058
# Epoch:   85        5 Batch loss: 0.484441 Batch F1: 0.7894736842105262
# Epoch:   85        6 Batch loss: 0.610074 Batch F1: 0.5925925925925927
# Train Avg Loss   85: 0.502459
#
# Train Avg F1   85: 0.7771522306035615
#
# Val Avg Loss   85: 0.260712
#
# Val Avg F1   85:  0.7172576832151301
#
# Optimal Val loss (Epoch 8): 0.2109687179327011
#
# Epoch 86
# --------------------------------------------------------------
# Epoch:   86        1 Batch loss: 0.468237 Batch F1: 0.8333333333333333
# Epoch:   86        2 Batch loss: 0.463831 Batch F1: 0.7586206896551724
# Epoch:   86        3 Batch loss: 0.497327 Batch F1: 0.7906976744186046
# Epoch:   86        4 Batch loss: 0.548881 Batch F1: 0.7857142857142856
# Epoch:   86        5 Batch loss: 0.456013 Batch F1: 0.8571428571428572
# Epoch:   86        6 Batch loss: 0.557035 Batch F1: 0.6875
# Train Avg Loss   86: 0.498554
#
# Train Avg F1   86: 0.7855014733773755
#
# Val Avg Loss   86: 0.250730
#
# Val Avg F1   86:  0.7259259259259259
#
# Optimal Val loss (Epoch 8): 0.2109687179327011
#
# Epoch 87
# --------------------------------------------------------------
# Epoch:   87        1 Batch loss: 0.531972 Batch F1: 0.7027027027027027
# Epoch:   87        2 Batch loss: 0.529294 Batch F1: 0.7555555555555555
# Epoch:   87        3 Batch loss: 0.410878 Batch F1: 0.878048780487805
# Epoch:   87        4 Batch loss: 0.539199 Batch F1: 0.7391304347826088
# Epoch:   87        5 Batch loss: 0.503199 Batch F1: 0.8076923076923077
# Epoch:   87        6 Batch loss: 0.522934 Batch F1: 0.7647058823529411
# Train Avg Loss   87: 0.506246
#
# Train Avg F1   87: 0.7746392772623202
#
# Val Avg Loss   87: 0.248580
#
# Val Avg F1   87:  0.7307859313938342
#
# Optimal Val loss (Epoch 8): 0.2109687179327011
#
# Epoch 88
# --------------------------------------------------------------
# Epoch:   88        1 Batch loss: 0.470760 Batch F1: 0.8510638297872339
# Epoch:   88        2 Batch loss: 0.514164 Batch F1: 0.8076923076923077
# Epoch:   88        3 Batch loss: 0.488363 Batch F1: 0.8181818181818182
# Epoch:   88        4 Batch loss: 0.476309 Batch F1: 0.8260869565217391
# Epoch:   88        5 Batch loss: 0.612433 Batch F1: 0.6808510638297872
# Epoch:   88        6 Batch loss: 0.458297 Batch F1: 0.8148148148148148
# Train Avg Loss   88: 0.503388
#
# Train Avg F1   88: 0.7997817984712835
#
# Val Avg Loss   88: 0.258914
#
# Val Avg F1   88:  0.7429787234042553
#
# Optimal Val loss (Epoch 8): 0.2109687179327011
#
# Epoch 89
# --------------------------------------------------------------
# Epoch:   89        1 Batch loss: 0.427454 Batch F1: 0.8799999999999999
# Epoch:   89        2 Batch loss: 0.477822 Batch F1: 0.8181818181818182
# Epoch:   89        3 Batch loss: 0.559605 Batch F1: 0.6
# Epoch:   89        4 Batch loss: 0.563997 Batch F1: 0.6829268292682927
# Epoch:   89        5 Batch loss: 0.490120 Batch F1: 0.8085106382978723
# Epoch:   89        6 Batch loss: 0.512036 Batch F1: 0.8292682926829269
# Train Avg Loss   89: 0.505172
#
# Train Avg F1   89: 0.7698145964051517
#
# Val Avg Loss   89: 0.272761
#
# Val Avg F1   89:  0.7019927536231884
#
# Optimal Val loss (Epoch 8): 0.2109687179327011
#
# Epoch 90
# --------------------------------------------------------------
# Epoch:   90        1 Batch loss: 0.486929 Batch F1: 0.7428571428571428
# Epoch:   90        2 Batch loss: 0.453360 Batch F1: 0.8108108108108107
# Epoch:   90        3 Batch loss: 0.565154 Batch F1: 0.7272727272727272
# Epoch:   90        4 Batch loss: 0.535270 Batch F1: 0.8000000000000002
# Epoch:   90        5 Batch loss: 0.460574 Batch F1: 0.8627450980392156
# Epoch:   90        6 Batch loss: 0.484430 Batch F1: 0.8421052631578947
# Train Avg Loss   90: 0.497619
#
# Train Avg F1   90: 0.7976318403562986
#
# Val Avg Loss   90: 0.246339
#
# Val Avg F1   90:  0.7359198998748435
#
# Optimal Val loss (Epoch 8): 0.2109687179327011
#
# Epoch 91
# --------------------------------------------------------------
# Epoch:   91        1 Batch loss: 0.513669 Batch F1: 0.7659574468085107
# Epoch:   91        2 Batch loss: 0.558192 Batch F1: 0.7142857142857143
# Epoch:   91        3 Batch loss: 0.406671 Batch F1: 0.8979591836734694
# Epoch:   91        4 Batch loss: 0.423575 Batch F1: 0.8636363636363636
# Epoch:   91        5 Batch loss: 0.577764 Batch F1: 0.7083333333333334
# Epoch:   91        6 Batch loss: 0.512114 Batch F1: 0.7586206896551724
# Train Avg Loss   91: 0.498664
#
# Train Avg F1   91: 0.7847987885654274
#
# Val Avg Loss   91: 0.253225
#
# Val Avg F1   91:  0.7529411764705882
#
# Optimal Val loss (Epoch 8): 0.2109687179327011
#
# Epoch 92
# --------------------------------------------------------------
# Epoch:   92        1 Batch loss: 0.461605 Batch F1: 0.8620689655172413
# Epoch:   92        2 Batch loss: 0.513185 Batch F1: 0.717948717948718
# Epoch:   92        3 Batch loss: 0.524199 Batch F1: 0.7843137254901961
# Epoch:   92        4 Batch loss: 0.372984 Batch F1: 0.9333333333333332
# Epoch:   92        5 Batch loss: 0.476333 Batch F1: 0.7894736842105262
# Epoch:   92        6 Batch loss: 0.644873 Batch F1: 0.6470588235294118
# Train Avg Loss   92: 0.498863
#
# Train Avg F1   92: 0.7890328750049044
#
# Val Avg Loss   92: 0.271225
#
# Val Avg F1   92:  0.721938775510204
#
# Optimal Val loss (Epoch 8): 0.2109687179327011
#
# Epoch 93
# --------------------------------------------------------------
# Epoch:   93        1 Batch loss: 0.487649 Batch F1: 0.8095238095238095
# Epoch:   93        2 Batch loss: 0.525764 Batch F1: 0.8
# Epoch:   93        3 Batch loss: 0.551767 Batch F1: 0.75
# Epoch:   93        4 Batch loss: 0.502062 Batch F1: 0.7916666666666667
# Epoch:   93        5 Batch loss: 0.484621 Batch F1: 0.8181818181818182
# Epoch:   93        6 Batch loss: 0.431562 Batch F1: 0.8947368421052632
# Train Avg Loss   93: 0.497238
#
# Train Avg F1   93: 0.8106848560795928
#
# Val Avg Loss   93: 0.248322
#
# Val Avg F1   93:  0.7445887445887447
#
# Optimal Val loss (Epoch 8): 0.2109687179327011
#
# Epoch 94
# --------------------------------------------------------------
# Epoch:   94        1 Batch loss: 0.437686 Batch F1: 0.88
# Epoch:   94        2 Batch loss: 0.475299 Batch F1: 0.8400000000000001
# Epoch:   94        3 Batch loss: 0.498756 Batch F1: 0.7727272727272727
# Epoch:   94        4 Batch loss: 0.439832 Batch F1: 0.823529411764706
# Epoch:   94        5 Batch loss: 0.552046 Batch F1: 0.7857142857142857
# Epoch:   94        6 Batch loss: 0.549507 Batch F1: 0.64
# Train Avg Loss   94: 0.492188
#
# Train Avg F1   94: 0.7903284950343775
#
# Val Avg Loss   94: 0.242622
#
# Val Avg F1   94:  0.7495652173913043
#
# Optimal Val loss (Epoch 8): 0.2109687179327011
#
# Epoch 95
# --------------------------------------------------------------
# Epoch:   95        1 Batch loss: 0.491502 Batch F1: 0.8163265306122449
# Epoch:   95        2 Batch loss: 0.552324 Batch F1: 0.7636363636363638
# Epoch:   95        3 Batch loss: 0.464393 Batch F1: 0.8813559322033899
# Epoch:   95        4 Batch loss: 0.441089 Batch F1: 0.85
# Epoch:   95        5 Batch loss: 0.539888 Batch F1: 0.7692307692307692
# Epoch:   95        6 Batch loss: 0.506355 Batch F1: 0.5555555555555556
# Train Avg Loss   95: 0.499258
#
# Train Avg F1   95: 0.7726841918730539
#
# Val Avg Loss   95: 0.236801
#
# Val Avg F1   95:  0.7723704866562009
#
# Optimal Val loss (Epoch 8): 0.2109687179327011
#
# Epoch 96
# --------------------------------------------------------------
# Epoch:   96        1 Batch loss: 0.477294 Batch F1: 0.8461538461538461
# Epoch:   96        2 Batch loss: 0.500176 Batch F1: 0.8076923076923077
# Epoch:   96        3 Batch loss: 0.393250 Batch F1: 0.8749999999999999
# Epoch:   96        4 Batch loss: 0.462261 Batch F1: 0.8292682926829268
# Epoch:   96        5 Batch loss: 0.532179 Batch F1: 0.7843137254901961
# Epoch:   96        6 Batch loss: 0.585025 Batch F1: 0.6428571428571428
# Train Avg Loss   96: 0.491697
#
# Train Avg F1   96: 0.7975475524794033
#
# Val Avg Loss   96: 0.298450
#
# Val Avg F1   96:  0.6679940268790443
#
# Optimal Val loss (Epoch 8): 0.2109687179327011
#
# Epoch 97
# --------------------------------------------------------------
# Epoch:   97        1 Batch loss: 0.534813 Batch F1: 0.7391304347826089
# Epoch:   97        2 Batch loss: 0.480587 Batch F1: 0.8181818181818181
# Epoch:   97        3 Batch loss: 0.552019 Batch F1: 0.6842105263157895
# Epoch:   97        4 Batch loss: 0.501057 Batch F1: 0.7826086956521738
# Epoch:   97        5 Batch loss: 0.422684 Batch F1: 0.8636363636363636
# Epoch:   97        6 Batch loss: 0.493403 Batch F1: 0.8125000000000001
# Train Avg Loss   97: 0.497427
#
# Train Avg F1   97: 0.7833779730947924
#
# Val Avg Loss   97: 0.247846
#
# Val Avg F1   97:  0.7523128679562658
#
# Optimal Val loss (Epoch 8): 0.2109687179327011
#
# Epoch 98
# --------------------------------------------------------------
# Epoch:   98        1 Batch loss: 0.476773 Batch F1: 0.8620689655172414
# Epoch:   98        2 Batch loss: 0.484145 Batch F1: 0.7894736842105263
# Epoch:   98        3 Batch loss: 0.540575 Batch F1: 0.7142857142857143
# Epoch:   98        4 Batch loss: 0.494952 Batch F1: 0.8363636363636363
# Epoch:   98        5 Batch loss: 0.452840 Batch F1: 0.8444444444444444
# Epoch:   98        6 Batch loss: 0.509743 Batch F1: 0.7199999999999999
# Train Avg Loss   98: 0.493171
#
# Train Avg F1   98: 0.7944394074702604
#
# Val Avg Loss   98: 0.258528
#
# Val Avg F1   98:  0.7269387755102041
#
# Optimal Val loss (Epoch 8): 0.2109687179327011
#
# Epoch 99
# --------------------------------------------------------------
# Epoch:   99        1 Batch loss: 0.527430 Batch F1: 0.7843137254901961
# Epoch:   99        2 Batch loss: 0.495907 Batch F1: 0.7906976744186046
# Epoch:   99        3 Batch loss: 0.463428 Batch F1: 0.8627450980392156
# Epoch:   99        4 Batch loss: 0.516262 Batch F1: 0.7999999999999999
# Epoch:   99        5 Batch loss: 0.523326 Batch F1: 0.7441860465116279
# Epoch:   99        6 Batch loss: 0.402573 Batch F1: 0.8799999999999999
# Train Avg Loss   99: 0.488154
#
# Train Avg F1   99: 0.8103237574099408
#
# Val Avg Loss   99: 0.254757
#
# Val Avg F1   99:  0.7414141414141413
#
# Optimal Val loss (Epoch 8): 0.2109687179327011
#
# Epoch 100
# --------------------------------------------------------------
# Epoch:  100        1 Batch loss: 0.419580 Batch F1: 0.8780487804878048
# Epoch:  100        2 Batch loss: 0.549565 Batch F1: 0.7391304347826088
# Epoch:  100        3 Batch loss: 0.544934 Batch F1: 0.7692307692307692
# Epoch:  100        4 Batch loss: 0.469323 Batch F1: 0.8095238095238095
# Epoch:  100        5 Batch loss: 0.549303 Batch F1: 0.76
# Epoch:  100        6 Batch loss: 0.406111 Batch F1: 0.9090909090909091
# Train Avg Loss  100: 0.489802
#
# Train Avg F1  100: 0.8108374505193169
#
# Val Avg Loss  100: 0.246048
#
# Val Avg F1  100:  0.7188219052001841
#
# Optimal Val loss (Epoch 8): 0.2109687179327011
#
# Done!
# ''

# %%
import json

# %%
results = json.load(open(path_to_res))

# %%
#print('best f1', np.max(results['val_f1']), np.argmax(results['val_f1']))
print('best f1 val', results['val_f1'][np.argmax(results['val_f1'])])
print('corr f1 train', results['train_f1'][np.argmax(results['val_f1'])])
print('corr f1 test', results['test_f1'][np.argmax(results['val_f1'])])
#print('best f1 train', np.max(results['train_f1']), np.argmax(results['train_f1']))
# Out:
# best f1 val 0.778061224489796
# corr f1 train 0.7907956600957662
# corr f1 test 0.6515151515151516

# %%
import matplotlib.pyplot as plt

# %%
plt.title('F1 score plot 5% RE threshold')
plt.ylabel('F1')
plt.xlabel('Epochs')
plt.plot(results['train_f1'],'-g', label='Train F1')
plt.plot(results['val_f1'],'-b', label='Val F1')
plt.legend(loc='upper left')
plt.ylim([0.0,1.0])
# Out:
# (0.0, 1.0)

# %%
list(results.keys())
# Out:
# ['train_loss',
#  'val_loss',
#  'test_loss',
#  'train_f1',
#  'val_f1',
#  'test_f1',
#  'train_prec',
#  'val_prec',
#  'test_prec',
#  'train_recall',
#  'val_recall',
#  'test_recall']

# %%
plt.title('Precision score plot 5% RE threshold')
plt.ylabel('Precision')
plt.xlabel('Epochs')
plt.plot(results['train_prec'],'-g', label='Train Precision')
plt.plot(results['val_prec'],'-b', label='Val Precision')
plt.legend(loc='upper left')
plt.ylim([0.0,1.0])
# Out:
# (0.0, 1.0)

# %%
plt.title('Recall score plot 5% RE threshold')
plt.ylabel('Recall')
plt.xlabel('Epochs')
plt.plot(results['train_recall'],'-g', label='Train Recall')
plt.plot(results['val_recall'],'-b', label='Val Recall')
plt.legend(loc='upper left')
plt.ylim([0.0,1.0])
# Out:
# (0.0, 1.0)

# %%
import torch
model = torch.load(best_model_path)
model.eval()
model
# Out:
# Classifier(
#   (conv1): RelGraphConv(
#     (linear_r): TypedLinear(in_size=113, out_size=64, num_types=8)
#     (dropout): Dropout(p=0.0, inplace=False)
#   )
#   (conv2): RelGraphConv(
#     (linear_r): TypedLinear(in_size=64, out_size=64, num_types=8)
#     (dropout): Dropout(p=0.0, inplace=False)
#   )
#   (lin): Linear(in_features=64, out_features=64, bias=True)
#   (classify): Linear(in_features=64, out_features=2, bias=True)
# )

# %%
from dgl_classifier. trainer import predict2samples
print(train_file)
train_data, val_data,test_data = predict2samples(model,train_file, val_file, test_file, community_no=10, verbose=True, clust_verbose=False, clust_load_path='/work/data/confs/May2/pred_clust.json')
# Out:
# /work/data/splits/splits_0.05/train.json

# %%
for k in train_data.keys():
    print(train_data[k])
    break
# Out:
# {'bloom_runtime': 0.087360461, 'jena_runtime': 0.084558884, 'gt': False, 'bgp_construction_duration': 0.00010609626770019531, 'tps_const_duration': 0.0005903244018554688, 'prediction': 1, 'inference_time': 0.006054401397705078}

# %%
from dgl_classifier.post import *
train_rt, avg_train = avg_runtime(train_data)
_,_, avg_train_jena,avg_train_blf = avg_runtime_type(train_data)
val_rt, avg_val = avg_runtime(val_data)
_,_, avg_val_jena,avg_val_blf = avg_runtime_type(val_data)
test_rt, avg_test = avg_runtime(test_data)
_,_, avg_test_jena,avg_test_blf = avg_runtime_type(test_data)

# %%
print(avg_train, avg_train_jena,avg_train_blf)
print(avg_val,avg_val_jena,avg_val_blf)
print(avg_test,avg_test_jena,avg_test_blf)
# Out:
# 3.289827162278379 3.2869220443741263 3.971899206534965
# 6.272527457122462 5.970634309770834 6.589601230302083
# 3.8210479244107685 3.8058100474687504 4.344179262739583
