# %% [markdown]
# file paths

# %%
train_file = '/work/data/splits/splits_0.05/train.json'
val_file = '/work/data/splits/splits_0.05/val.json'
test_file = '/work/data/splits/splits_0.05/test.json'

path_to_save = '/work/data/models'
path_to_res = '/work/data/results/31_5_2023_tp_graph_5re.txt'

# %% [markdown]
# import

# %%
# %load_ext autoreload
# %autoreload 2
import json
import dgl
from sklearn.metrics import f1_score
import torch as th
import dgl.nn.pytorch as dglnn
import torch.nn as nn
from dgl.dataloading import GraphDataLoader
import torch.nn.functional as F
import networkx as nx
import warnings
from feature_extraction.base_featurizer import BaseFeaturizer
import torch
from graph_construction.tps_graph import create_dummy_dgl_graph, tps_graph
import numpy as np

from dgl_classifier.trainer import GraphDataset,snap_pred, tps_to_dgl, get_clasification_vec,\
tps_graph_const, extract_data, runner


import warnings

from preprocessing.utils import load_BGPS_from_json
warnings.filterwarnings('ignore', category=UserWarning, message='TypedStorage is deprecated')

# %%
#seed
dgl.seed(1223)

# %% [markdown]
# Model

# %%
class Classifier(nn.Module):
    def __init__(self, in_dim, hidden_dim, n_classes):
        super(Classifier, self).__init__()
        self.conv1 = dglnn.RelGraphConv(in_dim, hidden_dim, 8)
        #self.conv1 = dglnn.GraphConv(in_dim, hidden_ˇdim)
        self.conv2 = dglnn.RelGraphConv(hidden_dim, hidden_dim, 8)
        #self.conv2 = dglnn.GraphConv(hidden_dim, hidden_dim)
        self.classify = nn.Linear(hidden_dim, n_classes)

    def forward(self, g, h, rel_types):
        # Apply graph convolution and activation.
        h = F.relu(self.conv1(g, h, rel_types))
        h = F.relu(self.conv2(g, h, rel_types))
        with g.local_scope():
            g.ndata['node_features'] = h
            # Calculate graph representation by average readout.
            hg = dgl.mean_nodes(g, 'node_features')
            return F.softmax( self.classify(hg), dim=1)
model = Classifier(113, 20, 2)

# %% [markdown]
# hyperparameters

# %%
early_stop =100
model = Classifier(113, 20, 2)
lr = 0.01
wd = 5e-4
epochs = 100

# %%
train_dataloader, val_dataloader, test_dataloader = extract_data(train_file, val_file, test_file, community_no=30, batch_size = 50, verbose=True)
# Out:
# /usr/local/lib/python3.10/dist-packages/dgl/backend/pytorch/tensor.py:52: UserWarning: Creating a tensor from a list of numpy.ndarrays is extremely slow. Please consider converting the list to a single numpy.ndarray with numpy.array() before converting to a tensor. (Triggered internally at ../torch/csrc/utils/tensor_new.cpp:245.)
#   return th.as_tensor(data, dtype=dtype)
# # of predicate feats not in validation 37
# # of predicate feats not in test 3
# Training dataset size 139
# Validation dataset size 50
# Test dataset size 45

# %%
runner(train_dataloader,val_dataloader,test_dataloader,model, early_stop, lr, wd, epochs, path_to_res)
# Out:
# Epoch 1
# --------------------------------------------------------------
# Epoch:    1        1 Batch loss: 0.695453 Batch F1: 0.6197183098591549
# Epoch:    1        2 Batch loss: 0.644735 Batch F1: 0.5500000000000002
# Epoch:    1        3 Batch loss: 0.674105 Batch F1: 0.17391304347826084
# Train Avg Loss    1: 0.671431
#
# Train Avg F1    1: 0.4478771177791386
#
# Val Avg Loss    1: 0.270988
#
# Val Avg F1    1:  0.4888888888888889
#
# Optimal Val loss (Epoch 1): 0.2709883749485016
#
# Epoch 2
# --------------------------------------------------------------
# Epoch:    2        1 Batch loss: 0.632986 Batch F1: 0.48484848484848486
# Epoch:    2        2 Batch loss: 0.583648 Batch F1: 0.8
# Epoch:    2        3 Batch loss: 0.618180 Batch F1: 0.6976744186046512
# Train Avg Loss    2: 0.611605
#
# Train Avg F1    2: 0.6608409678177121
#
# Val Avg Loss    2: 0.211099
#
# Val Avg F1    2:  0.7761194029850748
#
# Optimal Val loss (Epoch 2): 0.21109914779663086
#
# Epoch 3
# --------------------------------------------------------------
# Epoch:    3        1 Batch loss: 0.588075 Batch F1: 0.6122448979591836
# Epoch:    3        2 Batch loss: 0.574029 Batch F1: 0.7796610169491526
# Epoch:    3        3 Batch loss: 0.620041 Batch F1: 0.5806451612903226
# Train Avg Loss    3: 0.594049
#
# Train Avg F1    3: 0.6575170253995529
#
# Val Avg Loss    3: 0.253232
#
# Val Avg F1    3:  0.7636363636363634
#
# Optimal Val loss (Epoch 2): 0.21109914779663086
#
# Epoch 4
# --------------------------------------------------------------
# Epoch:    4        1 Batch loss: 0.498897 Batch F1: 0.8695652173913043
# Epoch:    4        2 Batch loss: 0.684990 Batch F1: 0.4736842105263157
# Epoch:    4        3 Batch loss: 0.527955 Batch F1: 0.7096774193548386
# Train Avg Loss    4: 0.570614
#
# Train Avg F1    4: 0.6843089490908195
#
# Val Avg Loss    4: 0.246957
#
# Val Avg F1    4:  0.7857142857142857
#
# Optimal Val loss (Epoch 2): 0.21109914779663086
#
# Epoch 5
# --------------------------------------------------------------
# Epoch:    5        1 Batch loss: 0.520815 Batch F1: 0.761904761904762
# Epoch:    5        2 Batch loss: 0.563032 Batch F1: 0.6666666666666665
# Epoch:    5        3 Batch loss: 0.605494 Batch F1: 0.761904761904762
# Train Avg Loss    5: 0.563114
#
# Train Avg F1    5: 0.7301587301587301
#
# Val Avg Loss    5: 0.224848
#
# Val Avg F1    5:  0.7719298245614036
#
# Optimal Val loss (Epoch 2): 0.21109914779663086
#
# Epoch 6
# --------------------------------------------------------------
# Epoch:    6        1 Batch loss: 0.486572 Batch F1: 0.8444444444444444
# Epoch:    6        2 Batch loss: 0.581893 Batch F1: 0.7450980392156864
# Epoch:    6        3 Batch loss: 0.585031 Batch F1: 0.6
# Train Avg Loss    6: 0.551165
#
# Train Avg F1    6: 0.7298474945533769
#
# Val Avg Loss    6: 0.226774
#
# Val Avg F1    6:  0.7719298245614036
#
# Optimal Val loss (Epoch 2): 0.21109914779663086
#
# Epoch 7
# --------------------------------------------------------------
# Epoch:    7        1 Batch loss: 0.511209 Batch F1: 0.7804878048780487
# Epoch:    7        2 Batch loss: 0.564136 Batch F1: 0.6829268292682926
# Epoch:    7        3 Batch loss: 0.531534 Batch F1: 0.8095238095238095
# Train Avg Loss    7: 0.535626
#
# Train Avg F1    7: 0.7576461478900504
#
# Val Avg Loss    7: 0.232918
#
# Val Avg F1    7:  0.7719298245614036
#
# Optimal Val loss (Epoch 2): 0.21109914779663086
#
# Epoch 8
# --------------------------------------------------------------
# Epoch:    8        1 Batch loss: 0.519562 Batch F1: 0.75
# Epoch:    8        2 Batch loss: 0.533463 Batch F1: 0.7727272727272727
# Epoch:    8        3 Batch loss: 0.541107 Batch F1: 0.75
# Train Avg Loss    8: 0.531377
#
# Train Avg F1    8: 0.7575757575757575
#
# Val Avg Loss    8: 0.224205
#
# Val Avg F1    8:  0.7719298245614036
#
# Optimal Val loss (Epoch 2): 0.21109914779663086
#
# Epoch 9
# --------------------------------------------------------------
# Epoch:    9        1 Batch loss: 0.537800 Batch F1: 0.7777777777777778
# Epoch:    9        2 Batch loss: 0.499990 Batch F1: 0.761904761904762
# Epoch:    9        3 Batch loss: 0.541250 Batch F1: 0.6666666666666666
# Train Avg Loss    9: 0.526347
#
# Train Avg F1    9: 0.7354497354497355
#
# Val Avg Loss    9: 0.215331
#
# Val Avg F1    9:  0.7719298245614036
#
# Optimal Val loss (Epoch 2): 0.21109914779663086
#
# Epoch 10
# --------------------------------------------------------------
# Epoch:   10        1 Batch loss: 0.532635 Batch F1: 0.76
# Epoch:   10        2 Batch loss: 0.514434 Batch F1: 0.717948717948718
# Epoch:   10        3 Batch loss: 0.494009 Batch F1: 0.7777777777777778
# Train Avg Loss   10: 0.513693
#
# Train Avg F1   10: 0.7519088319088318
#
# Val Avg Loss   10: 0.209044
#
# Val Avg F1   10:  0.7857142857142857
#
# Optimal Val loss (Epoch 10): 0.20904365181922913
#
# Epoch 11
# --------------------------------------------------------------
# Epoch:   11        1 Batch loss: 0.528523 Batch F1: 0.7755102040816326
# Epoch:   11        2 Batch loss: 0.502236 Batch F1: 0.8085106382978723
# Epoch:   11        3 Batch loss: 0.520601 Batch F1: 0.6923076923076924
# Train Avg Loss   11: 0.517120
#
# Train Avg F1   11: 0.7587761782290658
#
# Val Avg Loss   11: 0.220620
#
# Val Avg F1   11:  0.7636363636363634
#
# Optimal Val loss (Epoch 10): 0.20904365181922913
#
# Epoch 12
# --------------------------------------------------------------
# Epoch:   12        1 Batch loss: 0.465242 Batch F1: 0.8205128205128205
# Epoch:   12        2 Batch loss: 0.493267 Batch F1: 0.830188679245283
# Epoch:   12        3 Batch loss: 0.570107 Batch F1: 0.6206896551724139
# Train Avg Loss   12: 0.509539
#
# Train Avg F1   12: 0.7571303849768393
#
# Val Avg Loss   12: 0.177714
#
# Val Avg F1   12:  0.7999999999999999
#
# Optimal Val loss (Epoch 12): 0.17771421372890472
#
# Epoch 13
# --------------------------------------------------------------
# Epoch:   13        1 Batch loss: 0.511136 Batch F1: 0.7826086956521738
# Epoch:   13        2 Batch loss: 0.537725 Batch F1: 0.7826086956521738
# Epoch:   13        3 Batch loss: 0.441996 Batch F1: 0.9047619047619048
# Train Avg Loss   13: 0.496952
#
# Train Avg F1   13: 0.8233264320220841
#
# Val Avg Loss   13: 0.188003
#
# Val Avg F1   13:  0.8070175438596492
#
# Optimal Val loss (Epoch 12): 0.17771421372890472
#
# Epoch 14
# --------------------------------------------------------------
# Epoch:   14        1 Batch loss: 0.492315 Batch F1: 0.7659574468085107
# Epoch:   14        2 Batch loss: 0.510472 Batch F1: 0.7826086956521738
# Epoch:   14        3 Batch loss: 0.456773 Batch F1: 0.823529411764706
# Train Avg Loss   14: 0.486520
#
# Train Avg F1   14: 0.7906985180751303
#
# Val Avg Loss   14: 0.220329
#
# Val Avg F1   14:  0.7407407407407406
#
# Optimal Val loss (Epoch 12): 0.17771421372890472
#
# Epoch 15
# --------------------------------------------------------------
# Epoch:   15        1 Batch loss: 0.504082 Batch F1: 0.7317073170731707
# Epoch:   15        2 Batch loss: 0.502390 Batch F1: 0.7727272727272727
# Epoch:   15        3 Batch loss: 0.445068 Batch F1: 0.9047619047619048
# Train Avg Loss   15: 0.483847
#
# Train Avg F1   15: 0.8030654981874493
#
# Val Avg Loss   15: 0.194338
#
# Val Avg F1   15:  0.8135593220338982
#
# Optimal Val loss (Epoch 12): 0.17771421372890472
#
# Epoch 16
# --------------------------------------------------------------
# Epoch:   16        1 Batch loss: 0.528567 Batch F1: 0.7916666666666666
# Epoch:   16        2 Batch loss: 0.463700 Batch F1: 0.8333333333333333
# Epoch:   16        3 Batch loss: 0.420705 Batch F1: 0.8888888888888888
# Train Avg Loss   16: 0.470991
#
# Train Avg F1   16: 0.8379629629629629
#
# Val Avg Loss   16: 0.199329
#
# Val Avg F1   16:  0.8135593220338982
#
# Optimal Val loss (Epoch 12): 0.17771421372890472
#
# Epoch 17
# --------------------------------------------------------------
# Epoch:   17        1 Batch loss: 0.439431 Batch F1: 0.8571428571428572
# Epoch:   17        2 Batch loss: 0.452215 Batch F1: 0.8846153846153846
# Epoch:   17        3 Batch loss: 0.558996 Batch F1: 0.7317073170731707
# Train Avg Loss   17: 0.483547
#
# Train Avg F1   17: 0.8244885196104708
#
# Val Avg Loss   17: 0.201113
#
# Val Avg F1   17:  0.7796610169491525
#
# Optimal Val loss (Epoch 12): 0.17771421372890472
#
# Epoch 18
# --------------------------------------------------------------
# Epoch:   18        1 Batch loss: 0.515098 Batch F1: 0.8275862068965517
# Epoch:   18        2 Batch loss: 0.407477 Batch F1: 0.888888888888889
# Epoch:   18        3 Batch loss: 0.462377 Batch F1: 0.8275862068965517
# Train Avg Loss   18: 0.461651
#
# Train Avg F1   18: 0.8480204342273309
#
# Val Avg Loss   18: 0.226440
#
# Val Avg F1   18:  0.7857142857142857
#
# Optimal Val loss (Epoch 12): 0.17771421372890472
#
# Epoch 19
# --------------------------------------------------------------
# Epoch:   19        1 Batch loss: 0.457417 Batch F1: 0.8679245283018869
# Epoch:   19        2 Batch loss: 0.446909 Batch F1: 0.8695652173913043
# Epoch:   19        3 Batch loss: 0.520717 Batch F1: 0.7500000000000001
# Train Avg Loss   19: 0.475014
#
# Train Avg F1   19: 0.829163248564397
#
# Val Avg Loss   19: 0.220987
#
# Val Avg F1   19:  0.7857142857142857
#
# Optimal Val loss (Epoch 12): 0.17771421372890472
#
# Epoch 20
# --------------------------------------------------------------
# Epoch:   20        1 Batch loss: 0.468176 Batch F1: 0.7999999999999999
# Epoch:   20        2 Batch loss: 0.448888 Batch F1: 0.8727272727272727
# Epoch:   20        3 Batch loss: 0.457491 Batch F1: 0.8484848484848485
# Train Avg Loss   20: 0.458185
#
# Train Avg F1   20: 0.8404040404040404
#
# Val Avg Loss   20: 0.224857
#
# Val Avg F1   20:  0.7857142857142857
#
# Optimal Val loss (Epoch 12): 0.17771421372890472
#
# Epoch 21
# --------------------------------------------------------------
# Epoch:   21        1 Batch loss: 0.421760 Batch F1: 0.85
# Epoch:   21        2 Batch loss: 0.477991 Batch F1: 0.7999999999999999
# Epoch:   21        3 Batch loss: 0.472377 Batch F1: 0.875
# Train Avg Loss   21: 0.457376
#
# Train Avg F1   21: 0.8416666666666667
#
# Val Avg Loss   21: 0.228467
#
# Val Avg F1   21:  0.7586206896551724
#
# Optimal Val loss (Epoch 12): 0.17771421372890472
#
# Epoch 22
# --------------------------------------------------------------
# Epoch:   22        1 Batch loss: 0.491987 Batch F1: 0.8363636363636363
# Epoch:   22        2 Batch loss: 0.427031 Batch F1: 0.8636363636363635
# Epoch:   22        3 Batch loss: 0.455268 Batch F1: 0.8484848484848485
# Train Avg Loss   22: 0.458095
#
# Train Avg F1   22: 0.8494949494949494
#
# Val Avg Loss   22: 0.223774
#
# Val Avg F1   22:  0.7636363636363634
#
# Optimal Val loss (Epoch 12): 0.17771421372890472
#
# Epoch 23
# --------------------------------------------------------------
# Epoch:   23        1 Batch loss: 0.429473 Batch F1: 0.8846153846153847
# Epoch:   23        2 Batch loss: 0.504010 Batch F1: 0.761904761904762
# Epoch:   23        3 Batch loss: 0.476629 Batch F1: 0.8235294117647058
# Train Avg Loss   23: 0.470038
#
# Train Avg F1   23: 0.8233498527616175
#
# Val Avg Loss   23: 0.210414
#
# Val Avg F1   23:  0.7931034482758621
#
# Optimal Val loss (Epoch 12): 0.17771421372890472
#
# Epoch 24
# --------------------------------------------------------------
# Epoch:   24        1 Batch loss: 0.443779 Batch F1: 0.8444444444444444
# Epoch:   24        2 Batch loss: 0.500326 Batch F1: 0.7906976744186046
# Epoch:   24        3 Batch loss: 0.429221 Batch F1: 0.9130434782608695
# Train Avg Loss   24: 0.457775
#
# Train Avg F1   24: 0.8493951990413061
#
# Val Avg Loss   24: 0.220819
#
# Val Avg F1   24:  0.7868852459016394
#
# Optimal Val loss (Epoch 12): 0.17771421372890472
#
# Epoch 25
# --------------------------------------------------------------
# Epoch:   25        1 Batch loss: 0.464353 Batch F1: 0.8620689655172413
# Epoch:   25        2 Batch loss: 0.422904 Batch F1: 0.888888888888889
# Epoch:   25        3 Batch loss: 0.470312 Batch F1: 0.8387096774193549
# Train Avg Loss   25: 0.452523
#
# Train Avg F1   25: 0.8632225106084951
#
# Val Avg Loss   25: 0.247007
#
# Val Avg F1   25:  0.7407407407407406
#
# Optimal Val loss (Epoch 12): 0.17771421372890472
#
# Epoch 26
# --------------------------------------------------------------
# Epoch:   26        1 Batch loss: 0.446695 Batch F1: 0.8444444444444444
# Epoch:   26        2 Batch loss: 0.468404 Batch F1: 0.7894736842105263
# Epoch:   26        3 Batch loss: 0.472439 Batch F1: 0.8571428571428571
# Train Avg Loss   26: 0.462513
#
# Train Avg F1   26: 0.8303536619326093
#
# Val Avg Loss   26: 0.283386
#
# Val Avg F1   26:  0.7272727272727273
#
# Optimal Val loss (Epoch 12): 0.17771421372890472
#
# Epoch 27
# --------------------------------------------------------------
# Epoch:   27        1 Batch loss: 0.381970 Batch F1: 0.9473684210526316
# Epoch:   27        2 Batch loss: 0.545147 Batch F1: 0.6842105263157896
# Epoch:   27        3 Batch loss: 0.477755 Batch F1: 0.7777777777777778
# Train Avg Loss   27: 0.468291
#
# Train Avg F1   27: 0.8031189083820663
#
# Val Avg Loss   27: 0.284595
#
# Val Avg F1   27:  0.7272727272727273
#
# Optimal Val loss (Epoch 12): 0.17771421372890472
#
# Epoch 28
# --------------------------------------------------------------
# Epoch:   28        1 Batch loss: 0.483954 Batch F1: 0.7999999999999999
# Epoch:   28        2 Batch loss: 0.391355 Batch F1: 0.9130434782608695
# Epoch:   28        3 Batch loss: 0.580247 Batch F1: 0.7027027027027026
# Train Avg Loss   28: 0.485185
#
# Train Avg F1   28: 0.8052487269878573
#
# Val Avg Loss   28: 0.288963
#
# Val Avg F1   28:  0.6923076923076923
#
# Optimal Val loss (Epoch 12): 0.17771421372890472
#
# Epoch 29
# --------------------------------------------------------------
# Epoch:   29        1 Batch loss: 0.530500 Batch F1: 0.6857142857142857
# Epoch:   29        2 Batch loss: 0.440014 Batch F1: 0.8695652173913043
# Epoch:   29        3 Batch loss: 0.437476 Batch F1: 0.8837209302325582
# Train Avg Loss   29: 0.469330
#
# Train Avg F1   29: 0.8130001444460495
#
# Val Avg Loss   29: 0.233084
#
# Val Avg F1   29:  0.7666666666666666
#
# Optimal Val loss (Epoch 12): 0.17771421372890472
#
# Epoch 30
# --------------------------------------------------------------
# Epoch:   30        1 Batch loss: 0.454304 Batch F1: 0.88
# Epoch:   30        2 Batch loss: 0.505332 Batch F1: 0.7826086956521738
# Epoch:   30        3 Batch loss: 0.421149 Batch F1: 0.9
# Train Avg Loss   30: 0.460261
#
# Train Avg F1   30: 0.8542028985507245
#
# Val Avg Loss   30: 0.225641
#
# Val Avg F1   30:  0.7999999999999999
#
# Optimal Val loss (Epoch 12): 0.17771421372890472
#
# Epoch 31
# --------------------------------------------------------------
# Epoch:   31        1 Batch loss: 0.456757 Batch F1: 0.8627450980392156
# Epoch:   31        2 Batch loss: 0.446556 Batch F1: 0.8928571428571429
# Epoch:   31        3 Batch loss: 0.435706 Batch F1: 0.8148148148148148
# Train Avg Loss   31: 0.446340
#
# Train Avg F1   31: 0.8568056852370578
#
# Val Avg Loss   31: 0.215059
#
# Val Avg F1   31:  0.7931034482758621
#
# Optimal Val loss (Epoch 12): 0.17771421372890472
#
# Epoch 32
# --------------------------------------------------------------
# Epoch:   32        1 Batch loss: 0.484897 Batch F1: 0.8421052631578947
# Epoch:   32        2 Batch loss: 0.457617 Batch F1: 0.8292682926829269
# Epoch:   32        3 Batch loss: 0.415145 Batch F1: 0.8666666666666666
# Train Avg Loss   32: 0.452553
#
# Train Avg F1   32: 0.846013407502496
#
# Val Avg Loss   32: 0.223500
#
# Val Avg F1   32:  0.8070175438596492
#
# Optimal Val loss (Epoch 12): 0.17771421372890472
#
# Epoch 33
# --------------------------------------------------------------
# Epoch:   33        1 Batch loss: 0.359327 Batch F1: 0.9642857142857143
# Epoch:   33        2 Batch loss: 0.507858 Batch F1: 0.7500000000000001
# Epoch:   33        3 Batch loss: 0.486178 Batch F1: 0.823529411764706
# Train Avg Loss   33: 0.451121
#
# Train Avg F1   33: 0.8459383753501402
#
# Val Avg Loss   33: 0.230127
#
# Val Avg F1   33:  0.7796610169491525
#
# Optimal Val loss (Epoch 12): 0.17771421372890472
#
# Epoch 34
# --------------------------------------------------------------
# Epoch:   34        1 Batch loss: 0.458363 Batch F1: 0.8518518518518519
# Epoch:   34        2 Batch loss: 0.476211 Batch F1: 0.8260869565217391
# Epoch:   34        3 Batch loss: 0.395828 Batch F1: 0.9090909090909091
# Train Avg Loss   34: 0.443467
#
# Train Avg F1   34: 0.8623432391548334
#
# Val Avg Loss   34: 0.235437
#
# Val Avg F1   34:  0.7719298245614036
#
# Optimal Val loss (Epoch 12): 0.17771421372890472
#
# Epoch 35
# --------------------------------------------------------------
# Epoch:   35        1 Batch loss: 0.408817 Batch F1: 0.909090909090909
# Epoch:   35        2 Batch loss: 0.418719 Batch F1: 0.888888888888889
# Epoch:   35        3 Batch loss: 0.536748 Batch F1: 0.7804878048780488
# Train Avg Loss   35: 0.454761
#
# Train Avg F1   35: 0.8594892009526157
#
# Val Avg Loss   35: 0.237069
#
# Val Avg F1   35:  0.7719298245614036
#
# Optimal Val loss (Epoch 12): 0.17771421372890472
#
# Epoch 36
# --------------------------------------------------------------
# Epoch:   36        1 Batch loss: 0.374748 Batch F1: 0.9454545454545454
# Epoch:   36        2 Batch loss: 0.501065 Batch F1: 0.7804878048780488
# Epoch:   36        3 Batch loss: 0.470857 Batch F1: 0.823529411764706
# Train Avg Loss   36: 0.448890
#
# Train Avg F1   36: 0.8498239206991002
#
# Val Avg Loss   36: 0.241691
#
# Val Avg F1   36:  0.7796610169491525
#
# Optimal Val loss (Epoch 12): 0.17771421372890472
#
# Epoch 37
# --------------------------------------------------------------
# Epoch:   37        1 Batch loss: 0.434667 Batch F1: 0.88
# Epoch:   37        2 Batch loss: 0.427867 Batch F1: 0.9019607843137256
# Epoch:   37        3 Batch loss: 0.494376 Batch F1: 0.787878787878788
# Train Avg Loss   37: 0.452303
#
# Train Avg F1   37: 0.856613190730838
#
# Val Avg Loss   37: 0.241856
#
# Val Avg F1   37:  0.7796610169491525
#
# Optimal Val loss (Epoch 12): 0.17771421372890472
#
# Epoch 38
# --------------------------------------------------------------
# Epoch:   38        1 Batch loss: 0.512917 Batch F1: 0.8000000000000002
# Epoch:   38        2 Batch loss: 0.417308 Batch F1: 0.9152542372881356
# Epoch:   38        3 Batch loss: 0.403993 Batch F1: 0.8695652173913043
# Train Avg Loss   38: 0.444739
#
# Train Avg F1   38: 0.8616064848931466
#
# Val Avg Loss   38: 0.242945
#
# Val Avg F1   38:  0.7796610169491525
#
# Optimal Val loss (Epoch 12): 0.17771421372890472
#
# Epoch 39
# --------------------------------------------------------------
# Epoch:   39        1 Batch loss: 0.446484 Batch F1: 0.8571428571428572
# Epoch:   39        2 Batch loss: 0.467634 Batch F1: 0.7777777777777778
# Epoch:   39        3 Batch loss: 0.418491 Batch F1: 0.9166666666666666
# Train Avg Loss   39: 0.444203
#
# Train Avg F1   39: 0.8505291005291005
#
# Val Avg Loss   39: 0.244155
#
# Val Avg F1   39:  0.7719298245614036
#
# Optimal Val loss (Epoch 12): 0.17771421372890472
#
# Epoch 40
# --------------------------------------------------------------
# Epoch:   40        1 Batch loss: 0.505419 Batch F1: 0.8363636363636363
# Epoch:   40        2 Batch loss: 0.389929 Batch F1: 0.8823529411764706
# Epoch:   40        3 Batch loss: 0.439724 Batch F1: 0.8780487804878048
# Train Avg Loss   40: 0.445024
#
# Train Avg F1   40: 0.8655884526759706
#
# Val Avg Loss   40: 0.243919
#
# Val Avg F1   40:  0.7719298245614036
#
# Optimal Val loss (Epoch 12): 0.17771421372890472
#
# Epoch 41
# --------------------------------------------------------------
# Epoch:   41        1 Batch loss: 0.450929 Batch F1: 0.8372093023255814
# Epoch:   41        2 Batch loss: 0.436652 Batch F1: 0.8571428571428571
# Epoch:   41        3 Batch loss: 0.449767 Batch F1: 0.888888888888889
# Train Avg Loss   41: 0.445783
#
# Train Avg F1   41: 0.8610803494524425
#
# Val Avg Loss   41: 0.244245
#
# Val Avg F1   41:  0.7719298245614036
#
# Optimal Val loss (Epoch 12): 0.17771421372890472
#
# Epoch 42
# --------------------------------------------------------------
# Epoch:   42        1 Batch loss: 0.442067 Batch F1: 0.8749999999999999
# Epoch:   42        2 Batch loss: 0.474765 Batch F1: 0.7894736842105262
# Epoch:   42        3 Batch loss: 0.408288 Batch F1: 0.9090909090909091
# Train Avg Loss   42: 0.441707
#
# Train Avg F1   42: 0.8578548644338118
#
# Val Avg Loss   42: 0.248683
#
# Val Avg F1   42:  0.7796610169491525
#
# Optimal Val loss (Epoch 12): 0.17771421372890472
#
# Epoch 43
# --------------------------------------------------------------
# Epoch:   43        1 Batch loss: 0.475493 Batch F1: 0.8333333333333333
# Epoch:   43        2 Batch loss: 0.454177 Batch F1: 0.8444444444444444
# Epoch:   43        3 Batch loss: 0.393495 Batch F1: 0.9268292682926829
# Train Avg Loss   43: 0.441055
#
# Train Avg F1   43: 0.8682023486901534
#
# Val Avg Loss   43: 0.244064
#
# Val Avg F1   43:  0.7796610169491525
#
# Optimal Val loss (Epoch 12): 0.17771421372890472
#
# Epoch 44
# --------------------------------------------------------------
# Epoch:   44        1 Batch loss: 0.456542 Batch F1: 0.8571428571428572
# Epoch:   44        2 Batch loss: 0.465635 Batch F1: 0.8627450980392156
# Epoch:   44        3 Batch loss: 0.409793 Batch F1: 0.875
# Train Avg Loss   44: 0.443990
#
# Train Avg F1   44: 0.8649626517273576
#
# Val Avg Loss   44: 0.243754
#
# Val Avg F1   44:  0.7796610169491525
#
# Optimal Val loss (Epoch 12): 0.17771421372890472
#
# Epoch 45
# --------------------------------------------------------------
# Epoch:   45        1 Batch loss: 0.403625 Batch F1: 0.9056603773584906
# Epoch:   45        2 Batch loss: 0.527132 Batch F1: 0.7555555555555555
# Epoch:   45        3 Batch loss: 0.393466 Batch F1: 0.9142857142857143
# Train Avg Loss   45: 0.441407
#
# Train Avg F1   45: 0.8585005490665868
#
# Val Avg Loss   45: 0.245559
#
# Val Avg F1   45:  0.7796610169491525
#
# Optimal Val loss (Epoch 12): 0.17771421372890472
#
# Epoch 46
# --------------------------------------------------------------
# Epoch:   46        1 Batch loss: 0.372015 Batch F1: 0.9500000000000001
# Epoch:   46        2 Batch loss: 0.492454 Batch F1: 0.8235294117647057
# Epoch:   46        3 Batch loss: 0.483759 Batch F1: 0.8500000000000001
# Train Avg Loss   46: 0.449409
#
# Train Avg F1   46: 0.8745098039215686
#
# Val Avg Loss   46: 0.247700
#
# Val Avg F1   46:  0.7719298245614036
#
# Optimal Val loss (Epoch 12): 0.17771421372890472
#
# Epoch 47
# --------------------------------------------------------------
# Epoch:   47        1 Batch loss: 0.395157 Batch F1: 0.9166666666666666
# Epoch:   47        2 Batch loss: 0.438240 Batch F1: 0.8636363636363636
# Epoch:   47        3 Batch loss: 0.523374 Batch F1: 0.7894736842105262
# Train Avg Loss   47: 0.452257
#
# Train Avg F1   47: 0.8565922381711855
#
# Val Avg Loss   47: 0.250381
#
# Val Avg F1   47:  0.7586206896551724
#
# Optimal Val loss (Epoch 12): 0.17771421372890472
#
# Epoch 48
# --------------------------------------------------------------
# Epoch:   48        1 Batch loss: 0.441756 Batch F1: 0.8500000000000001
# Epoch:   48        2 Batch loss: 0.458430 Batch F1: 0.8292682926829269
# Epoch:   48        3 Batch loss: 0.445069 Batch F1: 0.8979591836734695
# Train Avg Loss   48: 0.448418
#
# Train Avg F1   48: 0.8590758254521322
#
# Val Avg Loss   48: 0.250317
#
# Val Avg F1   48:  0.7719298245614036
#
# Optimal Val loss (Epoch 12): 0.17771421372890472
#
# Epoch 49
# --------------------------------------------------------------
# Epoch:   49        1 Batch loss: 0.412469 Batch F1: 0.9056603773584904
# Epoch:   49        2 Batch loss: 0.499983 Batch F1: 0.7804878048780488
# Epoch:   49        3 Batch loss: 0.416968 Batch F1: 0.8888888888888888
# Train Avg Loss   49: 0.443140
#
# Train Avg F1   49: 0.8583456903751427
#
# Val Avg Loss   49: 0.245943
#
# Val Avg F1   49:  0.7719298245614036
#
# Optimal Val loss (Epoch 12): 0.17771421372890472
#
# Epoch 50
# --------------------------------------------------------------
# Epoch:   50        1 Batch loss: 0.416411 Batch F1: 0.9019607843137256
# Epoch:   50        2 Batch loss: 0.483032 Batch F1: 0.7804878048780488
# Epoch:   50        3 Batch loss: 0.429290 Batch F1: 0.8947368421052632
# Train Avg Loss   50: 0.442911
#
# Train Avg F1   50: 0.8590618104323459
#
# Val Avg Loss   50: 0.247433
#
# Val Avg F1   50:  0.7796610169491525
#
# Optimal Val loss (Epoch 12): 0.17771421372890472
#
# Epoch 51
# --------------------------------------------------------------
# Epoch:   51        1 Batch loss: 0.512487 Batch F1: 0.8275862068965517
# Epoch:   51        2 Batch loss: 0.428123 Batch F1: 0.8837209302325583
# Epoch:   51        3 Batch loss: 0.379495 Batch F1: 0.9090909090909091
# Train Avg Loss   51: 0.440035
#
# Train Avg F1   51: 0.873466015406673
#
# Val Avg Loss   51: 0.244487
#
# Val Avg F1   51:  0.7796610169491525
#
# Optimal Val loss (Epoch 12): 0.17771421372890472
#
# Epoch 52
# --------------------------------------------------------------
# Epoch:   52        1 Batch loss: 0.436485 Batch F1: 0.8727272727272727
# Epoch:   52        2 Batch loss: 0.486156 Batch F1: 0.7906976744186046
# Epoch:   52        3 Batch loss: 0.399771 Batch F1: 0.9090909090909091
# Train Avg Loss   52: 0.440804
#
# Train Avg F1   52: 0.8575052854122621
#
# Val Avg Loss   52: 0.244785
#
# Val Avg F1   52:  0.7719298245614036
#
# Optimal Val loss (Epoch 12): 0.17771421372890472
#
# Epoch 53
# --------------------------------------------------------------
# Epoch:   53        1 Batch loss: 0.435469 Batch F1: 0.8749999999999999
# Epoch:   53        2 Batch loss: 0.476495 Batch F1: 0.8260869565217391
# Epoch:   53        3 Batch loss: 0.418326 Batch F1: 0.8888888888888888
# Train Avg Loss   53: 0.443430
#
# Train Avg F1   53: 0.8633252818035425
#
# Val Avg Loss   53: 0.250160
#
# Val Avg F1   53:  0.7719298245614036
#
# Optimal Val loss (Epoch 12): 0.17771421372890472
#
# Epoch 54
# --------------------------------------------------------------
# Epoch:   54        1 Batch loss: 0.504462 Batch F1: 0.7368421052631577
# Epoch:   54        2 Batch loss: 0.387449 Batch F1: 0.9454545454545454
# Epoch:   54        3 Batch loss: 0.445644 Batch F1: 0.8648648648648648
# Train Avg Loss   54: 0.445852
#
# Train Avg F1   54: 0.8490538385275227
#
# Val Avg Loss   54: 0.249233
#
# Val Avg F1   54:  0.7586206896551724
#
# Optimal Val loss (Epoch 12): 0.17771421372890472
#
# Epoch 55
# --------------------------------------------------------------
# Epoch:   55        1 Batch loss: 0.432667 Batch F1: 0.8749999999999999
# Epoch:   55        2 Batch loss: 0.435406 Batch F1: 0.8571428571428572
# Epoch:   55        3 Batch loss: 0.469548 Batch F1: 0.8500000000000001
# Train Avg Loss   55: 0.445873
#
# Train Avg F1   55: 0.8607142857142858
#
# Val Avg Loss   55: 0.243668
#
# Val Avg F1   55:  0.7586206896551724
#
# Optimal Val loss (Epoch 12): 0.17771421372890472
#
# Epoch 56
# --------------------------------------------------------------
# Epoch:   56        1 Batch loss: 0.446022 Batch F1: 0.8627450980392156
# Epoch:   56        2 Batch loss: 0.449213 Batch F1: 0.8571428571428572
# Epoch:   56        3 Batch loss: 0.458613 Batch F1: 0.8125000000000001
# Train Avg Loss   56: 0.451283
#
# Train Avg F1   56: 0.8441293183940243
#
# Val Avg Loss   56: 0.246731
#
# Val Avg F1   56:  0.7796610169491525
#
# Optimal Val loss (Epoch 12): 0.17771421372890472
#
# Epoch 57
# --------------------------------------------------------------
# Epoch:   57        1 Batch loss: 0.367677 Batch F1: 0.9433962264150944
# Epoch:   57        2 Batch loss: 0.482437 Batch F1: 0.7894736842105263
# Epoch:   57        3 Batch loss: 0.492891 Batch F1: 0.8292682926829269
# Train Avg Loss   57: 0.447668
#
# Train Avg F1   57: 0.854046067769516
#
# Val Avg Loss   57: 0.241896
#
# Val Avg F1   57:  0.7719298245614036
#
# Optimal Val loss (Epoch 12): 0.17771421372890472
#
# Epoch 58
# --------------------------------------------------------------
# Epoch:   58        1 Batch loss: 0.355907 Batch F1: 0.9500000000000001
# Epoch:   58        2 Batch loss: 0.485388 Batch F1: 0.8085106382978724
# Epoch:   58        3 Batch loss: 0.506669 Batch F1: 0.8372093023255814
# Train Avg Loss   58: 0.449321
#
# Train Avg F1   58: 0.865239980207818
#
# Val Avg Loss   58: 0.245775
#
# Val Avg F1   58:  0.7586206896551724
#
# Optimal Val loss (Epoch 12): 0.17771421372890472
#
# Epoch 59
# --------------------------------------------------------------
# Epoch:   59        1 Batch loss: 0.416685 Batch F1: 0.9019607843137256
# Epoch:   59        2 Batch loss: 0.449049 Batch F1: 0.851063829787234
# Epoch:   59        3 Batch loss: 0.470023 Batch F1: 0.8235294117647058
# Train Avg Loss   59: 0.445252
#
# Train Avg F1   59: 0.858851341955222
#
# Val Avg Loss   59: 0.244575
#
# Val Avg F1   59:  0.7796610169491525
#
# Optimal Val loss (Epoch 12): 0.17771421372890472
#
# Epoch 60
# --------------------------------------------------------------
# Epoch:   60        1 Batch loss: 0.387963 Batch F1: 0.9333333333333332
# Epoch:   60        2 Batch loss: 0.464090 Batch F1: 0.8571428571428572
# Epoch:   60        3 Batch loss: 0.505487 Batch F1: 0.7894736842105262
# Train Avg Loss   60: 0.452513
#
# Train Avg F1   60: 0.8599832915622388
#
# Val Avg Loss   60: 0.235543
#
# Val Avg F1   60:  0.7586206896551724
#
# Optimal Val loss (Epoch 12): 0.17771421372890472
#
# Epoch 61
# --------------------------------------------------------------
# Epoch:   61        1 Batch loss: 0.517900 Batch F1: 0.8076923076923077
# Epoch:   61        2 Batch loss: 0.370589 Batch F1: 0.9333333333333332
# Epoch:   61        3 Batch loss: 0.446187 Batch F1: 0.8571428571428571
# Train Avg Loss   61: 0.444892
#
# Train Avg F1   61: 0.8660561660561661
#
# Val Avg Loss   61: 0.237704
#
# Val Avg F1   61:  0.7796610169491525
#
# Optimal Val loss (Epoch 12): 0.17771421372890472
#
# Epoch 62
# --------------------------------------------------------------
# Epoch:   62        1 Batch loss: 0.403520 Batch F1: 0.9047619047619048
# Epoch:   62        2 Batch loss: 0.443397 Batch F1: 0.8571428571428572
# Epoch:   62        3 Batch loss: 0.495016 Batch F1: 0.7999999999999999
# Train Avg Loss   62: 0.447311
#
# Train Avg F1   62: 0.8539682539682539
#
# Val Avg Loss   62: 0.234906
#
# Val Avg F1   62:  0.7796610169491525
#
# Optimal Val loss (Epoch 12): 0.17771421372890472
#
# Epoch 63
# --------------------------------------------------------------
# Epoch:   63        1 Batch loss: 0.426209 Batch F1: 0.8936170212765957
# Epoch:   63        2 Batch loss: 0.471573 Batch F1: 0.84
# Epoch:   63        3 Batch loss: 0.433000 Batch F1: 0.8571428571428571
# Train Avg Loss   63: 0.443594
#
# Train Avg F1   63: 0.8635866261398176
#
# Val Avg Loss   63: 0.236955
#
# Val Avg F1   63:  0.7796610169491525
#
# Optimal Val loss (Epoch 12): 0.17771421372890472
#
# Epoch 64
# --------------------------------------------------------------
# Epoch:   64        1 Batch loss: 0.442143 Batch F1: 0.8749999999999999
# Epoch:   64        2 Batch loss: 0.460003 Batch F1: 0.8333333333333333
# Epoch:   64        3 Batch loss: 0.421988 Batch F1: 0.8888888888888888
# Train Avg Loss   64: 0.441378
#
# Train Avg F1   64: 0.8657407407407406
#
# Val Avg Loss   64: 0.242693
#
# Val Avg F1   64:  0.7719298245614036
#
# Optimal Val loss (Epoch 12): 0.17771421372890472
#
# Epoch 65
# --------------------------------------------------------------
# Epoch:   65        1 Batch loss: 0.366893 Batch F1: 0.9333333333333332
# Epoch:   65        2 Batch loss: 0.523520 Batch F1: 0.761904761904762
# Epoch:   65        3 Batch loss: 0.443485 Batch F1: 0.8837209302325582
# Train Avg Loss   65: 0.444633
#
# Train Avg F1   65: 0.8596530084902178
#
# Val Avg Loss   65: 0.243333
#
# Val Avg F1   65:  0.7719298245614036
#
# Optimal Val loss (Epoch 12): 0.17771421372890472
#
# Epoch 66
# --------------------------------------------------------------
# Epoch:   66        1 Batch loss: 0.418635 Batch F1: 0.8979591836734694
# Epoch:   66        2 Batch loss: 0.464465 Batch F1: 0.8333333333333333
# Epoch:   66        3 Batch loss: 0.448473 Batch F1: 0.8484848484848485
# Train Avg Loss   66: 0.443858
#
# Train Avg F1   66: 0.859925788497217
#
# Val Avg Loss   66: 0.243142
#
# Val Avg F1   66:  0.7586206896551724
#
# Optimal Val loss (Epoch 12): 0.17771421372890472
#
# Epoch 67
# --------------------------------------------------------------
# Epoch:   67        1 Batch loss: 0.413222 Batch F1: 0.8936170212765957
# Epoch:   67        2 Batch loss: 0.474692 Batch F1: 0.8181818181818182
# Epoch:   67        3 Batch loss: 0.439807 Batch F1: 0.8717948717948718
# Train Avg Loss   67: 0.442573
#
# Train Avg F1   67: 0.8611979037510952
#
# Val Avg Loss   67: 0.242969
#
# Val Avg F1   67:  0.7796610169491525
#
# Optimal Val loss (Epoch 12): 0.17771421372890472
#
# Epoch 68
# --------------------------------------------------------------
# Epoch:   68        1 Batch loss: 0.431771 Batch F1: 0.88
# Epoch:   68        2 Batch loss: 0.427798 Batch F1: 0.8695652173913043
# Epoch:   68        3 Batch loss: 0.490229 Batch F1: 0.8108108108108109
# Train Avg Loss   68: 0.449932
#
# Train Avg F1   68: 0.8534586760673717
#
# Val Avg Loss   68: 0.245660
#
# Val Avg F1   68:  0.7796610169491525
#
# Optimal Val loss (Epoch 12): 0.17771421372890472
#
# Epoch 69
# --------------------------------------------------------------
# Epoch:   69        1 Batch loss: 0.491192 Batch F1: 0.816326530612245
# Epoch:   69        2 Batch loss: 0.417999 Batch F1: 0.8936170212765957
# Epoch:   69        3 Batch loss: 0.420104 Batch F1: 0.888888888888889
# Train Avg Loss   69: 0.443098
#
# Train Avg F1   69: 0.8662774802592432
#
# Val Avg Loss   69: 0.252456
#
# Val Avg F1   69:  0.7719298245614036
#
# Optimal Val loss (Epoch 12): 0.17771421372890472
#
# Epoch 70
# --------------------------------------------------------------
# Epoch:   70        1 Batch loss: 0.447083 Batch F1: 0.8372093023255814
# Epoch:   70        2 Batch loss: 0.404278 Batch F1: 0.888888888888889
# Epoch:   70        3 Batch loss: 0.522633 Batch F1: 0.7999999999999999
# Train Avg Loss   70: 0.457998
#
# Train Avg F1   70: 0.8420327304048234
#
# Val Avg Loss   70: 0.255084
#
# Val Avg F1   70:  0.7719298245614036
#
# Optimal Val loss (Epoch 12): 0.17771421372890472
#
# Epoch 71
# --------------------------------------------------------------
# Epoch:   71        1 Batch loss: 0.449989 Batch F1: 0.8571428571428572
# Epoch:   71        2 Batch loss: 0.432710 Batch F1: 0.888888888888889
# Epoch:   71        3 Batch loss: 0.474029 Batch F1: 0.8333333333333333
# Train Avg Loss   71: 0.452243
#
# Train Avg F1   71: 0.8597883597883597
#
# Val Avg Loss   71: 0.248399
#
# Val Avg F1   71:  0.7719298245614036
#
# Optimal Val loss (Epoch 12): 0.17771421372890472
#
# Epoch 72
# --------------------------------------------------------------
# Epoch:   72        1 Batch loss: 0.479234 Batch F1: 0.84
# Epoch:   72        2 Batch loss: 0.422322 Batch F1: 0.9019607843137256
# Epoch:   72        3 Batch loss: 0.446791 Batch F1: 0.8275862068965518
# Train Avg Loss   72: 0.449449
#
# Train Avg F1   72: 0.8565156637367591
#
# Val Avg Loss   72: 0.232388
#
# Val Avg F1   72:  0.7586206896551724
#
# Optimal Val loss (Epoch 12): 0.17771421372890472
#
# Epoch 73
# --------------------------------------------------------------
# Epoch:   73        1 Batch loss: 0.426499 Batch F1: 0.8571428571428572
# Epoch:   73        2 Batch loss: 0.473945 Batch F1: 0.8333333333333333
# Epoch:   73        3 Batch loss: 0.452354 Batch F1: 0.8571428571428572
# Train Avg Loss   73: 0.450933
#
# Train Avg F1   73: 0.8492063492063492
#
# Val Avg Loss   73: 0.224966
#
# Val Avg F1   73:  0.7796610169491525
#
# Optimal Val loss (Epoch 12): 0.17771421372890472
#
# Epoch 74
# --------------------------------------------------------------
# Epoch:   74        1 Batch loss: 0.464711 Batch F1: 0.8518518518518519
# Epoch:   74        2 Batch loss: 0.424728 Batch F1: 0.8837209302325583
# Epoch:   74        3 Batch loss: 0.445874 Batch F1: 0.8484848484848485
# Train Avg Loss   74: 0.445104
#
# Train Avg F1   74: 0.8613525435230862
#
# Val Avg Loss   74: 0.224576
#
# Val Avg F1   74:  0.8070175438596492
#
# Optimal Val loss (Epoch 12): 0.17771421372890472
#
# Epoch 75
# --------------------------------------------------------------
# Epoch:   75        1 Batch loss: 0.464038 Batch F1: 0.8333333333333333
# Epoch:   75        2 Batch loss: 0.442598 Batch F1: 0.8636363636363636
# Epoch:   75        3 Batch loss: 0.442844 Batch F1: 0.8648648648648648
# Train Avg Loss   75: 0.449827
#
# Train Avg F1   75: 0.8539448539448539
#
# Val Avg Loss   75: 0.235825
#
# Val Avg F1   75:  0.7666666666666666
#
# Optimal Val loss (Epoch 12): 0.17771421372890472
#
# Epoch 76
# --------------------------------------------------------------
# Epoch:   76        1 Batch loss: 0.436336 Batch F1: 0.8372093023255814
# Epoch:   76        2 Batch loss: 0.459698 Batch F1: 0.8627450980392156
# Epoch:   76        3 Batch loss: 0.460944 Batch F1: 0.8421052631578948
# Train Avg Loss   76: 0.452326
#
# Train Avg F1   76: 0.8473532211742306
#
# Val Avg Loss   76: 0.229223
#
# Val Avg F1   76:  0.7931034482758621
#
# Optimal Val loss (Epoch 12): 0.17771421372890472
#
# Epoch 77
# --------------------------------------------------------------
# Epoch:   77        1 Batch loss: 0.494826 Batch F1: 0.7999999999999999
# Epoch:   77        2 Batch loss: 0.406584 Batch F1: 0.9285714285714286
# Epoch:   77        3 Batch loss: 0.444487 Batch F1: 0.8275862068965518
# Train Avg Loss   77: 0.448632
#
# Train Avg F1   77: 0.8520525451559934
#
# Val Avg Loss   77: 0.234684
#
# Val Avg F1   77:  0.7796610169491525
#
# Optimal Val loss (Epoch 12): 0.17771421372890472
#
# Epoch 78
# --------------------------------------------------------------
# Epoch:   78        1 Batch loss: 0.435005 Batch F1: 0.875
# Epoch:   78        2 Batch loss: 0.449487 Batch F1: 0.8679245283018868
# Epoch:   78        3 Batch loss: 0.490971 Batch F1: 0.8
# Train Avg Loss   78: 0.458488
#
# Train Avg F1   78: 0.8476415094339623
#
# Val Avg Loss   78: 0.234072
#
# Val Avg F1   78:  0.7857142857142857
#
# Optimal Val loss (Epoch 12): 0.17771421372890472
#
# Epoch 79
# --------------------------------------------------------------
# Epoch:   79        1 Batch loss: 0.471810 Batch F1: 0.8461538461538461
# Epoch:   79        2 Batch loss: 0.521729 Batch F1: 0.7727272727272727
# Epoch:   79        3 Batch loss: 0.529291 Batch F1: 0.6086956521739131
# Train Avg Loss   79: 0.507610
#
# Train Avg F1   79: 0.7425255903516773
#
# Val Avg Loss   79: 0.406007
#
# Val Avg F1   79:  0.4285714285714286
#
# Optimal Val loss (Epoch 12): 0.17771421372890472
#
# Epoch 80
# --------------------------------------------------------------
# Epoch:   80        1 Batch loss: 0.585763 Batch F1: 0.6153846153846155
# Epoch:   80        2 Batch loss: 0.520893 Batch F1: 0.7027027027027029
# Epoch:   80        3 Batch loss: 0.472941 Batch F1: 0.8
# Train Avg Loss   80: 0.526532
#
# Train Avg F1   80: 0.7060291060291061
#
# Val Avg Loss   80: 0.207379
#
# Val Avg F1   80:  0.7931034482758621
#
# Optimal Val loss (Epoch 12): 0.17771421372890472
#
# Epoch 81
# --------------------------------------------------------------
# Epoch:   81        1 Batch loss: 0.521880 Batch F1: 0.7659574468085107
# Epoch:   81        2 Batch loss: 0.493134 Batch F1: 0.830188679245283
# Epoch:   81        3 Batch loss: 0.436531 Batch F1: 0.8387096774193549
# Train Avg Loss   81: 0.483848
#
# Train Avg F1   81: 0.8116186011577162
#
# Val Avg Loss   81: 0.267844
#
# Val Avg F1   81:  0.7761194029850748
#
# Optimal Val loss (Epoch 12): 0.17771421372890472
#
# Epoch 82
# --------------------------------------------------------------
# Epoch:   82        1 Batch loss: 0.516983 Batch F1: 0.7906976744186046
# Epoch:   82        2 Batch loss: 0.436276 Batch F1: 0.8846153846153846
# Epoch:   82        3 Batch loss: 0.475990 Batch F1: 0.8571428571428572
# Train Avg Loss   82: 0.476416
#
# Train Avg F1   82: 0.8441519720589489
#
# Val Avg Loss   82: 0.219105
#
# Val Avg F1   82:  0.7931034482758621
#
# Optimal Val loss (Epoch 12): 0.17771421372890472
#
# Epoch 83
# --------------------------------------------------------------
# Epoch:   83        1 Batch loss: 0.529278 Batch F1: 0.76
# Epoch:   83        2 Batch loss: 0.423913 Batch F1: 0.8780487804878048
# Epoch:   83        3 Batch loss: 0.444934 Batch F1: 0.8780487804878048
# Train Avg Loss   83: 0.466042
#
# Train Avg F1   83: 0.8386991869918697
#
# Val Avg Loss   83: 0.238247
#
# Val Avg F1   83:  0.7868852459016394
#
# Optimal Val loss (Epoch 12): 0.17771421372890472
#
# Epoch 84
# --------------------------------------------------------------
# Epoch:   84        1 Batch loss: 0.455830 Batch F1: 0.8679245283018868
# Epoch:   84        2 Batch loss: 0.403934 Batch F1: 0.909090909090909
# Epoch:   84        3 Batch loss: 0.511986 Batch F1: 0.7647058823529411
# Train Avg Loss   84: 0.457250
#
# Train Avg F1   84: 0.8472404399152457
#
# Val Avg Loss   84: 0.253818
#
# Val Avg F1   84:  0.7457627118644067
#
# Optimal Val loss (Epoch 12): 0.17771421372890472
#
# Epoch 85
# --------------------------------------------------------------
# Epoch:   85        1 Batch loss: 0.484310 Batch F1: 0.8095238095238095
# Epoch:   85        2 Batch loss: 0.420735 Batch F1: 0.8979591836734694
# Epoch:   85        3 Batch loss: 0.447939 Batch F1: 0.8717948717948718
# Train Avg Loss   85: 0.450995
#
# Train Avg F1   85: 0.8597592883307169
#
# Val Avg Loss   85: 0.255744
#
# Val Avg F1   85:  0.7719298245614036
#
# Optimal Val loss (Epoch 12): 0.17771421372890472
#
# Epoch 86
# --------------------------------------------------------------
# Epoch:   86        1 Batch loss: 0.405782 Batch F1: 0.9166666666666666
# Epoch:   86        2 Batch loss: 0.502796 Batch F1: 0.782608695652174
# Epoch:   86        3 Batch loss: 0.437924 Batch F1: 0.8571428571428572
# Train Avg Loss   86: 0.448834
#
# Train Avg F1   86: 0.8521394064872325
#
# Val Avg Loss   86: 0.254716
#
# Val Avg F1   86:  0.7586206896551724
#
# Optimal Val loss (Epoch 12): 0.17771421372890472
#
# Epoch 87
# --------------------------------------------------------------
# Epoch:   87        1 Batch loss: 0.419286 Batch F1: 0.8979591836734694
# Epoch:   87        2 Batch loss: 0.507387 Batch F1: 0.7727272727272727
# Epoch:   87        3 Batch loss: 0.389205 Batch F1: 0.918918918918919
# Train Avg Loss   87: 0.438626
#
# Train Avg F1   87: 0.8632017917732203
#
# Val Avg Loss   87: 0.246105
#
# Val Avg F1   87:  0.7586206896551724
#
# Optimal Val loss (Epoch 12): 0.17771421372890472
#
# Epoch 88
# --------------------------------------------------------------
# Epoch:   88        1 Batch loss: 0.465794 Batch F1: 0.8620689655172414
# Epoch:   88        2 Batch loss: 0.463184 Batch F1: 0.7999999999999999
# Epoch:   88        3 Batch loss: 0.395138 Batch F1: 0.918918918918919
# Train Avg Loss   88: 0.441372
#
# Train Avg F1   88: 0.8603292948120534
#
# Val Avg Loss   88: 0.237993
#
# Val Avg F1   88:  0.7796610169491525
#
# Optimal Val loss (Epoch 12): 0.17771421372890472
#
# Epoch 89
# --------------------------------------------------------------
# Epoch:   89        1 Batch loss: 0.442332 Batch F1: 0.8888888888888888
# Epoch:   89        2 Batch loss: 0.452888 Batch F1: 0.8510638297872342
# Epoch:   89        3 Batch loss: 0.436555 Batch F1: 0.8275862068965517
# Train Avg Loss   89: 0.443925
#
# Train Avg F1   89: 0.8558463085242249
#
# Val Avg Loss   89: 0.237934
#
# Val Avg F1   89:  0.7586206896551724
#
# Optimal Val loss (Epoch 12): 0.17771421372890472
#
# Epoch 90
# --------------------------------------------------------------
# Epoch:   90        1 Batch loss: 0.509987 Batch F1: 0.7916666666666666
# Epoch:   90        2 Batch loss: 0.402398 Batch F1: 0.9090909090909091
# Epoch:   90        3 Batch loss: 0.417308 Batch F1: 0.8947368421052632
# Train Avg Loss   90: 0.443231
#
# Train Avg F1   90: 0.8651648059542797
#
# Val Avg Loss   90: 0.241103
#
# Val Avg F1   90:  0.7586206896551724
#
# Optimal Val loss (Epoch 12): 0.17771421372890472
#
# Epoch 91
# --------------------------------------------------------------
# Epoch:   91        1 Batch loss: 0.457240 Batch F1: 0.8444444444444444
# Epoch:   91        2 Batch loss: 0.425363 Batch F1: 0.8695652173913043
# Epoch:   91        3 Batch loss: 0.447866 Batch F1: 0.8717948717948718
# Train Avg Loss   91: 0.443490
#
# Train Avg F1   91: 0.8619348445435402
#
# Val Avg Loss   91: 0.242225
#
# Val Avg F1   91:  0.7796610169491525
#
# Optimal Val loss (Epoch 12): 0.17771421372890472
#
# Epoch 92
# --------------------------------------------------------------
# Epoch:   92        1 Batch loss: 0.429043 Batch F1: 0.88
# Epoch:   92        2 Batch loss: 0.474509 Batch F1: 0.8333333333333333
# Epoch:   92        3 Batch loss: 0.423794 Batch F1: 0.8571428571428571
# Train Avg Loss   92: 0.442449
#
# Train Avg F1   92: 0.8568253968253968
#
# Val Avg Loss   92: 0.249270
#
# Val Avg F1   92:  0.7796610169491525
#
# Optimal Val loss (Epoch 12): 0.17771421372890472
#
# Epoch 93
# --------------------------------------------------------------
# Epoch:   93        1 Batch loss: 0.401807 Batch F1: 0.9259259259259259
# Epoch:   93        2 Batch loss: 0.548657 Batch F1: 0.7391304347826088
# Epoch:   93        3 Batch loss: 0.357282 Batch F1: 0.9375
# Train Avg Loss   93: 0.435916
#
# Train Avg F1   93: 0.867518786902845
#
# Val Avg Loss   93: 0.254496
#
# Val Avg F1   93:  0.7586206896551724
#
# Optimal Val loss (Epoch 12): 0.17771421372890472
#
# Epoch 94
# --------------------------------------------------------------
# Epoch:   94        1 Batch loss: 0.490515 Batch F1: 0.7692307692307693
# Epoch:   94        2 Batch loss: 0.388277 Batch F1: 0.9230769230769231
# Epoch:   94        3 Batch loss: 0.453165 Batch F1: 0.8717948717948718
# Train Avg Loss   94: 0.443986
#
# Train Avg F1   94: 0.8547008547008548
#
# Val Avg Loss   94: 0.253906
#
# Val Avg F1   94:  0.7586206896551724
#
# Optimal Val loss (Epoch 12): 0.17771421372890472
#
# Epoch 95
# --------------------------------------------------------------
# Epoch:   95        1 Batch loss: 0.358604 Batch F1: 0.96
# Epoch:   95        2 Batch loss: 0.425600 Batch F1: 0.8421052631578948
# Epoch:   95        3 Batch loss: 0.572177 Batch F1: 0.761904761904762
# Train Avg Loss   95: 0.452127
#
# Train Avg F1   95: 0.8546700083542188
#
# Val Avg Loss   95: 0.258904
#
# Val Avg F1   95:  0.7586206896551724
#
# Optimal Val loss (Epoch 12): 0.17771421372890472
#
# Epoch 96
# --------------------------------------------------------------
# Epoch:   96        1 Batch loss: 0.488793 Batch F1: 0.7804878048780488
# Epoch:   96        2 Batch loss: 0.449545 Batch F1: 0.8800000000000001
# Epoch:   96        3 Batch loss: 0.377418 Batch F1: 0.9230769230769231
# Train Avg Loss   96: 0.438585
#
# Train Avg F1   96: 0.8611882426516573
#
# Val Avg Loss   96: 0.256446
#
# Val Avg F1   96:  0.7586206896551724
#
# Optimal Val loss (Epoch 12): 0.17771421372890472
#
# Epoch 97
# --------------------------------------------------------------
# Epoch:   97        1 Batch loss: 0.445946 Batch F1: 0.8627450980392156
# Epoch:   97        2 Batch loss: 0.469454 Batch F1: 0.8260869565217391
# Epoch:   97        3 Batch loss: 0.412734 Batch F1: 0.8888888888888888
# Train Avg Loss   97: 0.442711
#
# Train Avg F1   97: 0.8592403144832813
#
# Val Avg Loss   97: 0.248174
#
# Val Avg F1   97:  0.7796610169491525
#
# Optimal Val loss (Epoch 12): 0.17771421372890472
#
# Epoch 98
# --------------------------------------------------------------
# Epoch:   98        1 Batch loss: 0.438614 Batch F1: 0.8636363636363636
# Epoch:   98        2 Batch loss: 0.471903 Batch F1: 0.8461538461538461
# Epoch:   98        3 Batch loss: 0.409085 Batch F1: 0.8888888888888888
# Train Avg Loss   98: 0.439867
#
# Train Avg F1   98: 0.8662263662263662
#
# Val Avg Loss   98: 0.247470
#
# Val Avg F1   98:  0.7796610169491525
#
# Optimal Val loss (Epoch 12): 0.17771421372890472
#
# Epoch 99
# --------------------------------------------------------------
# Epoch:   99        1 Batch loss: 0.403006 Batch F1: 0.888888888888889
# Epoch:   99        2 Batch loss: 0.510545 Batch F1: 0.7500000000000001
# Epoch:   99        3 Batch loss: 0.416583 Batch F1: 0.9130434782608695
# Train Avg Loss   99: 0.443378
#
# Train Avg F1   99: 0.8506441223832528
#
# Val Avg Loss   99: 0.254439
#
# Val Avg F1   99:  0.7586206896551724
#
# Optimal Val loss (Epoch 12): 0.17771421372890472
#
# Epoch 100
# --------------------------------------------------------------
# Epoch:  100        1 Batch loss: 0.372457 Batch F1: 0.9230769230769231
# Epoch:  100        2 Batch loss: 0.493217 Batch F1: 0.7999999999999999
# Epoch:  100        3 Batch loss: 0.469621 Batch F1: 0.8695652173913043
# Train Avg Loss  100: 0.445099
#
# Train Avg F1  100: 0.8642140468227425
#
# Val Avg Loss  100: 0.259666
#
# Val Avg F1  100:  0.7586206896551724
#
# Optimal Val loss (Epoch 12): 0.17771421372890472
#
# Done!

# %%
import json

# %%
results = json.load(open(path_to_res))

# %%
print('best f1', np.max(results['val_f1']), np.argmax(results['val_f1']))
print('best f1 val', results['val_f1'][np.argmax(results['val_f1'])])
print('corr f1 train', results['train_f1'][np.argmax(results['val_f1'])])
print('corr f1 test', results['test_f1'][np.argmax(results['val_f1'])])
print('best f1 train', np.max(results['train_f1']), np.argmax(results['train_f1']))
# Out:
# best f1 0.8135593220338982 14
# best f1 val 0.8135593220338982
# corr f1 train 0.8030654981874493
# corr f1 test 0.8235294117647058
# best f1 train 0.8745098039215686 45

# %%
import matplotlib.pyplot as plt

# %%
plt.title('F1 score plot 5% RE threshold')
plt.ylabel('F1')
plt.xlabel('Epochs')
plt.plot(results['train_f1'],'-g', label='Train F1')
plt.plot(results['val_f1'],'-b', label='Val F1')
plt.legend(loc='upper left')
plt.ylim([0.0,1.0])
# Out:
# (0.0, 1.0)

# %%
list(results.keys())
# Out:
# ['train_loss',
#  'val_loss',
#  'test_loss',
#  'train_f1',
#  'val_f1',
#  'test_f1',
#  'train_prec',
#  'val_prec',
#  'test_prec',
#  'train_recall',
#  'val_recall',
#  'test_recall']

# %%
plt.title('Precision score plot 5% RE threshold')
plt.ylabel('Precision')
plt.xlabel('Epochs')
plt.plot(results['train_prec'],'-g', label='Train Precision')
plt.plot(results['val_prec'],'-b', label='Val Precision')
plt.legend(loc='upper left')
plt.ylim([0.0,1.0])
# Out:
# (0.0, 1.0)

# %%
plt.title('Recall score plot 5% RE threshold')
plt.ylabel('Recall')
plt.xlabel('Epochs')
plt.plot(results['train_recall'],'-g', label='Train Recall')
plt.plot(results['val_recall'],'-b', label='Val Recall')
plt.legend(loc='upper left')
plt.ylim([0.0,1.0])
# Out:
# (0.0, 1.0)
